# %%
import spacy
import pandas as pd
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

# %%
nlp = spacy.blank("pl")

#ner = nlp.create_pipe("ner")


ner = nlp.add_pipe("ner",name="document_ner")
#ner = nlp.get_pipe("document_ner")
ner.add_label("civil_law")
ner.add_label("administrative_law")
ner.add_label("pharmaceutical_law")
ner.add_label("labor_law")
ner.add_label("medical_law")
ner.add_label("international_law")
ner.add_label("tax_law")
ner.add_label("constitutional_law")
ner.add_label("criminal_law")
ner.add_label("unknown")

nlp.to_disk("pl_document_ner");

# %%
TRAIN_DATA =[

    ("czy wspólnota mieszkaniowa może podjąć uchwałę dotyczącą zakupu wodomierzy odczytywanych radiowo do lokali pokrywając ich koszty",{"entities": [(47,56, "civil_law"),(100,106, "civil_law"),(39,46, "civil_law")]}),
("w jaki sposób gabinet lekarski klienta może sprowadzić preparaty witaminowe z innego kraju unii europejskiej",{"entities": [(44,54, "pharmaceutical_law"),(55,64, "pharmaceutical_law"),(65,75, "pharmaceutical_law")]}),
("czy klient może rozpocząć prace bez uzyskania pozwolenia kto dokonuje odbioru inwestycji",{"entities": [(46,56, "administrative_law")]}),
("czy klientka może prowadzić sprzedaż wysyłkową kosmetyków przez stronę internetową apteki",{"entities": [(47,57, "pharmaceutical_law"),(71,82, "pharmaceutical_law")]}),
("czy technik elektroradiologii może podać pacjentowi kontrast na zlecenie lekarza",{"entities": [(64,72, "medical_law"),(52,60, "medical_law"),(41,51, "medical_law"),(35,40, "medical_law")]}),
("czy sanepid będzie miał obowiązek odebrania lokalu od klienta jakie warunki powinien spełniać salon masażu",{"entities": [(4,11, "medical_law"),(68,75, "medical_law")]}),
("jakie kroki może podjąć klient w związku z przedstawionym stanem faktycznym",{"entities": [(0,5, "criminal_law")]}),
("co należy zrobić jeśli w sieci pojawią się opinie oczerniające lekarza",{"entities": [(31,38, "administrative_law"),(50,62, "administrative_law"),(25,30, "administrative_law"),(43,49, "administrative_law")]}),
("czy w przypadku wypisania na recepcie pełnopłatnej leku dostępnego bez recepty klient może wydać jako zamiennik lek dostępny na receptę jeśli spełnia wszystkie kryteria zamiennika dotyczące postaci dawki i liczby dawek",{"entities": [(29,37, "pharmaceutical_law"),(160,168, "pharmaceutical_law"),(128,135, "pharmaceutical_law"),(116,124, "pharmaceutical_law")]}),
("jakie przepisy kształtują instytucję mobbingu i jakie uprawnienia przysługują osobie która doświadczyła mobbingu w pracy",{"entities": [(37,45, "labor_law"),(104,112, "labor_law")]}),
("co może zrobić klientka w związku z powziętymi wątpliwościami dotyczącymi nieprawidłowości w protokołach rozpraw oraz innymi nieprawidłowościami dotyczącymi postępowania przed sądem lekarskim czy fakt że okręgowy sąd lekarski w warszawie posiadał dokumentację medyczną pacjentek klientki może stanowić naruszenie przepisów o dokumentacji medycznej",{"entities": [(204,212, "criminal_law"),(196,200, "criminal_law"),(247,259, "criminal_law"),(213,216, "criminal_law"),(228,237, "criminal_law"),(62,73, "criminal_law"),(145,156, "criminal_law"),(260,268, "criminal_law")]}),
("czym różni się telepraca od pracy zdalnej czy jeżeli praca zdalna jest praktykowana w firmie to można wystąpić o świadczenie telepracy",{"entities": [(59,65, "labor_law"),(19,24, "labor_law"),(53,58, "labor_law"),(86,92, "labor_law"),(34,41, "labor_law")]}),
("jak kształtuje się odpowiedzialność lekarza oraz jakie prawa ma pacjent w przypadku błędu medycznego podczas zabiegu",{"entities": [(84,89, "medical_law")]}),
("czy odległość pomiędzy stanowiskami do przyjmowania klientów apteki od strony pacjenta może być mniejsza niż  m",{"entities": [(39,51, "medical_law"),(92,95, "medical_law")]}),
("czy klientka musi wydać opinię na polecenie sądu na jakiej podstawie klientka może odmówić wydania opinii",{"entities": [(91,98, "criminal_law"),(24,30, "criminal_law")]}),
("czy pracodawca dowie się z jakiej przyczyny klient jest na kwarantannie czy w ważnej sprawie mechanik może przyjść do klienta żeby naprawić uszkodzoną instalację czy klient może odebrać list od listonosza który do niego przyjdzie czy gdyby klient wyszedł z domu i zatrzymała go na tym policja to czy w razie wykonania testu byłaby to podstawa do odwołania",{"entities": [(334,342, "medical_law"),(34,43, "medical_law"),(59,71, "medical_law"),(247,254, "medical_law"),(107,114, "medical_law"),(308,317, "medical_law")]}),
("czy odmowa wydania decyzji o pozwoleniu na budowę znajduje uzasadnienie w przepisach prawa",{"entities": [(43,49, "administrative_law"),(29,39, "administrative_law")]}),
("w jaki sposób członek zarządu może dokonać najmu swojego prywatnego samochodu na rzecz spółki z ograniczoną odpowiedzialnością",{"entities": [(96,107, "civil_law")]}),
("czy letni ojciec klientki pracownik sanepidu może zostać oddelegowany do pracy przy badaniach związanych z koronawirusem czy to że ojciec klientki od kilku lat pozostaje pod opieką lekarza wpływa na możliwość jego oddelegowania",{"entities": [(174,180, "labor_law")]}),
("czy w ramach aptek prowadzonych pod jednym numerem nip można dokonywać przesunięć leków z grupy p psychotropowych",{"entities": [(43,50, "pharmaceutical_law"),(13,18, "pharmaceutical_law"),(71,81, "pharmaceutical_law"),(19,31, "pharmaceutical_law"),(51,54, "pharmaceutical_law")]}),
("jak klient powinien ustosunkować się do wezwania otrzymanego od izby lekarskiej",{"entities": [(49,60, "medical_law")]}),
("jak kształtują się podstawy odpowiedzialności klientki i podmiotu leczniczego",{"entities": [(19,27, "medical_law")]}),
("czy przy odczytaniu aktu notarialnego bezwzględnie wymagana jest obecność wszystkich właścicieli lokali we wspólnocie mieszkaniowej",{"entities": [(25,37, "civil_law"),(97,103, "civil_law")]}),
("czy pracodawca ma prawo wypowiedzieć lub rozwiązać umowę o pracę zainteresowanej czy w sytuacji kiedy zainteresowana w okresie wypowiedzenia zajdzie w ciążę zostanie przywrócona do pracy",{"entities": [(166,177, "labor_law"),(151,156, "labor_law")]}),
("czy lekarz który nie jest zatrudniony może zostać skierowany do pracy przy zwalczaniu epidemii przez wojewodę na jakiej podstawie pracodawca może oddelegować osobę zatrudnioną w podmiocie leczniczym do pracy przy zwalczaniu epidemii",{"entities": [(26,37, "medical_law"),(178,187, "medical_law"),(50,60, "medical_law"),(158,163, "medical_law"),(188,198, "medical_law"),(101,109, "medical_law")]}),
("czy gabinet służący do udzielania świadczeń zdrowotnych może być pomieszczeniem przejściowym",{"entities": [(23,33, "medical_law"),(61,64, "medical_law")]}),
("czy szpital może żądać od klientki zwrotu części wynagrodzenia w zaistniałych okolicznościach",{"entities": [(65,77, "medical_law")]}),
("czy klient ma obowiązek wskazać kto prowadził pojazd jeżeli tego nie pamięta",{"entities": [(46,52, "administrative_law")]}),
("w jaki sposób klient może stać się współwłaścicielem nieruchomości z jakimi kosztami będzie się to wiązało",{"entities": [(85,91, "administrative_law")]}),
("czy klientka będąc współwłaścicielem nieruchomości może podpisać z innymi współwłaścicielami innymi członkami rodziny nową umowę najmu i płacić z tego tytułu czynsz",{"entities": [(74,92, "civil_law")]}),
("czy klientka może zawrzeć umowę proponowaną przez pracodawcę u którego odbywa staż podyplomowy",{"entities": [(71,77, "medical_law"),(78,82, "medical_law")]}),
("czy w okresie urlopu wychowawczego klientka może podjąć zatrudnienie w innym miejscu na podstawie umowy o pracę bądź w ramach indywidualnej praktyki lekarskiej jeżeli tak to czy klientka ma obowiązek poinformować o tym pracodawcę",{"entities": [(56,68, "labor_law")]}),
("czym skutkuje wydziedziczenie testamentowe w jaki sposób można podważyć wydziedziczenie",{"entities": [(14,29, "civil_law"),(30,42, "civil_law"),(5,13, "civil_law")]}),
("czy zatajając prawdę w ankiecie przed oddaniem krwi można narazić się na odpowiedzialność karną",{"entities": [(58,65, "medical_law"),(23,31, "medical_law")]}),
("czy sanepid będzie miał obowiązek odebrania lokalu od klienta jakie warunki powinien spełniać salon masażu",{"entities": [(4,11, "medical_law"),(68,75, "medical_law")]}),
("czy towarzystwo ubezpieczeniowe może żądać udostępnienia dokumentacji medycznej od lekarza bez załączenia zgody pacjenta",{"entities": [(43,56, "medical_law"),(95,105, "medical_law")]}),
("czy lekarz który nie jest zatrudniony może zostać skierowany do pracy przy zwalczaniu epidemii przez wojewodę na jakiej podstawie pracodawca może oddelegować osobę zatrudnioną w podmiocie leczniczym do pracy przy zwalczaniu epidemii",{"entities": [(26,37, "medical_law"),(178,187, "medical_law"),(50,60, "medical_law"),(158,163, "medical_law"),(188,198, "medical_law"),(101,109, "medical_law")]}),
("czy postępowanie spadkowe może zostać przeprowadzone przed notariuszem",{"entities": [(17,25, "civil_law")]}),
("jeżeli klient wypowie umowę o pracę to czy straci prawo do zaległego urlopu",{"entities": [(43,49, "labor_law")]}),
("jak kształtuje się odpowiedzialność podmiotu leczniczego i klienta za błędy lekarskie w jaki sposób należy odpowiedzieć na pismo",{"entities": [(107,119, "medical_law")]}),
("czy apteka w czasie godzin dla seniorów może obsługiwać również klientów którzy nie są seniorami oraz czy i dla kogo ustawodawca przewiduje kary za nieprzestrzeganie godzin dla seniorów",{"entities": [(31,39, "pharmaceutical_law")]}),
("czy pracownik może odmówić wykonania badań okresowych w trakcie trwania pandemii zgodnie z art m ust  ustawy o szczególnych rozwiązaniach związanych z zapobieganiem przeciwdziałaniem i zwalczaniem covid innych chorób zakaźnych oraz wywołanych nimi sytuacji kryzysowych",{"entities": [(185,196, "medical_law"),(111,123, "medical_law"),(37,42, "medical_law"),(165,182, "medical_law"),(232,242, "medical_law"),(151,164, "medical_law"),(203,209, "medical_law"),(27,36, "medical_law"),(124,137, "medical_law")]}),
("w jaki sposób klient może się zabezpieczyć na okoliczność że swój obowiązek alimentacyjny wobec byłej żony i córki wykonuje poprzez opłacanie należności za mieszkanie w którym uprawnione do alimentów mieszkają",{"entities": [(96,101, "civil_law"),(190,199, "civil_law"),(176,186, "civil_law")]}),
("jakie przepisy prawa obligują byłego zarządcę do przekazania dokumentacji wspólnoty mieszkaniowej",{"entities": [(49,60, "civil_law"),(21,29, "civil_law"),(37,45, "civil_law")]}),
("czy pracodawca może ustalić godziny świąteczne niedzielne od godziny  w niedzielę do godziny  w poniedziałek czy pracując w równoważnym systemie pracy pracodawca może dowolnie ustalać godziny pracy",{"entities": [(124,135, "labor_law")]}),
("jakie są prawa i obowiązki klientki na przesłuchaniu w charakterze świadka czy ze świadka klientka może stać się podejrzaną lub oskarżoną w sprawie",{"entities": [(0,5, "criminal_law"),(67,74, "criminal_law"),(82,89, "criminal_law"),(55,66, "criminal_law")]}),
("czy lekarzom przysługuje zasiłek opiekuńczy w sytuacji gdy zdecydują się na pozostanie w domu z uczącym się zdalnie dzieckiem w wieku poniżej  lat czy są od tego wyłączeni z powodu możliwości oddania dziecka do świetlicy szkolnej jako członkowie służb medycznych",{"entities": [(246,251, "medical_law"),(143,146, "medical_law"),(4,12, "medical_law")]}),
("czy klient może udzielać świadczeń zdrowotnych pacjentom którzy nie są chorzy na covid czy klient jest obowiązany do odbycia kwarantanny",{"entities": [(117,124, "medical_law")]}),
("z jakim wyprzedzeniem pracodawca powinien informować pracownika o wyjeździe służbowym czy pracodawca w czasie trwania epidemii ma szczególne obowiązki przy organizowaniu wyjazdu służbowego np zapewnienie jednoosobowych pokoi w hotelu",{"entities": [(192,203, "labor_law")]}),
("czy umowa o pracę klientki rozwiąże się z dniem wydania zaświadczenia lekarskiego czy w sytuacji klientki obowiązuje okres wypowiedzenia umowy o pracę czy w tej sytuacji klientka powinna udać się na urlop",{"entities": [(106,116, "medical_law"),(56,69, "medical_law"),(27,35, "medical_law")]}),
("czy prokurator może zwolnić lekarza z tajemnicy zawodowej czy prokurator może zażądać wydania kopii dokumentacji medycznej od lekarza",{"entities": [(28,35, "criminal_law"),(20,27, "criminal_law"),(86,93, "criminal_law"),(4,14, "criminal_law"),(62,72, "criminal_law"),(113,122, "criminal_law")]}),
("czy powód miał prawo ponownie skierować pozew o zapłatę czy klient może otrzymać zwrot kosztów poniesionych w elektronicznym postępowaniu upominawczym czy klient może otrzymać zwrot kosztów związanych z zastępstwem procesowym",{"entities": [(95,107, "civil_law"),(40,45, "civil_law"),(138,150, "civil_law")]}),
("kto może złożyć zawiadomienie o możliwości popełnienia przestępstwa mając na uwadze iż przestępstwo te mogło zostać popełnione przez zarząd spółdzielni",{"entities": [(16,29, "criminal_law"),(43,54, "criminal_law"),(55,67, "criminal_law"),(9,15, "criminal_law")]}),
("jakie są prawa i obowiązki świadka w postępowaniu karnym",{"entities": [(0,5, "criminal_law"),(27,34, "criminal_law"),(37,49, "criminal_law")]}),
("czy zgoda na wysyłanie wszelkiej dokumentacji od zarządcy wspólnoty mieszkaniowej do właścicieli lokali musi być udzielona w formie aktu notarialnego",{"entities": [(49,57, "civil_law"),(97,103, "civil_law")]}),
("czy klientka powinna wykonać polecenie służbowe wykonania samodzielnie transportu medycznego jak kształtuje się odpowiedzialność klientki w trakcie wykonywania transportu medycznego",{"entities": [(48,57, "medical_law"),(39,47, "medical_law")]}),
("czy pracodawca ma obowiązek przedłużenia umowy czy działanie pracodawcy może stanowić dyskryminację klienta",{"entities": [(86,99, "labor_law")]}),
("czy pracodawca może różnicować wysokość świadczeń z zakładowego funduszu świadczeń socjalnych w zależności od wysokości dokonanego odpisu na ten fundusz",{"entities": [(96,106, "labor_law"),(83,93, "labor_law"),(52,63, "labor_law")]}),
("czy pracodawca może nakazać lekarzowi który nie podpisał klauzuli optout pracę ponad wymiar  godzin tygodniowo bez zgody pracownika czy w przypadku osób zatrudnionych w wymiarze  etatu tygodniowy limit godzin jest proporcjonalnie zmniejszony",{"entities": [(196,201, "labor_law")]}),
("czy na rewersie recepty musi znajdować pieczątka osoby sporządzającej lek recepturowy",{"entities": [(7,15, "pharmaceutical_law"),(29,38, "pharmaceutical_law")]}),
("jak kształtuje się odpowiedzialność klientki za błędy lekarskie czy klientka jest zobowiązana do podania numeru swojej polisy oc",{"entities": [(119,125, "medical_law"),(105,111, "medical_law"),(97,104, "medical_law")]}),
("czy klientce należy się odprawa czy klientce należy się ekwiwalent za niewykorzystany urlop",{"entities": [(56,66, "labor_law"),(70,85, "labor_law"),(24,31, "labor_law")]}),
("czy lekarz postępuje zgodnie z prawem jeżeli wypisuje receptę na lek z refundacją na  dawek natomiast zdaniem pacjenta zapotrzebowanie na dany lek powinno być wypisane na  dawek czy każdy pacjent ma obowiązek posiadania internetowego konta pacjenta",{"entities": [(86,91, "medical_law"),(172,177, "medical_law"),(11,20, "medical_law"),(147,154, "medical_law"),(155,158, "medical_law")]}),
("czy w umowie o ustanowienie służebności strony mogą zobowiązać się do tego że na terenie objętym służebnością nie będzie postawiony płot a już istniejący zostanie usunięty",{"entities": [(28,39, "civil_law"),(15,27, "civil_law"),(97,109, "civil_law")]}),
("jakie formalności musi spełnić apteka przed dokonaniem zakupu alkoholu etylowego w celu sporządzania leków recepturowych i dezynfekcji",{"entities": [(55,61, "tax_law"),(31,37, "tax_law")]}),
("czy za wystawienie duplikatów faktur osobie nieupoważnionej klientka ponosi odpowiedzialność",{"entities": [(69,75, "criminal_law")]}),
("w jaki sposób powinien zachować się klient aby doszło do zmiany warunków pracy jednego z pracowników klienta",{"entities": [(64,72, "labor_law")]}),
("czy po uprawomocnieniu się postanowienia o umorzeniu postępowania pozwany może żądać zwrotu kwot ściągniętych w toku tej sprawy od kogo pozwany może żądać zwrotu kwot zajętych w postępowaniu egzekucyjnym czy oprócz żądania kwoty należności z postępowania egzekucyjnego można także żądać zwrotu kosztów egzekucyjnych czy uprawomocnienie się postanowienia o umorzeniu postępowania skutkuje tym że żadna z tych dwóch firm nie będzie mogła ponownie wystąpić z pozwem o to samo roszczenie",{"entities": [(167,175, "civil_law"),(92,96, "civil_law"),(162,166, "civil_law"),(379,387, "civil_law"),(43,52, "civil_law"),(356,365, "civil_law"),(302,315, "civil_law"),(66,73, "civil_law"),(136,143, "civil_law")]}),
("czy klient może zatrudnić obywatela ukrainy z częściowo uznanym szkoleniem specjalizacyjnym do pracy w szpitalnym oddziale ratunkowym",{"entities": [(36,43, "medical_law"),(103,113, "medical_law")]}),
("czy teściowa klientki może być stroną dwóch umów o dożywocie jak klientka może uzyskać mieszkanie od teściowej zanim zakończy się postępowanie dotyczące ubezwłasnowolnienia",{"entities": [(4,12, "civil_law")]}),
("czy szpital może żądać od klienta zwrotu części wynagrodzenia w zaistniałych okolicznościach",{"entities": [(64,76, "medical_law")]}),
("czy klient może iść na dyżur w trakcie kwarantanny",{"entities": [(23,28, "medical_law")]}),
("jak wygląda przesłuchanie świadka przed sądem w postępowaniu karnym jakie są uprawnienia świadka w sprawie karnej czy klientka jako świadek w postępowaniu karnym ma możliwość korzystania z pomocy pełnomocnika czy w toku postępowania klientka może się powoływać na zeznania złożone na policji czy klientka na rozprawie będzie przesłuchiwana razem z mężem który także jest świadkiem w tej sprawie czy klientka może się zapoznać z zeznaniami złożonymi na policji",{"entities": [(68,73, "criminal_law"),(264,272, "criminal_law"),(26,33, "criminal_law"),(89,96, "criminal_law"),(132,139, "criminal_law"),(4,11, "criminal_law"),(12,25, "criminal_law"),(77,88, "criminal_law"),(61,67, "criminal_law"),(155,161, "criminal_law"),(48,60, "criminal_law"),(142,154, "criminal_law")]}),
("czy możliwe jest umorzenie egzekucji co do świadczeń wymagalnych w przyszłości ze źródeł innych niż wynagrodzenie za pracę",{"entities": [(17,26, "civil_law")]}),
("czy zmiana sposobu użytkowania musi ściśle odpowiadać projektowi architekta skoro nie jest wymagana obecność kierownika budowy a nadzór budowlany wymaga tylko zgłoszenia",{"entities": [(65,75, "administrative_law"),(100,108, "administrative_law"),(11,18, "administrative_law"),(120,126, "administrative_law"),(136,145, "administrative_law")]}),
("czy pracownik klienta ma prawo odmówić przyjęcia trzeciej dawki szczepionki przeciwko covid czy klient może wypowiedzieć umowę o pracę z uwagi na odmowę przyjęcia trzeciej dawki szczepionki przeciwko covid",{"entities": [(49,57, "medical_law"),(163,171, "medical_law"),(39,48, "medical_law"),(153,162, "medical_law"),(137,142, "medical_law"),(58,63, "medical_law"),(172,177, "medical_law")]}),
("czy klientka może korzystać z dotychczasowych druków recept",{"entities": [(30,45, "medical_law")]}),
("jak przedstawia się obowiązek przechowywania dokumentacji medycznej w przypadku zakończenia prowadzenia działalności leczniczej",{"entities": [(80,91, "medical_law")]}),
("czy postępowanie szpitala narusza prawa pracownicze a w szczególności przepisy obezpieczeństwie i higienie pracy",{"entities": [(26,33, "labor_law")]}),
("czy obecny stan prawny pozwala na odmowę sprzedaży prezerwatyw spirali środków poronnych antykoncepcyjnych i homeopatii a także środków do procedury in vitro np stymulujących owulacje",{"entities": [(34,40, "pharmaceutical_law")]}),
("czy klientka może zrezygnować z udziału w pracach zespołu",{"entities": [(42,49, "labor_law")]}),
("czy osoba może wykazać że jest osobą bezrobotną pomimo że prowadzi własną działalność gospodarczą",{"entities": [(67,73, "labor_law")]}),
("czy klientka może domagać się zapłaty dodatku covidowego za grudzień  r",{"entities": [(60,68, "medical_law"),(46,56, "medical_law")]}),
("czy działalność dewelopera wypełnia znamiona przestępstwa oszustwa jakie kroki w przedmiotowej sprawie powinna podjąć mąż klientki",{"entities": [(67,72, "criminal_law"),(36,44, "criminal_law"),(27,35, "criminal_law"),(45,57, "criminal_law")]}),
("czy pracodawca może polecić klientowi kwalifikowanie pacjentów do szczepień na covid bez zmiany umowy o pracę",{"entities": [(38,52, "medical_law"),(66,75, "medical_law")]}),
("czy składki na okręgowe izby aptekarskie są na terenie całego kraju w takiej samej wysokości czy każda izba z osobna ustala ich wysokość czy zmiana miejsca zamieszkania przeniesienie się do innej izby wpływa na wysokość składek na izbę kto może być zwolniony z opłacania składek na okręgową izbę aptekarską kto może płacić niższe składki jaką składkę na okręgowa izbę lekarską płacą renciści niewykonujący zawodu oraz wykonujący zawód w niepełnym wymiarze czasu pracy",{"entities": [(47,54, "pharmaceutical_law"),(296,306, "pharmaceutical_law"),(4,11, "pharmaceutical_law"),(330,337, "pharmaceutical_law"),(437,446, "pharmaceutical_law"),(55,61, "pharmaceutical_law"),(169,182, "pharmaceutical_law"),(231,235, "pharmaceutical_law"),(291,295, "pharmaceutical_law"),(363,367, "pharmaceutical_law")]}),
("czy ojczym może kwestionować wartość spadku czy ojczym może żądać partycypacji w kosztach utrzymania nieruchomości czy ojczym może żądać rozbicia świadczenia na raty",{"entities": [(90,100, "civil_law"),(66,78, "civil_law"),(29,36, "civil_law"),(81,89, "civil_law"),(4,10, "civil_law"),(48,54, "civil_law"),(119,125, "civil_law")]}),
("czy przekształcenie lokalu użytkowego niemieszkalnego w lokal mieszkalny jest dopuszczalne i w jaki sposób należy tego dokonać czy zmiana sposobu użytkowania lokalu powinna wiązać się ze zmianami w księdze wieczystej",{"entities": [(138,145, "administrative_law"),(4,19, "administrative_law"),(187,195, "administrative_law")]}),
("czy w przypadku sprzedaży na kwotę do  złotych apteka może wystawić standardową fakturę vat",{"entities": [(68,79, "tax_law"),(80,87, "tax_law"),(29,34, "tax_law"),(47,53, "tax_law"),(16,25, "tax_law")]}),
("czy przekształcenie części lokalu mieszkalnego w użytkowy jest dopuszczalna i w jaki sposób tego dokonać",{"entities": [(4,19, "administrative_law"),(63,75, "administrative_law")]}),
("czy w związku z obecną sytuacją epidemiologiczną klientowi który jest lekarzem bez specjalizacji przysługują dodatkowe możliwości i uprawnienia",{"entities": [(32,48, "medical_law"),(16,22, "medical_law"),(109,118, "medical_law"),(70,78, "medical_law")]}),
("czy pracodawca może zmusić pracowników do wykorzystania zaległych urlopów wypoczynkowych jeżeli nie były przewidziane w planie urlopowym",{"entities": [(74,88, "labor_law"),(66,73, "labor_law"),(56,65, "labor_law")]}),
("czy lekarz w trakcie specjalizacji z chirurgii szczękowotwarzowej może wykonywać takie świadczenia w jaki sposób należałoby bezpiecznie skonstruować taką umowę",{"entities": [(47,65, "medical_law")]}),
("w jaki sposób klientka może żądać usunięcia wpisów",{"entities": [(28,33, "criminal_law")]}),
("czy okres stażu podyplomowego wlicza się do stażu pracy na podstawie którego oblicza się termin wypowiedzenia umowy o pracę jaki okres wypowiedzenia przysługuje klientowi",{"entities": [(77,84, "labor_law")]}),
("czy możliwe jest zawarcie przedwstępnej umowy o pracę",{"entities": [(17,25, "labor_law")]}),
("czy klientka może podjąć skuteczne kroki w celu uchylenia uchwały wspólnoty mieszkaniowej",{"entities": [(58,65, "civil_law")]}),
("czy właściciel strychu chcąc zaadaptować go na cele mieszkalne potrzebuje zgody wspólnoty mieszkaniowej w formie uchwały",{"entities": [(63,73, "civil_law")]}),
("w jaki sposób należy rozumieć i od kiedy obowiązuje   ust  pkt  lit b rozporządzenia ministra zdrowia w sprawie recept",{"entities": [(85,93, "medical_law"),(41,51, "medical_law")]}),
("jakie konsekwencje przewiduje prawo w momencie gdy klient nie wróci do pracy po zakończeniu urlopu bezpłatnego w jaki sposób klient może rozwiązać stosunek pracy",{"entities": [(147,155, "labor_law")]}),
("czym różni się umowa darowizny od umowy sprzedaży oraz jak kształtują się koszty w przypadku zawarcia tych umów",{"entities": [(21,30, "civil_law")]}),
("czy przy wprowadzaniu do dokumentacji medycznej kodów icd i icd wystarczy zaznaczyć wyłącznie główny kod czy należy szczegółowo oznaczyć podgrupę czy w przypadku gdy choroba danego pacjenta przypada na kilka podgrup należałoby wskazać wszystkie odpowiadające kody icdicd",{"entities": [(166,173, "medical_law"),(54,57, "medical_law"),(60,63, "medical_law")]}),
("czy wspólnota mieszkaniowa może czerpać korzyści z posiadania w kamienicy skrzynki energetycznej zktórej zasilane są również inne budynki",{"entities": [(74,82, "civil_law"),(64,73, "civil_law")]}),
("czy klientka może zrealizować receptę ze zniżką na lek z wykazu a wypisaną przez lekarza stażystę",{"entities": [(30,37, "pharmaceutical_law"),(18,29, "pharmaceutical_law"),(41,47, "pharmaceutical_law")]}),
("czy w trakcie obowiązywania zakazu przemieszczania klient może pojechać do innego miasta",{"entities": [(63,71, "medical_law")]}),
("czy można zostać kierownikiem działu farmacji szpitalnej w niepełnym wymiarze godzin na podstawie umowy o pracę lub umowy cywilnoprawnej jakie są zasady obliczania równoważnika  etatu w pełnym wymiarze godzin",{"entities": [(10,16, "pharmaceutical_law"),(37,45, "pharmaceutical_law"),(46,56, "pharmaceutical_law"),(62,68, "pharmaceutical_law"),(186,192, "pharmaceutical_law"),(59,68, "pharmaceutical_law"),(17,29, "pharmaceutical_law")]}),
("czy klient posiadający prawo do wykonywania zawodu może otworzyć aptekę w ramach spółki z osobą która nie posiada prawa do wykonywania zawodu technik farmacji",{"entities": [(142,149, "pharmaceutical_law"),(65,71, "pharmaceutical_law"),(11,22, "pharmaceutical_law")]}),
("czy postępowanie lekarza dyżurnego było zgodne z prawem czy przy poronieniu może asystować pielęgniarka czy poronienie należy odebrać na oddziale położniczym czy małżonka klienta ponosiłaby odpowiedzialność w razie wysunięcia roszczeń przeciwko szpitalowi przez pacjentkę",{"entities": [(17,24, "criminal_law")]}),
("czy dzieci klienta powinny obecnie dokonać czynności zmierzających do zrzeczenia się ewentualnego dziedziczenia po zmarłym spadkodawcy",{"entities": [(85,97, "civil_law"),(115,122, "civil_law"),(98,111, "civil_law")]}),
("czy pracownicy mogą przebywać w poradni czy klient będzie miał prawo do odmowy świadczenia pracy jeżeli pracodawca nie zapewni mu odpowiedniego wyposażenia oraz środków ochronnych w związku z zagrożeniem związanym z koronawirusem",{"entities": [(119,126, "medical_law"),(204,213, "medical_law"),(169,179, "medical_law"),(144,155, "medical_law"),(32,39, "medical_law"),(20,29, "medical_law"),(192,203, "medical_law")]}),
("czy działanie szpitala może być uznane za dyskryminację czy pracodawca musi zawiadomić pracownika o zamiarze zwolnienia",{"entities": [(42,55, "labor_law"),(100,108, "labor_law"),(32,38, "labor_law")]}),
("czy klientka może świadczyć usługi medycyny estetycznej w gabinecie kosmetycznym swojej córki",{"entities": [(44,55, "medical_law"),(18,27, "medical_law")]}),
("czy pisemne zapisy ustaleń wiążą strony czy dodatkowe zapisy wpływają na możliwość wypowiedzenia umowy",{"entities": [(4,11, "administrative_law"),(61,69, "administrative_law")]}),
("czy klient ma możliwości skutecznego odwołania się od decyzji wojewody o skierowaniu do pracy przy zwalczaniu epidemii",{"entities": [(73,84, "medical_law"),(62,70, "medical_law")]}),
("czy wojewoda może oddelegować pielęgniarkę do pracy przy zwalczaniu epidemii",{"entities": [(4,12, "medical_law"),(30,42, "medical_law")]}),
("czy klientce przysługuje urlop szkoleniowy skoro zakończyła studia w  r czy klientka musi wykorzystać urlop do końca roku i w jakim wymiarze czy klientka może uczestniczyć w szkoleniu w sobotę a urlop szkoleniowy wykorzystać w poniedziałek",{"entities": [(25,30, "medical_law"),(102,107, "medical_law"),(195,200, "medical_law"),(174,183, "medical_law"),(132,140, "medical_law"),(70,71, "medical_law"),(31,42, "medical_law"),(201,212, "medical_law"),(159,171, "medical_law")]}),
("jakie korzyści uzyskuje i posiada pracodawca z tytułu zatrudnienia osoby o umiarkowanym stopniu niepełnosprawności czy stroną umowy o pracę jest spółka cywilna nova med nazwiska wspólników czy przychodnia lekarska nova med",{"entities": [(165,168, "labor_law"),(160,164, "labor_law"),(214,218, "labor_law"),(96,114, "labor_law")]}),
("czy lekarz może odmówić pacjentowi badania jeżeli ten nie zgadza się na założenie maseczki ochronnej jeżeli tak to w oparciu o jaką podstawę prawną",{"entities": [(132,140, "medical_law"),(127,131, "medical_law"),(24,34, "medical_law")]}),
("czy spadkobiercy mogą ustalić że własność mieszkania będącego w spadku przypadnie w całości jednemu z nich niezależnie od wysokości udziału jaki zajmuje w wartości spadku w jaki sposób określa się wartość masy spadkowej czy istnieje konieczność wpisywania konkretnych kwot we wniosku o dział spadku",{"entities": [(33,41, "civil_law"),(197,204, "civil_law"),(268,272, "civil_law"),(210,219, "civil_law"),(286,291, "civil_law"),(84,91, "civil_law"),(22,29, "civil_law"),(4,16, "civil_law"),(205,209, "civil_law")]}),
("w jaki sposób klient wraz z resztą spadkobierców może sprzedać nieruchomość",{"entities": [(35,48, "civil_law")]}),
("czy klientka jako lekarz stażysta stomatolog mogła zostać zobowiązana do pomocy przy szczepieniach w ramach stażu",{"entities": [(25,33, "medical_law"),(85,98, "medical_law")]}),
("w jakiej formie pracodawca może polecić klientowi kwalifikowanie pacjentów do szczepień na covid bez zmiany umowy o pracę",{"entities": [(50,64, "medical_law"),(78,87, "medical_law")]}),
("czy można zostać kierownikiem działu farmacji szpitalnej w niepełnym wymiarze godzin na podstawie umowy o pracę lub umowy cywilnoprawnej jakie są zasady obliczania równoważnika  etatu w pełnym wymiarze godzin",{"entities": [(10,16, "pharmaceutical_law"),(37,45, "pharmaceutical_law"),(46,56, "pharmaceutical_law"),(62,68, "pharmaceutical_law"),(186,192, "pharmaceutical_law"),(59,68, "pharmaceutical_law"),(17,29, "pharmaceutical_law")]}),
("w jaki sposób powinno zostać podniesione wynagrodzenie pracowników w związku z podniesieniem wysokości minimalnego wynagrodzenia za pracę",{"entities": [(103,114, "labor_law")]}),
("czy w trakcie postępowania prowadzonego przez prezesa urzędu ochrony konkurencji i konsumentów na podstawie art  ust  ustawy z dnia  lutego  r o ochronie konkurencji i konsumentów przedkładając na pisemne wezwanie prowadzącego kontrolę kopii umów z konsumentami i klientami istnieje możliwość anonimizowania danych klientów w tym danych osobowych oraz anonimizowania wartości transakcji zawartych w umowach",{"entities": [(197,204, "administrative_law"),(315,323, "administrative_law"),(264,273, "administrative_law"),(145,153, "administrative_law"),(83,94, "administrative_law"),(168,179, "administrative_law"),(293,307, "administrative_law"),(352,366, "administrative_law")]}),
("czy apteka ma obowiązek przechowywać odpady medyczne po szczepieniu w lodówce jak długo apteka powinna przechowywać takie odpady",{"entities": [(37,43, "pharmaceutical_law")]}),
("czy pracodawca bez uprzedniej zgody pracownika może wprowadzić zmianę systemu pracy jeżeli został on określony w umowie o pracę",{"entities": [(52,62, "labor_law"),(63,69, "labor_law")]}),
("czy pracodawca musi wysłać pracownika na okresowe badanie lekarskie",{"entities": [(20,26, "labor_law"),(41,49, "labor_law")]}),
("czy klientka ma obowiązek precyzyjnego uzupełnienia aktu zgonu np jego daty i przyczyn zgonu jeżeli zmarła nie była bezpośrednią pacjentką klientki",{"entities": [(57,62, "medical_law"),(87,92, "medical_law"),(129,138, "medical_law"),(39,51, "medical_law")]}),
("jakich samochodów dotyczą dopłaty do samochodów elektrycznych czy dopłaty mogą dotyczyć samochodu demonstracyjnego",{"entities": [(26,33, "administrative_law"),(66,73, "administrative_law")]}),
("czy w tej sytuacji klient może wycofać się z podjęcia pracy jako kierownik apteki bez ponoszenia prawnych konsekwencji",{"entities": [(31,38, "labor_law")]}),
("czy urlop wychowawczy macierzyński wypoczynkowy i niezdolność do pracy potwierdzona zwolnieniem lekarskim stanowią przerwę w wykonywaniu zawodu farmaceuty",{"entities": [(115,122, "pharmaceutical_law"),(125,136, "pharmaceutical_law")]}),
("jak długo należy przechowywać ankiety epidemiologiczne w związku z covid",{"entities": [(30,37, "medical_law"),(38,54, "medical_law"),(17,29, "medical_law")]}),
("czy klientkę będzie obowiązywać tajemnica lekarska podczas składania zeznań przed sądem cywilnym",{"entities": [(59,68, "medical_law"),(69,75, "medical_law")]}),
("czy klient ma podstawy do ubiegania się o wypłatę tzw dodatku covidowego",{"entities": [(14,22, "medical_law"),(26,35, "medical_law")]}),
("czy dysponent zakładowego funduszu świadczeń socjalnych może dofinansować wszystkie imprezy pomimo sprzeciwu jednej z organizacji",{"entities": [(45,55, "labor_law"),(14,25, "labor_law")]}),
("co może zrobić klientka w związku z powziętymi wątpliwościami dotyczącymi nieprawidłowości w protokołach rozpraw oraz innymi nieprawidłowościami dotyczącymi postępowania przed sądem lekarskim czy fakt że okręgowy sąd lekarski w warszawie posiadał dokumentację medyczną pacjentek klientki może stanowić naruszenie przepisów o dokumentacji medycznej",{"entities": [(204,212, "criminal_law"),(196,200, "criminal_law"),(247,259, "criminal_law"),(213,216, "criminal_law"),(228,237, "criminal_law"),(62,73, "criminal_law"),(145,156, "criminal_law"),(260,268, "criminal_law")]}),
("czy lekarz pracujący w szpitalu jednoimiennym węzłowymkoordynacyjnym pracujący na oddziale niecovidowym który ma kontakt z personelem pracującym na oddziałach covidowych i pacjentami mogącymi być zarażonymi jest uprawniony do dodatku covidowego w wysokości  wynagrodzenia miesięcznego",{"entities": [(134,144, "medical_law"),(11,20, "medical_law"),(69,78, "medical_law"),(159,169, "medical_law"),(148,158, "medical_law"),(212,222, "medical_law"),(113,120, "medical_law"),(234,244, "medical_law"),(192,195, "medical_law"),(172,182, "medical_law")]}),
("czy postępowanie spadkowe może zostać przeprowadzone przed notariuszem",{"entities": [(17,25, "civil_law")]}),
("ile przerw na karmienie piersią przysługuje klientce i ile czasu mają trwać w przypadku gdyby klientka pracowała na pół etatu po  godziny dziennie ile przerw na karmienie piersią przysługuje klientce i ile czasu mają trwać w przypadku gdyby klientka pracowała na  etatu po  godzin dziennie czy praca w systemie równoważnego czasu pracy wpływa na ilość i długość przerw na karmienie piersią jeżeli klientce przysługiwałaby tylko jedna przerwa na karmienie piersią to ile minimalnie musiałaby pracować aby mieć do dyspozycji dwie przerwy po  minut",{"entities": [(311,323, "labor_law"),(294,299, "labor_law"),(24,31, "labor_law"),(171,178, "labor_law"),(382,389, "labor_law"),(455,462, "labor_law"),(103,112, "labor_law"),(250,259, "labor_law"),(346,351, "labor_law"),(406,421, "labor_law"),(14,23, "labor_law"),(161,170, "labor_law"),(372,381, "labor_law"),(445,454, "labor_law"),(4,10, "labor_law"),(151,157, "labor_law"),(362,368, "labor_law")]}),
("czy pracownicy mogą odmówić pracy po  godzin w poniedziałki i wtorki",{"entities": [(4,14, "labor_law")]}),
("jakie są prawa i obowiązki klientki na przesłuchaniu w charakterze świadka",{"entities": [(0,5, "criminal_law"),(55,66, "criminal_law")]}),
("czy z powodu niewypłacalności męża klientki jego rodzina np dziadkowie może zostać zobowiązana do płacenia alimentów na rzecz jego dziecka",{"entities": [(98,106, "civil_law"),(49,56, "civil_law"),(107,116, "civil_law")]}),
("czy o opłatach za miejsca w hali garażowej decydują wyłącznie właściciele tych miejsc parkingowych jak i przez kogo powinny być wyliczane te opłaty jakie kroki należy podjąć aby jak najszybciej ograniczyć ogólny dostęp do hali garażowej pozostałych mieszkańców niebędących właścicielami hali garażowej",{"entities": [(86,98, "civil_law"),(273,286, "civil_law"),(28,32, "civil_law"),(222,226, "civil_law"),(287,291, "civil_law"),(212,218, "civil_law"),(6,14, "civil_law"),(237,248, "civil_law"),(33,42, "civil_law"),(227,236, "civil_law")]}),
("w jaki sposób powinien przebiegać proces inwestycyjny aby klient mógł rozpocząć w nim działalność salonu kosmetycznego",{"entities": [(98,104, "administrative_law")]}),
("czy klient zobowiązany będzie do posiadania kasy fiskalnej",{"entities": [(33,43, "tax_law")]}),
("czy osoba wynajmująca lokal użytkowy w ramach działalności gospodarczej po zmianie charakteru najmu na najem prywatny jest obowiązana do dalszego opłacania podatku vat",{"entities": [(4,9, "tax_law"),(59,71, "tax_law"),(39,45, "tax_law"),(46,58, "tax_law"),(156,163, "tax_law")]}),
("czy lekarz może przekazać sądowi kopie dokumentacji medycznej pacjenta czy dokumentacja medyczna może zostać przekazana drogą mailową",{"entities": [(16,25, "medical_law"),(26,32, "medical_law"),(88,96, "medical_law"),(109,119, "medical_law"),(75,87, "medical_law")]}),
("czy w związku z obecną sytuacją epidemiologiczną klientowi który jest lekarzem bez specjalizacji przysługują dodatkowe możliwości i uprawnienia",{"entities": [(32,48, "medical_law"),(16,22, "medical_law"),(109,118, "medical_law"),(70,78, "medical_law")]}),
("w jakiej wysokości wynagrodzenie pracodawca powinien zapewnić pracownikom zatrudnionym w podmiocie leczniczym na czas kwarantanny bądź półkwarantanny",{"entities": [(74,86, "labor_law")]}),
("czy klient może domagać się naprawy usterki od wynajmującego lokal czy klient może dochodzić odszkodowania od wynajmującego lokal",{"entities": [(47,60, "civil_law"),(110,123, "civil_law"),(28,35, "civil_law")]}),
("czy klientka może wydać ośrodkowi zdrowia zapotrzebowanie na szczepionkę przeciwko grypie",{"entities": [(42,57, "pharmaceutical_law")]}),
("czy jeżeli klientka nie odniesie się do otrzymanego pisma może to skutkować negatywnymi konsekwencjami",{"entities": [(66,75, "civil_law"),(76,87, "civil_law")]}),
("czy klient może odmówić pacjentowi leczenia stomatologicznego w przypadku gdy ten w ciągu ostatnich  dni wrócił z zagranicy",{"entities": [(24,34, "medical_law"),(84,89, "medical_law")]}),
("czy w razie skazania za czyn z art  kodeksu karnego klient może utracić prawo wykonywania zawodu lekarza",{"entities": [(78,89, "criminal_law"),(36,43, "criminal_law"),(44,51, "criminal_law"),(12,20, "criminal_law")]}),
("czy szpital w którym klient ma odbywać staż zewnętrzny może wymagać od niego posiadania ubezpieczenia oc",{"entities": [(31,38, "medical_law"),(44,54, "medical_law"),(39,43, "medical_law")]}),
("czy pracownicy wspólnoty mieszkaniowej którzy zajmują kierownicze stanowiska mają nienormowany czas pracy",{"entities": [(4,14, "labor_law"),(66,76, "labor_law"),(54,65, "labor_law")]}),
("czy klientka może zgłosić aptekę pod nazwą apteka farmekspert lub apteka ekspert czy klientka nadal może prowadzić działalność w mediach społecznościowych oraz reklamować dermolek",{"entities": [(26,32, "pharmaceutical_law"),(129,136, "pharmaceutical_law"),(137,154, "pharmaceutical_law")]}),
("czy wzór ankiety powinien mieć w formie nadruku treść pieczątki jako nagłówek czy treść pieczątki jest prawidłowa",{"entities": [(48,53, "medical_law"),(82,87, "medical_law"),(26,30, "medical_law"),(9,16, "medical_law"),(54,63, "medical_law"),(88,97, "medical_law")]}),
("w jaki sposób klient wraz z małżonką mogą zabezpieczyć się na wypadek gdyby rodzina nie chciała się wyprowadzić lub dokonała zniszczeń w nieruchomości",{"entities": [(116,124, "civil_law"),(76,83, "civil_law"),(100,111, "civil_law")]}),
("czy pacjent może zwolnić klientkę z obowiązku zachowania tajemnicy lekarskiej w ramach postępowania przygotowawczego czy klientka powinna zostać poinformowana o zwolnieniu z obowiązku zachowania tajemnicy lekarskiej w postępowaniu przygotowawczym z wyprzedzeniem",{"entities": [(161,171, "criminal_law"),(17,24, "criminal_law"),(218,230, "criminal_law")]}),
("czy były pracodawca ma prawo żądać od klienta zwrotu pewnej kwoty wynikającej z umowy lojalnościowej",{"entities": [(66,77, "labor_law")]}),
("czy klientka może w dalszym ciągu ustosunkować się do wniosku wskazując iż nie zgadza się z zaproponowanym sposobem przeprowadzenia działu spadku",{"entities": [(79,85, "civil_law")]}),
("czy lekarz mający bezpośredni kontakt z innym lekarzem który zaraził się koronawirusem może dalej pracować w szpitalu czy powinien zostać skierowany na kwarantannę domową",{"entities": [(18,29, "medical_law"),(98,106, "medical_law"),(46,54, "medical_law"),(30,37, "medical_law"),(138,148, "medical_law"),(152,163, "medical_law")]}),
("jak kształtuje się odpowiedzialność lekarza pracującego na podstawie umowy o pracę czy polisa odpowiedzialności cywilnej klientki pokrywa szkody przy udzielaniu świadczeń opisanych w stanie prawnym",{"entities": [(36,43, "criminal_law"),(94,111, "criminal_law")]}),
("czy podmiot który wykonuje działalność leczniczą ma prawo kupić igły do iniekcji bez zapotrzebowania",{"entities": [(18,26, "pharmaceutical_law")]}),
("co powinien zrobić klient jeżeli zostanie skierowany do pracy przy zwalczaniu epidemii",{"entities": [(42,52, "medical_law")]}),
("w jaki sposób klientka może doprowadzić do przedłużenia okresu specjalizacji w ten sposób żeby przez rok przebywać na urlopie bezpłatnym",{"entities": [(105,114, "medical_law"),(43,55, "medical_law")]}),
("jak kształtuje się odpowiedzialność karna i cywilna klienta w sytuacji popełnienia przez niego błędu medycznego",{"entities": [(95,100, "medical_law")]}),
("co można zrobić w przedstawionych okolicznościach aby pociągnąć do odpowiedzialności właścicieli psów",{"entities": [(67,84, "criminal_law"),(34,49, "criminal_law")]}),
("czy spadkobiercy mogą zostać pociągnięci do odpowiedzialności w ramach umowy ubezpieczenia czy spadkobiercy mogą wystąpić do ubezpieczyciela z informacją jakie szkody poniósł poszkodowany w jakim terminie spadkobiercy powinni ustosunkować się do pisma ubezpieczyciela",{"entities": [(4,16, "civil_law"),(95,107, "civil_law"),(205,217, "civil_law")]}),
("jaką specjalizację należy posiadać na stanowisku starszego asystenta farmaceutycznego",{"entities": [(0,4, "medical_law"),(38,48, "medical_law")]}),
("czy w przypadku wypisania na recepcie pełnopłatnej leku dostępnego bez recepty klient może wydać jako zamiennik lek dostępny na receptę jeśli spełnia wszystkie kryteria zamiennika dotyczące postaci dawki i liczby dawek",{"entities": [(29,37, "pharmaceutical_law"),(160,168, "pharmaceutical_law"),(128,135, "pharmaceutical_law"),(116,124, "pharmaceutical_law")]}),
("czy pracodawca może zmusić pracowników do wykorzystania zaległych urlopów wypoczynkowych co to jest system rotacyjny czy przepisy prawa regulują minimalną ilość pracy na kontrakcie czy można oddelegować lekarzy rezydentów do pracy na innym oddziale czy pracodawca musi zapewnić środki ochronne lekarzom pracującym przy zwalczaniu epidemii czy w razie braku odpowiednich środków lekarz może odmówić pracy",{"entities": [(303,313, "medical_law"),(170,180, "medical_law"),(20,26, "medical_law"),(145,154, "medical_law"),(27,38, "medical_law"),(100,106, "medical_law"),(294,302, "medical_law")]}),
("czy klientka jest obowiązana do fizycznego nadzoru nad pracą lekarza ubiegającego się oprzyznanie prawa wykonywania zawodu czy osoba nadzorująca musi mieć taką samą specjalizację którą ma lekarz ubiegający się oprzyznanie prawa wykonywania zawodu jak kształtuje się odpowiedzialność klientki w zakresie nadzoru nad pracą lekarza ubiegającego się o przyznanie prawa wykonywania zawodu",{"entities": [(69,81, "medical_law"),(329,341, "medical_law"),(87,97, "medical_law"),(211,221, "medical_law"),(348,358, "medical_law"),(55,60, "medical_law"),(315,320, "medical_law"),(150,154, "medical_law"),(86,97, "medical_law"),(210,221, "medical_law")]}),
("w jaki sposób siostra klientki może zrzec się roszczenia o zachowek w stosunku do klientki",{"entities": [(14,21, "civil_law"),(59,67, "civil_law")]}),
("czy klientka ma obowiązek udzielić informacji zarządowi wspólnoty mieszkaniowej",{"entities": [(46,55, "civil_law")]}),
("czy osoby funkcyjne mogą świadczyć usługi na rzecz izby aptekarskiej w ramach prowadzonej działalności gospodarczej czy w takim przypadku izba będzie zobowiązana do odprowadzania składek na ubezpieczenia społeczne",{"entities": [(143,149, "administrative_law")]}),
("czy dyrektor szpitala może zabronić wykonywania pracy w innym miejscu czy za prace wyłącznie w jednym podmiocie klientowi należy się rekompensata czy dyrektor szpitala może zabronić wykonywania pracy w innym miejscu z datą wsteczną",{"entities": [(77,82, "labor_law")]}),
("czy klientka ma obowiązek korzystania z instalacji wody ciepłej",{"entities": [(40,50, "civil_law"),(51,55, "civil_law")]}),
("w jaki sposób klient może uzyskać numer księgi wieczystej swojego mieszkania",{"entities": [(40,46, "civil_law"),(47,57, "civil_law")]}),
("czy pracodawca może oddelegować lekarza rezydenta do pracy w ramach dyżuru medycznego na izbie przyjęć szpitala czy klientka powinna otrzymać polecenie pracodawcy na piśmie czy klientka bez podpisania klauzuli optout może być zobowiązana do dyżurowania ponad normy przewidziane w przepisach prawa czy w przypadku pełnienia dyżuru medycznego w piątek klientce będzie przysługiwać tzw zejście po dyżurze",{"entities": [(166,172, "medical_law"),(280,290, "medical_law"),(313,322, "medical_law"),(68,74, "medical_law"),(323,329, "medical_law"),(383,390, "medical_law"),(259,264, "medical_law"),(222,225, "medical_law"),(241,252, "medical_law"),(201,209, "medical_law"),(210,216, "medical_law")]}),
("czy pracodawca może zabronić pracownikom lekarzom noszenia maseczek na twarzach",{"entities": [(59,67, "medical_law"),(41,49, "medical_law"),(29,40, "medical_law")]}),
("kiedy lekarz może odmówić delegowania do walki z koronawirusem",{"entities": [(41,46, "labor_law")]}),
("czy apteka może wystawić jedną łączną fakturę na leki refundowane dla współmałżonków",{"entities": [(38,45, "tax_law"),(49,53, "tax_law"),(25,30, "tax_law"),(4,10, "tax_law")]}),
("czy klientka może być skierowana do zwalczania epidemii decyzją wojewody",{"entities": [(56,63, "medical_law"),(18,21, "medical_law")]}),
("czy w przypadku gdy pacjentka nie jest ubezwłasnowolniona syn pacjentki może podejmować za nią decyzje w zakresie prowadzenia leczenia",{"entities": [(39,57, "medical_law")]}),
("czy farmaceuta wystawiający refundowaną receptę pro familiae musi udowodnić zasadność jej wystawienia",{"entities": [(48,51, "pharmaceutical_law"),(40,47, "pharmaceutical_law"),(52,60, "pharmaceutical_law")]}),
("po którym roku klient może pracować w przychodni jako lekarz pediatra czy klient mógłby w trakcie specjalizacji przyjmować pacjentów w przychodni pediatrycznej",{"entities": [(112,122, "medical_law"),(27,35, "medical_law")]}),
("czy lekarz rezydent może otrzymać polecenie konsultowania w ramach szpitalnego oddziału ratunkowego oraz dyżurowania na dwóch oddziałach jednocześnie",{"entities": [(126,136, "medical_law"),(88,99, "medical_law"),(79,87, "medical_law"),(11,19, "medical_law"),(105,116, "medical_law")]}),
("czy w przypadku braku specjalisty na oddziale lekarz rezydent może nie opisać badania rtg wykonanego w związku z wypadkiem drogowym lub udarem pacjenta czy lekarz specjalista który kończy godzinny dyżur może opuścić miejsce pracy w przypadku braku osoby która przejmie oddział czy lekarz rezydent ma obowiązek stawienia się na dyżur przewidziany w grafiku jeżeli na oddziale w tym czasie nie będzie lekarza specjalisty",{"entities": [(22,33, "medical_law"),(197,202, "medical_law"),(327,332, "medical_law"),(310,319, "medical_law"),(163,174, "medical_law"),(53,61, "medical_law"),(288,296, "medical_law")]}),
("czy zmiana maszynisty w pracy może trwać dłużej niż  godzin",{"entities": [(4,10, "labor_law")]}),
("czy klient może przekazać swojemu bratu część działki w drodze darowizny",{"entities": [(34,39, "civil_law"),(56,62, "civil_law")]}),
("czy w związku z obecną sytuacją epidemiologiczną klientowi który jest lekarzem bez specjalizacji przysługują dodatkowe możliwości i uprawnienia",{"entities": [(32,48, "medical_law"),(16,22, "medical_law"),(109,118, "medical_law"),(70,78, "medical_law")]}),
("czy lekarze rezydenci mogą być delegowani do pełnienia dyżurów w ramach izby przyjęć czy na izbie przyjęć w szpitalu może dyżurować tylko jeden lekarz rezydent",{"entities": [(122,131, "medical_law"),(45,54, "medical_law"),(12,21, "medical_law"),(27,30, "medical_law"),(4,11, "medical_law")]}),
("czy oddelegowanie do pracy przy łóżkach covidowych wydane przez dyrektora szpitalaw formie ustnej jest dla klientki wiążące",{"entities": [(91,97, "labor_law")]}),
("czy w zaistniałych okolicznościach umowa ustna jest ważna i wiążąca czy mąż klientki może skutecznie rościć od pracodawcy przyrzeczonej podwyżki za miesiące od których miała ona obowiązywać zgodnie z ustną umową czy niedotrzymanie warunków rzeczonej umowy ustnej po stronie pracodawcy jest podstawą do skrócenia okresu wypowiedzenia bądź daje możliwość rozwiązania umowy bez wypowiedzenia przez męża klientki czy w razie powyższego rozwiązania stosunku pracy klientowi przysługiwałaby odprawa czy ze względu na obecną sytuację pandemiczną klient mógłby zostać zwolniony bez wskazania przyczyny oraz bez wypłacenia odprawy",{"entities": [(60,67, "labor_law"),(560,569, "labor_law"),(231,239, "labor_law"),(41,46, "labor_law"),(302,311, "labor_law"),(469,484, "labor_law"),(290,298, "labor_law"),(485,492, "labor_law"),(256,262, "labor_law")]}),
("czy klient może odmówić pacjentowi leczenia stomatologicznego w przypadku gdy ten w ciągu ostatnich  dni wrócił z zagranicy",{"entities": [(24,34, "medical_law"),(84,89, "medical_law")]}),
("jak należy rozumieć stwierdzenie iż klient nabył spadek po ojcu w całości czy notariusz który sporządził umowę dożywocia może wydać klientowi jej wypis lub kopię czy klient nabywając spadek po ojcu w całości nabył również własność pozostawionych przez ojca ruchomości",{"entities": [(222,230, "civil_law"),(43,48, "civil_law"),(208,213, "civil_law"),(231,245, "civil_law"),(20,32, "civil_law"),(66,73, "civil_law"),(200,207, "civil_law"),(49,55, "civil_law"),(183,189, "civil_law"),(59,63, "civil_law"),(193,197, "civil_law")]}),
("kiedy upłynie termin do nałożenia na pracownika kary porządkowej",{"entities": [(24,33, "labor_law")]}),
("czy wojewoda prowadzi rejestr lekarzy którzy nie mogą zostać skierowani do pracy przy zwalczaniu covid",{"entities": [(4,12, "medical_law"),(22,29, "medical_law")]}),
("czy farmaceuta zatrudniony w aptece szpitalnej może badać procedury dotyczące podawania leków pacjentom na oddziale",{"entities": [(36,46, "pharmaceutical_law")]}),
("czy w przypadku zajścia w ciążę w trakcie okresu pracy wskazanego w umowie klientka po powrocie będzie musiała dokończyć wymagany rok pracy w szpitalu czy przedmiotowa umowa jest dla klientki gwarancją że pracodawca przedłuży umowę o prace w przypadku zajścia przez nią w ciążę",{"entities": [(16,23, "labor_law"),(252,259, "labor_law"),(55,65, "labor_law"),(26,31, "labor_law"),(234,239, "labor_law")]}),
("czy działanie pacjentki jest zgodne z prawem jeżeli działanie pacjentki jest niezgodne z prawem jakie konsekwencje można względem niej wyciągnąć",{"entities": [(77,86, "administrative_law")]}),
("w jaki sposób klient może doprowadzić do eksmisji brata żony czy komornik może dokonać egzekucji z majątku klienta i jego żony",{"entities": [(26,37, "civil_law"),(65,73, "civil_law"),(41,49, "civil_law")]}),
("czy pracodawca może jednostronnie zmniejszyć żonie klienta wymiar czasu pracy z  na  etatu czy w związku ze zmniejszeniem wymiaru zatrudnienia na skutek epidemii obecnie pracownikowi przysługuje jakieś dodatkowe świadczenie czy w przypadku zamknięcia zakładu pracy żona klienta będzie miała możliwość pobierania zasiłku dla bezrobotnych",{"entities": [(122,129, "labor_law"),(34,44, "labor_law"),(170,182, "labor_law")]}),
("czy wspólnota może odpłatnie wynająć  miejsc parkingowych które znajdują się w cieniu czy wspólnota może ogrodzić miejsca parkingowe i przekazywać do nich klucz osobom które będą zainteresowane ich wynajmem",{"entities": [(45,57, "civil_law"),(122,132, "civil_law")]}),
("czy pracodawca ma możliwość udzielenia pracownikowi zatrudnionemu na podstawie umowy o pracę zaległego urlopu wypoczynkowego bez jego zgody jak kształtuje się kwestia urlopu dla członków zarządu zatrudnionych na podstawie umowy o pracę jaki będzie wymiar urlopu dla pracownika zatrudnionego na podstawie umowy o pracę w wymiarze  etatu",{"entities": [(187,194, "labor_law"),(110,124, "labor_law"),(39,51, "labor_law")]}),
("w przypadku jakich produktów pracownik sprzedaży w hurtowni farmaceutycznej ma obowiązek odesłania odmowy realizacji zamówienia wraz z uzasadnieniem",{"entities": [(51,59, "pharmaceutical_law"),(60,75, "pharmaceutical_law")]}),
("w jaki sposób klient może uzyskać numer księgi wieczystej swojego mieszkania",{"entities": [(40,46, "civil_law"),(47,57, "civil_law")]}),
("czy pracownik który nie mógł wykonać badań obowiązkowych z powodu zagrożenia koronawirusem powinien zostać zwolniony z wykonywania pracy z prawem do wynagrodzenia",{"entities": [(107,116, "labor_law")]}),
("czy w przedmiotowej sprawie ubezpieczyciel kierowcy będzie mógł domagać się regresu od syna klientki jakie kroki w przedmiotowej sprawie powinna podjąć klientka",{"entities": [(43,51, "administrative_law"),(52,58, "administrative_law")]}),
("czy klientka może sprzedać szczepionki na zapotrzebowanie przychodni w większej ilości",{"entities": [(42,57, "pharmaceutical_law")]}),
("czy przepisy powszechnie obowiązującego prawa wyznaczają kiedy skarbnik okręgowej izby aptekarskiej musi przedstawić sprawozdanie z wykonania budżetu oraz przedstawić projekt budżetu",{"entities": [(87,99, "pharmaceutical_law"),(142,149, "pharmaceutical_law"),(117,129, "pharmaceutical_law")]}),
("czy klient może odmówić pacjentowi leczenia stomatologicznego w przypadku gdy ten w ciągu ostatnich  dni wrócił z zagranicy",{"entities": [(24,34, "medical_law"),(84,89, "medical_law")]}),
("czy klient może odmówić udziału w pracach zespołu",{"entities": [(34,41, "labor_law")]}),
("czy pracodawca mógł zmienić wymiaru czasu pracy klientki na  etatu bez złożenia wypowiedzenia zmieniającego albo podpisania porozumienia zmieniającego w jaki sposób klientka może odwołać się od treści świadectwa pracy",{"entities": [(28,35, "labor_law"),(94,107, "labor_law"),(137,150, "labor_law")]}),
("na jakie wynagrodzenie wskazuje umowa o pracę na czas nieokreślony zawarta w dniu  grudnia  r godzinowe miesięczne czy roczne",{"entities": [(83,90, "labor_law"),(54,66, "labor_law")]}),
("czy klientka może żądać usunięcia zdjęć",{"entities": [(24,33, "administrative_law")]}),
("w przypadku jakich produktów pracownik sprzedaży w hurtowni farmaceutycznej ma obowiązek odesłania odmowy realizacji zamówienia wraz z uzasadnieniem",{"entities": [(51,59, "pharmaceutical_law"),(60,75, "pharmaceutical_law")]}),
("w jaki sposób klientka może dowiedzieć się jakie zadłużenie wchodzi w skład spadku",{"entities": [(70,75, "civil_law"),(60,67, "civil_law")]}),
("czy starszy asystent farmaceutyczny pracujący w aptece zakładowej zobowiązany jest ukończyć specjalizacją szpitalną",{"entities": [(21,35, "pharmaceutical_law")]}),
("czy klientka może zrealizować receptę ze zniżką jeżeli zawiera ona wszystkie wymagane prawem elementy ale oddział nfz  jest w całości w polu uprawnień dodatkowych",{"entities": [(141,150, "pharmaceutical_law"),(30,37, "pharmaceutical_law"),(18,29, "pharmaceutical_law"),(41,47, "pharmaceutical_law")]}),
("czy osoba która nie uczestniczy w rozmowie może ją nagrywać czy klient może otrzymać refundację kosztów pełnomocnika w razie dochodzenia roszczeń z tytułu naruszenia dóbr osobistych lub wniesienia zawiadomienia o popełnieniu przestępstwa",{"entities": [(166,170, "administrative_law"),(171,181, "administrative_law")]}),
("jaka w świetle obecnych przepisów prawa powinna być szerokość i wysokość drzwi do lokalu mieszkalnego prowadzących z klatki schodowej czy spółdzielnia może odmówić zgody na powiększenie otworu drzwiowego argumentując odmowę tym że budynek był budowany zgodnie z normami obowiązującymi ówcześnie",{"entities": [(15,23, "civil_law"),(173,185, "civil_law")]}),
("czy klientce należy się odprawa czy klientce należy się ekwiwalent za niewykorzystany urlop",{"entities": [(56,66, "labor_law"),(70,85, "labor_law"),(24,31, "labor_law")]}),
("czy klient posiadający prawo do wykonywania zawodu może otworzyć aptekę w ramach spółki z osobą która nie posiada prawa do wykonywania zawodu technik farmacji",{"entities": [(142,149, "pharmaceutical_law"),(65,71, "pharmaceutical_law"),(11,22, "pharmaceutical_law")]}),
("czy w przypadku wypisania na recepcie pełnopłatnej leku dostępnego bez recepty klient może wydać jako zamiennik lek dostępny na receptę jeśli spełnia wszystkie kryteria zamiennika dotyczące postaci dawki i liczby dawek",{"entities": [(29,37, "pharmaceutical_law"),(160,168, "pharmaceutical_law"),(128,135, "pharmaceutical_law"),(116,124, "pharmaceutical_law")]}),
("jakie koszty musi ponieść wspólnota mieszkaniowa w związku ze złożeniem wniosku o stwierdzenie nabycia spadku w którego skład wchodzi nieruchomość pozostająca we wspólnocie",{"entities": [(120,125, "civil_law"),(126,133, "civil_law"),(82,94, "civil_law")]}),
("jakie wynagrodzenie przysługuję lekarzowi rezydentowi skierowanemu przez wojewodę do pracy przy zwalczaniu covid jakie inne uprawnienia przysługują lekarzowi rezydentowi skierowanemu do pracy przy zwalczaniu covid",{"entities": [(54,66, "medical_law"),(170,182, "medical_law"),(42,53, "medical_law"),(158,169, "medical_law"),(73,81, "medical_law")]}),
("czy lekarzowi skierowanemu do pracy przy zwalczaniu epidemii decyzją wojewody przysługuje dodatek covidowy",{"entities": [(14,26, "medical_law"),(61,68, "medical_law"),(69,77, "medical_law")]}),
("czy w związku z treścią aktu notarialnego koniecznym jest wyrażenie zgody przez wspólnotę mieszkaniową w formie uchwały czy zarządca może wskazać iż na podstawie przedmiotowych zapisów aktów notarialnych potwierdza wyrażenie takiej zgody przez wszystkich współwłaścicieli",{"entities": [(80,89, "civil_law"),(29,41, "civil_law"),(42,52, "civil_law"),(124,132, "civil_law"),(58,67, "civil_law"),(215,224, "civil_law"),(191,203, "civil_law"),(112,119, "civil_law"),(162,176, "civil_law"),(90,102, "civil_law")]}),
("co może zrobić klientka w związku z powziętymi wątpliwościami dotyczącymi nieprawidłowości w protokołach rozpraw oraz innymi nieprawidłowościami dotyczącymi postępowania przed sądem lekarskim czy fakt że okręgowy sąd lekarski w warszawie posiadał dokumentację medyczną pacjentek klientki może stanowić naruszenie przepisów o dokumentacji medycznej",{"entities": [(204,212, "criminal_law"),(196,200, "criminal_law"),(247,259, "criminal_law"),(213,216, "criminal_law"),(228,237, "criminal_law"),(62,73, "criminal_law"),(145,156, "criminal_law"),(260,268, "criminal_law")]}),
("czy farmaceuta może pracować na oddziale w szpitalu",{"entities": [(20,28, "medical_law")]}),
("czy klientka będzie zobowiązana ponieść koszty prac ślusarza i przechowywania rzeczy dłużnika",{"entities": [(47,51, "civil_law"),(78,84, "civil_law")]}),
("czy apteka w czasie godzin dla seniorów może obsługiwać również klientów którzy nie są seniorami oraz czy i dla kogo ustawodawca przewiduje kary za nieprzestrzeganie godzin dla seniorów",{"entities": [(31,39, "pharmaceutical_law")]}),
("w jaki sposób klient powinien złożyć zeznania",{"entities": [(30,36, "criminal_law")]}),
("czy córka klienta nadal może wystawiać paragony w formie papierowej czy musi to robić online czy klient będący lekarzem na emeryturze może wystawiać paragony w formie papierowej",{"entities": [(39,47, "tax_law"),(149,157, "tax_law"),(80,85, "tax_law"),(4,9, "tax_law"),(123,133, "tax_law"),(57,67, "tax_law")]}),
("czy klientka może nadal prowadzić terapię małoletniego",{"entities": [(34,41, "medical_law")]}),
("czy osoba która nie jest farmaceutą może być wspólnikiem spółki jawnej prowadzącej aptekę czy zmiana w strukturze właścicielskiej spółki pociąga za sobą konieczność uzyskania nowej koncesji",{"entities": [(83,89, "pharmaceutical_law"),(114,129, "pharmaceutical_law"),(137,144, "pharmaceutical_law"),(103,113, "pharmaceutical_law"),(71,82, "pharmaceutical_law")]}),
("czy rezydent może dyżurować samodzielnie jak kształtuje się odpowiedzialność lekarza rezydenta za błąd medyczny w trakcie pełnienia dyżuru",{"entities": [(18,27, "medical_law"),(122,131, "medical_law"),(4,12, "medical_law"),(98,102, "medical_law")]}),
("czy klient może zarezerwować nocleg w hotelu pracownikom w delegacji",{"entities": [(45,56, "medical_law")]}),
("czy wywieszenie banneru reklamowego na elewacji budynku objętego ochroną konserwatorską wiąże się z koniecznością uiszczania opłat",{"entities": [(4,15, "administrative_law"),(39,47, "administrative_law")]}),
("jakie prawa przysługują klientce w związku z wezwaniem czy klientka może nie stawić się na przesłuchanie w związku z tym że jest w zaawansowanej ciąży",{"entities": [(0,5, "criminal_law"),(45,54, "criminal_law"),(91,104, "criminal_law")]}),
("w jaki sposób klientka może nabyć aptekę od rodziców",{"entities": [(34,40, "pharmaceutical_law")]}),
("czy podczas odbywania kwarantanny możliwa jest praca zdalna czy pracodawca może odmówić pracownikowi możliwości pracy zdalnej w trakcie kwarantanny",{"entities": [(53,59, "labor_law"),(47,52, "labor_law"),(88,100, "labor_law"),(118,125, "labor_law")]}),
("czy pracodawca ma obowiązek poinformowania związków zawodowych o nałożeniu kary na pracownika rozpatrując sprzeciw czy nałożona na pracownika kara była możliwa do nałożenia w związku z minutowym spóźnieniem o którym pracownik poinformował pracodawcę w dniu spóźnienia",{"entities": [(28,42, "labor_law"),(163,172, "labor_law"),(65,74, "labor_law")]}),
("jakie są prawa i obowiązki klientki w związku z wezwaniem do stawiennictwa na przesłuchanie w charakterze podejrzanego",{"entities": [(0,5, "criminal_law"),(61,74, "criminal_law"),(94,105, "criminal_law"),(48,57, "criminal_law"),(78,91, "criminal_law")]}),
("czy pracodawca ma prawo nie udzielić zgody na bezpłatny urlop pracownika",{"entities": [(46,55, "labor_law")]}),
("czy wzór ankiety powinien mieć w formie nadruku treść pieczątki jako nagłówek czy treść pieczątki jest prawidłowa",{"entities": [(48,53, "medical_law"),(82,87, "medical_law"),(26,30, "medical_law"),(9,16, "medical_law"),(54,63, "medical_law"),(88,97, "medical_law")]}),
("czy klientka może nadal zgłosić swoich pracowników do szczepień przeciwko covid",{"entities": [(39,50, "medical_law"),(54,63, "medical_law")]}),
("czy klient zobowiązany jest do udostępnienia dokumentacji medycznej mężowi zmarłej pacjentki",{"entities": [(31,44, "medical_law")]}),
("czy jeżeli nabywcą leku jest stowarzyszenie apteka jest zobowiązana zamieścić na paragonie numer nip",{"entities": [(11,18, "tax_law"),(44,50, "tax_law"),(56,67, "tax_law")]}),
("jakie są prawa i obowiązki klientki na przesłuchaniu w charakterze świadka jak kształtuje się kwestia zwolnienia z tajemnicy lekarskiej",{"entities": [(0,5, "criminal_law"),(67,74, "criminal_law"),(55,66, "criminal_law")]}),
("czy pracodawca może zobowiązać pracownika do szczepienia przeciw covid czy pracodawca może z tego powodu zwolnić pracownika dyscyplinarnie czy jeżeli pracownik odmówi szczepienia to powinien pokryć koszty badań z tym związane",{"entities": [(160,166, "labor_law")]}),
("czy klientka może rejestrować należności pobierane od pacjentów na kasie podmiotu leczniczego z którym będzie współpracować czy powinna korzystać z własnej kasy fiskalnej",{"entities": [(30,40, "tax_law"),(82,93, "tax_law"),(18,29, "tax_law"),(136,145, "tax_law"),(67,72, "tax_law"),(41,50, "tax_law")]}),
("czy szpital w którym klient ma odbywać staż zewnętrzny może wymagać od niego posiadania ubezpieczenia oc",{"entities": [(31,38, "medical_law"),(44,54, "medical_law"),(39,43, "medical_law")]}),
("jakie warunki musi spełnić przedsiębiorca by móc kupować i sprzedawać aktywne substancje czynne",{"entities": [(49,56, "pharmaceutical_law"),(78,88, "pharmaceutical_law")]}),
("jakie są prawa i obowiązki świadka w postępowaniu karnym kto może zwolnić klientkę z tajemnicy lekarskiej",{"entities": [(0,5, "criminal_law"),(66,73, "criminal_law"),(27,34, "criminal_law"),(50,56, "criminal_law"),(37,49, "criminal_law")]}),
("czy w przypadku złożenia w sądzie pracy sprawa z zakresu ubezpieczeń społecznych wniosku o doręczenie orzeczenia wraz z uzasadnieniem należy uiścić opłatę sądową",{"entities": [(57,68, "civil_law"),(40,46, "civil_law"),(27,33, "civil_law"),(91,101, "civil_law")]}),
("czym jest staż zewnętrzny o którym mowa w zarządzeniu czy klientkę dotyczą przepisy o skierowaniu do pracy przy zwalczaniu epidemii",{"entities": [(67,74, "medical_law"),(86,97, "medical_law"),(15,25, "medical_law"),(10,14, "medical_law")]}),
("czy organ administracyjny powinien w piśmie wysłanym do klienta wskazać również na planowaną budowę wewnętrznej drogi dojazdowej czy klient może użyć w sprzeciwie argumentu że warunki zabudowy mogą uniemożliwić w przyszłości budowę kolejnego zjazdu do działki klienta czy organ administracyjny postąpił właściwie dając klientowi jedynie  dni na złożenie odpowiedzi jak należy odpowiedzieć na pismo czy ma to być forma zastrzeżeń czy sprzeciwu czy argumentem blokującym planowaną inwestycję może być fakt że budynki mają powstać nie w linii istniejącej zabudowy",{"entities": [(145,149, "administrative_law"),(44,52, "administrative_law"),(4,9, "administrative_law"),(272,277, "administrative_law"),(83,92, "administrative_law"),(469,478, "administrative_law"),(93,99, "administrative_law"),(225,231, "administrative_law"),(198,210, "administrative_law"),(184,192, "administrative_law"),(118,128, "administrative_law"),(10,25, "administrative_law"),(278,293, "administrative_law")]}),
("czy szpital w którym klient ma odbywać staż zewnętrzny może wymagać od niego posiadania ubezpieczenia oc",{"entities": [(31,38, "medical_law"),(44,54, "medical_law"),(39,43, "medical_law")]}),
("jaki jest maksymalny czas oddelegowania na podstawie art  ust  ustawy o zawodach lekarza i lekarza dentysty czy okres oddelegowania przedłuża specjalizację czy klientka powinna otrzymywać dodatkowe wynagrodzenie za szczepienie",{"entities": [(72,80, "medical_law"),(10,20, "medical_law"),(188,197, "medical_law"),(21,25, "medical_law"),(99,107, "medical_law")]}),
("czy były pracodawca ma prawo żądać od klienta zwrotu pewnej kwoty wynikającej z umowy lojalnościowej",{"entities": [(66,77, "labor_law")]}),
("czy wnioski dotyczące spółki z oo zawarte w opinii prawnej o sygnaturze  sąw dalszym ciągu aktualne",{"entities": [(4,11, "civil_law")]}),
("jakie są prawa i obowiązki klienta na przesłuchaniu w charakterze świadka",{"entities": [(0,5, "criminal_law"),(54,65, "criminal_law")]}),
("czy dyrekcja szpitala może zobowiązać lekarza do zaprzestania wykonywania pracy w innych podmiotach leczniczych czy pracodawca może wprowadzić z dnia na dzień równoważny system pracy czy równoważny system pracy może dotyczyć tylko niektórych pracowników",{"entities": [(216,224, "labor_law"),(132,142, "labor_law"),(49,61, "labor_law"),(159,169, "labor_law"),(187,197, "labor_law")]}),
("czy w przedmiotowej sprawie doszło do popełnienia przestępstwa czy sprawę należy zgłosić na policję i jeżeli tak to kto powinien to zrobić  lekarz czy farmaceuta czy klientka może ponosić odpowiedzialność dyscyplinarną",{"entities": [(38,49, "criminal_law"),(140,146, "criminal_law"),(50,62, "criminal_law")]}),
("czy klientka może wystosować do zarządu spółki pismo z prośbą o wcześniejsze ustalanie terminu nadzwyczajnego lub zwyczajnego zgromadzenia wspólników jeszcze przed wysłaniem listu powiadamiającego przez zarząd",{"entities": [(126,138, "civil_law"),(55,61, "civil_law")]}),
("czy w przypadku gdy w jednym z pomieszczeń domu urządzony jest salon kosmetyczny wymagane jest utworzenie osobnego wejścia do danego salonu",{"entities": [(63,68, "administrative_law")]}),
("czy wnioski z opinii o sygn  są aktualne w świetle przepisów rozporządzenia ministra zdrowia w sprawie chorób zakaźnych powodujących powstanie obowiązku hospitalizacji izolacji lub izolacji w warunkach domowych oraz obowiązku kwarantanny lub nadzoru epidemiologicznego",{"entities": [(76,84, "medical_law"),(120,132, "medical_law"),(202,210, "medical_law")]}),
("jak przedstawiają się zasady odpowiedzialności cywilnej karnej i dyscyplinarnej apteki oraz technika farmaceutycznego w wypadku błędnego wydania leku",{"entities": [(92,100, "pharmaceutical_law"),(101,117, "pharmaceutical_law")]}),
("czy klientka może ubiegać się o przyznanie świadczenia postojowego dla siebie",{"entities": [(32,42, "medical_law")]}),
("czy klientka może się odwołać od zapisu w notatce policyjnej który jest nierzetelny i niezgodny z zaistniałym zdarzeniem czy dokumenty historii choroby syna klientki wpływają na kwalifikację prawną zdarzenia w kwestii czy doszło do wypadku drogowego czy kolizji czy policja powinna była poinformować męża i syna klientki o zakończeniu prowadzenia postępowania",{"entities": [(191,197, "criminal_law"),(144,151, "criminal_law"),(287,299, "criminal_law")]}),
("jak w zaistniałych okolicznościach ma zachować się lekarz rezydent",{"entities": [(6,18, "medical_law")]}),
("czy powiększenie balkonów w dużej wspólnocie mieszkaniowej może zostać sfinansowane ze środków zgormadzonych na funduszu remontowym",{"entities": [(17,25, "civil_law"),(4,16, "civil_law")]}),
("czy tzw zejście lekarza po dyżurze wlicza się do czasu pracy lekarza i należy się za ten czas wynagrodzenie czy klient będzie musiał odpracować czas przeznaczony na zejście",{"entities": [(133,143, "medical_law"),(89,93, "medical_law"),(144,148, "medical_law"),(8,15, "medical_law"),(27,34, "medical_law")]}),
("ile ryczałtu można wziąć na leki recepturowe",{"entities": [(19,24, "pharmaceutical_law")]}),
("czy wskazane przez klientkę rozwiązanie będzie zgodne w świetle obecnie obowiązujących przepisów",{"entities": [(28,39, "medical_law"),(4,12, "medical_law")]}),
("czy dzieci powinny być przyjmowane na szpitalnym oddziale ratunkowym przez lekarza pediatrę",{"entities": [(38,48, "medical_law"),(19,22, "medical_law"),(11,18, "medical_law"),(58,68, "medical_law")]}),
("czy farmaceuta może odmówić realizacji recepty papierowej bez kodu kreskowego wystawionej ze  odpłatnością",{"entities": [(62,66, "pharmaceutical_law"),(78,89, "pharmaceutical_law")]}),
("czy pieczęć nagłówkowa klienta może zawierać oznaczenie indywidualna specjalistyczna praktyka lekarska w jakiej formie musi być prowadzona dokumentacja medyczna czy musi być ona specjalnie zabezpieczona",{"entities": [(85,93, "medical_law"),(152,160, "medical_law"),(139,151, "medical_law"),(124,127, "medical_law"),(170,173, "medical_law")]}),
("czy lekarz jest obowiązany do stwierdzenia zgonu pacjenta z którym nie miał wcześniej kontaktu",{"entities": [(43,48, "medical_law")]}),
("czy związku z epidemią koronawirusa dniowy termin na uzupełnienie zgłoszenia ulega zawieszeniu",{"entities": [(23,35, "medical_law"),(14,22, "medical_law")]}),
("czy pismo z dnia  r jest oddelegowaniem o którym mowa w art    kodeksu pracy czy oświadczenie zobowiązanie do realizacji dyżurów zachowawczych w sor wynikające z zarządzenia nr  jest prawnie traktowane jako dobrowolna zgoda czy odpowiedź na natychmiastowe przekierowanie  odpowiedź na polecenie służbowe czy natychmiastowe przekierowanie o którym mowa w pkt  zarządzenia nr  powinno zostać wykonane w formie oddelegowania o którym mowa w art    kodeksu pracy",{"entities": [(390,398, "medical_law"),(25,39, "medical_law"),(94,106, "medical_law"),(18,19, "medical_law"),(147,148, "medical_law"),(175,176, "medical_law"),(372,373, "medical_law"),(218,223, "medical_law"),(256,270, "medical_law"),(323,337, "medical_law"),(375,382, "medical_law"),(241,255, "medical_law"),(308,322, "medical_law"),(162,173, "medical_law"),(359,370, "medical_law"),(295,303, "medical_law")]}),
("czym jest instytucja interwenienta ubocznego",{"entities": [(10,20, "civil_law"),(21,34, "civil_law")]}),
("które dokumenty klientka powinna pozostawić w aptece w celu umożliwienia jej dalszej działalności",{"entities": [(33,43, "pharmaceutical_law"),(77,84, "pharmaceutical_law")]}),
("na jakiej podstawie wspólnota mieszkaniowa może wybrać nowy zarząd czy deweloper w obecnej sprawie pełni funkcję administratora",{"entities": [(71,80, "civil_law"),(55,59, "civil_law"),(60,66, "civil_law")]}),
("czy klientka może zostać zobowiązana przez pracodawcę do zawarcia umowy kontraktoweji do odbywania w ramach tej umowy nocnych dyżurów w nocnej opiece zdrowotnej",{"entities": [(136,142, "medical_law"),(118,125, "medical_law")]}),
("czy w sytuacji skierowania przez wojewodę do pracy przy zwalczaniu epidemii jedno z rodziców może być zobligowane do pracy a drugie może zostać z dziećmi czy też oboje rodziców mogą być zobligowani do pracy",{"entities": [(98,101, "medical_law"),(182,185, "medical_law"),(33,41, "medical_law")]}),
("czy w czasie korzystania z urlopu wypoczynkowego klientce będzie przysługiwało wynagrodzenie kierownika apteki czy klientka będzie mogła skorzystać z urlopu wypoczynkowego po urlopie rodzicielskim w jaki sposób klientka może wypowiedzieć umowę i kiedy umowa ulegnie rozwiązaniu",{"entities": [(258,265, "labor_law"),(65,78, "labor_law"),(34,48, "labor_law"),(157,171, "labor_law"),(183,196, "labor_law")]}),
("czy wymagane jest wyrażenie zgody przez rodziców na zabieg powiększenia ust siedemnastoletniej pacjentki jeżeli tak to w jakiej formie należy udzielić wymaganej zgody",{"entities": [(52,58, "medical_law")]}),
("czy w związku ze zmianą nazwiska klientka musi zmienić nazwę spółki czy w związku ze zmianą nazwy spółki należy ponownie uzyskać zezwolenie na prowadzenie apteki",{"entities": [(24,32, "civil_law"),(17,23, "civil_law"),(85,91, "civil_law")]}),
("czy aby uznać daną osobę za rolnika indywidualnego koniecznym jest zamieszkiwanie przez tę osobę w gminie w której znajduje się gospodarstwo rolne przez okres ostatnich  lat jeżeli odpowiedź na pierwsze pytanie jest twierdząca w jaki sposób można uzyskać zgodę dyrektora generalnego krajowego ośrodka wsparcia rolnictwa na sprzedaż gruntów rolnych",{"entities": [(293,300, "administrative_law"),(99,105, "administrative_law"),(128,140, "administrative_law")]}),
("czy o opłatach za miejsca w hali garażowej decydują wyłącznie właściciele tych miejsc parkingowych jak i przez kogo powinny być wyliczane te opłaty jakie kroki należy podjąć aby jak najszybciej ograniczyć ogólny dostęp do hali garażowej pozostałych mieszkańców niebędących właścicielami hali garażowej",{"entities": [(86,98, "civil_law"),(273,286, "civil_law"),(28,32, "civil_law"),(222,226, "civil_law"),(287,291, "civil_law"),(212,218, "civil_law"),(6,14, "civil_law"),(237,248, "civil_law"),(33,42, "civil_law"),(227,236, "civil_law")]}),
("czy obniżenie premii motywacyjnej klientki było zgodne z prawem czy klientka może się odwołać od obniżenia premii do sądu",{"entities": [(14,20, "labor_law"),(107,113, "labor_law"),(4,13, "labor_law")]}),
("czy istnieje podstawa prawna do ukarania klienta za brak maseczki",{"entities": [(13,21, "medical_law"),(22,28, "medical_law")]}),
("czy klient może żądać od zarządu wspólnoty mieszkaniowej obniżenia ponoszonych przez niego kosztów utrzymania nieruchomości wspólnej",{"entities": [(99,109, "civil_law")]}),
("czy klient powinien zarejestrować podmiot leczniczy aby móc zatrudniać innych fizjoterapeutów",{"entities": [(60,70, "medical_law"),(42,51, "medical_law"),(34,41, "medical_law"),(71,77, "medical_law")]}),
("jakie są koszty wniesienia pozwu jeśli klient skorzysta z ubezpieczenia ochrony prawnej czy jeśli rozstrzygnięcie będzie niekorzystne dla klienta koszty będą pokrywanez ubezpieczenia ochrony prawnej do jakiej kwoty ubezpieczyciel będzie pokrywał koszty czy zespół adwokatów i radców prawnych z lex secure podtrzymuje swoje stanowisko",{"entities": [(27,32, "civil_law")]}),
("czy wykonywanie pracy jako farmaceuta na podstawie umowy cywilnoprawnej może zakończyć okres przerwy w wykonywaniu zawodu",{"entities": [(103,114, "pharmaceutical_law")]}),
("jaki jest skutek niezłożenia odpowiedzi na apelację w wymaganym terminie",{"entities": [(10,16, "civil_law"),(43,51, "civil_law")]}),
("jak kształtuje się odpowiedzialność za długi spadkowe klienta i jego ojca jak przeprowadzić postępowanie spadkowe",{"entities": [(39,44, "civil_law"),(45,53, "civil_law")]}),
("czy możliwe jest uchylenie się od złożonego oświadczenia woli  zgody na rozwiązanie stosunku pracy",{"entities": [(34,43, "labor_law"),(17,26, "labor_law")]}),
("czy miesięcznie dyżury wynosić będą  godzin i  minut czy ponad  godzin",{"entities": [(23,30, "medical_law")]}),
("czy pracodawca może zobowiązać pracownika do wykorzystania urlopu wypoczynkowego w określonym przez siebie terminie",{"entities": [(66,80, "labor_law"),(83,93, "labor_law")]}),
("czy osoba która prowadziła własną działalność gospodarczą nieprzerwanie przez okres  miesięcy może być traktowana jako osoba bezrobotna czy zakończenie prowadzenia działalności gospodarczej przez osobę o której mowa powyżej umożliwi jej uzyskanie statusu bezrobotnej czy okoliczność przyjmowania leków przeciwdepresyjnych ma znaczenie w kontekście uzyskania statusu osoby bezrobotnej",{"entities": [(125,135, "labor_law"),(103,113, "labor_law"),(247,254, "labor_law"),(358,365, "labor_law"),(255,266, "labor_law"),(27,33, "labor_law")]}),
("czy grafik pracy pracownika wpływa na czternastodniowy termin nałożenia kary porządkowej czy o nałożeniu kary porządkowej decyduje data otrzymania przez pracownika decyzji w tym przedmiocie czy wystawienia takiej decyzji czy nienałożenie kary porządkowej na pracownika skutkuje brakiem możliwości dochodzenia od pracownika odszkodowania na podstawie art  kodeksu pracy",{"entities": [(62,71, "labor_law"),(278,285, "labor_law"),(95,104, "labor_law"),(77,88, "labor_law"),(110,121, "labor_law"),(243,254, "labor_law")]}),
("czy klientka biorąc pod uwagę opisany stan faktyczny jest zobowiązania do posiadania kasy fiskalnej",{"entities": [(74,84, "tax_law")]}),
("czy brat powinien potwierdzić notariuszowi fakt przelania na swoje konto pieniędzy z konta matki czy można wezwać brata klienta do przedstawienia przed notariuszem bilingu wypłaty z własnego konta pieniędzy albo dowodu posiadania takiej sumy w celu rzekomego zdaniem przekazania kwoty   zł matce na podstawie umowy pożyczki czy można zobowiązać brata klienta przed notariuszem do wskazania świadków z imienia i nazwiska obecnych przy przeliczaniu i wręczaniu pieniędzy matce czy można go zobowiązać do pokazania przed notariuszem pisemnych potwierdzeń świadków o przekazaniu pieniędzy matce czy może jednak należy tę sprawę rozwiązać po spotkaniu z notariuszem w sprawie działu spadku które odbędzie się jakie jeszcze działania klient może jeszcze podjąć aby wyjaśnić swoje wątpliwości",{"entities": [(420,428, "civil_law"),(91,96, "civil_law"),(67,72, "civil_law"),(267,278, "civil_law"),(411,419, "civil_law"),(540,551, "civil_law"),(390,398, "civil_law"),(552,560, "civil_law"),(152,163, "civil_law"),(365,376, "civil_law"),(518,529, "civil_law"),(649,660, "civil_law"),(30,42, "civil_law"),(237,241, "civil_law")]}),
("w jaki sposób klient powinien złożyć zeznania",{"entities": [(30,36, "criminal_law")]}),
("czy korzystniejszym jest kupienie nieruchomości gruntowej a następnie przekazanie jej córce w formie darowizny czy przekazanie córce sumy potrzebnej do zakupu w formie aktu darowizny aby następnie córka sama dokonała zakupu nieruchomości gruntowej",{"entities": [(101,110, "civil_law"),(173,182, "civil_law"),(48,57, "civil_law"),(208,216, "civil_law"),(86,91, "civil_law"),(127,132, "civil_law"),(133,137, "civil_law")]}),
("czy przepisy prawa przewidują ilu specjalistów neurologii musi zatrudniać szpital wykonujący świadczenia finansowane przez nfz na oddziale neurologicznym",{"entities": [(105,116, "medical_law"),(63,73, "medical_law"),(47,57, "medical_law"),(34,46, "medical_law")]}),
("czy szpital zobowiązany jest do prowadzenia dokumentacji medycznej jedynie w formie elektronicznej czy są wyjątki dla których dokumentacja powinna być prowadzona nadal w formie papierowej",{"entities": [(126,138, "medical_law"),(147,150, "medical_law"),(106,113, "medical_law")]}),
("czy klientka może w dalszym ciągu ustosunkować się do wniosku wskazując iż nie zgadza się z zaproponowanym sposobem przeprowadzenia działu spadku",{"entities": [(79,85, "civil_law")]}),
("czy sklep może odmówić sprzedaży towarów osobom niezakrywającym nosa i ust",{"entities": [(64,68, "criminal_law"),(48,63, "criminal_law"),(33,40, "criminal_law"),(41,47, "criminal_law")]}),
("czy ojciec klientki może być jej pełnomocnikiem czy pełnomocnictwo musi mieć formę aktu notarialnego",{"entities": [(52,66, "civil_law")]}),
("czy apteka ogólnodostępna może podjąć współpracę z dietetykiem w ramach której w ustalonych dniachgodzinach w danym miesiącu dietetyk byłby dostępny dla pacjentów apteki celem udzielenia porad dietetycznych",{"entities": [(11,25, "pharmaceutical_law"),(140,148, "pharmaceutical_law")]}),
("czy klientowi przysługuje  dodatek do wynagrodzenia za cały dyżur czy tylko za jego część czy w związku z tym klientka powinna czekać na wypłatę dodatku i następnie się odwoływać od jego nieprawidłowej wysokości czy sprawę od razu przekazać prawnikom",{"entities": [(231,240, "medical_law"),(60,65, "medical_law")]}),
("w jaki sposób należałoby zaplanować dyżury medyczne klienta by uczynić zadość wymogowi pełnienia ich w wymiarze  godzin  minut tygodniowo",{"entities": [(87,96, "medical_law"),(103,111, "medical_law")]}),
("czy wnuczka może zostać zobowiązana do płacenia alimentów na rzecz swojej babki w jakim terminie należy zgłosić nabycie spadku do urzędu skarbowego w skład spadku wchodzi nieruchomość",{"entities": [(39,47, "civil_law"),(150,155, "civil_law"),(163,170, "civil_law"),(48,57, "civil_law")]}),
("czy klientka może podjąć jeszcze jakieś kroki w przedmiotowej sprawie czy istnieje inna instytucja do której klientka mogłaby zgłosić zaistniałą sytuację",{"entities": [(83,87, "administrative_law")]}),
("czy klientka może samodzielnie wytwarzać korony protetyczne czy klientka może sprzedawać wytworzone korony innym lekarzom",{"entities": [(48,59, "medical_law"),(41,47, "medical_law"),(100,106, "medical_law")]}),
("czy klient musi być reprezentowany w procesie od początku do końca czy wobec cofnięcia pełnomocnictwa klient może otrzymać zwrot kosztów zastępstwa procesowego",{"entities": [(87,101, "civil_law"),(61,66, "civil_law"),(20,34, "civil_law")]}),
("jaka w świetle obecnych przepisów prawa powinna być szerokość i wysokość drzwi do lokalu mieszkalnego prowadzących z klatki schodowej czy spółdzielnia może odmówić zgody na powiększenie otworu drzwiowego argumentując odmowę tym że budynek był budowany zgodnie z normami obowiązującymi ówcześnie",{"entities": [(231,238, "administrative_law")]}),
("czy klient jako farmaceuta może zostać zatrudniony w ramach stażu z urzędu pracy z wynagrodzeniem niższym niż minimalne",{"entities": [(83,97, "labor_law")]}),
("czy szpital w którym pracuje klientka jest szpitalem ii lub iiistopnia zabezpieczenia czy pracodawca klientki może wypłacać jej dodatek do wynagrodzenia jedynie za godziny przepracowane na bloku operacyjnymi z pacjentami z potwierdzonym zakażeniem covid",{"entities": [(237,247, "medical_law"),(172,185, "medical_law"),(71,85, "medical_law"),(43,52, "medical_law"),(115,123, "medical_law"),(210,220, "medical_law"),(53,55, "medical_law"),(223,236, "medical_law")]}),
("czy klient może żądać usunięcia swojego adresu ze strony aresztu śledczego",{"entities": [(22,31, "administrative_law")]}),
("czy wykreślenie niektórych zapisów przepisu o ochronie danych osobowych w załączonym pliku jest zgodne z prawem",{"entities": [(46,54, "administrative_law"),(35,43, "administrative_law")]}),
("czy zapis meble uszkodzone oraz zmontowane nie podlegają zwrotowi jest zgodny z prawem czy klient może odmówić przyjęcia zwrotu mebla",{"entities": [(47,56, "administrative_law")]}),
("czy klientka ma obowiązek pobierania od pacjentów zgody na przetwarzanie danych osobowych",{"entities": [(59,72, "administrative_law")]}),
("czy klientka wraz z pozostałymi spadkobiercami mogą już rozporządzać spadkiem czy spadkobierca musi wskazać sądowi nowe okoliczności aby móc otrzymać uzasadnienie postanowienia o nabyciu spadku w jaki sposób spadkobiercy mogą podzielić się spadkiem",{"entities": [(56,68, "civil_law"),(82,94, "civil_law"),(69,77, "civil_law"),(226,235, "civil_law"),(208,220, "civil_law"),(20,31, "civil_law")]}),
("czy rada nadzorcza może złożyć zawiadomienie o popełnieniu przestępstwa czy w powyższej kwestii potrzebna jest uchwała walnego zgromadzenia w jaki sposób spółdzielnia może odzyskać pieniądze które zostały przeznaczone na kary nałożone na prezesa i wiceprezesa",{"entities": [(47,58, "criminal_law"),(31,44, "criminal_law"),(59,71, "criminal_law"),(172,180, "criminal_law"),(181,190, "criminal_law"),(24,30, "criminal_law")]}),
("czy można wypowiedzieć umowę o pracę wysyłając pracodawcy mailowo skan podpisanego pisma zawierającego wypowiedzenie umowy o pracę czy można wypowiedzieć umowę o pracę składając pismo zawierające wypowiedzenie umowy o pracę informując o tym fakcie nieobecnego właściciela firmy",{"entities": [(71,82, "labor_law"),(37,46, "labor_law")]}),
("czy lekarz powinien wystawić dwie dodatkowe faktury za listopad i grudzień i zapłacić podatek niezależnie od tego kiedy otrzyma dodatek",{"entities": [(34,43, "medical_law"),(55,63, "medical_law"),(66,74, "medical_law"),(77,85, "medical_law")]}),
("czy po powrocie do kraju klientce należy się dodatek w związku z powrotem do polski",{"entities": [(65,73, "medical_law")]}),
("czy sąd zakreślił klientowi termin do złożenia odpowiedzi na pozew jak należałoby uprawdopodobnić w rozszerzeniu odpowiedzi na pozew że klient później doszedł do argumentów które są bardziej przemyślane",{"entities": [(61,66, "civil_law"),(127,132, "civil_law")]}),
("czy nieobecność jednego z właścicieli wspólnoty mieszkaniowej stanowi przeszkodę do skutecznego i wiążącego odczytania aktu notarialnego",{"entities": [(4,15, "civil_law")]}),
("czy możliwe jest dokonanie przez pracodawcę wypowiedzenia zmieniającego wraz z obniżeniem wynagrodzenia ewentualnie uzupełnienie różnicy dodatkiem",{"entities": [(58,71, "labor_law"),(79,89, "labor_law")]}),
("co może zrobić klientka aby wstrzymać budowę domu na sąsiedniej nieruchomości",{"entities": [(38,44, "administrative_law"),(53,63, "administrative_law")]}),
("czy pracodawca może zobowiązać klientkę do powrotu do pracy i podpisania zestawienia zbiorczego recept pomimo przekazania upoważnienia innemu pracownikowi czy kolejnego kierownika apteki powinna upoważnić klientka czy pracownik wyznaczony w miejsce klientki czy pracodawca może zobowiązać klientkę do powrotu do pracy w czasie trwania urlopu",{"entities": [(85,95, "pharmaceutical_law"),(73,84, "pharmaceutical_law")]}),
("co może zrobić apteka gdy pacjent złoży skargę na aptekę w związku z tym że nie było w niej szczepionek czy apteka może tworzyć listy oczekujących na szczepionki czy apteka może pobierać od pacjentów dane osobowe w celu stworzenia listy oczekujących co może zrobić apteka w sytuacji gdy w aptece nie będzie konkretnego typu leków a pacjentowi będzie kończyć się okres na jaki zostanie wystawiona recepta",{"entities": [(128,133, "administrative_law"),(231,236, "administrative_law"),(319,323, "administrative_law"),(205,212, "administrative_law"),(300,306, "administrative_law"),(343,349, "administrative_law"),(134,146, "administrative_law"),(237,249, "administrative_law")]}),
("czy lekarz prowadzący indywidualną praktykę lekarską wystawiający recepty refundowane przez rządowy system gabinetgovpl ma obowiązek raportowania zdarzeń medycznych do systemu p",{"entities": [(168,175, "medical_law"),(100,106, "medical_law")]}),
("w jaki sposób klientka może nabyć aptekę od rodziców",{"entities": [(34,40, "pharmaceutical_law")]}),
("czy zachowanie dyrektora jest zgodne z prawem czy klient może podpisać umowę o pracę jako rezydent z innym podmiotem",{"entities": [(90,98, "medical_law")]}),
("kto jest uprawniony do reprezentacji wspólnoty mieszkaniowej  uprawniony do wysłania wezwania do zapłaty wysłania wniosku o udostępnienie danych do cepiku złożenia pozwu w imieniu wspólnoty jakie dokumenty powinny stanowić dowód w postępowaniu sądowym",{"entities": [(164,169, "civil_law")]}),
("czy klientka musi płacić nowozatrudnionym pracownikom płacę minimalną czy tę wymaganą ustawą szczególną w trakcie okresu wypowiedzenia",{"entities": [(60,69, "medical_law"),(42,53, "medical_law")]}),
("czy klient może żądać od banku odszkodowania za działania oszustów",{"entities": [(25,30, "administrative_law")]}),
("czy wnuczka może zostać zobowiązana do płacenia alimentów na rzecz swojej babki w jakim terminie należy zgłosić nabycie spadku do urzędu skarbowego w skład spadku wchodzi nieruchomość",{"entities": [(39,47, "civil_law"),(150,155, "civil_law"),(163,170, "civil_law"),(48,57, "civil_law")]}),
("czy pracodawca dowie się z jakiej przyczyny klient jest na kwarantannie czy w ważnej sprawie mechanik może przyjść do klienta żeby naprawić uszkodzoną instalację czy klient może odebrać list od listonosza który do niego przyjdzie czy gdyby klient wyszedł z domu i zatrzymała go na tym policja to czy w razie wykonania testu byłaby to podstawa do odwołania",{"entities": [(334,342, "medical_law"),(34,43, "medical_law"),(59,71, "medical_law"),(247,254, "medical_law"),(107,114, "medical_law"),(308,317, "medical_law")]}),
("czy pracodawca może zmienić system czas pracy klienta z równoważnego na podstawowy czy pracodawca może zmienić ogłoszony już miesięczny harmonogram pracy",{"entities": [(56,68, "labor_law"),(136,147, "labor_law"),(125,135, "labor_law")]}),
("czy klientka może zostać skierowana do pracy przy zwalczaniu epidemii jak w przypadku skierowania do pracy przy zwalczaniu epidemii należy postąpić w związku z kontraktem z nfz",{"entities": [(139,147, "medical_law")]}),
("jakiej opłacie podlega wydanie decyzji przez konserwatora zabytków",{"entities": [(45,57, "administrative_law")]}),
("czy klientka może w trakcie urlopu wychowawczego zatrudnić się w gabinecie swojego małżonka",{"entities": [(28,34, "medical_law")]}),
("czy klientka może cofnąć wypowiedzenie umowy o pracę rezydentura czy wojewoda musi wyznaczyć inne miejsce odbywania rezydentury jeżeli lekarz medycyny pracy stwierdzi że klientka nie może pracować w szpitalu covidowym w wielkopolsce",{"entities": [(69,77, "medical_law"),(188,196, "medical_law"),(83,92, "medical_law"),(18,24, "medical_law"),(116,127, "medical_law")]}),
("czy pacjent może odmówić założenia maseczki w przychodni czy klientka może odmówić leczenia pacjenta w przypadku gdyby pojawił się w przychodni ponownie czy klientka powinna zgłosić gdzieś zaistniałą sytuację",{"entities": [(189,199, "criminal_law"),(35,43, "criminal_law")]}),
("czy szpital może żądać od klienta zwrotu części wynagrodzenia w zaistniałych okolicznościach",{"entities": [(64,76, "medical_law")]}),
("czy klientka dokonując zmian w dokumentacji medycznej poprzednich pacjentów będzie mogła posługiwać się pieczątką nowo powstałej grupowej praktyki",{"entities": [(54,65, "medical_law"),(23,28, "medical_law"),(89,99, "medical_law")]}),
("jakie kroki prawne może podjąć klientka",{"entities": [(0,5, "criminal_law"),(12,18, "criminal_law")]}),
("w jaki sposób lekarze mogą się bronić czy lekarz rezydent może pracować na oddziale intensywnej terapii",{"entities": [(84,95, "medical_law"),(63,71, "medical_law"),(49,57, "medical_law"),(14,21, "medical_law")]}),
("czy lekarz który skończył szkolenie specjalizacyjne jednak nie zdał jeszcze państwowego egzaminu specjalizacyjnego może wykonywać samodzielnie znieczulenia",{"entities": [(88,96, "medical_law"),(26,35, "medical_law"),(36,51, "medical_law"),(76,87, "medical_law"),(97,114, "medical_law")]}),
("jaki jest zakres wymaganych świadczeń medycznych lekarza podstawowej opieki zdrowotnej w odniesieniu do osoby chorej na chorobę zakaźną",{"entities": [(17,27, "medical_law")]}),
("czy klient może wrócić na poprzednie stanowisko pracy czy można ukarać pracownika karą pieniężną i jednocześnie potrącić mu premię",{"entities": [(112,120, "labor_law")]}),
("ile powinno wynosić wynagrodzenie klientki od dnia  lipca  r czy klientka powinna zażądać zawarcia umowy o pracę na czas określony",{"entities": [(12,19, "medical_law"),(59,60, "medical_law"),(116,120, "medical_law"),(4,11, "medical_law")]}),
("czy klientka może wydać ośrodkowi zdrowia zapotrzebowanie na szczepionkę przeciwko grypie",{"entities": [(42,57, "pharmaceutical_law")]}),
("w jaki sposób dokonać przepisania udziału męża klientki we własności nieruchomości na dzieci klientki w jaki sposób klientka może przejąć dług męża",{"entities": [(59,68, "civil_law")]}),
("czy klient jest uprawniony do wykonania obdukcji pacjentki",{"entities": [(16,26, "medical_law"),(30,39, "medical_law")]}),
("ile wynosiły odsetki kapitałowe na dzień zawarcia umowy pożyczki przez klienta jakie okoliczności brane są pod uwagę przy ocenie czy klient udzielił pożyczki w ramach prowadzonej działalności gospodarczej czy fakt że warunki umowy proponował pożyczkobiorca ma jakiś wpływ na karę czy jej wymiar czy przy ocenie czy klient prowadzi działalność gospodarczą ma znaczenie ilość udzielonych pożyczek na jaki moment należy dokonać oceny czy klient prowadzi działalność gospodarczą czy nie czy zaprzestanie udzielania pożyczek stanowi okoliczność łagodzącą czy wobec faktu iż prowizja została potrącona z należności głównej i klient nie wystosowywał żądania jej zapłaty stanowi okoliczność wyłączającą popełnienie czynu określonego w art    kodeksu karnego",{"entities": [(79,84, "criminal_law"),(13,20, "criminal_law"),(209,213, "criminal_law"),(322,330, "criminal_law"),(442,450, "criminal_law"),(734,741, "criminal_law"),(417,424, "criminal_law"),(707,712, "criminal_law"),(520,527, "criminal_law"),(663,670, "criminal_law"),(386,394, "criminal_law"),(511,519, "criminal_law"),(122,128, "criminal_law"),(304,310, "criminal_law")]}),
("do kogo klient powinien skierować wniosek o tzw dodatek covidowy",{"entities": [(24,33, "medical_law")]}),
("na jakiej podstawie i w jaki sposób klient może uzyskać zadośćuczynienie od biura podróży",{"entities": [(76,81, "administrative_law")]}),
("czy w przypadku zajścia w ciążę w trakcie okresu pracy wskazanego w umowie klientka po powrocie będzie musiała dokończyć wymagany rok pracy w szpitalu czy przedmiotowa umowa jest dla klientki gwarancją że pracodawca przedłuży umowę o prace w przypadku zajścia przez nią w ciążę",{"entities": [(16,23, "labor_law"),(252,259, "labor_law"),(55,65, "labor_law"),(26,31, "labor_law"),(234,239, "labor_law")]}),
("czy klientka wraz z pozostałymi spadkobiercami mogą już rozporządzać spadkiem czy spadkobierca musi wskazać sądowi nowe okoliczności aby móc otrzymać uzasadnienie postanowienia o nabyciu spadku w jaki sposób spadkobiercy mogą podzielić się spadkiem",{"entities": [(56,68, "civil_law"),(82,94, "civil_law"),(69,77, "civil_law"),(226,235, "civil_law"),(208,220, "civil_law"),(20,31, "civil_law")]}),
("czy pracodawca może skrócić okres wypowiedzenia bez zgody klientki czy pracodawca może zadecydować o tym że wypłaci klientce ekwiwalent pieniężny zamiast udzielania jej urlopu",{"entities": [(20,27, "labor_law"),(125,135, "labor_law"),(136,145, "labor_law")]}),
("w jaki sposób można sprawdzić czy istnieje testament notarialny czy zapis testamentu w którym spadkodawca rozporządza udziałem w mieszkaniu wywołuje skutki prawne jak uregulować sytuację prawną obrazów czy klientka może sprzedać obrazy bez przeprowadzania postępowania spadkowego",{"entities": [(20,29, "civil_law"),(43,52, "civil_law"),(129,139, "civil_law"),(74,84, "civil_law")]}),
("czy pracodawca może żądać od pracownika informacji na temat jego aktualnego dodatkowego zatrudnienia w związku z ryzykiem zakażenia pracownika koronawirusem w miejscu dodatkowego zatrudnienia",{"entities": [(76,87, "labor_law"),(167,178, "labor_law"),(65,75, "labor_law"),(113,121, "labor_law")]}),
("czy klient może przeprowadzać badanie kwalifikacyjne przed szczepieniem na covid",{"entities": [(59,71, "medical_law"),(38,52, "medical_law")]}),
("czy i w jaki sposób klientka jest w stanie obecnie wyegzekwować wydanie świadectwa pracy aby móc ubiegać się o rentę po zmarłym jeżeli postępowanie sądowe w sprawie wydania świadectwa toczyło się przed śmiercią męża klientki czy umowa kredytu nieubezpieczonego którą przesłała klientka rozwiązuje się z chwilą śmierci kredytobiorcy czy klientka obecnie może spłacić kredyt",{"entities": [(120,127, "civil_law"),(358,365, "civil_law"),(148,154, "civil_law")]}),
("czy wspólnota mieszkaniowa może pobierać opłaty na utrzymanie garażu mimo iż klient z niego nie korzysta",{"entities": [(32,40, "civil_law")]}),
("czy klientka ma prawo spisać numer dowodu osobistego pacjenta w celu sporządzenia dokumentacji medycznej",{"entities": [(69,81, "administrative_law")]}),
("czy oddelegowanie do pracy przy łóżkach covidowych wydane przez dyrektora szpitalaw formie ustnej jest dla klientki wiążące",{"entities": [(91,97, "labor_law")]}),
("czy po uzyskaniu pisemnej zgody dyrekcji na obowiązkowy staż kierunkowy lub kurs cofnięcie przez dyrekcję zgody w formie ustnej jest wiążące zakładając dobrowolność w odbywaniu dyżurów w sor czy jest dopuszczalne by ktoś poza klientka ustalał jej grafik na sor czy klientka musi odbyć dyżury w sor jeśli otrzymała grafik pracy na  dni przed okresem w którym grafik miał obowiązywać czy klientka musi odbywać dyżury w sor jeśli grafik w sor jest odgórnie narzucony i dyżur pokrywa się z obowiązkowym dyżurem zgodnie z programem specjalizacji który odbywa w macierzystym oddziale chirurgii które z dyżurów mają priorytet w sytuacji wypowiedzenia klauzuli optout obowiązkowe dyżury zgodnie z programem specjalizacji czy dyżury w sor czy po wypowiedzeniu klauzuli optout i ustalonym grafiku pracy w oddziale chirurgii oddziale macierzystym ustaleniu obowiązkowych zgodnie z programem specjalizacji dyżurów klientka ma prawo odmówić objęcia dyżurów na sor które powodują przekroczenie czasowych norm pracy odnosząc się do pytania wcześniejszego czy dyrekcja może klientkę na tej podstawie ukarać lub zwolnić",{"entities": [(846,859, "medical_law"),(400,407, "medical_law"),(517,526, "medical_law"),(689,698, "medical_law"),(870,879, "medical_law"),(466,471, "medical_law"),(81,90, "medical_law"),(17,25, "medical_law"),(7,16, "medical_law"),(547,553, "medical_law"),(56,60, "medical_law"),(76,80, "medical_law"),(556,568, "medical_law"),(823,835, "medical_law"),(644,652, "medical_law"),(751,759, "medical_law"),(653,659, "medical_law"),(760,766, "medical_law")]}),
("czy viregytk może być sprzedawany w ramach recepty ze  odpłatnością",{"entities": [(4,12, "pharmaceutical_law"),(22,33, "pharmaceutical_law")]}),
("czy aby wykonywać zabiegi z zakresu medycyny estetycznej np wstrzykiwanie toksyny botulinowej w ramach współpracy z podmiotem prowadzonym przez kosmetologa  klientce wystarczy posiadanie prawa wykonywania zawodu lekarza na stażu podyplomowym",{"entities": [(223,228, "medical_law"),(45,56, "medical_law"),(116,125, "medical_law"),(103,113, "medical_law")]}),
("jak przeprowadzić postępowanie spadkowe w niniejszej sytuacji",{"entities": [(31,39, "civil_law")]}),
("co może zrobić klientka w celu zabezpieczenia się przed odpowiedzialnością za błąd medyczny w przypadku pełnienia dyżuru na dwóch oddziałach jednocześnie",{"entities": [(31,45, "medical_law"),(104,113, "medical_law"),(114,120, "medical_law"),(130,140, "medical_law"),(78,82, "medical_law")]}),
("jakie dokumenty musi złożyć klientka aby uzasadnić ubieganie się o alimenty od ojca dzieci",{"entities": [(41,50, "civil_law"),(67,75, "civil_law"),(51,60, "civil_law")]}),
("co należy zrobić jeśli w sieci pojawią się opinie oczerniające lekarza",{"entities": [(31,38, "administrative_law"),(50,62, "administrative_law"),(25,30, "administrative_law"),(43,49, "administrative_law")]}),
("czy klient może iść na dyżur w trakcie kwarantanny",{"entities": [(23,28, "medical_law")]}),
("czy bank powinien zwrócić klientce proporcjonalną część kosztów prowizji kredytu",{"entities": [(35,49, "administrative_law"),(64,72, "administrative_law")]}),
("czy zarządca ma obowiązek udzielania firmom ubezpieczającym informacji dotyczących sprawcy szkody",{"entities": [(4,12, "civil_law")]}),
("w jaki sposób powinna postąpić klientka gdyby zgłosił się do niej pacjent z żądaniem odszkodowania w związki z ewentualnym błędem medycznym",{"entities": [(22,30, "medical_law")]}),
("czy klientka może negocjować pracę w wymiarze  lub  dni w tygodniu jakie załączniki stanowią integralną część umowy czy szpital będzie mógł zmienić miejsce wykonywania świadczeń z pracowni na poradnię dlaczego w   pkt  umowy jest mowa o dniach roboczych jeżeli w materiałach informacyjnych nie ma tego zapisu",{"entities": [(37,45, "medical_law")]}),
("czy dyrekcja szpitala może skierować rezydenta do pracy na oddziale niewynikającym z programu specjalizacji czy przy skierowaniu do tego rodzaju pracy rezydent powinien mieć wyznaczonego specjalistę opiekuna",{"entities": [(137,144, "medical_law"),(117,128, "medical_law"),(169,173, "medical_law"),(27,36, "medical_law"),(85,93, "medical_law"),(174,186, "medical_law"),(187,198, "medical_law"),(151,159, "medical_law"),(68,82, "medical_law")]}),
("czy bank powinien dokonać zwrotu części prowizji po całkowitej przedterminowej spłacie kredytu",{"entities": [(40,48, "administrative_law")]}),
("czy wypowiedzenie umowy o pracę złożone przez klienta jest skuteczne",{"entities": [(32,39, "labor_law")]}),
("czy klient może sporządzić lek mimo że wskazana przez lekarza na recepcie ilość substancji przekracza dawkę maksymalną czy zamiast  gramów fosforanu kodeiny prawidłowym zapisem byłoby dwanaście gramów fosforanu kodeiny czy zamiast sx w recepcie powinien znajdować się zapis s  x  proszek czy istnieje możliwość wydania podwójnej ilości leku recepturowego z grupy n ii  proszków",{"entities": [(65,73, "pharmaceutical_law"),(236,244, "pharmaceutical_law"),(132,138, "pharmaceutical_law"),(194,200, "pharmaceutical_law"),(102,107, "pharmaceutical_law"),(149,156, "pharmaceutical_law"),(211,218, "pharmaceutical_law"),(80,90, "pharmaceutical_law"),(139,148, "pharmaceutical_law"),(201,210, "pharmaceutical_law"),(319,328, "pharmaceutical_law"),(341,354, "pharmaceutical_law"),(254,263, "pharmaceutical_law"),(268,273, "pharmaceutical_law")]}),
("czy wystawienie oraz realizacja skierowania na leczenie szpitalne w szpitalu który zawarł umowę o udzielanie świadczeń opieki zdrowotnej na badania medycyny nuklearnej oraz badania tomografii komputerowej finansowane ze środków publicznych oraz ze środków innych niż środki publiczne badania rezonansu magnetycznego badania endoskopowe przewodu pokarmowego oraz badania echokardiograficzne płodu finansowane ze środków publicznych wystawionego w formie pisemnej poza systemem ezdrowie jest niezgodnaz prawem",{"entities": [(228,239, "medical_law"),(419,430, "medical_law"),(205,216, "medical_law"),(396,407, "medical_law"),(181,191, "medical_law"),(453,461, "medical_law"),(192,204, "medical_law"),(256,262, "medical_law")]}),
("czy w trakcie postępowania prowadzonego przez prezesa urzędu ochrony konkurencji i konsumentów na podstawie art  ust  ustawy z dnia  lutego  r o ochronie konkurencji i konsumentów przedkładając na pisemne wezwanie prowadzącego kontrolę kopii umów z konsumentami i klientami istnieje możliwość anonimizowania danych klientów w tym danych osobowych oraz anonimizowania wartości transakcji zawartych w umowach",{"entities": [(197,204, "administrative_law"),(315,323, "administrative_law"),(264,273, "administrative_law"),(145,153, "administrative_law"),(83,94, "administrative_law"),(168,179, "administrative_law"),(293,307, "administrative_law"),(352,366, "administrative_law")]}),
("czy tzw zejście po dyżurach medycznych w przypadku pełnienia dyżuru medycznego powyżej czasu określonego w umowie specjalizacyjnej przy podpisanej klauzuli optout wydłuża czas trwania szkolenia specjalizacyjnego",{"entities": [(19,27, "medical_law"),(184,193, "medical_law"),(51,60, "medical_law"),(61,67, "medical_law"),(163,170, "medical_law"),(171,175, "medical_law"),(8,15, "medical_law"),(147,155, "medical_law"),(156,162, "medical_law")]}),
("czy klient będąc stomatologiem bez specjalizacji z chirurgii stomatologicznej może pracować w szpitalnym oddziale chirurgii szczękowotwarzowej",{"entities": [(83,91, "medical_law"),(61,77, "medical_law"),(94,104, "medical_law")]}),
("czy w związku z przedstawionym stanem faktycznym klientka może skorzystać z częściowego przestoju ekonomicznego",{"entities": [(88,97, "labor_law")]}),
("na jaki okres czasu klient będący lekarzem specjalistą pracującym na podstawie umowy o pracę może zostać oddelegowany do pracy na oddziale covidowym",{"entities": [(27,33, "labor_law")]}),
("czy klientka zobowiązana jest do odrobienia dyżurów czy szkolenie specjalizacyjne zostanie przedłużone jakie obecnie uprawnienia przysługują klientce na podstawie art i ust d ustawy o zawodach lekarza i lekarza dentysty od kiedy obowiązuje ww przepis",{"entities": [(184,192, "medical_law"),(56,65, "medical_law"),(229,239, "medical_law"),(66,81, "medical_law"),(240,242, "medical_law"),(33,43, "medical_law"),(211,219, "medical_law")]}),
("czy okres odbywania stażu przez klienta będzie przedłużony o czas kwarantanny czy klient otrzyma wynagrodzenie za okres kiedy podmiot leczniczy pozostaje zamknięty jak powinien zachować się klient czy klient powinien udać się na urlop wypoczynkowy lub bezpłatny",{"entities": [(229,234, "medical_law"),(20,25, "medical_law"),(134,143, "medical_law"),(61,65, "medical_law"),(126,133, "medical_law")]}),
("czym skutkuje wydziedziczenie testamentowe w jaki sposób można podważyć wydziedziczenie",{"entities": [(14,29, "civil_law"),(30,42, "civil_law"),(5,13, "civil_law")]}),
("czy lekarz jest obowiązany do wystawienia karty zgonu pacjenta z którym nie miał wcześniej kontaktu",{"entities": [(48,53, "medical_law"),(42,47, "medical_law")]}),
("czy klientka podejmując pracę w hurtowni farmaceutycznej wykonywać będzie nadal zawód farmaceuty czy podejmując pracę w innym województwie należy zmienić właściwą izbę aptekarską",{"entities": [(32,40, "pharmaceutical_law"),(13,23, "pharmaceutical_law"),(101,111, "pharmaceutical_law"),(41,56, "pharmaceutical_law"),(163,167, "pharmaceutical_law")]}),
("czy klient może skutecznie żądać zwrotu spłaty części kredytu w jakiej formie klient może domagać się zwrotu",{"entities": [(40,46, "civil_law")]}),
("czy właściciel lokalu użytkowego magazynu w którym nie znajduje się grzejnik zobowiązany jest do partycypacji w kosztach ogrzewania nieruchomości wspólnej",{"entities": [(97,109, "civil_law"),(22,32, "civil_law"),(68,76, "civil_law"),(112,120, "civil_law"),(121,131, "civil_law")]}),
("co zrobić może wspólnik klienta czy partnerem spółki może być pielęgniarka",{"entities": [(36,45, "medical_law"),(58,61, "medical_law")]}),
("czy klient miał podstawy aby odmówić udzielania świadczeń zdrowotnych całej rodzinie problematycznego pacjenta",{"entities": [(16,24, "medical_law"),(37,47, "medical_law"),(76,84, "medical_law")]}),
("czy lekarz stażysta może przeprowadzać kwalifikację do szczepień w tzw szczepionkobusie poza terenem szpitala",{"entities": [(11,19, "medical_law"),(55,64, "medical_law")]}),
("czy pracodawca może oddelegować lekarza rezydenta do dyżurowania na sor",{"entities": [(53,64, "medical_law")]}),
("czy komornik zajął odpowiednią kwotę pieniędzy",{"entities": [(4,12, "civil_law")]}),
("czy klient jest zobowiązany do przestrzegania jakichkolwiek rekomendacji pochodzących nie od właścicieli apteki a wychodzących od zarządu sieci franczyzowej czy pracodawca może nakazać klientowi i innym pracownikom noszenie maseczek dokonywanie pomiaru temperatury i tym podobnych działań w ramach walki z epidemią",{"entities": [(130,137, "labor_law"),(271,280, "labor_law"),(298,303, "labor_law")]}),
("jakie przepisy regulują pożyczki społecznościowe jakie są maksymalne odsetki lub koszty pozaodsetkowe w umowie pożyczki czy pożyczka udzielona przez klienta miała charakter lichwy czy klientowi grozi odpowiedzialność karna",{"entities": [(0,5, "criminal_law"),(49,54, "criminal_law"),(69,76, "criminal_law"),(184,193, "criminal_law"),(194,199, "criminal_law")]}),
("czy osoba która nie jest farmaceutą może być wspólnikiem spółki jawnej prowadzącej aptekę czy zmiana w strukturze właścicielskiej spółki pociąga za sobą konieczność uzyskania nowej koncesji",{"entities": [(83,89, "pharmaceutical_law"),(114,129, "pharmaceutical_law"),(137,144, "pharmaceutical_law"),(103,113, "pharmaceutical_law"),(71,82, "pharmaceutical_law")]}),
("czy lekarz i ratownik medyczny mogą odmówić pracy w przypadku braku odpowiedniej odzieży ochronnej i szkoleń z zakresu indywidualnej ochrony przed koronawirusem",{"entities": [(81,88, "labor_law"),(68,80, "labor_law")]}),
("czy farmaceuta może odmówić realizacji recepty papierowej bez kodu kreskowego wystawionej ze  odpłatnością",{"entities": [(62,66, "pharmaceutical_law"),(78,89, "pharmaceutical_law")]}),
("czy zapotrzebowanie z apteczki oddziałowej skierowane do apteki szpitalnej musi zostać podpisane przez ordynatora oddziału czy wystarczy zlecenie wysłanie przez elektroniczny system szpitalny",{"entities": [(80,86, "pharmaceutical_law"),(64,74, "pharmaceutical_law"),(4,19, "pharmaceutical_law")]}),
("czy córka klienta może ubiegać się o zachowek po zmarłej babci w jakim terminie córka klienta może ubiegać się o zachowek",{"entities": [(37,45, "civil_law"),(57,62, "civil_law")]}),
("w jaki sposób klient może uzyskać skan opinii rzeczoznawcy",{"entities": [(34,38, "civil_law")]}),
("czy w przypadku gdy dwójka rodziców wychowuje dziecko do lat  i jeden z rodziców jest lekarzem może on zostać skierowany do pracy przy zwalczaniu epidemii przez wojewodę",{"entities": [(57,60, "medical_law"),(86,94, "medical_law"),(110,120, "medical_law"),(36,45, "medical_law")]}),
("czy pracodawca ma możliwość oddelegowania klientki do pełnienia dyżurów medycznych na innym oddziale aniżeli wskazanym jako miejsce pracy w wiążącej klientkę umowie o pracę",{"entities": [(109,118, "labor_law")]}),
("jak prezentuje się kwestia odpowiedzialności lekarza rezydenta w zaistniałych okolicznościach czy ewentualne roszczenia zostałyby pokryte przez szpital czy szpital pokryłby świadczenia wynikające z uznania odpowiedzialności klientki powstałe z jej winy wskutek błędu lekarskiego w trakcie przeprowadzanych przez nią procedur które nie były wymienione w zakresie czynności dołączonych do umowy klientki czy szpital pokryłby świadczenia wynikające z roszczeń pacjentów wskutek uznania odpowiedzialności klientki w takcie dobrowolnej pracy na sor mimo iż w umowie rezydenckiej wskazano oddział chirurgii jako jej miejsce pracy czy w przypadku nieszczęśliwego wypadku w trakcie dobrowolnej pracy na sor klientce zostanie wypłacone ubezpieczenie skoro w umowie rezydenckiej wskazano oddział chirurgii jako faktyczne miejsce pracy czy pismo z dnia  października r jest podstawą do cofnięcia zgody na realizację stażu w ramach rezydentury",{"entities": [(45,52, "criminal_law"),(561,573, "criminal_law"),(756,768, "criminal_law"),(829,834, "criminal_law"),(885,890, "criminal_law"),(574,582, "criminal_law"),(769,777, "criminal_law"),(727,740, "criminal_law"),(519,530, "criminal_law"),(674,685, "criminal_law"),(98,108, "criminal_law"),(27,44, "criminal_law"),(206,223, "criminal_law"),(483,500, "criminal_law"),(837,841, "criminal_law"),(78,93, "criminal_law"),(198,205, "criminal_law"),(475,482, "criminal_law"),(164,172, "criminal_law"),(414,422, "criminal_law"),(583,590, "criminal_law"),(778,785, "criminal_law"),(362,371, "criminal_law"),(267,278, "criminal_law")]}),
("czy stanowisko wyrażone w opiniach o sygn    jest prawidłowe",{"entities": [(15,23, "tax_law")]}),
("czy osoba która prowadziła własną działalność gospodarczą nieprzerwanie przez okres  miesięcy może być traktowana jako osoba bezrobotna czy zakończenie prowadzenia działalności gospodarczej przez osobę o której mowa powyżej umożliwi jej uzyskanie statusu bezrobotnej czy okoliczność przyjmowania leków przeciwdepresyjnych ma znaczenie w kontekście uzyskania statusu osoby bezrobotnej",{"entities": [(125,135, "labor_law"),(103,113, "labor_law"),(247,254, "labor_law"),(358,365, "labor_law"),(255,266, "labor_law"),(27,33, "labor_law")]}),
("czy klient może wydać zaświadczenie o jakie prosi córka potencjalnej pacjentki klienta",{"entities": [(22,35, "medical_law")]}),
("czy z uwagi na brak jakiegokolwiek pisma z zakładu ubezpieczeń społecznych wniosek klienta został rozpatrzony pozytywnie czy na zadane we wniosku pytanie klient powinien wskazać zwolnienie z obowiązku opłacania składek",{"entities": [(35,40, "medical_law"),(201,210, "medical_law"),(6,11, "medical_law")]}),
("czy pracownik musi odebrać tablet służbowy przeznaczony do wykonywania pracy czy pracodawca obowiązany jest dostarczyć odpowiednie zabezpieczenie do sprzętu służbowego powierzonego pracownikowi",{"entities": [(108,118, "labor_law")]}),
("czy klient ma obowiązek się zarejestrować w bdo w jaki sposób klient może się zarejestrować",{"entities": [(28,41, "administrative_law")]}),
("w jaki sposób należy rozumieć i od kiedy obowiązuje   ust  pkt  lit b rozporządzenia ministra zdrowia w sprawie recept",{"entities": [(85,93, "medical_law"),(41,51, "medical_law")]}),
("czy klientka która jest psychoterapeutą może zostać zwolniona z tajemnicy zawodowej przez sąd w postępowaniu cywilnym",{"entities": [(24,39, "medical_law")]}),
("czy jeżeli klient będzie wynajmował długoterminowo dwa mieszkania na podstawie umowy najmu okazjonalnego powstanie konieczność zarejestrowania działalności gospodarczej w tym zakresie jeżeli tak to jak wygląda opodatkowanie uzyskiwanych z tego tytułu przychodów oraz konieczność uiszczenia podatku w przypadku sprzedaży lokali czy jeżeli klient będzie wynajmował długoterminowo dwa mieszkania na podstawie umowy najmu okazjonalnego oraz trzecie mieszkanie w ramach najmu krótkoterminowego za pośrednictwem platformy internetowej powstanie konieczność zarejestrowania działalności gospodarczej w tym zakresie jeżeli tak to jak wygląda opodatkowanie uzyskiwanych z tego tytułu przychodów oraz kwestie środków trwałych amortyzacji czy kasy fiskalnej",{"entities": [(25,35, "civil_law"),(352,362, "civil_law"),(279,289, "civil_law"),(320,326, "civil_law"),(91,104, "civil_law"),(418,431, "civil_law"),(127,142, "civil_law"),(551,566, "civil_law"),(251,261, "civil_law"),(675,685, "civil_law"),(224,236, "civil_law"),(648,660, "civil_law"),(210,223, "civil_law"),(634,647, "civil_law")]}),
("jakie są prawa i obowiązki świadka w postępowaniu karnym",{"entities": [(0,5, "criminal_law"),(27,34, "criminal_law"),(37,49, "criminal_law")]}),
("czy jeśli w aptece jest szyba która osłania farmaceutów to czy muszą oni nosić maseczki lub przyłbice",{"entities": [(44,55, "medical_law"),(73,78, "medical_law"),(63,68, "medical_law"),(24,29, "medical_law"),(12,18, "medical_law")]}),
("czy pracodawca może jednostronnie zmniejszyć żonie klienta wymiar czasu pracy z  na  etatu czy w związku ze zmniejszeniem wymiaru zatrudnienia na skutek epidemii obecnie pracownikowi przysługuje jakieś dodatkowe świadczenie czy w przypadku zamknięcia zakładu pracy żona klienta będzie miała możliwość pobierania zasiłku dla bezrobotnych",{"entities": [(122,129, "labor_law"),(34,44, "labor_law"),(170,182, "labor_law")]}),
("czy kierownik apteki może podpisać zestawienie refundacyjne podczas przebywania na zwolnieniu lekarskim czy klientka może podpisać zestawienie refundacyjne",{"entities": [(35,46, "medical_law"),(131,142, "medical_law"),(4,13, "medical_law"),(47,59, "medical_law")]}),
("w nawiązaniu do sprawy o sygnaturze  klientka chce się dowiedzieć czy na przelewie za bilet lotniczy będący dowodem w sprawie może widnieć nazwisko innej osoby",{"entities": [(139,147, "administrative_law"),(86,91, "administrative_law")]}),
("co powinna zrobić klientka  przyjąć spadek z dobrodziejstwem inwentarza czy go odrzucić jak i kiedy należy tego dokonać czy pełnoletnie dzieci klientki również powinny odrzucić spadek",{"entities": [(45,60, "civil_law"),(79,87, "civil_law"),(168,176, "civil_law"),(36,42, "civil_law"),(61,71, "civil_law")]}),
("czy bank powinien zwrócić klientce proporcjonalną część kosztów prowizji kredytu hipotecznego",{"entities": [(35,49, "administrative_law"),(64,72, "administrative_law")]}),
("czy lek viregytk może być wydany poza wskazaniem na recepcie pro auctore lub pro familiae z odpłatnością",{"entities": [(65,72, "pharmaceutical_law"),(8,16, "pharmaceutical_law"),(52,60, "pharmaceutical_law"),(61,64, "pharmaceutical_law"),(77,80, "pharmaceutical_law"),(81,89, "pharmaceutical_law")]}),
("czy pracodawca mógł ustnie wprowadzić równoważny system czasu pracy i zobowiązać klientkę do pracy w dwie soboty po  godzin",{"entities": [(27,37, "labor_law"),(38,48, "labor_law")]}),
("czy żona klienta ma obowiązek udostępnienia dokumentacji medycznej w przypadku gdy ma wątpliwości co do tego czy ojciec dziecka posiada władzę rodzicielską czy oboje rodzice mają niezależnie od siebie i równocześnie prawo dostępu do dokumentacji medycznej dziecka",{"entities": [(30,43, "medical_law"),(86,97, "medical_law")]}),
("czy spadkobiercy mogą zostać pociągnięci do odpowiedzialności w ramach umowy ubezpieczenia czy spadkobiercy mogą wystąpić do ubezpieczyciela z informacją jakie szkody poniósł poszkodowany w jakim terminie spadkobiercy powinni ustosunkować się do pisma ubezpieczyciela",{"entities": [(4,16, "civil_law"),(95,107, "civil_law"),(205,217, "civil_law")]}),
("czy miesięcznie dyżury wynosić będą  godzin i  minut czy ponad  godzin",{"entities": [(23,30, "medical_law")]}),
("czy klientka ma prawo spisać numer dowodu osobistego pacjenta w celu sporządzenia dokumentacji medycznej",{"entities": [(69,81, "administrative_law")]}),
("czy obecnie należy przeprowadzić dział spadku",{"entities": [(33,38, "civil_law")]}),
("czy pracodawca może zobowiązać pracownika do wykonywania testu na covid raz w tygodniu",{"entities": [(72,75, "labor_law")]}),
("czy osoba która nie jest farmaceutą może być wspólnikiem spółki jawnej prowadzącej aptekę czy zmiana w strukturze właścicielskiej spółki pociąga za sobą konieczność uzyskania nowej koncesji",{"entities": [(83,89, "pharmaceutical_law"),(114,129, "pharmaceutical_law"),(137,144, "pharmaceutical_law"),(103,113, "pharmaceutical_law"),(71,82, "pharmaceutical_law")]}),
("czy zeznania świadków są wiarygodnymi zeznaniami dla okręgowego sądu lekarskiego bądź okręgowego rzecznika odpowiedzialności zawodowej czy nagranie rozmowy sporządzone bez zgody osoby nagrywanej może stanowić dowód w postępowaniu cywilnym czy okręgowy rzecznik odpowiedzialności zawodowej ma możliwość odnoszenia się do zasadności skierowań czy rozpoznawania chorób wydawanych przez klientkę czy decyzja okręgowego rzecznika odpowiedzialności zawodowej oparta zdaniem klientki na niezgodnych z prawdą ustaleniach powinna być zrewidowana czy klientka powinna otrzymać odpowiedź na odwołanie od decyzji okręgowego rzecznika odpowiedzialności zawodowej czy istnieje możliwość odwołania się od decyzji okręgowego rzecznika odpowiedzialności zawodowej wydanej na podstawie niezgodnych z dokumentacją szpitalną danych w jaki sposób klientka może uzyskać dostęp do akt sprawy postępowania dyscyplinarnego",{"entities": [(13,21, "civil_law"),(156,167, "civil_law"),(848,854, "civil_law"),(480,491, "civil_law"),(768,779, "civil_law")]}),
("czy jako osoba fizyczna wynajmująca mieszkanie klient może wystawić najemcy dokument kasa przyjęła",{"entities": [(68,75, "civil_law"),(76,84, "civil_law")]}),
("w jaki sposób należy przeprowadzić postępowanie spadkowe czy istnieje maksymalny czas w jakim należy je przeprowadzić",{"entities": [(48,56, "civil_law")]}),
("czy klient może odmówić przyjęcia pacjenta z uwagi na to że jest on roszczeniowy i nie można z nim dojść do porozumienia",{"entities": [(24,33, "medical_law"),(45,50, "medical_law")]}),
("czy klientce przysługuje roszczenie o wypłatę dodatku covidowego",{"entities": [(25,35, "medical_law")]}),
("czy od  lipca  r wszyscy lekarze którzy nie podpisali umowy z nfz nie zgadzając się na wymagane w umowie kontrolowanie przez urzędników nfz dokumentacji medycznej będą pozbawieni możliwości wypisywania recept na leki psychotropowe z tzw grupy iv",{"entities": [(15,16, "medical_law"),(25,32, "medical_law"),(237,242, "medical_law")]}),
("czy w przypadku skierowania klientki do pracy przy zwalczaniu epidemii w drodze decyzji wojewody okres pracy ulega wydłużeniu jeżeli klientka będzie na zwolnieniu chorobowym",{"entities": [(88,96, "medical_law")]}),
("czy można cofnąć skierowanie na test w kierunku koronawirusa czy jeśli pacjentka nie wyraża zgody na wykonanie testu to klientka musi zgłosić podejrzenie wystąpienia zakażenia do sanepidu",{"entities": [(39,47, "medical_law"),(154,165, "medical_law"),(142,153, "medical_law"),(48,60, "medical_law"),(101,110, "medical_law"),(10,16, "medical_law"),(32,36, "medical_law"),(17,28, "medical_law")]}),
("czy od  r administratorzy wspólnoty mieszkaniowej niezgodnie z prawem naliczali współwłaścicielom hali garażowej opłaty za partycypowanie w kosztach utrzymania nieruchomości wspólnej jeżeli tak to czy można domagać się zwrotu niesłusznie pobieranych od  r opłat za miejsca w garażu jeżeli odpowiedź na powyższe jest twierdząca czy można wówczas domagać się zapłaty od administratora wspólnoty mieszkaniowej",{"entities": [(174,182, "civil_law"),(149,159, "civil_law"),(98,102, "civil_law"),(140,148, "civil_law"),(103,112, "civil_law")]}),
("czy klient może domagać się wyznaczenia osoby która będzie nadzorować jego pracę kto odpowiada za ewentualne błędy medyczne popełnione przez klienta czy klient może domagać się kolejnego pisma z oddelegowaniem w związku z rozpoczęciem nowego roku kalendarzowego",{"entities": [(187,192, "medical_law"),(195,209, "medical_law")]}),
("czy osoba posiadająca kartę inwalidy zamieszkująca we wspólnocie ale niebędąca właścicielem mieszkania ani członkiem wspólnoty ma prawo do parkowania swojego samochodu na miejscu parkingowym przeznaczonym dla osób niepełnosprawnych czy osoba niebędąca członkiem wspólnoty która jest gościem członka wspólnoty posiadająca kartę inwalidy może parkować samochód na zamkniętym prywatnym terenie wspólnoty mieszkaniowej",{"entities": [(28,36, "administrative_law"),(327,335, "administrative_law"),(214,231, "administrative_law"),(69,78, "administrative_law"),(242,251, "administrative_law"),(139,149, "administrative_law"),(10,21, "administrative_law"),(309,320, "administrative_law"),(22,27, "administrative_law"),(321,326, "administrative_law"),(179,190, "administrative_law")]}),
("czy pozwany powinien zawiadomić sąd o wykonaniu nakazu zapłaty w postępowaniu upominawczym",{"entities": [(4,11, "civil_law")]}),
("czy klient może kontynuować pracę bez ważnych badań okresowych",{"entities": [(38,45, "labor_law"),(16,27, "labor_law")]}),
("czy lekarz poz może zlecić wykonanie testu kontrolnego u pacjentki",{"entities": [(11,14, "medical_law"),(27,36, "medical_law")]}),
("czy jeżeli klient skorzysta ze zwolnienia ze składek zus a następnie uda się na zwolnienie l będzie to wpływało na możliwość skorzystania z ulgi czy możliwe jest skierowanie do pracy przy epidemii klienta bądź jego żonę",{"entities": [(69,72, "medical_law"),(149,156, "medical_law"),(162,173, "medical_law")]}),
("czy klientka może udzielać świadczeń na podstawie umowy o świadczenie usług medycznych",{"entities": [(58,69, "medical_law")]}),
("czy klientka może wystawić matce pacjentki zaświadczenie potwierdzające że prowadziła leczenie jej córki",{"entities": [(43,56, "medical_law")]}),
("czy urlop dodatkowy przewidziany w   zakładowego układu zbiorowego pracy jest urlopem wypoczynkowym i powinien być jako taki traktowany",{"entities": [(10,19, "labor_law"),(86,99, "labor_law"),(78,85, "labor_law"),(37,48, "labor_law")]}),
("czy klientka ma obowiązek pobierania od pacjentów zgody na przetwarzanie danych osobowych",{"entities": [(59,72, "administrative_law")]}),
("co klientka powinna odpowiedzieć narodowemu funduszowi zdrowia czy termin siedmiu dni należy liczyć uwzględniając jedynie dni robocze",{"entities": [(93,99, "pharmaceutical_law")]}),
("czy wypowiedzenie złożone drogą mailową jest skuteczne czy pracodawca ma obowiązek poinformowania klientki o otrzymaniu wypowiedzenia",{"entities": [(18,25, "labor_law"),(83,97, "labor_law")]}),
("jak prawa i obowiązki ma klientka w związku z wezwaniem przez rzecznika odpowiedzialności zawodowej na przesłuchanie w charakterze świadka",{"entities": [(119,130, "criminal_law"),(46,55, "criminal_law"),(62,71, "criminal_law"),(72,89, "criminal_law"),(103,116, "criminal_law")]}),
("czy gdyby klient musiał zmienić stanowisko pracy u obecnego pracodawcy z powodu niezdolności do pracy na obecnym stanowisku  to pracodawca może zmienić jego obecne warunki płacy",{"entities": [(51,59, "labor_law"),(105,112, "labor_law")]}),
("czy klientka może zostać skierowana do pracy na innym oddziale który nie jest związany z jej specjalizacją i umiejętnościami",{"entities": [(78,86, "medical_law")]}),
("w jaki sposób klientka może zabezpieczyć przejście majątku po śmierci matki na jej rzecz",{"entities": [(70,75, "civil_law")]}),
("czy w przypadku wystawienia przez lekarza błędnej elektronicznej recepty ze  odpłatnością podczas gdy jest to lek refundowany pacjent może uzyskać refundację leku po okazaniu decyzji w aptece czy pacjent powinien udać się do lekarza po nową receptę",{"entities": [(114,125, "pharmaceutical_law"),(77,89, "pharmaceutical_law"),(147,157, "pharmaceutical_law")]}),
("czy klient może wydać zaświadczenie o jakie prosi córka potencjalnej pacjentki klienta",{"entities": [(22,35, "medical_law")]}),
("czy osoba wykonująca zlecone czynności w miejscu pracy i w domu w czasie kiedy jest taka potrzeba i raz w tygodniu pracująca w rejestracji w zależności jak przyjmują lekarze może być zatrudniona na umowę zlecenie czy musi na umowę o pracę kto ewentualnie mógłby podważyć charakter takiej umowy",{"entities": [(141,151, "labor_law"),(100,103, "labor_law")]}),
("czy dom pogrzebowy może przesyłać skany faktury papierowej bez zgody klienta",{"entities": [(48,58, "tax_law")]}),
("czy w przedmiotowej sytuacji klientka jest jedynym spadkobiercą jakie kroki powinna podjąć klientka aby przeprowadzić postępowanie spadkowe czy odnalezienie testamentu zmarłego brata matki klientki wpłynęłoby na sprawę spadkową po jego żonie",{"entities": [(183,188, "civil_law"),(51,63, "civil_law"),(131,139, "civil_law"),(219,227, "civil_law"),(157,167, "civil_law")]}),
("co należy zrobić jeśli w sieci pojawią się opinie oczerniające lekarza",{"entities": [(31,38, "administrative_law"),(50,62, "administrative_law"),(25,30, "administrative_law"),(43,49, "administrative_law")]}),
("jakie kroki prawne może podjąć klientka",{"entities": [(0,5, "criminal_law"),(12,18, "criminal_law")]}),
("czy wystawiając rachunek za lipiec klientka może wpisać kwotę  zł w miejsce uprzednio otrzymywanego tzw dodatku zembalowego",{"entities": [(16,24, "medical_law")]}),
("czy w wypadku śmierci krewnej klient musi podjąć jakieś kroki aby stać się pełnoprawnym właścicielem mieszkania czy w wypadku śmierci krewnej klient powinien zrobić coś z posiadanym testamentem",{"entities": [(22,29, "civil_law"),(134,141, "civil_law")]}),
("czy klienta będzie obowiązywać tajemnica lekarska podczas składania na piśmie zeznań przed sądem cywilnym",{"entities": [(71,77, "medical_law"),(58,67, "medical_law"),(78,84, "medical_law")]}),
("jak klient powinien ustosunkować się do wezwania otrzymanego od izby lekarskiej",{"entities": [(49,60, "medical_law")]}),
("czy klient może zastrzec aby wszelka korespondencja była mu doręczana wyłącznie do rąk własnych lub poprzez awizo czy istnieje prawny obowiązek posiadania skrzynki pocztowej przypisanej do mieszkania czy klient może zlikwidować skrzynkę pocztową przypisaną do jego mieszkania czy urzędy administracji publicznej mogą dokonywać doręczeń elektronicznych czy klient może zastrzec że nie chce otrzymywać pism z urzędów drogą elektroniczną",{"entities": [(16,24, "administrative_law"),(368,376, "administrative_law")]}),
("czy klient jest zobowiązany do zainstalowania aplikacji służącej potwierdzeniu realizacji obowiązku przestrzegania kwarantanny czy od obowiązku izolacji w warunkach domowych zostały przewidziane wyjątki",{"entities": [(165,173, "medical_law"),(56,64, "medical_law"),(46,55, "medical_law"),(31,45, "medical_law"),(65,78, "medical_law")]}),
("czy pracodawca może jednostronnie zmniejszyć żonie klienta wymiar czasu pracy z  na  etatu czy w związku ze zmniejszeniem wymiaru zatrudnienia na skutek epidemii obecnie pracownikowi przysługuje jakieś dodatkowe świadczenie czy w przypadku zamknięcia zakładu pracy żona klienta będzie miała możliwość pobierania zasiłku dla bezrobotnych",{"entities": [(122,129, "labor_law"),(34,44, "labor_law"),(170,182, "labor_law")]}),
("jakie dokumenty musi złożyć klientka aby uzasadnić ubieganie się o alimenty od ojca dzieci",{"entities": [(41,50, "civil_law"),(67,75, "civil_law"),(51,60, "civil_law")]}),
("w jaki sposób w zaistniałych okolicznościach najlepiej zabezpieczyć stosunek najmu lokalu użytkowego czy rzeczoną umowę można zabezpieczyć wekslem jaka powinna być treść takiego weksla i jaki powinien to być weksel czy są elementy treści weksla które wynajmujący musi wypełnić w obecności najemcy czy do weksla potrzebne jest porozumienie wekslowe jakie elementy weksla muszą zostać sporządzone odręcznie czy okoliczność że najemca zawarł związek małżeński i między małżonkami nie występuje rozdzielność majątkowa wpływa na kształt weksla i zobowiązania z tego weksla czy w danych sytuacjach konieczny jest poręczyciel jeśli tak to czy do weksla wymaganych jest więcej niż jeden poręczyciel jakie są jego obowiązki czy musi on posiadać jakieś szczególne dokumenty",{"entities": [(251,262, "civil_law"),(178,184, "civil_law"),(238,244, "civil_law"),(304,310, "civil_law"),(363,369, "civil_law"),(532,538, "civil_law"),(561,567, "civil_law"),(639,645, "civil_law"),(268,276, "civil_law"),(311,320, "civil_law"),(90,100, "civil_law"),(592,601, "civil_law"),(289,296, "civil_law"),(447,456, "civil_law"),(424,431, "civil_law"),(439,446, "civil_law"),(383,394, "civil_law"),(607,618, "civil_law"),(679,690, "civil_law"),(222,230, "civil_law"),(354,362, "civil_law")]}),
("czy w przedmiotowej sprawie doszło do popełnienia przestępstwa czy sprawę należy zgłosić na policję i jeżeli tak to kto powinien to zrobić  lekarz czy farmaceuta czy klientka może ponosić odpowiedzialność dyscyplinarną",{"entities": [(38,49, "criminal_law"),(140,146, "criminal_law"),(50,62, "criminal_law")]}),
("w jaki sposób przebiega odczytanie testamentu czym skutkuje wydziedziczenie testamentowe",{"entities": [(60,75, "civil_law"),(51,59, "civil_law"),(14,23, "civil_law"),(35,45, "civil_law")]}),
("czy w przedmiotowej sytuacji klientka jest jedynym spadkobiercą jakie kroki powinna podjąć klientka aby przeprowadzić postępowanie spadkowe czy odnalezienie testamentu zmarłego brata matki klientki wpłynęłoby na sprawę spadkową po jego żonie",{"entities": [(183,188, "civil_law"),(51,63, "civil_law"),(131,139, "civil_law"),(219,227, "civil_law"),(157,167, "civil_law")]}),
("czy jeśli w aptece znajduje się szyba pomiędzy farmaceutą a pacjentem to czy farmaceuta musi nosić maseczkę",{"entities": [(60,69, "medical_law"),(93,98, "medical_law"),(32,37, "medical_law"),(12,18, "medical_law")]}),
("czy w ramach indywidualnej praktyki lekarskiej wyłącznie w miejscu wezwania możliwe jest świadczenie usług dla podmiotu leczniczego np poz jeżeli odpowiedź na powyższe pytanie jest twierdząca czy w przypadku świadczenia usługw podmiocie leczniczym klient mógłby wystawiać recepty na swoją indywidualną praktykę lekarską wyłącznie w miejscu wezwania czy przepisy prawa określają w sposób wyczerpujący sprzęt jaki powinien posiadać lekarz prowadzący indywidualną praktykę lekarską wyłącznie w miejscu wezwania",{"entities": [(368,377, "medical_law"),(159,167, "medical_law"),(135,138, "medical_law"),(13,26, "medical_law"),(227,236, "medical_law"),(89,100, "medical_law"),(237,247, "medical_law"),(76,83, "medical_law")]}),
("czy szkolenie organizowane przez pracodawcę może się odbyć termin szkolenia został wyznaczony na przyszły tydzień",{"entities": [(14,26, "medical_law"),(4,13, "medical_law"),(66,75, "medical_law")]}),
("czy na klientce ciąży obowiązek zgłoszenia do jakiegoś organu informacji o zajściuw ciążę przez siedemnastoletnią pacjentkę",{"entities": [(62,72, "criminal_law"),(16,21, "criminal_law")]}),
("jakie kroki należy podjąć aby dokonać przeniesienia własności apteki oraz przeniesienia zezwolenia na prowadzenie apteki na nabywcę co stanie się z umową najmu lokalu w którym prowadzona jest apteka",{"entities": [(88,98, "pharmaceutical_law"),(124,131, "pharmaceutical_law")]}),
("czy osoba posiadająca kartę inwalidy zamieszkująca we wspólnocie ale niebędąca właścicielem mieszkania ani członkiem wspólnoty ma prawo do parkowania swojego samochodu na miejscu parkingowym przeznaczonym dla osób niepełnosprawnych czy osoba niebędąca członkiem wspólnoty która jest gościem członka wspólnoty posiadająca kartę inwalidy może parkować samochód na zamkniętym prywatnym terenie wspólnoty mieszkaniowej",{"entities": [(28,36, "administrative_law"),(327,335, "administrative_law"),(214,231, "administrative_law"),(69,78, "administrative_law"),(242,251, "administrative_law"),(139,149, "administrative_law"),(10,21, "administrative_law"),(309,320, "administrative_law"),(22,27, "administrative_law"),(321,326, "administrative_law"),(179,190, "administrative_law")]}),
("czy pracodawca może oddelegować lekarza rezydenta do pracy na oddziale covidowym czy pracodawca może zmusić lekarza rezydenta do zawarcia umowy zlecenia na dyżury medyczne",{"entities": [(101,107, "medical_law")]}),
("czy klientka może być skierowana do zwalczania epidemii decyzją wojewody",{"entities": [(56,63, "medical_law"),(18,21, "medical_law")]}),
("czy zarządca nieruchomości któremu deweloper powierzył zarząd nieruchomością wspólnąw formie aktu notarialnego może zrezygnować z zarządu i samodzielnie przekazać zarząd nieruchomością innemu podmiotowi bez angażowania w to wspólnoty mieszkaniowej",{"entities": [(98,110, "civil_law"),(4,12, "civil_law"),(35,44, "civil_law"),(55,61, "civil_law"),(163,169, "civil_law"),(62,76, "civil_law"),(170,184, "civil_law")]}),
("czy lekarz może odmówić pacjentowi badania jeżeli ten nie zgadza się na założenie maseczki ochronnej jeżeli tak to w oparciu o jaką podstawę prawną",{"entities": [(132,140, "medical_law"),(127,131, "medical_law"),(24,34, "medical_law")]}),
("czy tzw zejście lekarza po dyżurze wlicza się do czasu pracy lekarza rezydenta i należy się za ten czas wynagrodzenie czy powyższa kwestia została uregulowana w przepisach powszechnie obowiązujących",{"entities": [(161,171, "medical_law"),(99,103, "medical_law"),(147,158, "medical_law"),(8,15, "medical_law"),(27,34, "medical_law")]}),
("czy klientka może wystosować do zarządu spółki pismo z prośbą o wcześniejsze ustalanie terminu nadzwyczajnego lub zwyczajnego zgromadzenia wspólników jeszcze przed wysłaniem listu powiadamiającego przez zarząd",{"entities": [(126,138, "civil_law"),(55,61, "civil_law")]}),
("czy ustna umowa dot zmiany warunków pracy i płacy jest wiążąca czy klientka może domagać się zatrudnienia na nowych warunkach co mogłaby zrobić klientka gdyby pracodawca nie zgodził się na zmianę warunków pracy i płacy",{"entities": [(55,62, "labor_law"),(44,49, "labor_law"),(27,35, "labor_law"),(196,204, "labor_law"),(189,195, "labor_law"),(4,9, "labor_law")]}),
("czy klientka może usunąć zęba pacjentce bez zgody rodzica",{"entities": [(30,39, "medical_law")]}),
("czy ojczym może kwestionować wartość spadku czy ojczym może żądać partycypacji w kosztach utrzymania nieruchomości czy ojczym może żądać rozbicia świadczenia na raty",{"entities": [(90,100, "civil_law"),(66,78, "civil_law"),(29,36, "civil_law"),(81,89, "civil_law"),(4,10, "civil_law"),(48,54, "civil_law"),(119,125, "civil_law")]}),
("czy choroba klienta wpływa w jakiś sposób na jego postępowanie kwalifikacyjne czy klientowi przysługują dodatkowe uprawnienia w związku z chorobą",{"entities": [(4,11, "medical_law"),(104,113, "medical_law"),(63,77, "medical_law")]}),
("co może zrobić kobieta wobec swojego męża który stosuje wobec niej przemoc psychiczną i fizyczną jakie kary mogą spotkać osobę stosującą przemoc w rodzinie wobec żony",{"entities": [(97,102, "criminal_law"),(67,74, "criminal_law"),(137,144, "criminal_law")]}),
("w jaki sposób klient może uchronić się przed odziedziczeniem długów po swoich spadkodawcach",{"entities": [(61,67, "civil_law"),(45,60, "civil_law")]}),
("czy klientka może wystawić receptę na nazwisko pacjenta w podwójnej dawce w tym jednej dla partnera pacjenta",{"entities": [(27,34, "pharmaceutical_law"),(58,67, "pharmaceutical_law")]}),
("czy możliwym jest darowanie kwoty  zł czy jeżeli obdarowana jest córką darczyńcy powstanie konieczność uiszczenia podatku od darowizn",{"entities": [(18,27, "civil_law"),(103,113, "civil_law"),(4,12, "civil_law")]}),
("w jaki sposób przebiega odczytanie testamentu czym skutkuje wydziedziczenie testamentowe",{"entities": [(60,75, "civil_law"),(51,59, "civil_law"),(14,23, "civil_law"),(35,45, "civil_law")]}),
("czy pracownikowi przysługuje urlop szkoleniowy w wymiarze  dni",{"entities": [(4,16, "labor_law")]}),
("czy apteka ogólnodostępna może podjąć współpracę z dietetykiem w ramach której w ustalonych dniachgodzinach w danym miesiącu dietetyk byłby dostępny dla pacjentów apteki celem udzielenia porad dietetycznych",{"entities": [(11,25, "pharmaceutical_law"),(140,148, "pharmaceutical_law")]}),
("czy pracodawca może zmniejszyć etat matce klientki czy pracodawca może oddelegować klientkę do innej apteki",{"entities": [(20,30, "labor_law")]}),
("czy lekarz może wnosić o zapłatę za stwierdzenie zgonu jeżeli jego umowa o pełnienie dyżurów medycznych nie przewiduje takich obowiązków",{"entities": [(49,54, "medical_law"),(75,84, "medical_law")]}),
("czy apteka może prowadzić internetową sprzedaż suplementów diety i kosmetyków jakich formalności powinna dopełnić klientka celem rozpoczęcia takiej działalności",{"entities": [(67,77, "pharmaceutical_law"),(26,37, "pharmaceutical_law")]}),
("jakich formalności powinien dokonać lekarz pochodzący z ukrainy aby mógł pracować na terytorium polski",{"entities": [(56,63, "medical_law"),(73,81, "medical_law"),(85,95, "medical_law")]}),
("czy pracodawca może oddelegować lekarza rezydenta do dyżurowania na sor",{"entities": [(53,64, "medical_law")]}),
("czy klientka ma obowiązek podpisać regulamin miejsca pracy czy klientka będzie zobowiązana do przestrzegania regulaminu miejsca pracy nawet jeżeli go nie podpisze",{"entities": [(35,44, "labor_law")]}),
("co należy rozumieć przez choroby przewlekłe o których mowa w art  ust  pkt  ustawy o zapobieganiu oraz zwalczaniu zakażeń i chorób zakaźnych u ludzi czy klientce grozi odpowiedzialność karna w przypadku złożenia fałszywego oświadczenia",{"entities": [(143,148, "criminal_law"),(25,32, "criminal_law"),(85,97, "criminal_law"),(103,113, "criminal_law"),(76,82, "criminal_law"),(162,167, "criminal_law"),(10,18, "criminal_law")]}),
("jak długo należy przechowywać zapotrzebowania na zakup leków",{"entities": [(30,45, "pharmaceutical_law")]}),
("czy w związku z ostatnimi zmianami przepisów co do uprawnień wymaganych przy zakupie ziemi rolnej klient mimo że posiadał wcześniej ziemię rolną poniżej  ha musi posiadać aktualne uprawnienia wykonany kurs do zakupu ziemi rolnej",{"entities": [(139,144, "administrative_law"),(91,97, "administrative_law"),(26,34, "administrative_law"),(113,121, "administrative_law"),(85,90, "administrative_law"),(216,221, "administrative_law")]}),
("czy klient może przeprowadzać badanie kwalifikacyjne przed szczepieniem na covid",{"entities": [(59,71, "medical_law"),(38,52, "medical_law")]}),
("czy zamontowanie instalacji fotowoltaicznej zwiększy wymiar podatku od nieruchomości",{"entities": [(60,67, "tax_law")]}),
("czy pracodawca lekarza rezydenta może żądać zakazu konkurencji czy lekarz rezydent może nie podpisać takiego zakazu i jakie są tego konsekwencje czy wypowiedzenie umowy o pracę z powodu niepodpisania klauzuli o zakazie konkurencji może być powodem wypowiedzenia umowy o pracę co może obejmować zakaz konkurencji lekarza rezydenta",{"entities": [(51,62, "medical_law"),(219,230, "medical_law"),(300,311, "medical_law"),(284,293, "medical_law"),(74,82, "medical_law"),(236,239, "medical_law"),(200,208, "medical_law")]}),
("czy dyrekcja miała prawo do odmowy udzielenia zgód",{"entities": [(35,45, "medical_law")]}),
("czy klientka pełniąca dyżur w macierzystym oddziale może zostać oddelegowana do jednoczesnego odbywania dyżuru na sor czy klientka musi pełnić dyżur jeżeli otrzymała polecenie służbowe w tym zakresie tego samego dnia czy klientka musi stosować się do polecenia służbowego jeżeli jest ono przekazywane przez pracowników sor",{"entities": [(22,27, "medical_law"),(143,148, "medical_law"),(104,110, "medical_law"),(136,142, "medical_law"),(307,318, "medical_law"),(205,211, "medical_law"),(176,184, "medical_law"),(30,42, "medical_law"),(235,243, "medical_law")]}),
("czy w obecnej sytuacji dzieci sióstr które odrzuciły spadek wchodzą w krąg spadkobierców czy siostry mogą odrzucić spadek w imieniu małoletnich dzieci czy jeżeli dzieci sióstr dziedziczą po ojcu klienta to czy spadkobiercy mogą sprzedać mieszkanie które wchodzi w skład spadku bez zgody tych dzieci",{"entities": [(106,114, "civil_law"),(132,143, "civil_law"),(30,36, "civil_law"),(169,175, "civil_law"),(264,269, "civil_law"),(254,261, "civil_law"),(70,74, "civil_law"),(53,59, "civil_law"),(115,121, "civil_law"),(75,88, "civil_law"),(210,222, "civil_law"),(190,194, "civil_law")]}),
("czy klientka w piśmie do pełnomocnika może zawrzeć informacje na temat procesu leczenia pacjentki",{"entities": [(15,21, "medical_law")]}),
("czy w związku z powstaniem szpitala jednoimiennego klientka będzie mogła w nim pełnić dyżury medyczne i jednocześnie uczęszczać na staż do innej jednostki szpitala",{"entities": [(79,85, "medical_law"),(145,154, "medical_law"),(131,135, "medical_law")]}),
("jakie przepisy regulują kwestię przeprowadzania badań okresowych maszynistów w czasie pandemii co może zrobić pracownik jeśli mimo zawieszenia obowiązku wykonywania badań okresowych pracodawca poleca mu wykonanie takich badań",{"entities": [(65,76, "labor_law"),(54,64, "labor_law"),(171,181, "labor_law")]}),
("czy recepty na których przepisano wyłącznie produkty lecznicze niepodlegające refundacji mogą być wydawane na wzorach druków recept sprzed nowelizacji",{"entities": [(53,62, "pharmaceutical_law"),(78,88, "pharmaceutical_law")]}),
("w jaki sposób należałoby zaplanować dyżury medyczne klienta by uczynić zadość wymogowi pełnienia ich w wymiarze  godzin  minut tygodniowo",{"entities": [(87,96, "medical_law"),(103,111, "medical_law")]}),
("ile ryczałtu można wziąć na leki recepturowe",{"entities": [(19,24, "pharmaceutical_law")]}),
("czy klient może wykonywać znieczulenia na oddziale chirurgii jeżeli nie jest zatrudniony jako anestezjolog na oddziale anestezjologicznym",{"entities": [(77,88, "medical_law"),(26,38, "medical_law")]}),
("czy klient powinien ponosić koszty odstąpienia od umowy o imprezę turystyczną",{"entities": [(20,27, "medical_law")]}),
("w jaki sposób siostra klientki może zrzec się roszczenia o zachowek w stosunku do klientki",{"entities": [(14,21, "civil_law"),(59,67, "civil_law")]}),
("czy gdyby klientka chciała pracować w innym podmiocie leczniczym to czy zgodnie z prawem może świadczyć tam usługi medyczne przy kwalifikacji do szczepień ochronnych przeciwko covid",{"entities": [(155,165, "medical_law"),(27,35, "medical_law"),(44,53, "medical_law"),(54,64, "medical_law"),(145,154, "medical_law"),(94,103, "medical_law")]}),
("czy umowa zawarta z agencją mienia wojskowego może przewidywać że wspólnota będzie zobowiązana do ponoszenia kosztów utrzymania użyczonej nieruchomości czy wspólnota może żądać użyczenia części a nie całości działki czy przepisy powszechnie obowiązujące regulują kwestię częstotliwości prześwietlania drzew na nieruchomości",{"entities": [(117,127, "civil_law"),(98,108, "civil_law"),(200,207, "civil_law")]}),
("czy klientce będzie przysługiwać tzw świadczenie postojowe",{"entities": [(37,48, "medical_law")]}),
("czy klientka powinna przekazać dokumentację medyczną czy klientka powinna odpowiedzieć na pytania dotyczące leczenia pacjentki na żądanie sądu",{"entities": [(21,30, "medical_law"),(74,86, "medical_law")]}),
("czy wniosek o skrócenie kary ograniczenia wolności może zostać złożony przez pracodawcę skazanej",{"entities": [(42,50, "criminal_law"),(77,87, "criminal_law")]}),
("czy dodatek covidowy jest składnikiem wynagrodzenia jak powinno kształtować się wynagrodzenie klientki",{"entities": [(56,63, "medical_law"),(12,20, "medical_law"),(64,75, "medical_law")]}),
("w jakim czasie pracownik powinien zostać poinformowany o tym że pracodawca będzie żądał od niego zwrotu kosztów związanych z naruszeniem obowiązków pracowniczych czy pracownik jest zobowiązany do podpisania proponowanej przez pracodawcę ugody",{"entities": [(148,161, "labor_law")]}),
("czy wykonywanie pracy przy szczepieniach przeciwko covid w ramach umowy cywilnoprawnej zlecenia koliduje z otrzymywaniem dodatku covidowego przysługującego z tytułu zatrudnienia na podstawie umowy o pracę",{"entities": [(158,164, "medical_law"),(4,15, "medical_law"),(72,86, "medical_law"),(129,139, "medical_law"),(27,40, "medical_law")]}),
("co klientka może zrobić z dokumentacją medyczną zgromadzoną w formie papierowej",{"entities": [(26,38, "medical_law")]}),
("czy szkolenie organizowane przez pracodawcę może się odbyć termin szkolenia został wyznaczony na przyszły tydzień",{"entities": [(14,26, "medical_law"),(4,13, "medical_law"),(66,75, "medical_law")]}),
("co należy zrobić jeśli w sieci pojawią się opinie oczerniające lekarza",{"entities": [(31,38, "administrative_law"),(50,62, "administrative_law"),(25,30, "administrative_law"),(43,49, "administrative_law")]}),
("jakie kroki prawne może podjąć rodzina po zmarłym w celu wyegzekwowania przeprowadzenia sekcji zwłok  czy klientka musi przeprowadzić sekcję zwłok w przypadku niemożliwości ustalenia przyczyn zgonu pacjenta",{"entities": [(0,5, "criminal_law"),(12,18, "criminal_law"),(173,182, "criminal_law"),(95,100, "criminal_law"),(141,146, "criminal_law"),(88,94, "criminal_law"),(72,87, "criminal_law")]}),
("czy nieruchomość jest obciążona hipoteką lub innymi prawami osób trzecich co oznacza wpis dotyczący migracji w dziale iv księgi wieczystej",{"entities": [(121,127, "civil_law"),(90,99, "civil_law"),(32,40, "civil_law")]}),
("w jaki sposób klientka może wyegzekwować zaległe wynagrodzenie od pracodawcy czy klientka może rozwiązać umowę o pracę bez okresu wypowiedzenia z winy pracodawcy w związku z brakiem zapłaty zaległego wynagrodzenia",{"entities": [(146,150, "labor_law"),(174,181, "labor_law"),(41,48, "labor_law")]}),
("czy szpital musi przystąpić do pracowniczych planów kapitałowych czy pracownicy mogą nie zgodzić się na przystąpienie do pracowniczych planów kapitałowych jeżeli szpital przystąpi do pracowniczych planów kapitałowych to czy pracownicy mogą indywidualnie od nich odstąpić",{"entities": [(69,79, "labor_law"),(224,234, "labor_law"),(52,64, "labor_law"),(142,154, "labor_law"),(204,216, "labor_law"),(31,44, "labor_law"),(121,134, "labor_law"),(183,196, "labor_law"),(45,51, "labor_law"),(135,141, "labor_law"),(197,203, "labor_law"),(89,96, "labor_law")]}),
("czy w wypadku śmierci krewnej klient musi podjąć jakieś kroki aby stać się pełnoprawnym właścicielem mieszkania czy w wypadku śmierci krewnej klient powinien zrobić coś z posiadanym testamentem",{"entities": [(22,29, "civil_law"),(134,141, "civil_law")]}),
("czy w przypadku zmiany architekta klientka będzie zobowiązana zapłacić całe umówione wynagrodzenie obecnemu architektowi czy w przypadku zmiany architekta obecny architekt nadal będzie musiał dokonywać wpisów w dzienniku budowy",{"entities": [(23,33, "administrative_law"),(144,154, "administrative_law"),(43,49, "administrative_law"),(178,184, "administrative_law")]}),
("jak klient ma się zachować w związku z wezwaniem na przesłuchanie w charakterze świadka",{"entities": [(68,79, "criminal_law"),(39,48, "criminal_law"),(52,65, "criminal_law")]}),
("czy możliwa jest sprzedaż punktu aptecznego prowadzonego w formie jednoosobowej działalności gospodarczej wraz przeniesieniem zezwolenia na prowadzenie punktu aptecznego",{"entities": [(33,43, "pharmaceutical_law"),(111,125, "pharmaceutical_law"),(126,136, "pharmaceutical_law"),(26,32, "pharmaceutical_law"),(152,158, "pharmaceutical_law"),(66,79, "pharmaceutical_law")]}),
("w jaki sposób klientka może poinformować pacjenta o tym że odstępuje od leczenia jeżeli klientka zdecyduje się na rozmowę telefoniczną to czy może nagrać tą rozmowę jeżeli klientka zdecyduje się na rozmowę z pacjentem to czy przy tej rozmowie może być obecny inny lekarz jak należy rozumieć pojęcie nieudzielenia pomocy w niebezpieczeństwie utraty życia ciężkiego uszkodzenia ciała lub ciężkiego rozstroju zdrowia",{"entities": [(348,353, "criminal_law"),(114,121, "criminal_law"),(157,164, "criminal_law"),(198,205, "criminal_law"),(97,106, "criminal_law"),(181,190, "criminal_law"),(28,40, "criminal_law"),(264,270, "criminal_law"),(354,363, "criminal_law"),(386,395, "criminal_law"),(282,290, "criminal_law")]}),
("w jaki sposób klient może domagać się wypłaty dodatku w pełnej wysokości",{"entities": [(56,62, "medical_law"),(38,45, "medical_law")]}),
("jakie kroki może podjąć klientka aby bank odblokował jej środki znajdujące się na rachunku bankowym",{"entities": [(64,74, "civil_law")]}),
("jaka dokumentacja powinna towarzyszyć dostawie suplementów diety która jest przyjmowana w hurtowni farmaceutycznej czy suplement diety w formie półproduktu może zostać przyjęty w hurtowni farmaceutycznej",{"entities": [(161,167, "pharmaceutical_law"),(90,98, "pharmaceutical_law"),(179,187, "pharmaceutical_law"),(99,114, "pharmaceutical_law")]}),
("czy odmowa ergo hestii jest zasadna jakie kroki może podjąć klient aby uzyskać odszkodowanie",{"entities": [(28,35, "civil_law")]}),
("czy klient jest zobowiązany do zapłaty całej kwoty na rzecz szpitala w przedmiotowej sprawie czy ugoda zawarta pomiędzy szpitalem a klientem jest bezwzględnie wiążąca",{"entities": [(120,129, "medical_law"),(103,110, "medical_law")]}),
("czy działalność dewelopera wypełnia znamiona przestępstwa oszustwa jakie kroki w przedmiotowej sprawie powinna podjąć mąż klientki",{"entities": [(67,72, "criminal_law"),(36,44, "criminal_law"),(27,35, "criminal_law"),(45,57, "criminal_law")]}),
("czy klient musi być reprezentowany w procesie od początku do końca czy wobec cofnięcia pełnomocnictwa klient może otrzymać zwrot kosztów zastępstwa procesowego",{"entities": [(87,101, "civil_law"),(61,66, "civil_law"),(20,34, "civil_law")]}),
("czy dyrekcja miała prawo do odmowy udzielenia zgód",{"entities": [(35,45, "medical_law")]}),
("czy pracodawca może oddelegować lekarza rezydenta do pracy w szpitalnym oddziale ratunkowym",{"entities": [(61,71, "medical_law")]}),
("czy pracownik apteki posiadający specjalizację i stopnia ma tytuł specjalisty",{"entities": [(21,32, "pharmaceutical_law")]}),
("czy klientka ma obowiązek posiadania kasy fiskalnej",{"entities": [(26,36, "tax_law")]}),
("czy w opisanych przez klientkę warunkach przeprowadzenie teleporady jest zgodnez prawem gdzie rodzice dziecka mogą zgłosić zaistniałą sytuację gdyby okazało się że postępowanie lekarza jest niezgodne z prawem",{"entities": [(57,67, "medical_law"),(149,156, "medical_law"),(41,56, "medical_law")]}),
("czy farmaceuta może wystawić receptę pro familiae na lek antykoncepcyjny",{"entities": [(37,40, "pharmaceutical_law"),(29,36, "pharmaceutical_law"),(41,49, "pharmaceutical_law")]}),
("czy konkurencyjna firma może żądać aby klient zaprzestał sprzedaży danego modelu krzeseł",{"entities": [(4,17, "international_law")]}),
("czy klientowi przysługuje  dodatek do wynagrodzenia za cały dyżur czy tylko za jego część czy w związku z tym klientka powinna czekać na wypłatę dodatku i następnie się odwoływać od jego nieprawidłowej wysokości czy sprawę od razu przekazać prawnikom",{"entities": [(231,240, "medical_law"),(60,65, "medical_law")]}),
("na jaki okres czasu może być zastosowane tymczasowe aresztowanie jak kształtują się prawa i obowiązki pracownika oraz pracodawcy w przypadku tymczasowego aresztowania czy pracownik tymczasowo aresztowany może zostać zwolniony z pracy",{"entities": [(102,112, "criminal_law"),(69,79, "criminal_law")]}),
("czy klient ma możliwości skutecznego odwołania się od decyzji wojewody o skierowaniu do pracy przy zwalczaniu epidemii",{"entities": [(73,84, "medical_law"),(62,70, "medical_law")]}),
("czy klient może udzielać świadczeń zdrowotnych pacjentom którzy nie są chorzy na covid czy klient jest obowiązany do odbycia kwarantanny",{"entities": [(117,124, "medical_law")]}),
("jaka odpowiedzialność grozi klientowi w przedmiotowej sprawie czy klient powinien odpowiadać wyczerpująco w odpowiedzi na skargę czy bardziej wskazane wydaje się zachowanie na tym etapie powściągliwości i oczekiwanie na dalszy rozwój wydarzeń",{"entities": [(180,186, "medical_law"),(142,150, "medical_law")]}),
("jakie wynagrodzenie przysługuję lekarzowi rezydentowi skierowanemu przez wojewodę do pracy przy zwalczaniu covid jakie inne uprawnienia przysługują lekarzowi rezydentowi skierowanemu do pracy przy zwalczaniu covid",{"entities": [(54,66, "medical_law"),(170,182, "medical_law"),(42,53, "medical_law"),(158,169, "medical_law"),(73,81, "medical_law")]}),
("jakie są podstawy odpowiedzialności lekarza prowadzącego indywidualną praktykę lekarską",{"entities": [(9,17, "medical_law"),(44,56, "medical_law")]}),
("czy klientka może wraz z siostrą wystąpić do sądu o zgodny dział spadku po ich matce czy należy poczekać na otwarcie testamentu po babci czy przed otwarciem testamentu klientka powinna uzyskać akt poświadczenia dziedziczenia po babci czy wystarczy że podczas ogłoszenia testamentu przedstawi postanowienie sądu ostwierdzeniu nabycia spadku po swojej matce czy we wniosku o dział spadku po matce klientki konieczne jest wymienienie wszystkich darowizn otrzymanych od matki klientki oraz dołączenie potwierdzeń przelewu lub umów darowizny czy jeżeli we wniosku o zgodny dział spadku nie zostanie wymieniona któraś z darowizn to czy można tę darowiznę uwzględnić przy dochodzeniu zachowku",{"entities": [(466,471, "civil_law"),(527,536, "civil_law"),(497,508, "civil_law"),(59,64, "civil_law"),(373,378, "civil_law"),(568,573, "civil_law"),(649,659, "civil_law"),(442,450, "civil_law"),(614,622, "civil_law"),(211,224, "civil_law"),(639,648, "civil_law"),(131,136, "civil_law"),(228,233, "civil_law"),(509,517, "civil_law"),(117,127, "civil_law"),(157,167, "civil_law"),(270,280, "civil_law"),(292,305, "civil_law")]}),
("czy farmaceuta jest uprawniony do wystawiania recept pro familiae i pro auctore",{"entities": [(53,56, "pharmaceutical_law"),(68,71, "pharmaceutical_law"),(57,65, "pharmaceutical_law")]}),
("co klientka powinna odpowiedzieć narodowemu funduszowi zdrowia czy termin siedmiu dni należy liczyć uwzględniając jedynie dni robocze",{"entities": [(93,99, "pharmaceutical_law")]}),
("jakie przesłanki musi spełniać izba przyjęć aby była uznana przez szpital jako izba przyjęć",{"entities": [(31,35, "medical_law"),(79,83, "medical_law"),(53,59, "medical_law"),(6,16, "medical_law")]}),
("czy w przypadku wystawienia przez lekarza błędnej elektronicznej recepty ze  odpłatnością podczas gdy jest to lek refundowany pacjent może uzyskać refundację leku po okazaniu decyzji w aptece czy pacjent powinien udać się do lekarza po nową receptę",{"entities": [(114,125, "pharmaceutical_law"),(77,89, "pharmaceutical_law"),(147,157, "pharmaceutical_law")]}),
("czy podmiot leczniczy zlecający badania diagnostyczne pacjenta do innego podmiotu leczniczego powinien zawrzeć umowę powierzenia przetwarzania danych osobowych czy w przypadku stosowania przepisu art  ust  pkt  ustawy o prawach pacjentai rzeczniku praw pacjenta należy z podmiotem z którym współpracuje się regularniew zakresie wykonywania badań diagnostycznych podpisać umowę o powierzeniu przetwarzania danych przyjmując że zachodzi sytuacja kiedy oba podmioty lecznicze są odrębnymi administratorami danych",{"entities": [(290,302, "administrative_law"),(129,142, "administrative_law"),(391,404, "administrative_law"),(346,361, "administrative_law"),(187,195, "administrative_law"),(426,434, "administrative_law")]}),
("czy przebywając na urlopie wypoczynkowym można podjąć zatrudnienie o innego pracodawcy",{"entities": [(27,40, "labor_law"),(4,15, "labor_law"),(54,66, "labor_law")]}),
("czy klient może wyjaśnić zaistniałą sytuację podając szczegółową historię choroby innych pacjentek",{"entities": [(82,88, "medical_law")]}),
("w jakich sytuacjach psycholog który w trakcie terapii poweźmie informację o popełnieniu przestępstwa ma obowiązek zgłosić ten fakt organom ścigania czy psycholog zobowiązany jest poinformować pacjenta że dokona odpowiedniego zgłoszenia do organów ścigania",{"entities": [(126,130, "criminal_law"),(139,147, "criminal_law"),(76,87, "criminal_law"),(179,191, "criminal_law"),(88,100, "criminal_law"),(54,62, "criminal_law"),(131,138, "criminal_law"),(239,246, "criminal_law"),(20,29, "criminal_law"),(152,161, "criminal_law"),(9,19, "criminal_law")]}),
("czy zarząd dużej wspólnoty mieszkaniowej może żądać udostępnienia informacji o osobach które pobierają dodatek mieszkaniowy z miejskiego ośrodka pomocy społecznej",{"entities": [(137,144, "administrative_law")]}),
("czy dodatek do wynagrodzenia przysługuje lekarzowi świadczącemu usługi medyczne na rzecz pacjentów zakażonych covid w szpitalu tymczasowym czy dodatek do wynagrodzenia w maksymalnej kwocie  tys jest przyznawany na daną osobę czy na miejsce pracy tj czy pracując w więcej niż jednym podmiocie leczniczym należy się dodatek do każdego wynagrodzenia",{"entities": [(282,291, "medical_law"),(219,224, "medical_law"),(292,302, "medical_law"),(127,138, "medical_law"),(275,281, "medical_law"),(99,109, "medical_law")]}),
("czy prezes urzędu ochrony danych osobowych może nałożyć karę pieniężną na portal znanylekarzpl za niezgodne z prawem udostępnianie danych osobowych klienta czy klient może dochodzić odszkodowania i zadośćuczynienia od portalu znanylekarzpl za niezgodne z prawem udostępnianie danych osobowych",{"entities": [(117,130, "administrative_law"),(262,275, "administrative_law"),(218,225, "administrative_law"),(74,80, "administrative_law"),(81,94, "administrative_law"),(226,239, "administrative_law"),(98,107, "administrative_law"),(243,252, "administrative_law")]}),
("czy szkolenie organizowane przez pracodawcę może się odbyć termin szkolenia został wyznaczony na przyszły tydzień",{"entities": [(14,26, "medical_law"),(4,13, "medical_law"),(66,75, "medical_law")]}),
("jakie przesłanki musi spełniać izba przyjęć aby była uznana przez szpital jako izba przyjęć",{"entities": [(31,35, "medical_law"),(79,83, "medical_law"),(53,59, "medical_law"),(6,16, "medical_law")]}),
("co klientka powinna odpowiedzieć narodowemu funduszowi zdrowia czy termin siedmiu dni należy liczyć uwzględniając jedynie dni robocze",{"entities": [(93,99, "pharmaceutical_law")]}),
("co może zrobić klient w związku z zachowaniem pracodawcy",{"entities": [(34,45, "labor_law")]}),
("z jakiego powodu sąd nie zdecydował się na rozpatrzenie sprawy w postępowaniu nakazowym",{"entities": [(43,55, "civil_law")]}),
("czy klientkę obowiązują nowe przepisy dotyczące obowiązku prowadzenia kasy fiskalnej online",{"entities": [(48,57, "tax_law")]}),
("w jaki sposób gabinet lekarski klienta może sprowadzić preparaty witaminowe z innego kraju unii europejskiej",{"entities": [(44,54, "pharmaceutical_law"),(55,64, "pharmaceutical_law"),(65,75, "pharmaceutical_law")]}),
("czy klient ma obowiązek się zarejestrować w bdo w jaki sposób klient może się zarejestrować",{"entities": [(28,41, "administrative_law")]}),
("czy klient musi uwzględnić w przychodzie pożyczę otrzymaną z urzędu pracy w ramach wsparcia przedsiębiorców w okresie epidemii covid czy klient musi od tej kwoty zapłacić podatek",{"entities": [(162,170, "medical_law")]}),
("czy osoba przebywająca na urlopie wychowawczym jest w dalszym ciągu traktowana jako członek związku zawodowego",{"entities": [(68,78, "labor_law"),(34,46, "labor_law")]}),
("czy w przypadku skierowania klientki do pracy przy zwalczaniu epidemii w drodze decyzji wojewody okres pracy ulega wydłużeniu jeżeli klientka będzie na zwolnieniu chorobowym",{"entities": [(88,96, "medical_law")]}),
("jaki okres wypowiedzenia znajduje zastosowanie w sytuacji klientki czy przepisy określają maksymalną liczbę godzin jakie pracownik może przepracowaćw trakcie weekendu",{"entities": [(34,46, "labor_law"),(25,33, "labor_law")]}),
("czy klient może zawrzeć umowę w przedmiocie pełnienia funkcji kierownika specjalizacji w ramach swojej działalności gospodarczej",{"entities": [(44,53, "medical_law"),(54,61, "medical_law")]}),
("czy informacja o tym że pacjent wyraził zgodę wystarczy do udostepnienia informacji czy też towarzystwo ubezpieczeniowe powinno przedstawić kopię tej zgody",{"entities": [(32,39, "medical_law"),(128,139, "medical_law"),(120,127, "medical_law"),(40,45, "medical_law")]}),
("czy klientka może zrezygnować z odbywania dyżurów w związku z opieką nad miesięcznym dzieckiem czy dotyczy to tylko dyżurów samodzielnych czy może również towarzyszących czy klientka będzie musiała odrobić dyżury których nie pełniła z powodów zdrowotnych gdy pracowała będąc w ciąży w  r",{"entities": [(124,137, "medical_law"),(18,29, "medical_law")]}),
("czy na receptach spoza ue zagranicznych np z ukrainy na rewersie należy wpisywać dane paszportu",{"entities": [(56,64, "pharmaceutical_law"),(7,16, "pharmaceutical_law"),(72,80, "pharmaceutical_law")]}),
("czy klient jest zobowiązany do zainstalowania aplikacji służącej potwierdzeniu realizacji obowiązku przestrzegania kwarantanny",{"entities": [(56,64, "medical_law"),(46,55, "medical_law"),(31,45, "medical_law"),(65,78, "medical_law")]}),
("czy będąc kierownikiem punktu aptecznego jest możliwym również pracowanie w aptece ogólnodostępnej czy zatrudnienie na stanowisku kierownika punktu aptecznego jest możliwe nie tylko w pełnym wymiarze czasu pracy",{"entities": [(30,40, "pharmaceutical_law"),(148,158, "pharmaceutical_law"),(184,190, "pharmaceutical_law"),(83,98, "pharmaceutical_law"),(10,22, "pharmaceutical_law"),(23,29, "pharmaceutical_law"),(141,147, "pharmaceutical_law")]}),
("czy klientka może dochodzić zwrotu wartości zapłaconych kar w toczącej się sprawie sądowej o podział majątku wspólnego",{"entities": [(93,100, "civil_law"),(83,90, "civil_law"),(56,59, "civil_law")]}),
("czy nabywane od dystrybutora nowe podwozie pod zabudowę domków nabywane jako homologowana przyczepa ciężarowa musi być zarejestrowane przed dalszą odsprzedażą",{"entities": [(4,12, "administrative_law"),(63,71, "administrative_law")]}),
("w jaki sposób klientka może dowiedzieć się jakie zadłużenie wchodzi w skład spadku",{"entities": [(70,75, "civil_law"),(60,67, "civil_law")]}),
("czy klientowi który jest na emeryturze przysługuje wyższa ulga podatkowa w związku z podwyższeniem maksymalnej kwoty jaką można wpłacić na ikze",{"entities": [(111,116, "tax_law"),(122,127, "tax_law"),(75,82, "tax_law"),(39,50, "tax_law"),(28,38, "tax_law"),(63,72, "tax_law")]}),
("czy importer sprowadzający do unii europejskiej produkty kosmetyczne które są już w niej sprzedawane musi przeprowadzać ocenę bezpieczeństwa produktów oraz dokonywać rejestracji na portalu cpnp",{"entities": [(120,125, "international_law"),(126,140, "international_law"),(89,100, "international_law"),(57,68, "international_law"),(4,12, "international_law"),(13,26, "international_law")]}),
("czy w sytuacji w której jeden z rodziców wyraża zgodę na leczenie dziecka a drugi rodzic nie wyraża zgody na leczenie dziecka lekarz może podjąć leczenie czy pismo ojca klienta stanowi dokumentację medyczną czy przychodnia może udostępnić matce pacjenta pismo ojca pacjenta",{"entities": [(211,222, "medical_law"),(48,53, "medical_law")]}),
("ile wynosi kwota wolna od potrąceń komorniczych z rachunku bankowego czy alimenty podlegają egzekucji jakie działania może podjąć klientka aby odzyskać środki zgromadzone na rachunku bankowym",{"entities": [(82,91, "administrative_law")]}),
("czy klient pracując jako lekarz rezydent na podstawie umowy o pracę za h dyżur w sobotę powinien otrzymać wolny poniedziałek",{"entities": [(73,78, "medical_law"),(32,40, "medical_law")]}),
("co należy zrobić jeśli w internecie pojawią się opinie oczerniające lekarza",{"entities": [(36,43, "administrative_law"),(55,67, "administrative_law"),(48,54, "administrative_law"),(25,35, "administrative_law")]}),
("czy pracodawca może nagrywać dźwięk i obraz w kabinie maszynisty",{"entities": [(46,53, "administrative_law"),(38,43, "administrative_law")]}),
("jakie są prawa i obowiązki klientki w związku z wezwaniem do stawiennictwa na przesłuchanie w charakterze podejrzanego",{"entities": [(0,5, "criminal_law"),(61,74, "criminal_law"),(94,105, "criminal_law"),(48,57, "criminal_law"),(78,91, "criminal_law")]}),
("czy pracodawca może wypowiedzieć klientce umowę o pracę w przypadku likwidacji stanowiska pracy czy klientce będzie przysługiwała odprawa czy klientka może przejść na emeryturę pomostową",{"entities": [(79,89, "labor_law"),(130,137, "labor_law")]}),
("jak klientka powinna postąpić aby nie stracić odbytego stażu",{"entities": [(21,29, "medical_law")]}),
("czy klient powinien zapłacić za źle wykonane dzieło czy klient może się starać o zadośćuczynienie odszkodowanie lub ewentualne obniżenie ceny jakie konsekwencje grożą klientowi w przypadku braku zapłaty jakie są potencjalne koszty postępowania gdyby sprawa została skierowana na drogę sądową",{"entities": [(250,256, "civil_law")]}),
("w jakiej wysokości klientka powinna rozliczać podatek od nieruchomości oraz w jaki sposób powinna go odprowadzać czy klientka powinna zgłosić do urzędu miasta że nastąpi przekształcenie mieszkania spółdzielczego na własnościowe",{"entities": [(186,196, "tax_law"),(36,45, "tax_law"),(57,70, "tax_law")]}),
("na jakich podstawach prawnych klientka mogłaby zostać pociągnięta do odpowiedzialności lub jakie roszczenia mogłyby zostać do niej skierowane",{"entities": [(91,96, "criminal_law"),(39,46, "criminal_law"),(21,29, "criminal_law"),(69,86, "criminal_law")]}),
("czy zgoda pacjenta na udzielenie świadczenia zdrowotnego o podwyższonym ryzyku może być udzielana na tablecie szyfrującym dane czy przepisy wymagają formy pisemnej czy dokumenty podpisywane przez pacjenta muszą być przechowywane w formie papierowej czy wystarczająca jest forma zeskanowania tych dokumentów",{"entities": [(122,126, "medical_law"),(45,56, "medical_law"),(155,163, "medical_law"),(4,9, "medical_law"),(22,32, "medical_law"),(205,210, "medical_law"),(149,154, "medical_law"),(84,87, "medical_law"),(211,214, "medical_law")]}),
("czy zespół ratownictwa medycznego w którym nie ma lekarza może podać przymusowo leki podczas stosowania przymusu bezpośredniego",{"entities": [(63,68, "medical_law")]}),
("gdzie należy złożyć pozew o separację czy musi on zostać złożony w miejscu zamieszkania klientki i jej męża czy może zostać złożony w innym miejscu zamieszkania rodziców klientki czy klientka ma obowiązek powrotu do domu jeżeli zażyczy sobie tego jej mąż",{"entities": [(20,25, "civil_law"),(57,64, "civil_law"),(124,131, "civil_law")]}),
("czy klient będzie ponosił koszty szkolenia w przypadku rozwiązania umowy o pracę za porozumieniem stron czy klient będzie ponosił koszty szkolenia w przypadku gdyby odmówił zmiany stanowiska a następnie pracodawca wypowiedziałby umowę o pracę",{"entities": [(18,25, "labor_law"),(122,129, "labor_law"),(180,190, "labor_law"),(84,97, "labor_law")]}),
("w jaki sposób należy uzyskać zgodę na zabieg bądź szczepienie w przypadku pacjentów starszych niezdolnych do świadomego wyrażenia woli",{"entities": [(38,44, "medical_law"),(50,61, "medical_law"),(120,129, "medical_law"),(29,34, "medical_law")]}),
("czy zamieszczając w poście link do dostępnego w internecie artykułu klient musi prosić autora bądź inną o zgodę jeżeli tak to w jaki sposób i w jakiej formie należałoby tego dokonać jeżeli nie to czy i w jaki sposób należałoby opisać źródło pochodzenia artykułu",{"entities": [(59,67, "international_law")]}),
("co należy zrobić jeśli w sieci pojawią się opinie oczerniające lekarza",{"entities": [(31,38, "administrative_law"),(50,62, "administrative_law"),(25,30, "administrative_law"),(43,49, "administrative_law")]}),
("czy klientka jako lekarz z zawieszonym prawem wykonywania zawodu może pracować jako asystent medyczny przy kwalifikowaniu do szczepień",{"entities": [(107,121, "medical_law"),(70,78, "medical_law"),(84,92, "medical_law")]}),
("czy klient może udostępnić historię kont bankowych wspólnoty mieszkaniowej",{"entities": [(41,50, "administrative_law"),(36,40, "administrative_law")]}),
("jakie przepisy prawa obligują byłego zarządcę do przekazania dokumentacji wspólnoty mieszkaniowej",{"entities": [(49,60, "civil_law"),(21,29, "civil_law"),(37,45, "civil_law")]}),
("czy mąż klientki powinien podpisać z bratem umowę najmu lokalu mieszkalnego z datą wsteczną w jakim czasie administrator powinien przedstawiać rozliczenia czy administrator powinien regulować należne drugiemu współwłaścicielowi zyski na bieżąco czy administrator może pobierać wynagrodzenie za sprawowanie zarządu nieruchomością kto może pełnić rolę rozjemcy w sporze między współwłaścicielami",{"entities": [(314,328, "civil_law"),(182,191, "civil_law"),(268,276, "civil_law")]}),
("czy dodatki do wynagrodzenia mogą wliczać się do minimalnego wynagrodzenia pracowników",{"entities": [(49,60, "labor_law")]}),
("co należy zrobić w przedstawionych okolicznościach czy klient powinien udostępnić żonie zmarłego pacjenta dokumentacje medyczną",{"entities": [(106,118, "medical_law")]}),
("czy spółka z oo może być komplementariuszem w spółce komandytowej czy wspólnik spółki z oo będącej wspólnikiem spółki komandytowej może być jednocześnie wspólnikiem spółki komandytowej",{"entities": [(99,110, "civil_law"),(153,164, "civil_law"),(53,65, "civil_law"),(118,130, "civil_law"),(91,98, "civil_law")]}),
("czy konieczność używania nowych druków recept od  lipca  r dotyczy również lekarzy radiologów którzy wypisują recepty wyłącznie na swoje potrzeby",{"entities": [(16,24, "medical_law"),(57,58, "medical_law"),(25,31, "medical_law")]}),
("czy lekarz stażysta może przeprowadzać kwalifikację do szczepień w tzw szczepionkobusie poza terenem szpitala",{"entities": [(11,19, "medical_law"),(55,64, "medical_law")]}),
("jakie kroki prawne może podjąć klientka",{"entities": [(0,5, "criminal_law"),(12,18, "criminal_law")]}),
("czy klient ma obowiązek wprowadzania kas fiskalnych online",{"entities": [(41,51, "tax_law"),(37,40, "tax_law")]}),
("czy klientka może wziąć udział w postępowaniu odwoławczym które odbywa się w grudniu  r czyli po upływie roku od rozpoczęcia specjalizacji czy termin  miesięcy liczy się do dnia złożenia wniosku czy rozpoczęcia drugiej rezydentury czy klientka musi zrezygnować z pierwszej specjalizacjiw terminie do  dni od zakwalifikowania się na drugą bez względu na czas rozpoczęcia pierwszej specjalizacji czy jeśli klientka zrezygnuje z rezydentury przed dniem  listopada  i nie dostanie sięna specjalizacje w wyniku postępowania odwoławczego to traci prawo do odbywania rezydentury czy też może złożyć wniosek o odbywanie rezydentury w następnym roku",{"entities": [(602,611, "medical_law"),(263,272, "medical_law"),(370,379, "medical_law"),(483,496, "medical_law"),(451,460, "medical_law"),(626,635, "medical_law"),(332,337, "medical_law"),(97,104, "medical_law"),(308,324, "medical_law"),(499,505, "medical_law"),(86,87, "medical_law"),(64,70, "medical_law"),(353,357, "medical_law"),(219,230, "medical_law"),(426,437, "medical_law"),(560,571, "medical_law"),(612,623, "medical_law"),(113,124, "medical_law"),(199,210, "medical_law"),(358,369, "medical_law"),(178,186, "medical_law"),(413,423, "medical_law"),(249,260, "medical_law")]}),
("jakich formalności musi dopełnić klientka aby nabyć gospodarstwo rolne od swoich rodziców i dokonywać wszystkich czynności z nim związanych czy klientka jako dzierżawca nieruchomości rolnej musi być wykształcona jako rolnik indywidualny",{"entities": [(183,189, "administrative_law"),(52,64, "administrative_law")]}),
("czy zakład opiekuńczoleczniczy dalej zol może przyjąć chorego niezdolnego do wyrażenia świadomej woli przed uzyskaniem zgody sądu co należy zrobić w sytuacji gdy pacjent został przyjęty do zol przed uzyskaniem zgody sądu a rodzina chce zabrać chorego do domu",{"entities": [(108,118, "medical_law"),(199,209, "medical_law"),(87,96, "medical_law"),(77,86, "medical_law"),(54,61, "medical_law"),(243,250, "medical_law"),(46,53, "medical_law"),(37,40, "medical_law"),(189,192, "medical_law")]}),
("czy treść umowy o zakazie konkurencji podpisanej przez klientkę jest zgodna z prawem",{"entities": [(18,25, "labor_law")]}),
("w jakiej formie zawrzeć umowę pożyczki czy  złotych w ramach procentu od pożyczki będzie podlegało opodatkowaniu czy można ustanowić hipotekę na zakupionej przez córkę klienta i jej męża nieruchomości",{"entities": [(99,112, "civil_law")]}),
("czy podejmowanie uchwał w przedmiocie udzielenia zarządowi absolutorium przez wspólnotę mieszkaniową jest obowiązkowe co dzieje się w przypadku w którym zarządowi nie zostanie udzielone absolutorium",{"entities": [(17,23, "civil_law"),(78,87, "civil_law"),(59,71, "civil_law"),(49,58, "civil_law"),(153,162, "civil_law"),(4,16, "civil_law"),(121,127, "civil_law"),(88,100, "civil_law")]}),
("czy klientka może sprzedać szczepionki na zapotrzebowanie przychodni w większej ilości",{"entities": [(42,57, "pharmaceutical_law")]}),
("czy w przedmiotowej sprawie doszło do skutecznego podjęcia uchwał czy zarządca ma obowiązek wykonać te uchwały",{"entities": [(59,65, "civil_law"),(70,78, "civil_law")]}),
("czy dysponent zakładowego funduszu świadczeń socjalnych może dofinansować wszystkie imprezy pomimo sprzeciwu jednej z organizacji",{"entities": [(45,55, "labor_law"),(14,25, "labor_law")]}),
("czy konkurencyjna firma może żądać aby klient zaprzestał sprzedaży danego modelu krzeseł",{"entities": [(4,17, "international_law")]}),
("czy pisemne zapisy ustaleń wiążą strony czy dodatkowe zapisy wpływają na możliwość wypowiedzenia umowy",{"entities": [(4,11, "administrative_law"),(61,69, "administrative_law")]}),
("co klientka może skutecznie zmienić miejsce odbywania szkolenia specjalizacyjnego",{"entities": [(54,63, "medical_law")]}),
("czy dyrektor szpitala miał prawo oddelegować klientkę do pracy na oddziale nocneji świątecznej opieki zdrowotnej czy niniejsze oddelegowanie może trwać dłużej niż  miesiące",{"entities": [(127,140, "medical_law"),(117,126, "medical_law"),(75,82, "medical_law"),(83,94, "medical_law")]}),
("czy recepty na których przepisano wyłącznie produkty lecznicze niepodlegające refundacji mogą być wydawane na wzorach druków recept sprzed nowelizacji",{"entities": [(53,62, "pharmaceutical_law"),(78,88, "pharmaceutical_law")]}),
("czy klientka jako lekarz rezydent pediatrii może zostać zobowiązana przez pracodawcę do pełnienia dyżurów na oddziale noworodkowym",{"entities": [(88,97, "medical_law"),(34,43, "medical_law"),(25,33, "medical_law")]}),
("co może zrobić klientka w związku z powziętymi wątpliwościami dotyczącymi nieprawidłowości w protokołach rozpraw oraz innymi nieprawidłowościami dotyczącymi postępowania przed sądem lekarskim czy fakt że okręgowy sąd lekarski w warszawie posiadał dokumentację medyczną pacjentek klientki może stanowić naruszenie przepisów o dokumentacji medycznej",{"entities": [(204,212, "criminal_law"),(196,200, "criminal_law"),(247,259, "criminal_law"),(213,216, "criminal_law"),(228,237, "criminal_law"),(62,73, "criminal_law"),(145,156, "criminal_law"),(260,268, "criminal_law")]}),
("czy indywidualna interpretacja podatkowa jest prawnie wiążąca wstecz",{"entities": [(31,40, "tax_law")]}),
("co może zrobić klient aby móc zapewnić sobie możliwość zamieszkiwania w domu należącym do syna i synowej klienta dożywotnio",{"entities": [(77,86, "civil_law"),(97,104, "civil_law")]}),
("w jaki sposób klientka może wyegzekwować zaległe wynagrodzenie od pracodawcy czy klientka może rozwiązać umowę o pracę bez okresu wypowiedzenia z winy pracodawcy w związku z brakiem zapłaty zaległego wynagrodzenia",{"entities": [(146,150, "labor_law"),(174,181, "labor_law"),(41,48, "labor_law")]}),
("czy pracownik może zwracać się bezpośrednio do reprezentującego go związku zawodowego z prośbą o interwencję w sprawie wykreślenia z akt nagany udzielonej mu przez pracodawcę czy powinien najpierw skorzystać z drogi służbowej",{"entities": [(75,85, "labor_law"),(137,143, "labor_law")]}),
("kto powinien ponieść koszty remontu balkonów w budynku wspólnoty mieszkaniowej",{"entities": [(36,44, "civil_law"),(28,35, "civil_law")]}),
("czy przepisy prawa przewidują ilu specjalistów neurologii musi zatrudniać szpital wykonujący świadczenia finansowane przez nfz na oddziale neurologicznym",{"entities": [(105,116, "medical_law"),(63,73, "medical_law"),(47,57, "medical_law"),(34,46, "medical_law")]}),
("czy apteka może sprzedawać wodę mineralną czy apteka może kupować wodę mineralną w hurtowniach spożywczych",{"entities": [(58,65, "pharmaceutical_law"),(27,31, "pharmaceutical_law"),(66,70, "pharmaceutical_law"),(32,41, "pharmaceutical_law"),(71,80, "pharmaceutical_law")]}),
("jaki jest wymiar urlopu rodzicielskiego od kiedy klient może skorzystać z urlopu rodzicielskiego w jaki sposób należy zgłosić się do dobrowolnego ubezpieczenia chorobowego",{"entities": [(24,39, "labor_law"),(81,96, "labor_law")]}),
("które dokumenty klientka powinna pozostawić w aptece w celu umożliwienia jej dalszej działalności",{"entities": [(33,43, "pharmaceutical_law"),(77,84, "pharmaceutical_law")]}),
("czy istnieje możliwość złożenia wniosku o wyłączenie mieszkania z masy spadkowej i przeniesienie własności mieszkania na kupującego przez sąd",{"entities": [(71,80, "civil_law"),(66,70, "civil_law"),(97,106, "civil_law")]}),
("czy ochrona wynikająca z wniosku o obniżenie wymiaru czasu pracy oznacza również ochronę przed zwolnieniem z przyczyn leżących po stronie pracodawcy z wypłatą odpowiedniego odszkodowania",{"entities": [(12,22, "labor_law"),(45,52, "labor_law"),(109,117, "labor_law"),(81,88, "labor_law"),(35,44, "labor_law"),(118,126, "labor_law"),(4,11, "labor_law"),(151,158, "labor_law"),(95,106, "labor_law")]}),
("urlop wypoczynkowy obniżający ilość godzin w pracy  czy pracodawca może go udzielić",{"entities": [(30,35, "labor_law")]}),
("jakie są wymagania dotyczące prowadzenia obrotu kosmetykami przez hurtownie farmaceutyczne jakie dokumenty musi posiadać kosmetyk albo wyrób kosmetyczny aby mógł być przedmiotem obrotu",{"entities": [(166,177, "pharmaceutical_law"),(41,47, "pharmaceutical_law"),(76,90, "pharmaceutical_law"),(66,75, "pharmaceutical_law")]}),
("czy klient może odmówić przyjęcia pacjenta z uwagi na to że nie może z jego rodzicami dojść do porozumienia",{"entities": [(24,33, "medical_law"),(45,50, "medical_law")]}),
("czy prawo pozwala na to aby ratownik medyczny mógł wykonywać badania na zlecenie podmiotu leczniczego",{"entities": [(72,80, "medical_law"),(28,36, "medical_law")]}),
("czy wspólnota mieszkaniowa może podjąć uchwałę dotyczącą zakupu wodomierzy odczytywanych radiowo do lokali pokrywając ich koszty",{"entities": [(47,56, "civil_law"),(100,106, "civil_law"),(39,46, "civil_law")]}),
("czy dyrektor szpitala może zabronić wykonywania pracy w innym miejscu czy za prace wyłącznie w jednym podmiocie klientowi należy się rekompensata czy dyrektor szpitala może zabronić wykonywania pracy w innym miejscu z datą wsteczną",{"entities": [(77,82, "labor_law")]}),
("czy możliwe jest powiększenie składu osobowego spółki jawnej bez dokonywania zmian w zezwoleniu do prowadzenie apteki",{"entities": [(17,29, "civil_law")]}),
("czy klient ma możliwość ubiegania się o wypłatę dodatku do wynagrodzenia",{"entities": [(24,33, "medical_law")]}),
("jakie są prawa i obowiązki klientki na przesłuchaniu w charakterze świadka jak kształtuje się kwestia zwolnienia z tajemnicy lekarskiej",{"entities": [(0,5, "criminal_law"),(67,74, "criminal_law"),(55,66, "criminal_law")]}),
("czy diagnosta laboratoryjny posiadający również specjalizację w immunologii klinicznej spełnia warunek o którym mowa w warunkach konkursu",{"entities": [(87,94, "medical_law")]}),
("czy hurtownia nr  może powtórnie przepakować leki w polskie opakowania ale z inną ilością tabletek np hurtownia nr  przepakowała produkt leczniczy w opakowania po  tabletek a hurtownia nr  chce przepakować produkt leczniczy w opakowania po  tabletek",{"entities": [(90,98, "pharmaceutical_law"),(164,172, "pharmaceutical_law"),(60,70, "pharmaceutical_law"),(149,159, "pharmaceutical_law"),(226,236, "pharmaceutical_law"),(33,44, "pharmaceutical_law"),(194,205, "pharmaceutical_law")]}),
("na jakich zasadach sąd przyznaje zwrot kosztów procesu stronie która zmieniła pełnomocnika w trakcie procesu",{"entities": [(47,54, "civil_law")]}),
("czy ustalenie z narodowym funduszem zdrowia kwalifikuje się jako pożyczka w rozumieniu art zzd ustawy o szczególnych rozwiązaniach związanych z zapobieganiem przeciwdziałaniem i zwalczaniem covid innych chorób zakaźnych oraz wywołanych nimi sytuacji kryzysowych o której mowa w oświadczeniu",{"entities": [(178,189, "medical_law"),(104,116, "medical_law"),(26,35, "medical_law"),(158,175, "medical_law"),(225,235, "medical_law"),(76,86, "medical_law"),(144,157, "medical_law"),(16,25, "medical_law"),(196,202, "medical_law"),(250,261, "medical_law"),(117,130, "medical_law")]}),
("czy ojciec klienta jako współwłaściciel nieruchomości może wystąpić do sądu z wnioskiem o założenie księgi wieczystej jeżeli odpowiedź na pytanie pierwsze jest pozytywna to czy księga wieczysta będzie dotyczyć jedynie  części czy całej nieruchomości jakie korzyści przyniesie założenie księgi wieczystej czy w chwili obecnej możliwe jest założenie księgi wieczystej gdy żadna z działek nie jest przydzielona danej osobie",{"entities": [(100,106, "civil_law"),(286,292, "civil_law"),(348,354, "civil_law"),(90,99, "civil_law"),(276,285, "civil_law"),(338,347, "civil_law"),(107,117, "civil_law"),(293,303, "civil_law"),(355,365, "civil_law"),(146,154, "civil_law")]}),
("czy klientka może w trakcie urlopu wychowawczego zatrudnić się w gabinecie swojego małżonka",{"entities": [(28,34, "medical_law")]}),
("czy klientka może wydać zaświadczenie o odbyciu praktyki na podstawie zaświadczenia z urzędu pracy",{"entities": [(40,47, "pharmaceutical_law")]}),
("czy klientka może wnosić o skrócenie okresu obowiązywania zakazu prowadzenia pojazdów mechanicznych w ruchu lądowym",{"entities": [(58,64, "criminal_law")]}),
("kiedy lekarz może odmówić udzielenia świadczenia zdrowotnego czy lekarz ma obowiązek zasugerowania innego lekarza",{"entities": [(49,60, "medical_law"),(26,36, "medical_law")]}),
("jakie prawa przysługują klientce w związku z wezwaniem",{"entities": [(0,5, "criminal_law")]}),
("czy umowę najmu lokalu użytkowego należy zarejestrować w urzędzie skarbowym",{"entities": [(23,33, "civil_law")]}),
("czy klient powinien zapłacić za źle wykonane dzieło czy klient może się starać o zadośćuczynienie odszkodowanie lub ewentualne obniżenie ceny jakie konsekwencje grożą klientowi w przypadku braku zapłaty jakie są potencjalne koszty postępowania gdyby sprawa została skierowana na drogę sądową",{"entities": [(250,256, "civil_law")]}),
("czy w związku z zaistniałą sytuacją pracownica klienta też została objęta kwarantanną czy pracownica klienta ma możliwość nieodbywania kwarantanny",{"entities": [(74,85, "medical_law"),(67,73, "medical_law")]}),
("czy w związku z zaistniałą sytuacją pracownica klienta też została objęta kwarantanną czy pracownica klienta ma możliwość nieodbywania kwarantanny",{"entities": [(74,85, "medical_law"),(67,73, "medical_law")]}),
("jakie środki prawne przysługują klientowi jeżeli w trakcie egzekucji komorniczej okaże się że dłużnik nie posiada majątku jakie środki prawne przysługują klientowi jeżeli w trakcie egzekucji komorniczej okaże się że dłużnik wyjechał poza granice kraju",{"entities": [(0,5, "criminal_law"),(122,127, "criminal_law"),(13,19, "criminal_law"),(135,141, "criminal_law"),(32,41, "criminal_law"),(154,163, "criminal_law"),(69,80, "criminal_law"),(191,202, "criminal_law"),(94,101, "criminal_law"),(216,223, "criminal_law"),(81,86, "criminal_law"),(203,208, "criminal_law"),(6,12, "criminal_law"),(128,134, "criminal_law")]}),
("czy klient ma obowiązek uzyskać pozwolenie na budowę ogrodzenia czy klient ma obowiązek uzyskać zgodę sąsiadów na budowę ogrodzenia",{"entities": [(32,42, "administrative_law"),(53,63, "administrative_law"),(46,52, "administrative_law"),(114,120, "administrative_law")]}),
("na jakie wynagrodzenie wskazuje umowa o pracę na czas nieokreślony zawarta w dniu  grudnia  r godzinowe miesięczne czy roczne",{"entities": [(83,90, "labor_law"),(54,66, "labor_law")]}),
("w jakiej wysokości grzywnę sąd może wymierzyć bratu klientki czy do odpowiedzialności mogą zostać pociągnięte również osoby zamieszkałe pod adresem na który doręczono wezwanie",{"entities": [(27,30, "criminal_law"),(68,85, "criminal_law")]}),
("czy na receptach papierowych należy umieszczać kod kreskowy czy istnieje możliwość nabycia nowych druków recept za pośrednictwem izby lekarskiej",{"entities": [(36,46, "pharmaceutical_law"),(17,28, "pharmaceutical_law"),(7,16, "pharmaceutical_law")]}),
("jakie prawa i obowiązki ma osoba wezwana na przesłuchanie w charakterze świadka wpostępowaniu cywilnym",{"entities": [(33,40, "medical_law"),(80,93, "medical_law")]}),
("czy apteka może sprzedać testy na covid do domu dziecka",{"entities": [(25,30, "pharmaceutical_law")]}),
("jakich formalności należy dopełnić w związku z sprowadzeniem samochodu z usa z przeznaczeniem do sprzedaży na części",{"entities": [(61,70, "tax_law"),(37,44, "tax_law"),(97,106, "tax_law")]}),
("czy w równoważnym systemie czasu pracy pracownik może rozpoczynać pracę w drugiej dobie pracowniczej wcześniej niż w pierwszej przy zachowaniu przerwy między jednym a drugim dniem wynoszącej  godzin",{"entities": [(132,142, "labor_law"),(6,17, "labor_law")]}),
("który podmiot leczniczy powinien wypłacić dodatek covidowy klientce która realizując staż podyplomowy dyżurowała w podmiocie zewnętrznym w ramach szpitalnego oddziału ratunkowego",{"entities": [(14,23, "medical_law"),(115,124, "medical_law"),(33,41, "medical_law"),(158,166, "medical_law"),(6,13, "medical_law"),(125,136, "medical_law"),(50,58, "medical_law"),(85,89, "medical_law"),(90,101, "medical_law")]}),
("jakie będzie minimalne wynagrodzenie asystentki stomatologicznej zatrudnionej przez klienta na pełny etat",{"entities": [(48,64, "medical_law"),(37,47, "medical_law"),(65,77, "medical_law")]}),
("czy pracodawca może zobowiązać pracowników do pracy w godzinach nadliczbowych w każdą niedzielę",{"entities": [(64,77, "labor_law")]}),
("czy klient pracując jako lekarz rezydent na podstawie umowy o pracę za h dyżur w sobotę powinien otrzymać wolny poniedziałek",{"entities": [(73,78, "medical_law"),(32,40, "medical_law")]}),
("czy klient musi podawać swoje dane osobowe w raporcie odsyłanym do głównego inspektoratu transportu drogowego w którym zgadza się na przyjęcie mandatu",{"entities": [(35,42, "administrative_law"),(100,109, "administrative_law")]}),
("czy klient ma możliwość wglądu w nagranie monitoringu wspólnoty mieszkaniowej w celu identyfikacji właścicieli psów których nieczystości nie są usuwane",{"entities": [(24,30, "administrative_law"),(42,53, "administrative_law")]}),
("w jaki sposób klientka może usprawiedliwić nieobecność na rozprawie w sądzie",{"entities": [(43,54, "civil_law"),(58,67, "civil_law")]}),
("czy lekarz stażysta może być oddelegowany przez pracodawcę do pracy na dyżurze godzinnym na szpitalnym oddziale ratunkowym przy zwalczaniu koronawirusa jeżeli nadzór lekarza specjalisty byłby pełniony jedynie telefonicznie czy dyrekcja szpitala nawiązując nowy stosunek pracy może w umowie wpisać że umowa została zawarta z lekarzem zamiast lekarz stażysta",{"entities": [(174,185, "medical_law"),(139,151, "medical_law"),(11,19, "medical_law"),(324,332, "medical_law"),(92,102, "medical_law"),(192,200, "medical_law"),(159,165, "medical_law"),(314,321, "medical_law"),(25,28, "medical_law"),(71,78, "medical_law"),(112,122, "medical_law")]}),
("jak prezentuje się kwestia odpowiedzialności lekarza rezydenta w zaistniałych okolicznościach czy ewentualne roszczenia zostałyby pokryte przez szpital czy szpital pokryłby świadczenia wynikające z uznania odpowiedzialności klientki powstałe z jej winy wskutek błędu lekarskiego w trakcie przeprowadzanych przez nią procedur które nie były wymienione w zakresie czynności dołączonych do umowy klientki czy szpital pokryłby świadczenia wynikające z roszczeń pacjentów wskutek uznania odpowiedzialności klientki w takcie dobrowolnej pracy na sor mimo iż w umowie rezydenckiej wskazano oddział chirurgii jako jej miejsce pracy czy w przypadku nieszczęśliwego wypadku w trakcie dobrowolnej pracy na sor klientce zostanie wypłacone ubezpieczenie skoro w umowie rezydenckiej wskazano oddział chirurgii jako faktyczne miejsce pracy czy pismo z dnia  października r jest podstawą do cofnięcia zgody na realizację stażu w ramach rezydentury",{"entities": [(45,52, "criminal_law"),(561,573, "criminal_law"),(756,768, "criminal_law"),(829,834, "criminal_law"),(885,890, "criminal_law"),(574,582, "criminal_law"),(769,777, "criminal_law"),(727,740, "criminal_law"),(519,530, "criminal_law"),(674,685, "criminal_law"),(98,108, "criminal_law"),(27,44, "criminal_law"),(206,223, "criminal_law"),(483,500, "criminal_law"),(837,841, "criminal_law"),(78,93, "criminal_law"),(198,205, "criminal_law"),(475,482, "criminal_law"),(164,172, "criminal_law"),(414,422, "criminal_law"),(583,590, "criminal_law"),(778,785, "criminal_law"),(362,371, "criminal_law"),(267,278, "criminal_law")]}),
("czy recepty elektroniczne na leki narkotyczne lub odurzające mogą być zrealizowane w terminie zaczynającym się od daty realizacji recepty",{"entities": [(50,60, "pharmaceutical_law")]}),
("czy pracodawca ma prawo przymusowo skierować klienta na urlop wypoczynkowy w terminie innym niż wynika to z planu urlopowego",{"entities": [(108,113, "labor_law")]}),
("czy zabronionym jest wskazywanie wyniku mierzenia temperatury pacjentowi po przyjściu do gabinetu na ankiecie epidemiologicznej czy lekarz prowadzący prywatny gabinet ma prawo odmówić wysyłania fakturrachunków do pacjentów na adres mailowy czy lekarz prowadzący prywatny gabinet ma prawo odmówić udostępniania dokumentacji medycznej na wskazany przez klienta adres mailowy",{"entities": [(50,61, "medical_law"),(33,39, "medical_law"),(110,127, "medical_law"),(150,158, "medical_law"),(262,270, "medical_law"),(101,109, "medical_law"),(62,72, "medical_law"),(296,309, "medical_law"),(232,239, "medical_law"),(184,193, "medical_law")]}),
("czy przy zgłaszaniu budowy domku letniskowego o powierzchni do  m należy dołączyć projekt budowlany",{"entities": [(20,26, "administrative_law"),(82,89, "administrative_law"),(27,32, "administrative_law")]}),
("od kiedy lekarz specjalista może wystawić receptę z refundacją dla seniorów czy refundacja na szczepionki influvactetra i vaxigriptetra przysługuje seniorom jedynie w przypadku chorób współistniejących",{"entities": [(67,75, "pharmaceutical_law"),(42,49, "pharmaceutical_law"),(80,90, "pharmaceutical_law")]}),
("czy pracodawca może polecić klientowi kwalifikowanie pacjentów do szczepień na covid bez zmiany umowy o pracę czy za kwalifikowanie pacjentów do szczepień przysługuje dodatek do wynagrodzenia",{"entities": [(38,52, "medical_law"),(117,131, "medical_law"),(66,75, "medical_law"),(145,154, "medical_law")]}),
("czy pracodawca jeżeli nie udzieli urlopu klientowi będzie zobowiązany do wypłaty ekwiwalentu za niewykorzystany urlop czy niewykorzystany urlop oraz brak ekwiwalentu mogą skutkować prawem do wykorzystania urlopu u następnego pracodawcy klienta",{"entities": [(96,111, "labor_law"),(122,137, "labor_law"),(26,33, "labor_law"),(81,92, "labor_law"),(154,165, "labor_law")]}),
("czy klientka może odmówić wykonania polecenia pracodawcy",{"entities": [(26,35, "medical_law")]}),
("czy klientka musi wydać opinię na polecenie sądu na jakiej podstawie klientka może odmówić wydania opinii",{"entities": [(91,98, "criminal_law"),(24,30, "criminal_law")]}),
("w jaki sposób pani xx oraz pani z mogą przekazać nieruchomość dzieciom pani y",{"entities": [(14,18, "civil_law"),(27,31, "civil_law"),(71,75, "civil_law")]}),
("czy informacja o lekach przyjmowanych przez znajomą klientki jest objęta tajemnicą zawodową",{"entities": [(73,82, "medical_law"),(66,72, "medical_law")]}),
("czy firma z którą skontaktował się zleceniodawca jest wiarygodna co może zrobić zleceniodawca aby chronić swoje dane osobowe które przekazał w wiadomości",{"entities": [(117,124, "administrative_law")]}),
("czy w przedmiotowej sprawie doszło do skutecznego podjęcia uchwał czy zarządca ma obowiązek wykonać te uchwały",{"entities": [(59,65, "civil_law"),(70,78, "civil_law")]}),
("czy po uprawomocnieniu się postanowienia o umorzeniu postępowania pozwany może żądać zwrotu kwot ściągniętych w toku tej sprawy od kogo pozwany może żądać zwrotu kwot zajętych w postępowaniu egzekucyjnym czy oprócz żądania kwoty należności z postępowania egzekucyjnego można także żądać zwrotu kosztów egzekucyjnych czy uprawomocnienie się postanowienia o umorzeniu postępowania skutkuje tym że żadna z tych dwóch firm nie będzie mogła ponownie wystąpić z pozwem o to samo roszczenie",{"entities": [(167,175, "civil_law"),(92,96, "civil_law"),(162,166, "civil_law"),(379,387, "civil_law"),(43,52, "civil_law"),(356,365, "civil_law"),(302,315, "civil_law"),(66,73, "civil_law"),(136,143, "civil_law")]}),
("czy członek wspólnoty jest zobowiązany do uiszczania zaliczki inwestycyjnoremontowej mimo że w planie gospodarczym wspólnota na bieżący rok i następny nie planuje żadnych remontów",{"entities": [(53,61, "civil_law")]}),
("czy pracodawca w przypadku gdy klientka powróci do pracy będzie miał możliwość oddelegowania klientki do pracy w placówce znajdującej się w rzeszowie która nie należy do oddziału banku w łańcucie w jaki sposób powinna zachować się klientka chcąc jak najszybciej zakończyć stosunek prawny łączący ją z bankiem przy zachowaniu świadczeń wynikających z likwidacji placówek",{"entities": [(314,324, "labor_law"),(240,245, "labor_law"),(272,280, "labor_law"),(262,271, "labor_law")]}),
("czy podjęcie uchwały może się odbyć w trybie indywidualnego zbierania głosów",{"entities": [(45,59, "civil_law"),(60,69, "civil_law"),(4,12, "civil_law"),(13,20, "civil_law")]}),
("w jaki sposób klient może uzyskać numer księgi wieczystej swojego mieszkania",{"entities": [(40,46, "civil_law"),(47,57, "civil_law")]}),
("czy straż ochrony kolei może żądać od maszynistów dozoru opisanego w piśmie z dnia  maja  r",{"entities": [(57,66, "labor_law"),(84,88, "labor_law"),(38,49, "labor_law")]}),
("ile ryczałtu można wziąć na leki recepturowe",{"entities": [(19,24, "pharmaceutical_law")]}),
("czy klientka może podjąć jeszcze jakieś kroki w przedmiotowej sprawie czy istnieje inna instytucja do której klientka mogłaby zgłosić zaistniałą sytuację",{"entities": [(83,87, "administrative_law")]}),
("czy grupowa praktyka lekarska może zatrudnić lekarza",{"entities": [(12,20, "medical_law")]}),
("czy klientka zobowiązana jest wydać pacjentowi całą jego dokumentację medyczną",{"entities": [(47,51, "medical_law"),(36,46, "medical_law")]}),
("jaką podstawę prawną zwolnienia z vat klient powinien wpisać na fakturze",{"entities": [(21,31, "tax_law")]}),
("czy klient ma obowiązek wypełnienia i podpisania takiego pisma czy i bez niego należy mu się dodatek covidowy jak liczy się wysokości dodatku covidowego  za poszczególne dni przepracowane z pacjentami covidowymi czy od całości miesięcznej pensji",{"entities": [(174,187, "medical_law"),(57,62, "medical_law"),(24,35, "medical_law"),(142,152, "medical_law"),(101,109, "medical_law"),(190,200, "medical_law")]}),
("czy po powrocie do kraju klientce należy się dodatek w związku z powrotem do polski",{"entities": [(65,73, "medical_law")]}),
("czy obecnie obowiązujące przepisy prawne przewidują wyjątki od obowiązku zakrywania ust oraz nosa",{"entities": [(52,59, "medical_law")]}),
("czy klient może zatrudnić obywatela ukrainy z częściowo uznanym szkoleniem specjalizacyjnym do pracy w szpitalnym oddziale ratunkowym",{"entities": [(36,43, "medical_law"),(103,113, "medical_law")]}),
("czy klientka może zamontować kamerę na zewnętrznej części budynku",{"entities": [(39,50, "administrative_law"),(18,28, "administrative_law")]}),
("w jaki sposób klient może doprecyzować wysokość kosztów dojazdu aby w przyszłości nie budziła ona sporów czy obecnie obowiązujące przepisy regulują maksymalne stawki kosztów dojazdu pełnomocnika",{"entities": [(56,63, "civil_law"),(174,181, "civil_law")]}),
("czy istnieje możliwość wyprzedzenia decyzji administracyjnej o skierowaniu do pracy przy zwalczaniu epidemii i wysłaniu wcześniej do wojewody informacji o posiadaniu dziecka czy istnieje formularz takiego pisma",{"entities": [(44,60, "medical_law"),(63,74, "medical_law"),(133,141, "medical_law")]}),
("czy szpital może potrącać wynagrodzenie rezydentom za zejście po dyżurze czy klient po dyżurze w niedzielę do północy może dyżurować w poniedziałki od godziny  jak powinno kształtować się wynagrodzenie klienta za dyżury w niedziele",{"entities": [(123,132, "medical_law"),(110,117, "medical_law"),(17,25, "medical_law"),(54,61, "medical_law"),(135,147, "medical_law"),(164,171, "medical_law"),(65,72, "medical_law"),(87,94, "medical_law"),(172,183, "medical_law"),(40,50, "medical_law")]}),
("czy klientka ma prawo wystąpić o dofinansowanie wynagrodzeń",{"entities": [(22,30, "medical_law"),(33,47, "medical_law")]}),
("czy w nowo otwartym salonie kosmetycznym gdzie jest tylko jedna osoba pracująca właścicielka musi być księgowa czy osoba która prowadzi księgowość musi mieć uprawnienia",{"entities": [(20,27, "administrative_law")]}),
("czy stawiennictwo klientki na policji w związku z wezwaniem na przesłuchanie w charakterze świadka stanowi wyjście z pracy w celach prywatnych",{"entities": [(4,17, "criminal_law"),(91,98, "criminal_law"),(79,90, "criminal_law"),(50,59, "criminal_law"),(99,106, "criminal_law"),(63,76, "criminal_law")]}),
("czy każdy pacjent u którego wykonano test przesiewowy w kierunku covid jest podejrzanym o zakażenie",{"entities": [(56,64, "medical_law"),(37,41, "medical_law")]}),
("czy fakt że pożyczkobiorca klienta  spółka jawna  została wykreślona z krajowego rejestru sądowego wpływa negatywnie na możliwość egzekwowania długu przez klienta",{"entities": [(90,98, "civil_law"),(143,148, "civil_law")]}),
("czy istnieją przepisy które regulują skuteczność bądź formę wprowadzenia opisanego przez klienta rozwiązania  przesyłania pracownikom poleceń drogą mailową",{"entities": [(54,59, "labor_law"),(73,82, "labor_law"),(37,48, "labor_law")]}),
("czy wykonawca nagrobka słusznie żąda wskazania nr pesel klientki w treści umowy",{"entities": [(32,36, "administrative_law")]}),
("w jakich sytuacjach psycholog który w trakcie terapii poweźmie informację o popełnieniu przestępstwa ma obowiązek zgłosić ten fakt organom ścigania czy psycholog zobowiązany jest poinformować pacjenta że dokona odpowiedniego zgłoszenia do organów ścigania",{"entities": [(126,130, "criminal_law"),(139,147, "criminal_law"),(76,87, "criminal_law"),(179,191, "criminal_law"),(88,100, "criminal_law"),(54,62, "criminal_law"),(131,138, "criminal_law"),(239,246, "criminal_law"),(20,29, "criminal_law"),(152,161, "criminal_law"),(9,19, "criminal_law")]}),
("czy pracodawca może nagrywać dźwięk i obraz w kabinie maszynisty",{"entities": [(46,53, "administrative_law"),(38,43, "administrative_law")]}),
("czy jeżeli lekarz na recepcie wpisze mniejszą dawkę leku niż zawiera całe opakowanie to czy możliwe jest wydanie całego opakowania",{"entities": [(21,29, "pharmaceutical_law"),(46,51, "pharmaceutical_law"),(113,119, "pharmaceutical_law")]}),
("w jaki sposób wspólnota mieszkaniowa może uchronić się przed ewentualnymi roszczeniami przyszłych nabywców części współwłasności nieruchomości garażowej",{"entities": [(114,128, "civil_law"),(98,106, "civil_law")]}),
("czy pracodawca może zabronić pracownikom lekarzom noszenia maseczek na twarzach",{"entities": [(59,67, "medical_law"),(41,49, "medical_law"),(29,40, "medical_law")]}),
("w jaki sposób klient może się zabezpieczyć na okoliczność że swój obowiązek alimentacyjny wobec byłej żony i córki wykonuje poprzez opłacanie należności za mieszkanie w którym uprawnione do alimentów mieszkają",{"entities": [(96,101, "civil_law"),(190,199, "civil_law"),(176,186, "civil_law")]}),
("czy klientka może skutecznie doprowadzić do wstrzymania zniesienia współwłasności kto powinien ponieść koszty zniesienia współwłasności",{"entities": [(29,40, "civil_law"),(67,81, "civil_law"),(56,66, "civil_law"),(110,120, "civil_law")]}),
("czy w związku z obecną sytuacją epidemiologiczną istnieje możliwość oddelegowania lekarzy rezydentów do pracy w innym miejscu niż są zatrudnieni czy lekarz będzie miał prawo do odmowy świadczenia pracy jeżeli szpital nie zapewni mu odpowiedniego wyposażenia oraz środków ochronnych przed szerzącą się epidemią covid",{"entities": [(32,48, "medical_law"),(221,228, "medical_law"),(271,281, "medical_law"),(246,257, "medical_law"),(301,309, "medical_law"),(16,22, "medical_law")]}),
("w jaki sposób dzielony jest spadek po zmarłej babci w jakim czasie po śmierci spadkodawcy należy podjąć kroki prawne jakie formalności i gdzie należy dopełnić jakie opłaty się z tym wiążą",{"entities": [(28,34, "civil_law"),(78,89, "civil_law"),(46,51, "civil_law")]}),
("co klientka powinna zawrzeć w wyjaśnieniach do wielkopolskiej izby lekarskiej w przedmiocie prowadzonego postępowania przygotowawczego przez prokuraturę w którym występuje jako podejrzana",{"entities": [(92,104, "medical_law"),(141,152, "medical_law")]}),
("czy wykonawca nagrobka słusznie żąda wskazania nr pesel klientki w treści umowy",{"entities": [(32,36, "administrative_law")]}),
("czy istnieją przepisy które regulują skuteczność bądź formę wprowadzenia opisanego przez klienta rozwiązania  przesyłania pracownikom poleceń drogą mailową",{"entities": [(54,59, "labor_law"),(73,82, "labor_law"),(37,48, "labor_law")]}),
("czy jeżeli lekarz na recepcie wpisze mniejszą dawkę leku niż zawiera całe opakowanie to czy możliwe jest wydanie całego opakowania",{"entities": [(21,29, "pharmaceutical_law"),(46,51, "pharmaceutical_law"),(113,119, "pharmaceutical_law")]}),
("czy klientka może cofnąć wypowiedzenie umowy o pracę rezydentura czy wojewoda musi wyznaczyć inne miejsce odbywania rezydentury jeżeli lekarz medycyny pracy stwierdzi że klientka nie może pracować w szpitalu covidowym w wielkopolsce",{"entities": [(69,77, "medical_law"),(188,196, "medical_law"),(83,92, "medical_law"),(18,24, "medical_law"),(116,127, "medical_law")]}),
("czy przełożony może zmienić zakres obowiązków klientki jaka jest odpowiedzialność klientki w przypadku szkody wyrządzonej pracodawcy na nowym stanowisku czy zmiana stanowiska pracy może wiązać się z obniżeniem wynagrodzenia klientki",{"entities": [(164,174, "labor_law"),(157,163, "labor_law"),(199,209, "labor_law")]}),
("czy klient może samodzielnie podwyższyć stawkę o wskaźnik inflacji i wykazać nową stawkę na fakturze czy wymagany jest aneks do umowy",{"entities": [(40,46, "medical_law"),(82,88, "medical_law"),(119,124, "medical_law"),(77,81, "medical_law"),(29,39, "medical_law")]}),
("czy klient musi być reprezentowany w procesie od początku do końca czy wobec cofnięcia pełnomocnictwa klient może otrzymać zwrot kosztów zastępstwa procesowego",{"entities": [(87,101, "civil_law"),(61,66, "civil_law"),(20,34, "civil_law")]}),
("czy przewidziany przepisami letni okres wydłuża się przy pracy na podstawie umowy zlecenie w niepełnym wymiarze czasu czy farmaceuta może zaliczyć sobie na poczet letniego okresu przepracowane już wcześniej godziny",{"entities": [(28,33, "pharmaceutical_law"),(93,102, "pharmaceutical_law"),(163,171, "pharmaceutical_law")]}),
("kto powinien wyrazić zgodę na samodzielne odbywanie dyżurów medycznych przez klientkę",{"entities": [(42,51, "medical_law"),(21,26, "medical_law")]}),
("czy pracodawca może wysłać pracownika na badanie covid kto ponosi koszty takiego badania",{"entities": [(20,26, "labor_law")]}),
("w jaki sposób klient może ogłosić rozpoczęcie działalności gospodarczej nie naruszając obowiązującego lekarzy zakazu reklamy",{"entities": [(110,116, "criminal_law")]}),
("czy w razie gdyby test męża klientki wyszedł pozytywny to czy klientka będzie obowiązana do odbycia kwarantanny razem z nim",{"entities": [(92,99, "medical_law"),(37,44, "medical_law"),(18,22, "medical_law")]}),
("na jakiej podstawie wspólnota mieszkaniowa może wybrać nowy zarząd czy deweloper w obecnej sprawie pełni funkcję administratora",{"entities": [(71,80, "civil_law"),(55,59, "civil_law"),(60,66, "civil_law")]}),
("który podmiot leczniczy powinien wypłacać dodatek covidowy lekarzowi rezydentowi który odbywa staż zewnętrzny przewidziany w programie specjalizacji i w ramach stażu udziela świadczeń medycznych w szpitalnym oddziale ratunkowym oraz izbie przyjęć",{"entities": [(160,165, "medical_law"),(69,80, "medical_law"),(14,23, "medical_law"),(125,134, "medical_law"),(87,93, "medical_law"),(197,207, "medical_law"),(6,13, "medical_law"),(33,41, "medical_law"),(50,58, "medical_law"),(99,109, "medical_law"),(166,173, "medical_law"),(94,98, "medical_law"),(217,227, "medical_law")]}),
("czy klient będzie ponosił koszty szkolenia w przypadku rozwiązania umowy o pracę za porozumieniem stron czy klient będzie ponosił koszty szkolenia w przypadku gdyby odmówił zmiany stanowiska a następnie pracodawca wypowiedziałby umowę o pracę",{"entities": [(18,25, "labor_law"),(122,129, "labor_law"),(180,190, "labor_law"),(84,97, "labor_law")]}),
("czy szpital ma prawo odmówić przyjęcia pacjenta niecovidowego na odział anestezjologii i intensywnej terapii czy w sytuacji przebywania pacjentów covidowych i niecovidowych w jednym szpitalu muszą być spełnione do dodatkowe wymagania np izolatki osobne ciągi komunikacyjne czy pacjenci ci mogą przebywać w sąsiadujących ze sobą salach",{"entities": [(89,100, "medical_law"),(224,233, "medical_law"),(146,156, "medical_law"),(162,172, "medical_law"),(214,223, "medical_law"),(29,38, "medical_law"),(294,303, "medical_law"),(191,196, "medical_law"),(197,200, "medical_law"),(175,181, "medical_law"),(277,285, "medical_law")]}),
("czy sprzedaż nieruchomości będzie zwolniona z podatku vat",{"entities": [(13,26, "tax_law"),(46,53, "tax_law"),(34,43, "tax_law")]}),
("w nawiązaniu do sprawy o sygnaturze  klientka chce się dowiedzieć czy na przelewie za bilet lotniczy będący dowodem w sprawie może widnieć nazwisko innej osoby",{"entities": [(139,147, "administrative_law"),(86,91, "administrative_law")]}),
("w jakich sytuacjach psycholog który w trakcie terapii poweźmie informację o popełnieniu przestępstwa w przeszłości ma obowiązek zgłosić ten fakt organom ścigania",{"entities": [(140,144, "criminal_law"),(76,87, "criminal_law"),(88,100, "criminal_law"),(54,62, "criminal_law"),(145,152, "criminal_law"),(20,29, "criminal_law"),(9,19, "criminal_law")]}),
("czy wypisując recepty pro auctore i pro familiae w dalszym ciągu można korzystać ze starych druków",{"entities": [(84,91, "medical_law"),(59,64, "medical_law")]}),
("czy pracownik może zwracać się bezpośrednio do reprezentującego go związku zawodowego z prośbą o interwencję w sprawie wykreślenia z akt nagany udzielonej mu przez pracodawcę czy powinien najpierw skorzystać z drogi służbowej",{"entities": [(75,85, "labor_law"),(137,143, "labor_law")]}),
("czy klientka może ubiegać się o świadczenie postojowe",{"entities": [(32,43, "medical_law")]}),
("czy klient może odmówić przyjęcia pacjenta z uwagi na to że kwestionuje on metody leczenia klienta i nie można z nim dojść do porozumienia",{"entities": [(24,33, "medical_law"),(45,50, "medical_law")]}),
("czy klientka ma obowiązek dokonania wpisu do centralnego rejestru podmiotów akcyzowych dalej crpa w związku z nowelizacją ustawy o podatku akcyzowym",{"entities": [(57,65, "tax_law"),(100,107, "tax_law"),(131,138, "tax_law"),(76,86, "tax_law")]}),
("czy żona klienta zobowiązana jest do wykorzystania urlopu wypoczynkowego przed pójściem na urlop wychowawczy",{"entities": [(58,72, "labor_law")]}),
("czy nowy zarząd spółki z oo może podpisać umowę z nfz przed dokonaniem wpisu do krsu",{"entities": [(4,8, "civil_law"),(9,15, "civil_law"),(71,76, "civil_law"),(60,70, "civil_law")]}),
("czy na receptach papierowych należy umieszczać kod kreskowy czy istnieje możliwość nabycia nowych druków recept za pośrednictwem izby lekarskiej",{"entities": [(36,46, "pharmaceutical_law"),(17,28, "pharmaceutical_law"),(7,16, "pharmaceutical_law")]}),
("czy klientce przysługuje roszczenie o wypłatę dodatku covidowego",{"entities": [(25,35, "medical_law")]}),
("czy klienta będzie obowiązywać tajemnica lekarska podczas składania na piśmie zeznań przed sądem cywilnym",{"entities": [(71,77, "medical_law"),(58,67, "medical_law"),(78,84, "medical_law")]}),
("w jaki sposób pracodawca powinien zrekompensować pracownikowi dzień ustawowo wolny od pracy przypadający w sobotę tj dnia  sierpnia  r",{"entities": [(49,61, "labor_law"),(123,131, "labor_law")]}),
("czy można w umowie zastrzec że płatność nastąpi w dwóch częściach pierwsza przy zawarciu umowy a druga przed wydaniem kluczy czy takie zastrzeżenie jest bezpieczne dla sprzedającego",{"entities": [(31,39, "civil_law"),(56,65, "civil_law")]}),
("w jaki sposób należy rozumieć i od kiedy obowiązuje   ust  pkt  lit b rozporządzenia ministra zdrowia w sprawie recept",{"entities": [(85,93, "medical_law"),(41,51, "medical_law")]}),
("czy klientka jako lekarz rezydent może kwalifikować pacjentów do szczepień przeciwko covid",{"entities": [(25,33, "medical_law"),(39,51, "medical_law"),(65,74, "medical_law")]}),
("czy przepisy ustawy o zasadach ustalania minimalnego wynagrodzenia zasadniczego pracowników zatrudnionych w podmiotach leczniczych dotyczą również osób zatrudnionych na stanowisku sprzątaczki",{"entities": [(67,79, "medical_law"),(131,138, "medical_law"),(31,40, "medical_law"),(80,91, "medical_law"),(169,179, "medical_law")]}),
("czy w związku z zaistniałą sytuacją pracownica klienta też została objęta kwarantanną czy pracownica klienta ma możliwość nieodbywania kwarantanny",{"entities": [(74,85, "medical_law"),(67,73, "medical_law")]}),
("czy klientka może skutecznie wycofać wypowiedzenie umowy o pracę jeśli minie okres wypowiedzenia",{"entities": [(29,36, "labor_law")]}),
("czy klientka może prowadzić sprzedaż wysyłkową kosmetyków przez stronę internetową apteki",{"entities": [(47,57, "pharmaceutical_law"),(71,82, "pharmaceutical_law")]}),
("czy świadczenie postojowe jest jednorazowe czy gdyby umowa zlecenia została przekształcona w umowę o pracę to czy klientce przysługiwałyby świadczenia o których mowa w tzw tarczy antykryzysowej przeznaczone dla pracowników",{"entities": [(172,178, "medical_law"),(179,193, "medical_law"),(4,15, "medical_law"),(194,206, "medical_law")]}),
("czy w związku ze zmianą nazwiska klientka musi zmienić nazwę spółki czy w związku ze zmianą nazwy spółki należy ponownie uzyskać zezwolenie na prowadzenie apteki",{"entities": [(24,32, "civil_law"),(17,23, "civil_law"),(85,91, "civil_law")]}),
("jaki wymiar czasu pracy będzie miał zastosowanie do klienta oddelegowanego na podstawie art    kodeksu pracy",{"entities": [(36,48, "labor_law")]}),
("czy klientka ma obowiązek partycypowania w kosztach utrzymania nieruchomości która wchodzi w skład odziedziczonego spadku jak będzie wyglądał dział spadku jeżeli spadkobiercy nie mogą dojść do porozumienia czy zasadnym jest aby klientka udzieliła pełnomocnictwa do prowadzenia tej sprawy zawodowemu pełnomocnikowi",{"entities": [(247,261, "civil_law"),(52,62, "civil_law"),(93,98, "civil_law"),(210,218, "civil_law"),(83,90, "civil_law"),(142,147, "civil_law"),(43,51, "civil_law"),(162,174, "civil_law")]}),
("jakie kroki może podjąć w przedmiotowej sprawie klientka",{"entities": [(0,5, "criminal_law")]}),
("czy klient może wykonywać znieczulenia na oddziale chirurgii jeżeli nie jest zatrudniony jako anestezjolog na oddziale anestezjologicznym",{"entities": [(77,88, "medical_law"),(26,38, "medical_law")]}),
("czy istnieje możliwość pociągnięcia do odpowiedzialności zawodowej biegłego lekarza za treść opinii",{"entities": [(87,92, "medical_law"),(67,75, "medical_law")]}),
("czy klientowi przysługuje dodatek za pracę w jednym miejscu na podstawie rozporządzenia ministra zdrowia z dnia  kwietnia  r w sprawie standardów w zakresie ograniczeń przy udzielaniu świadczeń opieki zdrowotnej pacjentom innym niż z podejrzeniem lub zakażeniem wirusem sarscov przez osoby wykonujące zawód medyczny mające bezpośredni kontakt z pacjentami z podejrzeniem lub zakażeniem tym wirusem",{"entities": [(88,96, "medical_law"),(323,334, "medical_law"),(251,261, "medical_law"),(375,385, "medical_law"),(262,269, "medical_law"),(173,183, "medical_law"),(157,167, "medical_law"),(123,124, "medical_law"),(335,342, "medical_law"),(270,277, "medical_law"),(135,145, "medical_law"),(345,355, "medical_law"),(45,51, "medical_law"),(234,246, "medical_law"),(358,370, "medical_law")]}),
("co klientka ma zrobić z dokumentacją medyczną czy klientka może oddać dokumentacje medyczną do archiwum",{"entities": [(70,82, "medical_law"),(24,36, "medical_law")]}),
("w jak sposób klient może odrzucić spadek",{"entities": [(25,33, "civil_law")]}),
("czy klient po powrocie będzie musiał odbyć kwarantannę czy przepisy wprowadzające obowiązek kwarantanny po powrocie do polski są zgodne z konstytucją",{"entities": [(14,22, "constitutional_law"),(107,115, "constitutional_law"),(59,67, "constitutional_law")]}),
("w jakim zakresie rodzic odpowiada za złamanie kwarantanny przez czternastoletnie dziecko w jakim zakresie czternastoletnie dziecko odpowiada za złamanie kwarantanny",{"entities": [(46,57, "criminal_law"),(17,23, "criminal_law"),(37,45, "criminal_law"),(144,152, "criminal_law")]}),
("czy klientka mogła korzystać z zasiłku opiekuńczego w okresie gdy mąż klientki zawiesił prowadzenie działalności gospodarczej czy klientka mogła korzystać z zasiłku opiekuńczego w dniu w którym odbywała wieczorny dyżur czy klientka powinna podjąć jakieś kroki w związku z zaistniałą sytuacją",{"entities": [(213,218, "medical_law"),(180,184, "medical_law"),(194,202, "medical_law")]}),
("czy klient może udzielać świadczeń zdrowotnych pacjentom którzy nie są chorzy na covid czy klient jest obowiązany do odbycia kwarantanny",{"entities": [(117,124, "medical_law")]}),
("czy konieczność używania nowych druków recept od  lipca  r dotyczy również lekarzy radiologów którzy wypisują recepty wyłącznie na swoje potrzeby",{"entities": [(16,24, "medical_law"),(57,58, "medical_law"),(25,31, "medical_law")]}),
("czy lekarz specjalista musi być obecny fizycznie podczas konsultacji na prośbę lekarza rezydenta czy szpital może nakazać pracę lekarzom ponad  h w tygodniu bez podpisania klauzuli optout z jakim wyprzedzeniem lekarz musi dowiedzieć się że będzie pełnił dyżur",{"entities": [(247,253, "medical_law"),(11,22, "medical_law"),(28,31, "medical_law"),(128,136, "medical_law"),(172,180, "medical_law"),(181,187, "medical_law")]}),
("czy pracodawca może ustnie polecić klientowi kwalifikowanie pacjentów do szczepień na covid czy pracodawca powinien zapewnić rezydentom nadzór wykwalifikowanego w tym przedmiocie lekarza w jakich godzinach lekarz rezydent może kwalifikować pacjentów czy za kwalifikowanie pacjentów do szczepień przysługuje dodatek do wynagrodzenia",{"entities": [(45,59, "medical_law"),(257,271, "medical_law"),(136,142, "medical_law"),(213,221, "medical_law"),(227,239, "medical_law"),(73,82, "medical_law"),(285,294, "medical_law"),(143,160, "medical_law"),(125,135, "medical_law")]}),
("czy dyrektor szkoły specjalnej może zarządzić odbywanie zajęć stacjonarnie również dla klas",{"entities": [(46,55, "medical_law"),(56,61, "medical_law")]}),
("czy w sytuacji gdy postępowanie egzekucyjne zostanie zawieszone klient nie będzie musiał wnosić opłat egzekucyjnych czy w takim wypadku klient będzie zwolniony z wszelkich opłat egzekucyjnokomorniczych",{"entities": [(102,115, "civil_law")]}),
("jakie kroki prawne może podjąć klientka",{"entities": [(0,5, "criminal_law"),(12,18, "criminal_law")]}),
("z jakiego powodu sąd nie zdecydował się na rozpatrzenie sprawy w postępowaniu nakazowym",{"entities": [(43,55, "civil_law")]}),
("czy w świetle obowiązujących przepisów klient będzie miał rację w sporze ze sprzedawcą kas fiskalnych",{"entities": [(46,52, "administrative_law")]}),
("czy klientka może podjąć skuteczne kroki w celu uchylenia uchwały wspólnoty mieszkaniowej",{"entities": [(58,65, "civil_law")]}),
("czy w związku z epidemią klientka może wznowić planowe przyjęcia protetyczne",{"entities": [(16,24, "medical_law"),(55,64, "medical_law")]}),
("czy klient może odmówić przyjęcia pacjenta z uwagi na to że kwestionuje on metody leczenia klienta i nie można z nim dojść do porozumienia",{"entities": [(24,33, "medical_law"),(45,50, "medical_law")]}),
("czy oświadczenie o posiadanym prawie do dysponowania nieruchomością która stanowi współwłasność klienta i jego brata na cele budowlane może złożyć małżonka klienta",{"entities": [(120,124, "administrative_law"),(125,134, "administrative_law")]}),
("czy lekarz stażysta może bez nadzoru kwalifikować pacjentów do szczepień przeciwko covid jak kształtuje się kwestia wynagrodzenia lekarza stażysty za przeprowadzanie kwalifikacji do szczepień przeciwko covid czy polecenie pracodawcy dotyczące ww czynności powinno być wydane na piśmie",{"entities": [(138,146, "medical_law"),(243,245, "medical_law"),(11,19, "medical_law"),(256,263, "medical_law"),(264,267, "medical_law"),(37,49, "medical_law"),(63,72, "medical_law"),(182,191, "medical_law")]}),
("w jaki sposób klientka może poinformować pacjenta o tym że odstępuje od leczenia jeżeli klientka zdecyduje się na rozmowę telefoniczną to czy może nagrać tą rozmowę jeżeli klientka zdecyduje się na rozmowę z pacjentem to czy przy tej rozmowie może być obecny inny lekarz jak należy rozumieć pojęcie nieudzielenia pomocy w niebezpieczeństwie utraty życia ciężkiego uszkodzenia ciała lub ciężkiego rozstroju zdrowia",{"entities": [(348,353, "criminal_law"),(114,121, "criminal_law"),(157,164, "criminal_law"),(198,205, "criminal_law"),(97,106, "criminal_law"),(181,190, "criminal_law"),(28,40, "criminal_law"),(264,270, "criminal_law"),(354,363, "criminal_law"),(386,395, "criminal_law"),(282,290, "criminal_law")]}),
("czy klientka może podjąć dodatkową pracę w ośrodku rehabilitacyjnym niebędącym jednostką macierzystą w której odbywa ona staż podyplomowy",{"entities": [(79,88, "medical_law"),(110,116, "medical_law"),(121,125, "medical_law")]}),
("czy klientka może być powołana do zwalczania epidemii na stanowisko inne niż lekarz pediatra jakie konsekwencje grożą klientce jeżeli nie stawi się w miejscu skierowania na jakich zasadach jest nakładana kara za niestawienie się w miejscu skierowania czy w przypadku gdy szpital nie zapewni klientce środków ochrony osobistej może ona odmówić pracy przy zwalczaniu epidemii czy obowiązkowe ubezpieczenie oc klientki będzie obowiązywało w miejscu w którym zostanie skierowana klientka jak kształtuje się odpowiedzialność lekarza skierowanego do pracy przy zwalczaniu epidemii za ewentualne błędy medyczne jakie uprawnienia wynikające ze stosunku pracy ma lekarz skierowany do zwalczania epidemii",{"entities": [(520,527, "criminal_law"),(93,98, "criminal_law"),(604,609, "criminal_law"),(300,307, "criminal_law"),(354,364, "criminal_law"),(555,565, "criminal_law"),(77,83, "criminal_law"),(654,660, "criminal_law"),(390,403, "criminal_law"),(578,588, "criminal_law"),(158,169, "criminal_law"),(239,250, "criminal_law"),(45,53, "criminal_law"),(365,373, "criminal_law"),(566,574, "criminal_law"),(610,621, "criminal_law"),(180,188, "criminal_law")]}),
("jakie są prawa i obowiązki klientki na przesłuchaniu w charakterze świadka czy ze świadka klientka może stać się podejrzaną lub oskarżoną w sprawie",{"entities": [(0,5, "criminal_law"),(67,74, "criminal_law"),(82,89, "criminal_law"),(55,66, "criminal_law")]}),
("czy klientka może powołać się na klauzulę sumienia",{"entities": [(33,41, "medical_law"),(18,25, "medical_law")]}),
("czy jeżeli klientka odmówi pracy na oddziale macierzystym to pracodawca może wypowiedzieć jej umowę czy polecenie ordynatora jest zgodne z prawem",{"entities": [(45,57, "medical_law")]}),
("czy w opisanych przez klientkę warunkach przeprowadzenie teleporady jest zgodnez prawem gdzie rodzice dziecka mogą zgłosić zaistniałą sytuację gdyby okazało się że postępowanie lekarza jest niezgodne z prawem",{"entities": [(57,67, "medical_law"),(149,156, "medical_law"),(41,56, "medical_law")]}),
("czy refundowane wyroby medyczne np pieluchomajtki można przesuwać między aptekami oróżnych nipach",{"entities": [(16,22, "pharmaceutical_law"),(4,15, "pharmaceutical_law")]}),
("czy obowiązek posiadania kas fiskalnych online od  lipca  r dotyczy lekarzy i podmiotów leczniczych",{"entities": [(29,39, "tax_law"),(51,56, "tax_law"),(14,24, "tax_law"),(25,28, "tax_law"),(68,75, "tax_law"),(60,67, "tax_law")]}),
("czy fakt że pożyczkobiorca klienta  spółka jawna  została wykreślona z krajowego rejestru sądowego wpływa negatywnie na możliwość egzekwowania długu przez klienta",{"entities": [(90,98, "civil_law"),(143,148, "civil_law")]}),
("czy klientka powinna mieć przy sobie akt małżeństwa w celu udowodnienia że certyfikat covid oraz karta ekuz zostały wystawione dla niej",{"entities": [(21,25, "medical_law"),(75,85, "medical_law"),(116,126, "medical_law")]}),
("co powinien zrobić klient w celu wyegzekwowania zapłaty dodatku covidowego w przypadku w którym wezwanie do zapłaty okazało się nieskuteczne",{"entities": [(116,123, "medical_law"),(64,74, "medical_law")]}),
("czy klientka może się odwołać od zapisu w notatce policyjnej który jest nierzetelny i niezgodny z zaistniałym zdarzeniem czy dokumenty historii choroby syna klientki wpływają na kwalifikację prawną zdarzenia w kwestii czy doszło do wypadku drogowego czy kolizji czy policja powinna była poinformować męża i syna klientki o zakończeniu prowadzenia postępowania",{"entities": [(191,197, "criminal_law"),(144,151, "criminal_law"),(287,299, "criminal_law")]}),
("czy podwieszka znajdująca się nad miejscem postojowym położona jest na odpowiedniej wysokości czy klient może domagać się usunięcia podwieszki mimo że mógł się dowiedzieć o jej istnieniu w momencie zakupu miejsca postojowego",{"entities": [(122,131, "administrative_law")]}),
("czy konkurencyjna firma może zgłosić do urzędu unii europejskiej ds własności intelektualnej że firma klienta nie ma prawa do wykorzystywania wzoru przemysłowego",{"entities": [(4,17, "international_law")]}),
("czy klient może wliczyć czas stażu do okresu wymaganego doświadczenia zawodowego",{"entities": [(29,34, "medical_law"),(24,28, "medical_law")]}),
("czy komenda rejonowa policji wydział do walki z przestępczością przeciwko mieniu zajmując się sprawami cywilnoprawnymi może orzec wiążącą mającą skutki prawne decyzję",{"entities": [(152,158, "criminal_law")]}),
("co może zrobić kupujący gdy po podpisaniu umowy przedwstępnej a przed zawarciem umowy przyrzeczonej sprzedawca umiera a kupujący chciałby zakupić dom jaka jest różnica zawarcia umowy przedwstępnej w formie umowy pisemnej i aktu notarialnego",{"entities": [(48,61, "civil_law"),(183,196, "civil_law"),(160,167, "civil_law")]}),
("czy lekarz dentysta nieposiadający specjalizacji który uczestniczył w licznych kursachi posiada wieloletnie doświadczenie kliniczne może zostać uznany za specjalistę ortodoncji",{"entities": [(154,165, "medical_law"),(108,121, "medical_law"),(11,19, "medical_law")]}),
("czy rękawice ochronne muszą spełniać specjalne normy bezpieczeństwa czy klient może zastąpić rękawice ochronne zwykłymi rękawiczkami foliowymi",{"entities": [(53,67, "international_law"),(4,12, "international_law"),(93,101, "international_law"),(13,21, "international_law"),(102,110, "international_law")]}),
("czy w przedmiotowej sprawie doszło do skutecznego podjęcia uchwał czy zarządca ma obowiązek wykonać te uchwały",{"entities": [(59,65, "civil_law"),(70,78, "civil_law")]}),
("w jaki sposób klient powinien złożyć zeznania",{"entities": [(30,36, "criminal_law")]}),
("jak w najszybszy sposób klientka może rozwiązać umowę o pracę zawartą na czas określony jaki okres wypowiedzenia obowiązuje klientkę",{"entities": [(62,69, "labor_law")]}),
("czy lekarz jest zobowiązany do wydania pacjentowi opisu tomografii przetłumaczonego na język polski",{"entities": [(56,66, "medical_law"),(50,55, "medical_law"),(39,49, "medical_law")]}),
("czy dzieci klienta powinny obecnie dokonać czynności zmierzających do zrzeczenia się ewentualnego dziedziczenia po zmarłym spadkodawcy",{"entities": [(85,97, "civil_law"),(115,122, "civil_law"),(98,111, "civil_law")]}),
("czy niepubliczny zakład opieki zdrowotnej jako prywatny ośrodek ma obowiązek prowadzenia dokumentacji medycznej w formie elektronicznej",{"entities": [(47,55, "medical_law")]}),
("czy klient będący farmaceutą może wziąć udział w materiałach filmowych typu webinar dotyczących produktów leczniczych danej firmy farmaceutycznej",{"entities": [(34,39, "pharmaceutical_law")]}),
("czy klientowi przysługuje do wynagrodzenia tzw dodatek covidowy w wysokości   wynagrodzenia",{"entities": [(55,63, "medical_law")]}),
("czy klientka może podjąć skuteczne kroki dążące do obniżenia opłat utrzymania miejsc parkingowych",{"entities": [(67,77, "civil_law")]}),
("czy pracodawca może nagrywać głos i obraz w kabinie maszynisty w jakich sytuacjach pracodawca może przeglądać nagrania monitoringu czy pracodawca może nagrywać głos i obraz celem upokarzania pracowników",{"entities": [(29,33, "administrative_law"),(160,164, "administrative_law"),(44,51, "administrative_law"),(119,130, "administrative_law"),(36,41, "administrative_law"),(167,172, "administrative_law")]}),
("na jakiej podstawie oraz w jakiej formie należy zatrudnić osobę do pełnienia obowiązków klientki kto będzie osobą odpowiedzialną przez okres usprawiedliwionej nieobecności klientki w pracy",{"entities": [(114,128, "pharmaceutical_law")]}),
("jakie kroki należy poczynić aby uruchomić sprawę spadkową jakie dokumenty będą potrzebne do przeprowadzenia postępowania spadkowego",{"entities": [(79,88, "civil_law"),(49,57, "civil_law")]}),
("czy klientka ma prawo odmówić podpisana historii leczenia pacjentki jeżeli nie jest pewna oraz nie ma możliwości tego zweryfikowania czy klientka ma obowiązek podpisać dokumentację medyczną ze wsteczną datą która nie spełnia norma prawnych czy pracodawca może przenieść odpowiedzialność za błąd medyczny na klientkę",{"entities": [(217,224, "medical_law"),(202,206, "medical_law"),(40,48, "medical_law"),(290,294, "medical_law")]}),
("czy osoba która nie jest farmaceutą może być wspólnikiem spółki jawnej prowadzącej aptekę czy zmiana w strukturze właścicielskiej spółki pociąga za sobą konieczność uzyskania nowej koncesji",{"entities": [(83,89, "pharmaceutical_law"),(114,129, "pharmaceutical_law"),(137,144, "pharmaceutical_law"),(103,113, "pharmaceutical_law"),(71,82, "pharmaceutical_law")]}),
("czy apteka może wystawić fakturę za zrealizowane recepty na pacjenta oraz leki dostępne bez recepty gdzie nabywcą jest sam pacjent ale płatnikiem dom opieki społecznej albo fundacja",{"entities": [(49,56, "tax_law"),(92,99, "tax_law"),(25,32, "tax_law"),(74,78, "tax_law"),(150,156, "tax_law"),(106,113, "tax_law"),(4,10, "tax_law")]}),
("czy klientka może udostępnić ubezpieczycielowi posiadaną dokumentację medyczną zmarłego pacjenta",{"entities": [(47,56, "medical_law"),(29,46, "medical_law")]}),
("jak należy rozumieć stwierdzenie iż klient nabył spadek po ojcu w całości czy notariusz który sporządził umowę dożywocia może wydać klientowi jej wypis lub kopię czy klient nabywając spadek po ojcu w całości nabył również własność pozostawionych przez ojca ruchomości",{"entities": [(222,230, "civil_law"),(43,48, "civil_law"),(208,213, "civil_law"),(231,245, "civil_law"),(20,32, "civil_law"),(66,73, "civil_law"),(200,207, "civil_law"),(49,55, "civil_law"),(183,189, "civil_law"),(59,63, "civil_law"),(193,197, "civil_law")]}),
("czy lekarz jest zobowiązany do wydania pacjentowi opisu tomografii przetłumaczonego na język polski",{"entities": [(56,66, "medical_law"),(50,55, "medical_law"),(39,49, "medical_law")]}),
("czy wspólnota mieszkaniowa może czerpać korzyści z posiadania w kamienicy skrzynki energetycznej zktórej zasilane są również inne budynki",{"entities": [(74,82, "civil_law"),(64,73, "civil_law")]}),
("czy z prawnego punktu widzenia niepożądany odczyn poszczepienny jest zdarzeniem niepożądanym",{"entities": [(15,21, "pharmaceutical_law")]}),
("czy klientka mogłaby zostać skierowana do pracy na innym oddziale który nie jest związany z jej specjalizacją i umiejętnościami czy w razie skierowania klientki na oddział niezwiązany z jej specjalizacją i umiejętnościami ponosi ona jakąkolwiek odpowiedzialność prawną karną cywilną dyscyplinarną czy umownie mogłaby być zwolniona z odpowiedzialności czy w razie skierowania klientki na oddział wykraczający poza jej specjalizację i umiejętności może ona natychmiastowo rozwiązać umowę",{"entities": [(262,268, "criminal_law"),(13,20, "criminal_law"),(309,316, "criminal_law"),(417,430, "criminal_law"),(51,56, "criminal_law"),(112,127, "criminal_law"),(206,221, "criminal_law"),(96,109, "criminal_law"),(190,203, "criminal_law"),(283,296, "criminal_law"),(222,228, "criminal_law"),(333,350, "criminal_law"),(164,171, "criminal_law"),(387,394, "criminal_law"),(140,151, "criminal_law"),(363,374, "criminal_law")]}),
("czy pracownicy wspólnoty mieszkaniowej którzy zajmują kierownicze stanowiska mają nienormowany czas pracy",{"entities": [(4,14, "labor_law"),(66,76, "labor_law"),(54,65, "labor_law")]}),
("czy lekarz odbywający szkolenie specjalizacyjne z dziedziny ginekologii może zostać skierowany do pracy przy zwalczaniu epidemii kto może skierować lekarza rezydenta do pracy przy zwalczaniu epidemii",{"entities": [(22,31, "medical_law"),(50,59, "medical_law"),(60,71, "medical_law"),(32,47, "medical_law"),(138,147, "medical_law"),(84,94, "medical_law")]}),
("ile maksymalnie może pracować lekarz rezydent bez klauzuli optout w ciągu tygodnia wprzyjętym okresie rozliczeniowym",{"entities": [(21,29, "medical_law"),(37,45, "medical_law"),(68,73, "medical_law"),(50,58, "medical_law"),(59,65, "medical_law")]}),
("jaki jest zakres wymaganych świadczeń medycznych lekarza podstawowej opieki zdrowotnej w odniesieniu do osoby chorej na chorobę zakaźną",{"entities": [(17,27, "medical_law")]}),
("czy klientka po śmierci swojego brata będzie zobowiązana do zapłaty zachowku na rzecz żyjącej córki brata czy na skutek darowania udziału w prawie własności nieruchomości synowi klientka będzie miała jakieś obowiązki względem swojej córki",{"entities": [(113,119, "civil_law"),(171,177, "civil_law"),(68,76, "civil_law"),(140,146, "civil_law"),(147,156, "civil_law")]}),
("w jaki sposób gabinet lekarski klienta może sprowadzić preparaty witaminowe z innego kraju unii europejskiej",{"entities": [(44,54, "pharmaceutical_law"),(55,64, "pharmaceutical_law"),(65,75, "pharmaceutical_law")]}),
("jaką podstawę prawną zwolnienia z vat klient powinien wpisać na fakturze",{"entities": [(21,31, "tax_law")]}),
("czy klientka może powołać się na klauzulę sumienia",{"entities": [(33,41, "medical_law"),(18,25, "medical_law")]}),
("czy córka klienta nadal może wystawiać paragony w formie papierowej czy musi to robić online czy klient będący lekarzem na emeryturze może wystawiać paragony w formie papierowej",{"entities": [(39,47, "tax_law"),(149,157, "tax_law"),(80,85, "tax_law"),(4,9, "tax_law"),(123,133, "tax_law"),(57,67, "tax_law")]}),
("czy lekarz może wykonać szczepienie szczepionką przyniesioną przez pacjenta",{"entities": [(24,35, "medical_law")]}),
("czy lekarz rezydent może otrzymać polecenie konsultowania w ramach szpitalnego oddziału ratunkowego oraz dyżurowania na dwóch oddziałach jednocześnie",{"entities": [(126,136, "medical_law"),(88,99, "medical_law"),(79,87, "medical_law"),(11,19, "medical_law"),(105,116, "medical_law")]}),
("czy prawnie dopuszczalnym jest wprowadzenie możliwości głosowania elektronicznego przez internet przez członków wspólnoty mieszkaniowej mailowo lub przez odpowiedni program bez podpisu elektronicznego",{"entities": [(66,81, "civil_law"),(88,96, "civil_law"),(31,43, "civil_law")]}),
("czy w przypadku zlecenia zarządzania wspólnotą mieszkaniową zewnętrznej firmie zarządzającej zarząd wspólnoty przed podpisaniem umowy z firmą musi uzyskać zgodę wspólnoty mieszkaniowej",{"entities": [(93,99, "civil_law"),(47,59, "civil_law")]}),
("jakie prawa i obowiązki ma osoba wezwana na przesłuchanie w charakterze świadka wpostępowaniu cywilnym jak kształtuje się odpowiedzialność klienta w przedmiotowej sprawie",{"entities": [(33,40, "medical_law"),(80,93, "medical_law")]}),
("czy klient może skutecznie odwołać się od decyzji jakie są warunki pracy w przypadku oddelegowania do pracy przy zwalczaniu epidemii przez wojewodę",{"entities": [(59,66, "medical_law")]}),
("jaka jest podstawa prawna wymogu monitorowania temperatury podczas transportu wyrobów medycznych",{"entities": [(10,18, "medical_law"),(19,25, "medical_law"),(47,58, "medical_law")]}),
("jakie są limity pracy w godzinach nadliczbowych w podstawowym systemie czasu pracy",{"entities": [(34,47, "labor_law")]}),
("kto ponosi koszty wymiany bezpieczników licznikowych oraz samych liczników przynależnych do poszczególnych mieszkań we wspólnocie mieszkaniowej kto ponosi koszty związane ze zużyciem wody z pionu mokrego",{"entities": [(107,115, "civil_law"),(65,74, "civil_law"),(183,187, "civil_law"),(92,106, "civil_law")]}),
("czy na receptach spoza ue zagranicznych np z ukrainy na rewersie należy wpisywać dane paszportu",{"entities": [(56,64, "pharmaceutical_law"),(7,16, "pharmaceutical_law"),(72,80, "pharmaceutical_law")]}),
("jakie są prawa i obowiązki klientki na przesłuchaniu w charakterze świadka czy ze świadka klientka może stać się podejrzaną lub oskarżoną w sprawie",{"entities": [(0,5, "criminal_law"),(67,74, "criminal_law"),(82,89, "criminal_law"),(55,66, "criminal_law")]}),
("czy klientka może negocjować pracę w wymiarze  lub  dni w tygodniu jakie załączniki stanowią integralną część umowy czy szpital będzie mógł zmienić miejsce wykonywania świadczeń z pracowni na poradnię dlaczego w   pkt  umowy jest mowa o dniach roboczych jeżeli w materiałach informacyjnych nie ma tego zapisu",{"entities": [(37,45, "medical_law")]}),
("czy klientka musi przesłać całą dokumentację medyczną kancelarii prawnej",{"entities": [(27,31, "medical_law")]}),
("co należy zrobić jeśli w internecie pojawią się opinie oczerniające lekarza",{"entities": [(36,43, "administrative_law"),(55,67, "administrative_law"),(48,54, "administrative_law"),(25,35, "administrative_law")]}),
("jakie prawa i obowiązki ma osoba wezwana na przesłuchanie w charakterze świadka wpostępowaniu cywilnym",{"entities": [(33,40, "medical_law"),(80,93, "medical_law")]}),
("jak przedstawia się obowiązek przechowywania dokumentacji medycznej w przypadku zakończenia prowadzenia działalności leczniczej",{"entities": [(80,91, "medical_law")]}),
("czy klient ma podstawy do ubiegania się o wypłatę tzw dodatku covidowego",{"entities": [(14,22, "medical_law"),(26,35, "medical_law")]}),
("czy wspólnota mieszkaniowa powinna wyrazić zgodę w formie uchwały na zlikwidowanie wewnętrznej instalacji gazowej przez właścicielkę lokalu mieszkalnego i zastąpienie jej instalacją elektryczną",{"entities": [(95,105, "civil_law"),(58,65, "civil_law")]}),
("czy nowa właścicielka nieruchomości powinna wystąpić do sądu z wnioskiem o eksmisję czy przepisy o covid chronią klienta przed eksmisją czy eksmisji powinny dokonać organy policji",{"entities": [(9,21, "civil_law"),(140,148, "civil_law")]}),
("czy pracodawca ma prawo nie udzielić zgody na bezpłatny urlop pracownika",{"entities": [(46,55, "labor_law")]}),
("czy lekarzowi który pracuje w zakładzie opieki leczniczej zol częste przypadki covid przysługuje tzw dodatek covidowy",{"entities": [(58,61, "medical_law"),(47,57, "medical_law")]}),
("w jaki sposób klient powinien przechowywać dokumentację medyczną po zakończeniu działalności podmiotu leczniczego",{"entities": [(30,42, "medical_law")]}),
("czy duża wspólnota mieszkaniowa może zawrzeć z właścicielem sąsiedniej nieruchomości umowę umożliwiającą przejazd przez sąsiednią nieruchomość przez członków wspólnoty jeżeli odpowiedź na pytanie pierwsze jest twierdząca w jakiej formie powinna zostać sporządzona taka umowa czy klientka może otrzymać wzór takiej umowy",{"entities": [(252,263, "civil_law"),(4,8, "civil_law"),(196,204, "civil_law")]}),
("czy przed powrotem do pracy klient powinien uzyskać stosowne zaświadczenie lub decyzję z których wynikałby fakt odbycia przez niego obowiązkowej dniowej kwarantanny",{"entities": [(10,18, "medical_law"),(112,119, "medical_law"),(132,144, "medical_law"),(61,74, "medical_law")]}),
("czy przychodnia może zaszczepić z pozostałych szczepionek pracowników medycznych spoza placówki zapisanych na szczepienie ale nie mających skierowania w systemie kto odpowiada za zachowanie kolejności szczepień zgodnie z planem",{"entities": [(110,121, "medical_law"),(4,15, "medical_law"),(58,69, "medical_law"),(21,31, "medical_law"),(153,161, "medical_law"),(201,210, "medical_law"),(130,138, "medical_law")]}),
("czy mama klientki musi powiadomić zarząd wspólnoty mieszkaniowej o remoncie centralnego ogrzewania w swoim mieszkaniu grzejnika czy po skończeniu remontu członkowie zarządu mają prawo wejść do mieszkania w celu weryfikacji przeprowadzonych robót",{"entities": [(4,8, "civil_law"),(34,40, "civil_law"),(146,153, "civil_law"),(184,189, "civil_law"),(154,164, "civil_law"),(107,117, "civil_law"),(88,98, "civil_law")]}),
("jakie należy podjąć kroki w celu ubezwłasnowolnienia częściowego brata klienta",{"entities": [(33,52, "civil_law")]}),
("czy jeżeli nabywcą leku jest stowarzyszenie apteka jest zobowiązana zamieścić na paragonie numer nip",{"entities": [(11,18, "tax_law"),(44,50, "tax_law"),(56,67, "tax_law")]}),
("czy pracodawca będzie mógł wypowiedzieć umowę o pracę jeżeli pracownik skorzysta z dnia wolnego na oddanie krwi czy w przypadku takiego wypowiedzenia pracownik będzie mógł się odwołać",{"entities": [(88,95, "labor_law")]}),
("w jakiej formie należy doręczyć szpitalowi zaświadczenie o przeciwwskazaniach do odbywania dyżurów godzinnych czy klientka może przestać dyżurować po wyrobieniu dyżurów wynikających z programu specjalizacji",{"entities": [(137,146, "medical_law"),(184,192, "medical_law"),(43,56, "medical_law"),(128,136, "medical_law")]}),
("czy podczas odbywania kwarantanny możliwa jest praca zdalna czy pracodawca może odmówić pracownikowi możliwości pracy zdalnej w trakcie kwarantanny",{"entities": [(53,59, "labor_law"),(47,52, "labor_law"),(88,100, "labor_law"),(118,125, "labor_law")]}),
("w jakiej formie zawrzeć umowę pożyczki czy  złotych w ramach procentu od pożyczki będzie podlegało opodatkowaniu czy można ustanowić hipotekę na zakupionej przez córkę klienta i jej męża nieruchomości",{"entities": [(99,112, "civil_law")]}),
("czy można pozbawić prawa własności osobę która otrzymała udział w nieruchomości w formie darowizny",{"entities": [(25,34, "civil_law")]}),
("czy lekarzom przysługuje zasiłek opiekuńczy w sytuacji gdy zdecydują się na pozostanie w domu z uczącym się zdalnie dzieckiem w wieku poniżej  lat czy są od tego wyłączeni z powodu możliwości oddania dziecka do świetlicy szkolnej jako członkowie służb medycznych",{"entities": [(246,251, "medical_law"),(143,146, "medical_law"),(4,12, "medical_law")]}),
("co w zaistniałej sytuacji może zrobić klient dlaczego zmianę decyzji dostarczono w pierwszej kolejności zakładowi pracy a nie klientowi",{"entities": [(54,60, "labor_law")]}),
("jakie są prawa i obowiązki klientki w związku z wezwaniem do stawiennictwa na przesłuchanie w charakterze podejrzanego",{"entities": [(0,5, "criminal_law"),(61,74, "criminal_law"),(94,105, "criminal_law"),(48,57, "criminal_law"),(78,91, "criminal_law")]}),
("w jaki sposób klient może uzyskać numer księgi wieczystej swojego mieszkania",{"entities": [(40,46, "civil_law"),(47,57, "civil_law")]}),
("czy działanie pacjentki jest zgodne z prawem jeżeli działanie pacjentki jest niezgodne z prawem jakie konsekwencje można względem niej wyciągnąć",{"entities": [(77,86, "administrative_law")]}),
("na jakiej podstawie wspólnota mieszkaniowa może wybrać nowy zarząd czy deweloper w obecnej sprawie pełni funkcję administratora",{"entities": [(71,80, "civil_law"),(55,59, "civil_law"),(60,66, "civil_law")]}),
("jak należy rozumieć stwierdzenie iż klient nabył spadek po ojcu w całości czy notariusz który sporządził umowę dożywocia może wydać klientowi jej wypis lub kopię czy klient nabywając spadek po ojcu w całości nabył również własność pozostawionych przez ojca ruchomości",{"entities": [(222,230, "civil_law"),(43,48, "civil_law"),(208,213, "civil_law"),(231,245, "civil_law"),(20,32, "civil_law"),(66,73, "civil_law"),(200,207, "civil_law"),(49,55, "civil_law"),(183,189, "civil_law"),(59,63, "civil_law"),(193,197, "civil_law")]}),
("czy zmiana w strukturze właścicielskiej spółki jawnej pociąga za sobą konieczność uzyskania nowego zezwolenia na prowadzenie apteki w jaki sposób do spółki jawnej może dołączyć nowy wspólnik",{"entities": [(24,39, "pharmaceutical_law"),(99,109, "pharmaceutical_law"),(54,61, "pharmaceutical_law"),(13,23, "pharmaceutical_law")]}),
("czy prawnie dopuszczalnym jest wprowadzenie możliwości głosowania elektronicznego przez internet przez członków wspólnoty mieszkaniowej mailowo lub przez odpowiedni program bez podpisu elektronicznego",{"entities": [(66,81, "civil_law"),(88,96, "civil_law"),(31,43, "civil_law")]}),
("jak powinna zachować się klientka w związku z wezwaniem przez policję na przesłuchanie w charakterze świadka",{"entities": [(89,100, "criminal_law"),(46,55, "criminal_law"),(73,86, "criminal_law")]}),
("czy klient jest uprawniony do wydania zaświadczenia potrzebnego w ramach postępowaniao ubezwłasnowolnienie czy klient może wydać zaświadczenie pacjentce która nie posiada dowodu osobistego",{"entities": [(87,106, "medical_law"),(143,152, "medical_law"),(171,177, "medical_law"),(16,26, "medical_law"),(38,51, "medical_law"),(129,142, "medical_law")]}),
("czy klientka może wykonywać badania u kobiet w drugim trymestrze ciąży czy klientka może zostać pociągnięta do odpowiedzialności karnej za nierozpoznanie wady płodu w drugim trymestrze",{"entities": [(89,95, "pharmaceutical_law"),(47,53, "pharmaceutical_law"),(167,173, "pharmaceutical_law"),(54,64, "pharmaceutical_law")]}),
("czy klientka ma obowiązek wykonać polecenie pracodawcy czy zakres polisy oc którą posiada klientka pokrywa także badanie pacjentów skierowanych przez policję czy osoby współpracujące z podmiotem leczniczym na podstawie umów cywilnoprawnych również mogą zostać zmuszeni do badania pacjentów skierowanych przez policję",{"entities": [(131,143, "labor_law"),(290,302, "labor_law"),(224,239, "labor_law")]}),
("czy przekazanie przez klienta dokumentacji medycznej ubezpieczycielowi stanowi naruszenie tajemnicy lekarskiej czy przekazanie ubezpieczycielowi przez klienta informacji niezapisanych mających istotny wpływ na przebieg sprawy stanowi naruszenie tajemnicy lekarskiej",{"entities": [(79,89, "medical_law"),(234,244, "medical_law"),(184,192, "medical_law"),(53,70, "medical_law"),(127,144, "medical_law")]}),
("jaka forma prawna przedsiębiorstwa pozwoli zatrudnić lekarza dentystę na podstawie umowy o pracę",{"entities": [(61,69, "medical_law"),(11,17, "medical_law")]}),
("czy z korespondencji z pacjentką wynika groźba w stosunku do klientki",{"entities": [(40,46, "criminal_law")]}),
("jakie są prawa i obowiązki klienta na przesłuchaniu w charakterze świadka czy na przesłuchaniu klienta będzie obowiązywać tajemnica lekarska",{"entities": [(0,5, "criminal_law"),(66,73, "criminal_law"),(54,65, "criminal_law"),(110,121, "criminal_law")]}),
("czy postępowanie szpitala narusza prawa pracownicze a w szczególności przepisy obezpieczeństwie i higienie pracy",{"entities": [(26,33, "labor_law")]}),
("jak długo apteka musi pozostać zamknięta po jej sprzedaży w jakim terminie inspektorat sanitarny powinien rozpoznać wniosek o przeniesienie zezwolenia na prowadzenie apteki ogólnodostępnej",{"entities": [(140,150, "pharmaceutical_law"),(126,139, "pharmaceutical_law"),(31,40, "pharmaceutical_law")]}),
("czy klientka chcąc aby recepcjonistka przygotowała dokumentację medyczną pacjenta następnego dnia rano ma możliwość wysłania wiadomości sms zawierającej imię i nazwisko pacjenta na telefon znajdujący się w recepcji czy przepisy wymagają aby w trakcie kontroli uodo podmiot posiadał dokumenty potwierdzające okresową zmianę haseł w systemie komputerowym",{"entities": [(160,168, "administrative_law"),(23,37, "administrative_law"),(153,157, "administrative_law"),(273,281, "administrative_law"),(125,135, "administrative_law")]}),
("jakie obecnie obowiązują limity osób w przypadku spotkań",{"entities": [(14,24, "medical_law")]}),
("czy dyrektor szpitala może traktować klientkę inaczej niż innych lekarzy czy dyrektor szpitala może nie zaliczyć klientce specjalizacji",{"entities": [(27,36, "medical_law"),(58,64, "medical_law")]}),
("czy recepcjonistka odpowiada za udostępnienie danych osobowych pacjentki osobie postronnej jakie konsekwencje może ponieść administrator danych klientka w związku z zaistniałą sytuacją czy klientka powinna podjąć w tej sprawie dodatkowe czynności",{"entities": [(4,18, "administrative_law"),(32,45, "administrative_law")]}),
("czy w przypadku odrzucenia spadku przez dziecko córki spadkodawcy żona teścia również będzie musiała odrzucić spadek jak wygląda procedura odrzucenia spadku w imieniu małoletnich dzieci czy istnieje rejestr w którym można uzyskać informacje na temat długów spadkodawcy",{"entities": [(250,256, "civil_law"),(101,109, "civil_law"),(167,178, "civil_law"),(110,116, "civil_law"),(54,65, "civil_law"),(16,26, "civil_law"),(139,149, "civil_law")]}),
("na jakiej podstawie prawnej zostały wprowadzone ograniczenia dotyczące wesel jakie grożą sankcje wymierzone przez inspektora sanitarnego za nieprzestrzeganie ograniczeń na weselu",{"entities": [(158,168, "medical_law"),(125,136, "medical_law"),(140,157, "medical_law")]}),
("czy można zostać kierownikiem działu farmacji szpitalnej w niepełnym wymiarze godzin na podstawie umowy o pracę lub umowy cywilnoprawnej jakie są zasady obliczania równoważnika  etatu w pełnym wymiarze godzin",{"entities": [(10,16, "pharmaceutical_law"),(37,45, "pharmaceutical_law"),(46,56, "pharmaceutical_law"),(62,68, "pharmaceutical_law"),(186,192, "pharmaceutical_law"),(59,68, "pharmaceutical_law"),(17,29, "pharmaceutical_law")]}),
("czy w miejscu obecnie funkcjonującej apteki jeżeli zostanie zamknięta może powstać nowa apteka na podstawie nowego zezwolenia przy uwzględnieniu że odległość do najbliżej apteki wynosi ok  metrów",{"entities": [(115,125, "pharmaceutical_law"),(83,87, "pharmaceutical_law"),(60,69, "pharmaceutical_law")]}),
("gdzie klientka może znaleźć listę jednostek akredytowanych do prowadzenia szkoleń dla oia w krakowie",{"entities": [(34,43, "pharmaceutical_law")]}),
("czy klienta będzie obowiązywać tajemnica lekarska podczas składania na piśmie zeznań przed sądem cywilnym",{"entities": [(71,77, "medical_law"),(58,67, "medical_law"),(78,84, "medical_law")]}),
("czy klient może odmówić udziału w pracach zespołu",{"entities": [(34,41, "labor_law")]}),
("czy wezwanie zostało klientowi prawidłowo doręczone czy przepisy prawa przewidują minimalny czas na rozbiórkę komórki czy zarządca nieruchomości wspólnej może samodzielnie ustalać od kiedy będzie pobierana opłata zgodnie z uchwałą",{"entities": [(145,153, "civil_law"),(206,212, "civil_law"),(122,130, "civil_law"),(42,51, "civil_law"),(110,117, "civil_law")]}),
("czy zachowanie dyrektora jest zgodne z prawem czy klient może podpisać umowę o pracę jako rezydent z innym podmiotem",{"entities": [(90,98, "medical_law")]}),
("zgoda jakiego organu jest wymagana w niniejszej sytuacji",{"entities": [(26,34, "medical_law"),(0,5, "medical_law"),(14,20, "medical_law")]}),
("czy klientka ma obowiązek partycypowania w kosztach utrzymania nieruchomości która wchodzi w skład odziedziczonego spadku jak będzie wyglądał dział spadku jeżeli spadkobiercy nie mogą dojść do porozumienia czy zasadnym jest aby klientka udzieliła pełnomocnictwa do prowadzenia tej sprawy zawodowemu pełnomocnikowi",{"entities": [(247,261, "civil_law"),(52,62, "civil_law"),(93,98, "civil_law"),(210,218, "civil_law"),(83,90, "civil_law"),(142,147, "civil_law"),(43,51, "civil_law"),(162,174, "civil_law")]}),
("czy członkowi rodziny zmarłego pacjenta który został przesłuchany w charakterze świadka w postępowaniu dotyczącym odpowiedzialności zawodowej pielęgniarek i który chce wykonywać prawazmarłego pacjenta można odmówić dostępu do akt tego postępowania na tej podstawie iż złożył zeznania jako świadek",{"entities": [(168,177, "criminal_law"),(275,283, "criminal_law"),(80,87, "criminal_law"),(163,167, "criminal_law"),(142,154, "criminal_law"),(68,79, "criminal_law"),(22,30, "criminal_law"),(183,191, "criminal_law"),(114,131, "criminal_law"),(90,102, "criminal_law")]}),
("czy pracodawca może oddelegować lekarza rezydenta do pracy w szpitalnym oddziale ratunkowym sor czy pracodawca może oddelegować lekarza zatrudnionego na podstawie umowy kontraktowej do pracy w szpitalnym oddziale ratunkowym sor",{"entities": [(169,181, "medical_law"),(61,71, "medical_law"),(193,203, "medical_law"),(81,91, "medical_law"),(213,223, "medical_law")]}),
("pod jakim warunkiem lekarz w trakcie specjalizacji może zacząć przyjmować pacjentów w poradni specjalistycznej w ramach nfz",{"entities": [(63,73, "medical_law"),(86,93, "medical_law"),(56,62, "medical_law"),(94,110, "medical_law")]}),
("czy pracodawca może zmienić system czas pracy klienta z równoważnego na podstawowy czy pracodawca może zmienić ogłoszony już miesięczny harmonogram pracy",{"entities": [(56,68, "labor_law"),(136,147, "labor_law"),(125,135, "labor_law")]}),
("czy farmaceuta jest uprawniony do wystawiania recept pro familiae i pro auctore",{"entities": [(53,56, "pharmaceutical_law"),(68,71, "pharmaceutical_law"),(57,65, "pharmaceutical_law")]}),
("czy klientka będzie zobowiązana ponieść koszty prac ślusarza i przechowywania rzeczy dłużnika",{"entities": [(47,51, "civil_law"),(78,84, "civil_law")]}),
("czy pracownik klienta ma prawo odmówić przyjęcia trzeciej dawki szczepionki przeciwko covid czy klient może wypowiedzieć umowę o pracę z uwagi na odmowę przyjęcia trzeciej dawki szczepionki przeciwko covid",{"entities": [(49,57, "medical_law"),(163,171, "medical_law"),(39,48, "medical_law"),(153,162, "medical_law"),(137,142, "medical_law"),(58,63, "medical_law"),(172,177, "medical_law")]}),
("jakich formalności należy dopełnić w związku z sprowadzeniem samochodu z usa z przeznaczeniem do sprzedaży na części",{"entities": [(61,70, "tax_law"),(37,44, "tax_law"),(97,106, "tax_law")]}),
("czy do dokonania podziału nieruchomości lokalowej mieszkalnej na lokal użytkowy i mieszkalny wymagana jest uchwała o wyrażeniu zgody wspólnoty mieszkaniowej gdyby uchwała wspólnoty była konieczna  czy w sytuacji ustalania wielkości udziałów w częściach wspólnych nieruchomości istnieje możliwość prawnego zobligowania do tego członka wspólnoty który nie wyraził by na to zgody jakie dokumenty oprócz przedstawionych powinna przygotować klientka do dokonania podziału nieruchomości u notariusza czy podczas jednego spotkania u notariusza klientka może dokonać podziału lokalu oraz przekazania własności jednego z nich poprzez darowiznę",{"entities": [(253,262, "civil_law"),(17,25, "civil_law"),(458,466, "civil_law"),(559,567, "civil_law"),(580,591, "civil_law"),(7,16, "civil_law"),(448,457, "civil_law"),(483,493, "civil_law"),(526,536, "civil_law"),(232,240, "civil_law"),(243,252, "civil_law"),(592,601, "civil_law")]}),
("jak przedstawiają się prawa i obowiązki pracownika oraz pracodawcy w sytuacji powrotu pracownika z urlopu związanego z macierzyństwem",{"entities": [(4,17, "labor_law")]}),
("czy gabinet stomatologiczny może zatrudniać rejestratorki medyczne oraz sekretarki medyczne czy zamiast rejestratorek medycznych oraz sekretarek medycznych gabinet stomatologiczny może zatrudniać recepcjonistki",{"entities": [(33,43, "medical_law"),(185,195, "medical_law"),(12,27, "medical_law"),(164,179, "medical_law")]}),
("czy w związku z zajściem w ciążę umowa pracownicy zostanie automatycznie przekształcona w umowę na czas nieokreślony",{"entities": [(39,49, "labor_law"),(27,32, "labor_law")]}),
("jakie uprawnienia przysługują oskarżycielowi posiłkowemu w postepowaniu w sprawach o wykroczenia",{"entities": [(0,5, "criminal_law"),(6,17, "criminal_law")]}),
("czy na recepcie weterynaryjnej na lek psychotropowy o kategorii iiip i ivp musi być kod jeżeli tak to czy może być zapisany odręcznie",{"entities": [(7,15, "pharmaceutical_law"),(54,63, "pharmaceutical_law")]}),
("jakie są prawa i obowiązki klientki na przesłuchaniu w charakterze świadka jak kształtuje się kwestia zwolnienia z tajemnicy lekarskiej",{"entities": [(0,5, "criminal_law"),(67,74, "criminal_law"),(55,66, "criminal_law")]}),
("czy ustalenie z narodowym funduszem zdrowia kwalifikuje się jako pożyczka w rozumieniu art zzd ustawy o szczególnych rozwiązaniach związanych z zapobieganiem przeciwdziałaniem i zwalczaniem covid innych chorób zakaźnych oraz wywołanych nimi sytuacji kryzysowych o której mowa w oświadczeniu",{"entities": [(178,189, "medical_law"),(104,116, "medical_law"),(26,35, "medical_law"),(158,175, "medical_law"),(225,235, "medical_law"),(76,86, "medical_law"),(144,157, "medical_law"),(16,25, "medical_law"),(196,202, "medical_law"),(250,261, "medical_law"),(117,130, "medical_law")]}),
("czy klient mający ochronę przedemerytalną może otrzymać pracę bez dyżurów medycznych czy umowa klienta powinna być zmieniona gdy pracuje on w przychodni a nie na oddziale ginekologicznopołożniczym w jaki sposób nalicza się wynagrodzenie urlopowe klienta",{"entities": [(18,25, "labor_law"),(26,41, "labor_law"),(237,245, "labor_law")]}),
("czy na podstawie otrzymanego aneksu klientka skutecznie rozwiąże umowę z nfz",{"entities": [(56,64, "medical_law"),(17,28, "medical_law")]}),
("w jaki sposób klientka może wyegzekwować nieparkowanie na jej miejscu parkingowym od osoby nieuprawnionej",{"entities": [(70,81, "administrative_law")]}),
("czy obecnie obowiązujące przepisy prawne przewidują wyjątki od obowiązku zakrywania ust oraz nosa",{"entities": [(52,59, "medical_law")]}),
("w jaki sposób w zaistniałych okolicznościach najlepiej zabezpieczyć stosunek najmu lokalu użytkowego czy rzeczoną umowę można zabezpieczyć wekslem jaka powinna być treść takiego weksla i jaki powinien to być weksel czy są elementy treści weksla które wynajmujący musi wypełnić w obecności najemcy czy do weksla potrzebne jest porozumienie wekslowe jakie elementy weksla muszą zostać sporządzone odręcznie czy okoliczność że najemca zawarł związek małżeński i między małżonkami nie występuje rozdzielność majątkowa wpływa na kształt weksla i zobowiązania z tego weksla czy w danych sytuacjach konieczny jest poręczyciel jeśli tak to czy do weksla wymaganych jest więcej niż jeden poręczyciel jakie są jego obowiązki czy musi on posiadać jakieś szczególne dokumenty",{"entities": [(251,262, "civil_law"),(178,184, "civil_law"),(238,244, "civil_law"),(304,310, "civil_law"),(363,369, "civil_law"),(532,538, "civil_law"),(561,567, "civil_law"),(639,645, "civil_law"),(268,276, "civil_law"),(311,320, "civil_law"),(90,100, "civil_law"),(592,601, "civil_law"),(289,296, "civil_law"),(447,456, "civil_law"),(424,431, "civil_law"),(439,446, "civil_law"),(383,394, "civil_law"),(607,618, "civil_law"),(679,690, "civil_law"),(222,230, "civil_law"),(354,362, "civil_law")]}),
("czy klientka może być powołana do zwalczania epidemii na stanowisko inne niż lekarz pediatra jakie konsekwencje grożą klientce jeżeli nie stawi się w miejscu skierowania na jakich zasadach jest nakładana kara za niestawienie się w miejscu skierowania czy w przypadku gdy szpital nie zapewni klientce środków ochrony osobistej może ona odmówić pracy przy zwalczaniu epidemii czy obowiązkowe ubezpieczenie oc klientki będzie obowiązywało w miejscu w którym zostanie skierowana klientka jak kształtuje się odpowiedzialność lekarza skierowanego do pracy przy zwalczaniu epidemii za ewentualne błędy medyczne jakie uprawnienia wynikające ze stosunku pracy ma lekarz skierowany do zwalczania epidemii",{"entities": [(520,527, "criminal_law"),(93,98, "criminal_law"),(604,609, "criminal_law"),(300,307, "criminal_law"),(354,364, "criminal_law"),(555,565, "criminal_law"),(77,83, "criminal_law"),(654,660, "criminal_law"),(390,403, "criminal_law"),(578,588, "criminal_law"),(158,169, "criminal_law"),(239,250, "criminal_law"),(45,53, "criminal_law"),(365,373, "criminal_law"),(566,574, "criminal_law"),(610,621, "criminal_law"),(180,188, "criminal_law")]}),
("czy klientka może podjąć skuteczne kroki w celu uchylenia uchwały wspólnoty mieszkaniowej",{"entities": [(58,65, "civil_law")]}),
("czy szpital może potrącać lekarzom rezydentom wynagrodzenie za czas zejścia po dyżurze",{"entities": [(68,75, "medical_law"),(17,25, "medical_law"),(63,67, "medical_law"),(26,34, "medical_law"),(35,45, "medical_law")]}),
("czy w trakcie tygodniowego stażu cząstkowego klientka jest zobowiązana dyżurować w przypadku odpowiedzi twierdzącej na którym oddziale klientka będzie zobowiązana dyżurować",{"entities": [(71,80, "medical_law"),(27,32, "medical_law"),(104,115, "medical_law")]}),
("jakie są prawa i obowiązki klientki na przesłuchaniu w charakterze świadka",{"entities": [(0,5, "criminal_law"),(55,66, "criminal_law")]}),
("czy klientka jeżeli posiada nową książkę kontroli w aptece to czy musi wypełnić do końca książkę starą czy może ją wyrejestrować i korzystać już z nowej",{"entities": [(41,49, "pharmaceutical_law"),(33,40, "pharmaceutical_law"),(89,96, "pharmaceutical_law")]}),
("czy apteka może zaopatrywać się w środki spożywcze specjalnego przeznaczenia żywieniowego od podmiotów niebędących hurtowniami farmaceutycznymi",{"entities": [(63,76, "pharmaceutical_law"),(51,62, "pharmaceutical_law"),(41,50, "pharmaceutical_law"),(77,89, "pharmaceutical_law"),(16,27, "pharmaceutical_law")]}),
("czy lekarz który skorzystał już z możliwości ponownego zakwalifikowania i rozpoczęcia rezydentury o innym module podstawowym w okresie pierwszych  miesięcy od rozpoczęcia pierwotnej specjalizacji dalej zachowuje prawo do ponownego zakwalifikowania i rozpoczęcia rezydentury w obrębie tego samego modułu podstawowego",{"entities": [(55,71, "medical_law"),(231,247, "medical_law"),(45,54, "medical_law"),(221,230, "medical_law"),(289,295, "medical_law"),(86,97, "medical_law"),(262,273, "medical_law"),(74,85, "medical_law"),(159,170, "medical_law"),(250,261, "medical_law")]}),
("czy klientce mogą grozić jakieś konsekwencję prawne z powodu prowadzenia indywidualnej praktyki lekarskiej niewpisanej do rejestru podmiotów wykonujących działalność leczniczą",{"entities": [(45,51, "criminal_law")]}),
("jakie kroki prawne może podjąć klientka",{"entities": [(0,5, "criminal_law"),(12,18, "criminal_law")]}),
("czy spółdzielnia może wskazać członkowi spółdzielni mieszkaniowej zakres obowiązków gospodarza osiedla wynikających z zawartej umowy o pracę",{"entities": [(95,102, "civil_law")]}),
("czy mąż klientki powinien podpisać z bratem umowę najmu lokalu mieszkalnego z datą wsteczną w jakim czasie administrator powinien przedstawiać rozliczenia czy administrator powinien regulować należne drugiemu współwłaścicielowi zyski na bieżąco czy administrator może pobierać wynagrodzenie za sprawowanie zarządu nieruchomością kto może pełnić rolę rozjemcy w sporze między współwłaścicielami",{"entities": [(314,328, "civil_law"),(182,191, "civil_law"),(268,276, "civil_law")]}),
("z jakiej pomocy może skorzystać osoba prowadząca jednoosobową działalność gospodarczą i jednocześnie będąca w stosunku pracy",{"entities": [(38,48, "medical_law"),(101,107, "medical_law")]}),
("gdzie należy złożyć pozew o separację czy musi on zostać złożony w miejscu zamieszkania klientki i jej męża czy może zostać złożony w innym miejscu zamieszkania rodziców klientki czy klientka ma obowiązek powrotu do domu jeżeli zażyczy sobie tego jej mąż",{"entities": [(20,25, "civil_law"),(57,64, "civil_law"),(124,131, "civil_law")]}),
("czy każdorazowo recepta musi zawierać określoną liczbę jednostek dawkowania",{"entities": [(16,23, "pharmaceutical_law"),(55,64, "pharmaceutical_law"),(38,47, "pharmaceutical_law")]}),
("czy klient może domagać się zwrotu pieniędzy za zakupiony komputer",{"entities": [(48,57, "administrative_law")]}),
("czy szpital może żądać od klientki zwrotu części wynagrodzenia w zaistniałych okolicznościach",{"entities": [(65,77, "medical_law")]}),
("czy klient może odmówić przyjęcia pacjenta z uwagi na to że jest on roszczeniowy i nie można z nim dojść do porozumienia",{"entities": [(24,33, "medical_law"),(45,50, "medical_law")]}),
("czy w obecnej sytuacji możliwym jest przeprowadzenie egzaminów kończących kursy zawodowe na pośrednika w obrocie nieruchomościami oraz zarządcę nieruchomości z zachowaniem standardów sanitarnych jeśli jest to możliwe to jakie kroki należy podjąć aby móc przeprowadzić takie egzaminy",{"entities": [(74,79, "medical_law"),(37,52, "medical_law"),(183,194, "medical_law"),(172,182, "medical_law"),(6,13, "medical_law"),(209,216, "medical_law")]}),
("jakie prawa przysługują klientce w związku z wezwaniem czy klientka może nie stawić się na przesłuchanie w związku z tym że jest w zaawansowanej ciąży",{"entities": [(0,5, "criminal_law"),(45,54, "criminal_law"),(91,104, "criminal_law")]}),
("czy w tej sytuacji klient może wycofać się z podjęcia pracy jako kierownik apteki bez ponoszenia prawnych konsekwencji",{"entities": [(31,38, "labor_law")]}),
("czy klientka będzie mogła skorzystać ze zwolnienia z vat jeżeli będzie świadczyć usługi na rzecz podmiotu leczniczego jako farmaceuta",{"entities": [(71,80, "medical_law")]}),
("czy klient jest zobowiązany do odbycia obowiązkowej kwarantanny domowej czy klient ma podstawy do zaskarżenia decyzji komendanta straży granicznej o wpisaniu klienta na listę osób objętych obowiązkową kwarantanną domową czy klient jest zobowiązany do zainstalowania aplikacji kwarantanna domowa",{"entities": [(31,38, "medical_law"),(86,94, "medical_law"),(180,188, "medical_law"),(266,275, "medical_law"),(251,265, "medical_law"),(64,71, "medical_law"),(213,219, "medical_law"),(201,212, "medical_law"),(39,51, "medical_law")]}),
("czy szpital prawidłowo wypłacił klientce dodatek do wynagrodzenia w związku z leczeniem pacjentów chorych na covid",{"entities": [(23,31, "medical_law"),(98,105, "medical_law"),(78,87, "medical_law")]}),
("czy pracodawca może potrącić z wynagrodzenia wypłaconą uprzednio nadwyżkę z powodu nieprawidłowo wyliczonej stawki za urlop wypoczynkowy czy klientka może domagać się jakiejś rekompensaty",{"entities": [(20,28, "labor_law")]}),
("jakie jest obecnie minimalne wynagrodzenia lekarza odbywającego specjalizacje w trybie pozarezydenckim",{"entities": [(64,77, "medical_law"),(51,63, "medical_law")]}),
("czy zgodnie z obecnie obowiązującym porządkiem prawnym za odbywanie szkolenia specjalizacyjnego w trybie pozarezydenckim na podstawie umowy cywilnoprawnej lekarzowi przysługuje wynagrodzenie czy jeżeli lekarz rozpoczął szkolenie w ww trybie i jego umowa nie przywidywała wynagrodzenia to podmiot zatrudniający lekarza zobowiązany jest do wypłaty lekarzowi wynagrodzenia",{"entities": [(58,67, "medical_law"),(219,228, "medical_law"),(68,77, "medical_law"),(231,233, "medical_law"),(47,54, "medical_law"),(140,154, "medical_law"),(288,295, "medical_law"),(338,345, "medical_law"),(78,95, "medical_law"),(105,120, "medical_law")]}),
("czy klientka musi płacić nowozatrudnionym pracownikom płacę minimalną czy tę wymaganą ustawą szczególną w trakcie okresu wypowiedzenia",{"entities": [(60,69, "medical_law"),(42,53, "medical_law")]}),
("na czym polega rozliczenie się z kancelarią na zasadzie prowizji czy klientka może otrzymywać pieniądze na swoje konto aby przelewać je kancelarii",{"entities": [(113,118, "civil_law"),(47,55, "civil_law"),(8,14, "civil_law")]}),
("jak powinien zachować się w przedmiotowej sprawie klient jak przedstawia się odpowiedzialność klienta za błąd w sztuce jaką dokumentację powinien udostępnić klient",{"entities": [(119,123, "medical_law"),(105,109, "medical_law")]}),
("czy szkolenie organizowane przez pracodawcę może się odbyć termin szkolenia został wyznaczony na przyszły tydzień",{"entities": [(14,26, "medical_law"),(4,13, "medical_law"),(66,75, "medical_law")]}),
("jak przebiega procedura zgłoszenia mobbingu jakie są koszty postępowania sądowego w sprawie o mobbing czy przegranie procesu o mobbing przez klienta może spowodować dla niego konsekwencje karne czy odwołanie klienta z zajmowanego stanowiska było zgodne z prawem",{"entities": [(94,101, "labor_law"),(127,134, "labor_law"),(230,240, "labor_law"),(35,43, "labor_law")]}),
("ile maksymalnie może pracować lekarz rezydent bez klauzuli optout w ciągu tygodnia wprzyjętym okresie rozliczeniowym",{"entities": [(21,29, "medical_law"),(37,45, "medical_law"),(68,73, "medical_law"),(50,58, "medical_law"),(59,65, "medical_law")]}),
("czy dodatkowe dni urlopowe z tytułu umiarkowanego stopnia niepełnosprawności należy wykorzystać w tym samym roku w którym urlop nabyto czy urlop ten można wykorzystać w następnym roku czy osoba która w tym samym roku kalendarzowym została zdyskwalifikowana z grupy umiarkowanego stopnia niepełnosprawności a następnie została do tej grupy zakwalifikowana musi przepracować jeden rok kalendarzowy aby nabyć dodatkowe  dni urlopu wypoczynkowego",{"entities": [(58,76, "labor_law"),(287,305, "labor_law"),(50,57, "labor_law"),(279,286, "labor_law"),(36,49, "labor_law"),(265,278, "labor_law"),(18,26, "labor_law")]}),
("jakie dokumenty musi złożyć klientka aby uzasadnić ubieganie się o alimenty od ojca dzieci",{"entities": [(41,50, "civil_law"),(67,75, "civil_law"),(51,60, "civil_law")]}),
("który podmiot leczniczy powinien wypłacać dodatek covidowy lekarzowi rezydentowi który odbywa staż zewnętrzny przewidziany w programie specjalizacji i w ramach stażu udziela świadczeń medycznych w szpitalnym oddziale ratunkowym oraz izbie przyjęć",{"entities": [(160,165, "medical_law"),(69,80, "medical_law"),(14,23, "medical_law"),(125,134, "medical_law"),(87,93, "medical_law"),(197,207, "medical_law"),(6,13, "medical_law"),(33,41, "medical_law"),(50,58, "medical_law"),(99,109, "medical_law"),(166,173, "medical_law"),(94,98, "medical_law"),(217,227, "medical_law")]}),
("czy w związku z treścią aktu notarialnego koniecznym jest wyrażenie zgody przez wspólnotę mieszkaniową w formie uchwały czy zarządca może wskazać iż na podstawie przedmiotowych zapisów aktów notarialnych potwierdza wyrażenie takiej zgody przez wszystkich współwłaścicieli",{"entities": [(80,89, "civil_law"),(29,41, "civil_law"),(42,52, "civil_law"),(124,132, "civil_law"),(58,67, "civil_law"),(215,224, "civil_law"),(191,203, "civil_law"),(112,119, "civil_law"),(162,176, "civil_law"),(90,102, "civil_law")]}),
("czy przesłany pozew został sporządzony w sposób prawidłowy ile wynosi opłata sądowa od pozwu i gdzie klient powinien ją zapłacić w jaki sposób klient powinien złożyć pozew w sądzie",{"entities": [(70,76, "civil_law"),(87,92, "civil_law"),(14,19, "civil_law"),(166,171, "civil_law"),(77,83, "civil_law")]}),
("co powinien zrobić klient jeżeli zostanie skierowany do pracy przy zwalczaniu epidemii",{"entities": [(42,52, "medical_law")]}),
("czy klient ma podstawy do ubiegania się o wypłatę tzw dodatku covidowego",{"entities": [(14,22, "medical_law"),(26,35, "medical_law")]}),
("czy w przedmiotowej sprawie rzecznik podlega odpowiedzialności karnej",{"entities": [(28,36, "medical_law")]}),
("w jaki sposób powinna postąpić klientka gdyby zgłosił się do niej pacjent z żądaniem odszkodowania w związki z ewentualnym błędem medycznym",{"entities": [(22,30, "medical_law")]}),
("czy w przypadku wystawienia przez lekarza błędnej elektronicznej recepty ze  odpłatnością podczas gdy jest to lek refundowany pacjent może uzyskać refundację leku po okazaniu decyzji w aptece czy pacjent powinien udać się do lekarza po nową receptę",{"entities": [(114,125, "pharmaceutical_law"),(77,89, "pharmaceutical_law"),(147,157, "pharmaceutical_law")]}),
("czy grupowa praktyka lekarska może zatrudnić lekarza",{"entities": [(12,20, "medical_law")]}),
("czy klient może zobowiązać byłą żonę do partycypacji w kosztach utrzymania mieszkania",{"entities": [(64,74, "civil_law"),(40,52, "civil_law"),(27,31, "civil_law"),(55,63, "civil_law")]}),
("czy po okresie leczenia i rehabilitacji klientowi przysługuje płatny urlop wypoczynkowy",{"entities": [(62,68, "labor_law")]}),
("czy osoba zatrudniająca męża klienta może zobowiązać go do wykorzystania urlopu wypoczynkowego czy klient może wystosować do wojewody pismo w którym wskaże że nie może on zostać skierowany do pracy niosącej ryzyko zakażenia przy zwalczaniu epidemii",{"entities": [(111,121, "medical_law"),(125,133, "medical_law"),(178,188, "medical_law"),(73,79, "medical_law")]}),
("czy klientka może wystosować do zarządu spółki pismo z prośbą o wcześniejsze ustalanie terminu nadzwyczajnego lub zwyczajnego zgromadzenia wspólników jeszcze przed wysłaniem listu powiadamiającego przez zarząd",{"entities": [(126,138, "civil_law"),(55,61, "civil_law")]}),
("czy obniżenie premii motywacyjnej klientki było zgodne z prawem czy klientka może się odwołać od obniżenia premii do sądu",{"entities": [(14,20, "labor_law"),(107,113, "labor_law"),(4,13, "labor_law")]}),
("czy na podstawie ustawy o zapobieganiu oraz zwalczaniu zakażeń i chorób zakaźnych u ludzi można egzekwować obowiązek noszenia maseczki",{"entities": [(84,89, "criminal_law"),(117,125, "criminal_law"),(26,38, "criminal_law"),(44,54, "criminal_law"),(17,23, "criminal_law")]}),
("czy okoliczność iż ojciec klientki odrzucił spadek po drugiej żonie ma wpływ na sytuację klientki",{"entities": [(44,50, "civil_law")]}),
("czy klientka może bez rezygnacji z funkcji kierownika jednej apteki objąć funkcję kierownika w innej aptece czy kierownik apteki może być zatrudniony na pół etatu",{"entities": [(74,81, "pharmaceutical_law")]}),
("w jakim terminie pracodawca może żądać wyjaśnień od pracownika czy takiemu pracownikowi powinna zostać cofnięta premia",{"entities": [(75,87, "labor_law")]}),
("czy kartoteka wypełniana odręcznie podczas wizyty pacjenta stanowi również dokumentację medyczną w rozumieniu przepisów ustawy czy klientka ma obowiązek udostępnienia pacjentowi treści kartoteki jeżeli tak to w jakiej formie od kiedy funkcjonuje możliwość sporządzania dokumentacji w postaci elektronicznej",{"entities": [(153,166, "medical_law"),(99,109, "medical_law"),(167,177, "medical_law"),(234,245, "medical_law")]}),
("czy lekarz może odmówić przyjęcia pacjenta który odmawia podania danych osobowych przy zakładaniu karty pacjenta",{"entities": [(98,103, "medical_law"),(24,33, "medical_law"),(57,64, "medical_law"),(49,56, "medical_law")]}),
("jakie są prawa i obowiązki klientki na przesłuchaniu w charakterze świadka",{"entities": [(0,5, "criminal_law"),(55,66, "criminal_law")]}),
("czy w razie skazania za czyn z art  kodeksu karnego klient może utracić prawo wykonywania zawodu lekarza",{"entities": [(78,89, "criminal_law"),(36,43, "criminal_law"),(44,51, "criminal_law"),(12,20, "criminal_law")]}),
("na jakich zasadach lekarze mogą wystawiać recepty refundowane w trakcie telekonsultacji",{"entities": [(50,61, "pharmaceutical_law")]}),
("czy klient może wrócić na poprzednie stanowisko pracy czy można ukarać pracownika karą pieniężną i jednocześnie potrącić mu premię",{"entities": [(112,120, "labor_law")]}),
("czy klient może podawać pacjentom leki mimo że zgodnie ze światowymi zaleceniami nie powinno się ich stosować poza testami klinicznymi",{"entities": [(16,23, "medical_law"),(69,80, "medical_law"),(85,92, "medical_law"),(101,109, "medical_law")]}),
("czy klient może podważyć wiarygodność sporządzonych przez siebie oświadczeń czy prokurator miał prawo odmówić podjęcia czynności w sprawie przeciwko małżonce klienta czy przedstawione okoliczności mogą wpłynąć na decyzję sądu w zakresie złagodzenia kary jeżeli klient dobrowolnie podda się karze",{"entities": [(91,95, "criminal_law"),(80,90, "criminal_law"),(119,128, "criminal_law")]}),
("czy działanie dyrekcji szpitala związane z wypłacaniem dodatku covidowego jest prawidłowe",{"entities": [(63,73, "medical_law")]}),
("czy pracodawca ma obowiązek zapewnienia każdemu pracownikowi przejechanie takiej samej ilości kilometrów czy zarząd związku zawodowego jest zobowiązany do udzielenia odpowiedzi na otrzymane pismo",{"entities": [(124,134, "labor_law"),(48,60, "labor_law")]}),
("czy klientka może wystawić matce pacjentki zaświadczenie potwierdzające że prowadziła leczenie jej córki",{"entities": [(43,56, "medical_law")]}),
("czy postępowanie dotyczące ubezwłasnowolnienia może zakończyć na pierwszej rozprawie czy możliwy jest zakres opiekikurateli nad ubezwłasnowolnionym gdzie osoba powołana członek rodziny zarządzałaby wyłącznie majątkiem ubezwłasnowolnionego czy pełnomocnik procesowy członek rodziny osoby mającej być ubezwłasnowolnioną może zostać jej opiekunemkuratorem",{"entities": [(27,46, "civil_law"),(89,96, "civil_law"),(75,84, "civil_law"),(208,217, "civil_law")]}),
("co powinien zrobić klient w celu wyegzekwowania zapłaty dodatku covidowego w przypadku w którym wezwanie do zapłaty okazało się nieskuteczne",{"entities": [(116,123, "medical_law"),(64,74, "medical_law")]}),
("czy klientka ma obowiązek dokonania wpisu do centralnego rejestru podmiotów akcyzowych dalej crpa w związku z nowelizacją ustawy o podatku akcyzowym",{"entities": [(57,65, "tax_law"),(100,107, "tax_law"),(131,138, "tax_law"),(76,86, "tax_law")]}),
("czy dyrekcja szpitala może zobowiązać klienta do pełnienia dyżurów medycznych na szpitalnym oddziale ratunkowym",{"entities": [(49,58, "medical_law"),(81,91, "medical_law")]}),
("czy od  r administratorzy wspólnoty mieszkaniowej niezgodnie z prawem naliczali współwłaścicielom hali garażowej opłaty za partycypowanie w kosztach utrzymania nieruchomości wspólnej jeżeli tak to czy można domagać się zwrotu niesłusznie pobieranych od  r opłat za miejsca w garażu jeżeli odpowiedź na powyższe jest twierdząca czy można wówczas domagać się zapłaty od administratora wspólnoty mieszkaniowej",{"entities": [(174,182, "civil_law"),(149,159, "civil_law"),(98,102, "civil_law"),(140,148, "civil_law"),(103,112, "civil_law")]}),
("czy obecnie możliwe jest oddelegowanie lekarzy rezydentów do wykonywania zadań które nie są przewidziane w programie specjalizacji",{"entities": [(25,38, "medical_law"),(107,116, "medical_law"),(73,78, "medical_law"),(12,19, "medical_law")]}),
("czy hurtownia farmaceutyczna może zaopatrywać się w towary z wyłączeniem produktów leczniczych od drogerii",{"entities": [(34,45, "pharmaceutical_law")]}),
("jakie możliwości prawne ma klient ubiegania się o sprostowanie wypisu",{"entities": [(34,43, "medical_law")]}),
("czy klient ma możliwość wglądu w nagranie monitoringu wspólnoty mieszkaniowej w celu identyfikacji właścicieli psów których nieczystości nie są usuwane",{"entities": [(24,30, "administrative_law"),(42,53, "administrative_law")]}),
("czy klientka może wystosować do zarządu spółki pismo z prośbą o wcześniejsze ustalanie terminu nadzwyczajnego lub zwyczajnego zgromadzenia wspólników jeszcze przed wysłaniem listu powiadamiającego przez zarząd",{"entities": [(126,138, "civil_law"),(55,61, "civil_law")]}),
("czy przekształcenie części lokalu mieszkalnego w użytkowy jest dopuszczalna i w jaki sposób tego dokonać",{"entities": [(4,19, "administrative_law"),(63,75, "administrative_law")]}),
("czy jeżeli klient skorzysta ze zwolnienia ze składek zus a następnie uda się na zwolnienie l będzie to wpływało na możliwość skorzystania z ulgi czy możliwe jest skierowanie do pracy przy epidemii klienta bądź jego żonę",{"entities": [(69,72, "medical_law"),(149,156, "medical_law"),(162,173, "medical_law")]}),
("czy rada nadzorcza może złożyć zawiadomienie o popełnieniu przestępstwa czy w powyższej kwestii potrzebna jest uchwała walnego zgromadzenia w jaki sposób spółdzielnia może odzyskać pieniądze które zostały przeznaczone na kary nałożone na prezesa i wiceprezesa",{"entities": [(47,58, "criminal_law"),(31,44, "criminal_law"),(59,71, "criminal_law"),(172,180, "criminal_law"),(181,190, "criminal_law"),(24,30, "criminal_law")]}),
("czy klient jest zobowiązany do zainstalowania aplikacji służącej potwierdzeniu realizacji obowiązku przestrzegania kwarantanny",{"entities": [(56,64, "medical_law"),(46,55, "medical_law"),(31,45, "medical_law"),(65,78, "medical_law")]}),
("czy pracodawca mógł ustnie wprowadzić równoważny system czasu pracy i zobowiązać klientkę do pracy w dwie soboty po  godzin",{"entities": [(27,37, "labor_law"),(38,48, "labor_law")]}),
("czy wspólnota mieszkaniowa powinna pokryć koszty naprawy drzwi komórki lokatorskiej",{"entities": [(49,56, "civil_law"),(63,70, "civil_law")]}),
("czy legalne jest założenie spółki w składzie osobowym który jest w innej spółce czy usługi dostawy jedzenia są zwolnione z podatku vat czy spółka może rozszerzyć działalność o dostawy jedzenia i korzystać ze zwolnienia vat",{"entities": [(151,161, "tax_law"),(99,107, "tax_law"),(184,192, "tax_law"),(162,173, "tax_law"),(208,218, "tax_law"),(195,204, "tax_law"),(139,145, "tax_law"),(123,130, "tax_law"),(91,98, "tax_law"),(176,183, "tax_law")]}),
("czy zarządzenie dyrekcji szpitala jest dla klientki wiążące pomimo zapisu przewidzianego w zawartej przez nią umowie o pracę",{"entities": [(74,88, "labor_law")]}),
("czy klient będący lekarzem stażystą może podpisać umowę zlecenie ze szpitalem w którym odbywa staż cząstkowy na potrzeby kwalifikowania do szczepień przeciwko covid",{"entities": [(121,135, "medical_law"),(56,64, "medical_law"),(68,77, "medical_law"),(112,120, "medical_law"),(87,93, "medical_law"),(18,26, "medical_law"),(94,98, "medical_law"),(139,148, "medical_law")]}),
("z jakich składników majątku komornik może prowadzić egzekucję",{"entities": [(42,51, "criminal_law")]}),
("czy klientce przysługuje dodatek covidowy jeżeli tak to w jakiej wysokości",{"entities": [(33,41, "medical_law")]}),
("czy bank powinien zwrócić klientce proporcjonalną część kosztów prowizji kredytu",{"entities": [(35,49, "administrative_law"),(64,72, "administrative_law")]}),
("czy po dniu  lipca  r będą funkcjonowały recepty papierowe czy na receptach papierowych od dnia  lipca  r będzie można przepisać lek refundowany",{"entities": [(76,87, "pharmaceutical_law"),(119,128, "pharmaceutical_law"),(27,40, "pharmaceutical_law"),(66,75, "pharmaceutical_law"),(49,58, "pharmaceutical_law")]}),
("czy pracodawca może zobowiązać pracowników do wykorzystania zaległych urlopów wypoczynkowych jeżeli nie były przewidziane w planie urlopowym",{"entities": [(78,92, "labor_law"),(70,77, "labor_law"),(60,69, "labor_law")]}),
("czy klient musi uwzględnić w przychodzie pożyczę otrzymaną z urzędu pracy w ramach wsparcia przedsiębiorców w okresie epidemii covid czy klient musi od tej kwoty zapłacić podatek",{"entities": [(162,170, "medical_law")]}),
("czy dodatki do wynagrodzenia mogą wliczać się do minimalnego wynagrodzenia pracowników",{"entities": [(49,60, "labor_law")]}),
("w jaki sposób klientka może odrzucić spadek",{"entities": [(28,36, "civil_law")]}),
("czy istnieje możliwość pozasądowego podziału majątku wspólnego małżonków co wchodzi w skład majątku osobistego małżonków czy darowizna przekazana na rzecz małżonki wchodzi w skład jej majątku osobistego jak po rozwodzie kształtuje się kwestia spłaty kredytu",{"entities": [(63,72, "civil_law"),(111,120, "civil_law"),(36,44, "civil_law"),(155,163, "civil_law"),(86,91, "civil_law"),(174,179, "civil_law"),(76,83, "civil_law"),(164,171, "civil_law"),(210,219, "civil_law"),(243,249, "civil_law"),(53,62, "civil_law")]}),
("w jaki sposób klient może doprecyzować wysokość kosztów dojazdu aby w przyszłości nie budziła ona sporów czy obecnie obowiązujące przepisy regulują maksymalne stawki kosztów dojazdu pełnomocnika",{"entities": [(56,63, "civil_law"),(174,181, "civil_law")]}),
("czy wywieszenie banneru reklamowego na elewacji budynku objętego ochroną konserwatorską wiąże się z koniecznością uiszczania opłat",{"entities": [(4,15, "administrative_law"),(39,47, "administrative_law")]}),
("czy w przedmiotowej sprawie występuje konflikt interesów",{"entities": [(38,46, "medical_law")]}),
("czy pracownicy która nie pojawi się w pracy od  kwietnia będzie przysługiwało prawo do wynagrodzenia czy w przypadku rozwiązania umowy o pracę z winy pracownika pracownica będzie mogła wykorzystać urlop wypoczynkowy za kwiecień",{"entities": [(145,149, "labor_law"),(4,14, "labor_law"),(64,77, "labor_law")]}),
("czy jeżeli klientka odmówi pracy na oddziale macierzystym to pracodawca może wypowiedzieć jej umowę czy polecenie ordynatora jest zgodne z prawem",{"entities": [(45,57, "medical_law")]}),
("w jaki sposób klientka może dochodzić zapłaty dodatku covidowego za listopad i grudzień  r",{"entities": [(68,76, "medical_law"),(79,87, "medical_law"),(54,64, "medical_law")]}),
("o ile wcześniej pracownik musi uprzedzić pracodawcę że ten chce skorzystać z urlopu na żądanie czy pracodawca może zasłaniać się argumentem że brak jest pracowników i z tego powodu nie udzieli pracownikowi urlopu gdzie pracownicy wskazują że w zakładzie pracy pracuje dostatecznie dużo pracowników aby móc skorzystać z tego urlopu czy pracownik dzwoniąc do dyspozytora który w danym czasie pełni obowiązki bezpośredniego przełożonego musi dodatkowo takie żądanie skierować do niebezpośredniego przełożonego czy wystarczy poinformowanie bezpośredniego przełożonego",{"entities": [(219,229, "labor_law"),(390,395, "labor_law"),(185,192, "labor_law"),(421,433, "labor_law"),(494,506, "labor_law"),(193,205, "labor_law")]}),
("na jakich zasadach sąd przyznaje zwrot kosztów procesu stronie która zmieniła pełnomocnika w trakcie procesu",{"entities": [(47,54, "civil_law")]}),
("czy klientka powinna przekazać dokumentację medyczną czy klientka powinna odpowiedzieć na pytania dotyczące leczenia pacjentki na żądanie sądu",{"entities": [(21,30, "medical_law"),(74,86, "medical_law")]}),
("czy klientka po śmierci swojego brata będzie zobowiązana do zapłaty zachowku na rzecz żyjącej córki brata czy na skutek darowania udziału w prawie własności nieruchomości synowi klientka będzie miała jakieś obowiązki względem swojej córki",{"entities": [(113,119, "civil_law"),(171,177, "civil_law"),(68,76, "civil_law"),(140,146, "civil_law"),(147,156, "civil_law")]}),
("czy klientka jako lekarz stażysta stomatolog mogła zostać zobowiązana do pomocy przy szczepieniach w ramach stażu",{"entities": [(25,33, "medical_law"),(85,98, "medical_law")]}),
("czy hurtownia farmaceutyczna może zaopatrywać i zbywać sprzęt medyczny",{"entities": [(55,61, "pharmaceutical_law"),(48,54, "pharmaceutical_law"),(34,45, "pharmaceutical_law")]}),
("czy na recepcie weterynaryjnej na lek psychotropowy o kategorii iiip i ivp musi być kod jeżeli tak to czy może być zapisany odręcznie",{"entities": [(7,15, "pharmaceutical_law"),(54,63, "pharmaceutical_law")]}),
("czy klientka może zrezygnować z odbywania dyżurów w związku z opieką nad miesięcznym dzieckiem czy dotyczy to tylko dyżurów samodzielnych czy może również towarzyszących czy klientka będzie musiała odrobić dyżury których nie pełniła z powodów zdrowotnych gdy pracowała będąc w ciąży w  r",{"entities": [(124,137, "medical_law"),(18,29, "medical_law")]}),
("czy apteka może nabyć suplementy diety i wyroby medyczne od innej apteki",{"entities": [(41,47, "pharmaceutical_law"),(22,32, "pharmaceutical_law")]}),
("czy lekarz może odmówić pacjentowi badania jeżeli ten nie zgadza się na założenie maseczki ochronnej jeżeli tak to w oparciu o jaką podstawę prawną",{"entities": [(132,140, "medical_law"),(127,131, "medical_law"),(24,34, "medical_law")]}),
("czy klient może samodzielnie opisywać i zatwierdzać badania rentgenowskie oraz badania tomografii komputerowej bez nadzoru lekarza specjalisty",{"entities": [(87,97, "medical_law"),(60,73, "medical_law"),(98,110, "medical_law"),(29,37, "medical_law")]}),
("jak obecnie wyglądają regulacje dotyczące przyjmowania pacjenta małoletniego przez lekarza bez obecności opiekuna prawnego oraz wyrażania zgody przez takiego pacjenta oraz jego opiekuna jak również pacjenta który ukończył  rok życia",{"entities": [(12,21, "medical_law"),(64,76, "medical_law"),(42,54, "medical_law"),(213,221, "medical_law"),(95,104, "medical_law"),(105,113, "medical_law"),(177,185, "medical_law")]}),
("czy za wystawienie duplikatów faktur osobie nieupoważnionej klientka ponosi odpowiedzialność",{"entities": [(69,75, "criminal_law")]}),
("jakie dokumenty klientka powinna obecnie złożyć aby zakończyć proces likwidacji spółki z oo",{"entities": [(62,68, "civil_law")]}),
("czy w wypowiedzeniu umowy o pracę zawartej na czas nieokreślony musi być podany powód wypowiedzenia czy w przypadku gdy umowa zostanie wypowiedziana niezgodnie z prawem pracownik musi być przywrócony do pracy czy można wypłacić pracownikowi odszkodowanie",{"entities": [(135,148, "labor_law"),(6,19, "labor_law"),(80,85, "labor_law"),(51,63, "labor_law"),(228,240, "labor_law")]}),
("czy pomimo tego iż uchwała została podjęta większością głosów to nadal istnieje obowiązek dalszego zbierania głosów czy w treści uchwały należy zamieszczać rubrykę informującą o wstrzymaniu się od głosu w jaki sposób odpowiedzieć na zarzut iż sposób zbierania głosów mógł mieć istotny wpływ na treść uchwały czy zarząd wspólnoty mieszkaniowej ma możliwość wyjścia z inicjatywą anulowania uchwały a następnie zbierania głosów pod identyczną uchwałą z zachowaniem wymogów formalnych",{"entities": [(197,202, "civil_law"),(99,108, "civil_law"),(250,259, "civil_law"),(408,417, "civil_law"),(35,42, "civil_law"),(312,318, "civil_law"),(440,447, "civil_law"),(55,61, "civil_law"),(109,115, "civil_law"),(260,266, "civil_law"),(418,424, "civil_law"),(129,136, "civil_law"),(300,307, "civil_law"),(388,395, "civil_law"),(43,54, "civil_law"),(90,98, "civil_law")]}),
("czy wprowadzenie przez urząd miasta takiej podwyżki jest zasadne i czy może ona być dokonana ze skutkiem wstecznym co grozi poprzedniej właścicielce jeśli nie wyrazi zgody na podwyżkę",{"entities": [(136,148, "civil_law"),(105,114, "civil_law"),(57,64, "civil_law"),(159,165, "civil_law"),(96,104, "civil_law"),(4,16, "civil_law"),(29,35, "civil_law"),(43,51, "civil_law"),(124,135, "civil_law")]}),
("czy upływ  miesięcy od momentu śmierci spadkodawcy wpływa na procedurę dziedziczenia",{"entities": [(39,50, "civil_law")]}),
("czy klientka powinna dokonywać opłat za mieszkanie żonie zmarłego wynajmującego jeżeli nie posiada ona jeszcze dokumentu potwierdzającego status spadkobiercy",{"entities": [(111,120, "civil_law"),(66,79, "civil_law")]}),
("czy po powrocie z urlopu macierzyńskiego klientka będzie zobowiązana do pracy w pełnym wymiarze godzin czy klientka będzie zobowiązana do pełnienia dyżurów po powrocie do pracy z urlopu macierzyńskiego czy klientce po powrocie do pracy z urlopu macierzyńskiego będzie przysługiwała przerwa na karmienie",{"entities": [(138,147, "medical_law"),(87,95, "medical_law"),(18,24, "medical_law"),(179,185, "medical_law"),(238,244, "medical_law")]}),
("co powinien zrobić klient w przedstawionej sytuacji aby przeprowadzić sprawę spadkową czy klient może sprzedać odziedziczone prawo przed upływem pięciu lat od nabycia",{"entities": [(111,124, "civil_law"),(77,85, "civil_law")]}),
("jakie jest obecnie minimalne wynagrodzenia lekarza odbywającego specjalizacje w trybie pozarezydenckim",{"entities": [(64,77, "medical_law"),(51,63, "medical_law")]}),
("czy klient może uzupełnić braki formalne odpowiedzi na pozew a jednocześnie rozszerzyć jej zakres czy ustanowienie pełnomocnika podlega opłacie czy sąd może żądać od klienta adresu email czy pisma procesowe wystosowane na adres email klienta będą uznane za doręczone",{"entities": [(181,186, "civil_law"),(228,233, "civil_law"),(102,114, "civil_law"),(55,60, "civil_law"),(174,180, "civil_law"),(32,40, "civil_law")]}),
("jakie są prawa i obowiązki klientki w związku z wezwaniem do stawiennictwa na przesłuchanie w charakterze podejrzanego",{"entities": [(0,5, "criminal_law"),(61,74, "criminal_law"),(94,105, "criminal_law"),(48,57, "criminal_law"),(78,91, "criminal_law")]}),
("czy lekarzom przysługuje zasiłek opiekuńczy w sytuacji gdy zdecydują się na pozostanie w domu z uczącym się zdalnie dzieckiem w wieku poniżej  lat czy są od tego wyłączeni z powodu możliwości oddania dziecka do świetlicy szkolnej jako członkowie służb medycznych",{"entities": [(246,251, "medical_law"),(143,146, "medical_law"),(4,12, "medical_law")]}),
("na jakich zasadach po dniu  lipca  r będą funkcjonowały recepty papierowe w jaki sposób klientka powinna wydrukować papierowe recepty",{"entities": [(42,55, "pharmaceutical_law"),(64,73, "pharmaceutical_law"),(116,125, "pharmaceutical_law")]}),
("czy klient ma obowiązek stawić się w prokuraturze w związku z faktem że przebywa na zwolnieniu lekarskim",{"entities": [(84,94, "criminal_law"),(72,80, "criminal_law"),(37,49, "criminal_law")]}),
("jak kształtują się podstawy odpowiedzialności klientki i podmiotu leczniczego",{"entities": [(19,27, "medical_law")]}),
("czy pracodawca może zobowiązać lekarzy rezydentów do pełnienia dyżurów medycznych w sobotę",{"entities": [(53,62, "medical_law")]}),
("klientka zastanawia się czy pobieranie emerytury jest przeszkodą dla uzyskania świadczenia postojowego czy klientka może złożyć jeden wniosek o zwolnienie z obowiązku opłacania składek ubezpieczenia społecznego dotyczący trzech miesięcy czy też należy składać wniosek po upływie każdego miesiąca",{"entities": [(167,176, "medical_law"),(271,278, "medical_law"),(199,210, "medical_law")]}),
("czy zmiana maszynisty w pracy może trwać dłużej niż  godzin",{"entities": [(4,10, "labor_law")]}),
("jakie czynności powinna podjąć wspólnota mieszkaniowa założenie funduszu celowego w celu wybudowania windy dla osób niepełnosprawnych czy wspólnota mieszkaniowa może uchwałą wspólników przeksięgować środki z funduszu remontowego na fundusz celowy",{"entities": [(217,228, "civil_law"),(54,63, "civil_law"),(166,173, "civil_law")]}),
("o ile wcześniej pracownik musi uprzedzić pracodawcę że ten chce skorzystać z urlopu na żądanie czy pracodawca może zasłaniać się argumentem że brak jest pracowników i z tego powodu nie udzieli pracownikowi urlopu gdzie pracownicy wskazują że w zakładzie pracy pracuje dostatecznie dużo pracowników aby móc skorzystać z tego urlopu czy pracownik dzwoniąc do dyspozytora który w danym czasie pełni obowiązki bezpośredniego przełożonego musi dodatkowo takie żądanie skierować do niebezpośredniego przełożonego czy wystarczy poinformowanie bezpośredniego przełożonego",{"entities": [(219,229, "labor_law"),(390,395, "labor_law"),(185,192, "labor_law"),(421,433, "labor_law"),(494,506, "labor_law"),(193,205, "labor_law")]}),
("czy klientka będzie mogła być zwolniona z vat",{"entities": [(30,39, "tax_law")]}),
("czy konkurencyjna firma może zgłosić do urzędu unii europejskiej ds własności intelektualnej że firma klienta nie ma prawa do wykorzystywania wzoru przemysłowego",{"entities": [(4,17, "international_law")]}),
("na czym polega instytucja zasiedzenia nieruchomości czy w przedmiotowej sprawie może dojść do zasiedzenia jeżeli tak to po jakim czasie",{"entities": [(15,25, "civil_law"),(8,14, "civil_law"),(26,37, "civil_law"),(94,105, "civil_law")]}),
("czy klientka bez pisemnej zgody pacjentki może wydać dokumentację medyczną obecnemu lekarzowi prowadzącemu czy klientka może udostępnić dokumentację medyczną drogą mailową",{"entities": [(17,25, "medical_law"),(94,106, "medical_law")]}),
("o ile wcześniej pracownik musi uprzedzić pracodawcę że ten chce skorzystać z urlopu na żądanie czy pracodawca może zasłaniać się argumentem że brak jest pracowników i z tego powodu nie udzieli pracownikowi urlopu gdzie pracownicy wskazują że w zakładzie pracy pracuje dostatecznie dużo pracowników aby móc skorzystać z tego urlopu czy pracownik dzwoniąc do dyspozytora który w danym czasie pełni obowiązki bezpośredniego przełożonego musi dodatkowo takie żądanie skierować do niebezpośredniego przełożonego czy wystarczy poinformowanie bezpośredniego przełożonego",{"entities": [(219,229, "labor_law"),(390,395, "labor_law"),(185,192, "labor_law"),(421,433, "labor_law"),(494,506, "labor_law"),(193,205, "labor_law")]}),
("czy klient może jakoś zmusić zarządcę wspólnoty do ścięcia zaniedbanej trawy",{"entities": [(29,37, "civil_law")]}),
("czy lekarz dokonujący badania kwalifikacyjnego przed zaszczepieniem pacjenta musi zawsze wystawić zaświadczenie o przeprowadzeniu takiego badania",{"entities": [(114,129, "medical_law"),(98,111, "medical_law")]}),
("czy klient jest uprawniony do wykonania obdukcji pacjentki",{"entities": [(16,26, "medical_law"),(30,39, "medical_law")]}),
("jaka jest funkcjonalna różnica między rozwiązaniem które przewiduje kupno nieruchomości budynkowej wraz z nieruchomością gruntową dla których założono odrębne księgi wieczyste od kupna lokalu w dwulokalowym budynku gdzie nieruchomość gruntowa pozostaje we współwłasności właścicieli obu lokali",{"entities": [(256,270, "civil_law"),(159,165, "civil_law"),(106,120, "civil_law"),(121,129, "civil_law"),(179,184, "civil_law"),(23,30, "civil_law")]}),
("w jak sposób klient może odrzucić spadek",{"entities": [(25,33, "civil_law")]}),
("czy dyrektor szpitala może zabronić wykonywania pracy w innym miejscu czy za prace wyłącznie w jednym podmiocie klientowi należy się rekompensata czy dyrektor szpitala może zabronić wykonywania pracy w innym miejscu z datą wsteczną",{"entities": [(77,82, "labor_law")]}),
("czy w trakcie pracy w ramach skierowania do pracy na podstawie decyzji wojewody klientka ma możliwość skorzystania z urlopu wypoczynkowego czy w trakcie trwania pracy w ramach ww skierowania klientka ma możliwość skorzystania z sześciu dni urlopu szkoleniowego",{"entities": [(102,114, "labor_law"),(213,225, "labor_law"),(124,138, "labor_law")]}),
("czy kartoteka wypełniana odręcznie podczas wizyty pacjenta stanowi również dokumentację medyczną w rozumieniu przepisów ustawy czy klientka ma obowiązek udostępnienia pacjentowi treści kartoteki jeżeli tak to w jakiej formie od kiedy funkcjonuje możliwość sporządzania dokumentacji w postaci elektronicznej",{"entities": [(153,166, "medical_law"),(99,109, "medical_law"),(167,177, "medical_law"),(234,245, "medical_law")]}),
("czy klientka będzie zobowiązana ponieść koszty prac ślusarza i przechowywania rzeczy dłużnika",{"entities": [(47,51, "civil_law"),(78,84, "civil_law")]}),
("czy w przedstawionej sytuacji klient potrzebuje zgody byłej małżonki",{"entities": [(54,59, "civil_law"),(37,47, "civil_law")]}),
("czy towarzystwo ubezpieczeniowe może żądać udostępnienia dokumentacji medycznej od lekarza bez załączenia zgody pacjenta",{"entities": [(43,56, "medical_law"),(95,105, "medical_law")]}),
("czy pracodawca musi wysłać pracownika na okresowe badanie lekarskie",{"entities": [(20,26, "labor_law"),(41,49, "labor_law")]}),
("na jakiej podstawie oraz w jakiej formie należy zatrudnić osobę do pełnienia obowiązków klientki kto będzie osobą odpowiedzialną przez okres usprawiedliwionej nieobecności klientki w pracy",{"entities": [(114,128, "pharmaceutical_law")]}),
("czy klient może zobowiązać byłą żonę do partycypacji w kosztach utrzymania mieszkania",{"entities": [(64,74, "civil_law"),(40,52, "civil_law"),(27,31, "civil_law"),(55,63, "civil_law")]}),
("czy apteka może sprzedawać domowe testy na sarscov",{"entities": [(34,39, "pharmaceutical_law")]}),
("czy klientka może zrealizować receptę ze zniżką na lek z wykazu a wypisaną przez lekarza stażystę",{"entities": [(30,37, "pharmaceutical_law"),(18,29, "pharmaceutical_law"),(41,47, "pharmaceutical_law")]}),
("czy w przypadku zlecenia zarządzania wspólnotą mieszkaniową zewnętrznej firmie zarządzającej zarząd wspólnoty przed podpisaniem umowy z firmą musi uzyskać zgodę wspólnoty mieszkaniowej",{"entities": [(93,99, "civil_law"),(47,59, "civil_law")]}),
("czy planowanie przez pracodawcę pracy w niedzielę jest podstawą do skrócenia przez klientkę okresu wypowiedzenia umowy o pracę",{"entities": [(67,76, "labor_law"),(55,63, "labor_law")]}),
("czy lekarz stażysta może wydawać pacjentom skierowanie na domową izolację",{"entities": [(11,19, "medical_law"),(58,64, "medical_law"),(43,54, "medical_law")]}),
("czy pracodawca może odmówić odbycia stażu zewnętrznego przez klienta",{"entities": [(28,35, "medical_law"),(36,41, "medical_law"),(42,54, "medical_law")]}),
("jak powinna zachować się klientka w związku z wezwaniem przez policję na przesłuchanie w charakterze świadka",{"entities": [(89,100, "criminal_law"),(46,55, "criminal_law"),(73,86, "criminal_law")]}),
("czy pracodawca zainteresowanego może zmusić go do rozwiązania przez niego umowy o pracę czy w przedstawionej sytuacji zainteresowanemu przysługuje zaległy urlop wypoczynkowy",{"entities": [(147,154, "labor_law")]}),
("czy klientka ma obowiązek udzielania informacji synowi pacjenta o stanie zdrowia pacjenta w czasie gdy nie przebywa on w szpitalu pomiędzy hospitalizacjami czy na nowej zgodzie na leczenie należy odnotować że jest ona udzielona ponownie",{"entities": [(169,176, "medical_law"),(26,36, "medical_law")]}),
("czy pracownik musi odebrać tablet służbowy przeznaczony do wykonywania pracy czy pracodawca obowiązany jest dostarczyć odpowiednie zabezpieczenie do sprzętu służbowego powierzonego pracownikowi",{"entities": [(108,118, "labor_law")]}),
("czy klient może wytoczyć proces żądającej zachowku córce babci o uporczywe zaniedbanie obowiązków rodzinnych",{"entities": [(25,31, "civil_law"),(42,50, "civil_law"),(51,56, "civil_law"),(57,62, "civil_law")]}),
("czy w ramach aptek prowadzonych pod jednym numerem nip można dokonywać przesunięć leków psychotropowych narkotycznych i prekursorów",{"entities": [(43,50, "pharmaceutical_law"),(13,18, "pharmaceutical_law"),(71,81, "pharmaceutical_law"),(88,103, "pharmaceutical_law"),(19,31, "pharmaceutical_law"),(51,54, "pharmaceutical_law")]}),
("jakie obecnie obowiązują limity osób w przypadku spotkań",{"entities": [(14,24, "medical_law")]}),
("czy aktualne przepisy regulują kierunek otwierania drzwi pomieszczenia w którym znajduje się kocioł gazowy o mocy  kw czy w  roku kiedy projekt budowlanybył zatwierdzany do pozwolenia na budowę przepisy regulowały kierunek otwierania drzwi w zależności od mocy kotła",{"entities": [(40,50, "administrative_law"),(223,233, "administrative_law"),(136,143, "administrative_law"),(187,193, "administrative_law"),(31,39, "administrative_law"),(214,222, "administrative_law"),(173,183, "administrative_law"),(57,70, "administrative_law")]}),
("czy kierownik apteki może podpisać zestawienie refundacyjne podczas przebywania na zwolnieniu lekarskim czy klientka może podpisać zestawienie refundacyjne",{"entities": [(35,46, "medical_law"),(131,142, "medical_law"),(4,13, "medical_law"),(47,59, "medical_law")]}),
("czy klientce przysługuje możliwość skorzystania zwolnienia od pracy w związku z opieką nad dzieckiem",{"entities": [(35,47, "labor_law"),(80,86, "labor_law")]}),
("czy pracodawca może skrócić w zakładzie pracy porę nocną z  godzin do  godzin",{"entities": [(20,27, "labor_law")]}),
("czy w przypadku gdy dwójka rodziców wychowuje dziecko do lat  i jeden z rodziców jest lekarzem może on zostać skierowany do pracy przy zwalczaniu epidemii przez wojewodę",{"entities": [(57,60, "medical_law"),(86,94, "medical_law"),(110,120, "medical_law"),(36,45, "medical_law")]}),
("czy składki na okręgowe izby aptekarskie są na terenie całego kraju w takiej samej wysokości czy każda izba z osobna ustala ich wysokość czy zmiana miejsca zamieszkania przeniesienie się do innej izby wpływa na wysokość składek na izbę kto może być zwolniony z opłacania składek na okręgową izbę aptekarską kto może płacić niższe składki jaką składkę na okręgowa izbę lekarską płacą renciści niewykonujący zawodu oraz wykonujący zawód w niepełnym wymiarze czasu pracy",{"entities": [(47,54, "pharmaceutical_law"),(296,306, "pharmaceutical_law"),(4,11, "pharmaceutical_law"),(330,337, "pharmaceutical_law"),(437,446, "pharmaceutical_law"),(55,61, "pharmaceutical_law"),(169,182, "pharmaceutical_law"),(231,235, "pharmaceutical_law"),(291,295, "pharmaceutical_law"),(363,367, "pharmaceutical_law")]}),
("czy obowiązek posiadania kas fiskalnych online od  lipca  r dotyczy lekarzy i podmiotów leczniczych",{"entities": [(29,39, "tax_law"),(51,56, "tax_law"),(14,24, "tax_law"),(25,28, "tax_law"),(68,75, "tax_law"),(60,67, "tax_law")]}),
("czy klient może być oddelegowany na oddział covidowy i pełnić funkcje pielęgniarskie czy klient może skorzystać z urlopu bezpłatnego bez zgody pracodawcy",{"entities": [(55,61, "medical_law"),(114,120, "medical_law"),(44,52, "medical_law"),(16,19, "medical_law")]}),
("czy lekarz poz może zlecić wykonanie testu kontrolnego u pacjentki",{"entities": [(11,14, "medical_law"),(27,36, "medical_law")]}),
("z jakimi formalnościami wiąże się rozwiązanie umowy o pracę za porozumieniem stron",{"entities": [(63,76, "labor_law")]}),
("jak kształtuje się odpowiedzialność klientki za błędy lekarskie czy klientka jest zobowiązana do podania numeru swojej polisy oc",{"entities": [(119,125, "medical_law"),(105,111, "medical_law"),(97,104, "medical_law")]}),
("jakie działania może podjąć klientka w sytuacji gdy nie zgadza się z wysokością odszkodowania za holowanie pojazdu",{"entities": [(56,62, "civil_law")]}),
("czy pracodawca może zabronić lekarzowi wykonywania pracy w innych podmiotach leczniczych czy klient może zwrócić się do jakiejś instytucji z żądaniem zwrotu utraconego zarobku czy pracodawca może żądać od lekarza informacji dotyczących zatrudnienia w innych podmiotach leczniczych",{"entities": [(157,167, "labor_law")]}),
("czy jako osoba fizyczna wynajmująca mieszkanie klient może wystawić najemcy dokument kasa przyjęła",{"entities": [(68,75, "civil_law"),(76,84, "civil_law")]}),
("co klientka może skutecznie zmienić miejsce odbywania szkolenia specjalizacyjnego",{"entities": [(54,63, "medical_law")]}),
("jakie wynagrodzenie przysługuję lekarzowi rezydentowi skierowanemu przez wojewodę do pracy przy zwalczaniu covid jakie inne uprawnienia przysługują lekarzowi rezydentowi skierowanemu do pracy przy zwalczaniu covid",{"entities": [(54,66, "medical_law"),(170,182, "medical_law"),(42,53, "medical_law"),(158,169, "medical_law"),(73,81, "medical_law")]}),
("czy pracownik który w ciągu roku był na zwolnieniu lekarskim zachowuje prawo do urlopu wypoczynkowego za cały rok czy podstawa wymiaru urlopu będzie zmniejszona",{"entities": [(127,134, "labor_law"),(87,101, "labor_law")]}),
("czy świadectwo pracy powinno uwzględniać zmianę formy prowadzenia działalności gospodarczej a w konsekwencji zmianę nazwy pracodawcy",{"entities": [(4,14, "labor_law"),(41,47, "labor_law"),(109,115, "labor_law")]}),
("czy klient ma obowiązek wypełnienia i podpisania takiego pisma czy i bez niego należy mu się dodatek covidowy jak liczy się wysokości dodatku covidowego  za poszczególne dni przepracowane z pacjentami covidowymi czy od całości miesięcznej pensji",{"entities": [(174,187, "medical_law"),(57,62, "medical_law"),(24,35, "medical_law"),(142,152, "medical_law"),(101,109, "medical_law"),(190,200, "medical_law")]}),
("czy odległość pomiędzy stanowiskami do przyjmowania klientów apteki od strony pacjenta może być mniejsza niż  m",{"entities": [(39,51, "medical_law"),(92,95, "medical_law")]}),
("w jaki sposób należy uzyskać zgodę na zabieg bądź szczepienie w przypadku pacjentów starszych niezdolnych do świadomego wyrażenia woli",{"entities": [(38,44, "medical_law"),(50,61, "medical_law"),(120,129, "medical_law"),(29,34, "medical_law")]}),
("czy klientka odpowiada za to aby w aptece był farmaceuta co w przypadku gdy klientka będzie musiała wziąć l a nie będzie innego farmaceuty który mógłby pracować w aptece czy klientka musi wypracowywać nadgodziny jakich czynności musi klientka dokonać w związku z zakończeniem zatrudnienia na stanowisku kierownika apteki co stanie się z niewykorzystanym urlopem klientki",{"entities": [(100,105, "pharmaceutical_law"),(263,275, "pharmaceutical_law")]}),
("w jakiej formie pracodawca może polecić klientowi kwalifikowanie pacjentów do szczepień na covid bez zmiany umowy o pracę",{"entities": [(50,64, "medical_law"),(78,87, "medical_law")]}),
("jakie jest obecnie minimalne wynagrodzenia lekarza odbywającego specjalizacje w trybie pozarezydenckim",{"entities": [(64,77, "medical_law"),(51,63, "medical_law")]}),
("w jaki sposób klientka powinna regulować opłaty za mieszkanie",{"entities": [(31,40, "civil_law")]}),
("co powinien zrobić klient w celu wyegzekwowania zapłaty dodatku covidowego w przypadku w którym wezwanie do zapłaty okazało się nieskuteczne",{"entities": [(116,123, "medical_law"),(64,74, "medical_law")]}),
("jak kształtują się podstawy odpowiedzialności klienta prowadzącego leczenie w ramach indywidualnej praktyki lekarskiej",{"entities": [(19,27, "medical_law"),(85,98, "medical_law"),(54,66, "medical_law")]}),
("czy klientka może dochodzić zwrotu wartości zapłaconych kar w toczącej się sprawie sądowej o podział majątku wspólnego",{"entities": [(93,100, "civil_law"),(83,90, "civil_law"),(56,59, "civil_law")]}),
("czy wspólnota może zakazać klientce wjazdu na parking na nieruchomości wspólnej",{"entities": [(36,42, "civil_law")]}),
("czy towarzystwo ubezpieczeń powinno poinformować klienta o tym że kończy mu się ubezpieczenie oc",{"entities": [(16,27, "civil_law")]}),
("czy klient będzie ponosił koszty szkolenia w przypadku rozwiązania umowy o pracę za porozumieniem stron czy klient będzie ponosił koszty szkolenia w przypadku gdyby odmówił zmiany stanowiska a następnie pracodawca wypowiedziałby umowę o pracę",{"entities": [(18,25, "labor_law"),(122,129, "labor_law"),(180,190, "labor_law"),(84,97, "labor_law")]}),
("jakie kroki prawne może podjąć wspólnota mieszkaniowa w przedmiotowej sprawie",{"entities": [(0,5, "criminal_law"),(12,18, "criminal_law")]}),
("czy gdyby klientka chciała pracować w innym podmiocie leczniczym to czy zgodnie z prawem może świadczyć tam usługi medyczne przy kwalifikacji do szczepień ochronnych przeciwko covid",{"entities": [(155,165, "medical_law"),(27,35, "medical_law"),(44,53, "medical_law"),(54,64, "medical_law"),(145,154, "medical_law"),(94,103, "medical_law")]}),
("jakie czynności może podjąć spółdzielnia mieszkaniowa aby wyegzekwować swoje żądanie jaki organ może powiadomić spółdzielnia mieszkaniowa żeby wyegzekwować swoje żądanie",{"entities": [(90,95, "administrative_law")]}),
("czy na każdej fakturze trzeba umieszczać kod gtu  czy w przypadku wystawienia dwóch recept dwóm różnym osobom klientka może wystawić fakturę obejmującą płatność za obie recepty na jedną z tych osób",{"entities": [(169,176, "tax_law"),(133,140, "tax_law"),(84,90, "tax_law"),(180,185, "tax_law"),(14,22, "tax_law")]}),
("czy lekarz może odmówić przyjęcia pacjenta który odmawia podania danych osobowych przy zakładaniu karty pacjenta",{"entities": [(98,103, "medical_law"),(24,33, "medical_law"),(57,64, "medical_law"),(49,56, "medical_law")]}),
("czy z korespondencji z pacjentką wynika groźba w stosunku do klientki",{"entities": [(40,46, "criminal_law")]}),
("czy klient jest zobowiązany do prowadzenia elektronicznej dokumentacji medycznej od  lipca  r czy zleceniodawca klienta może zobowiązać klienta do prowadzenia elektronicznej dokumentacji medycznej jakie sankcje dla podmiotu leczniczego wiążą się z niezachowaniem obowiązku prowadzenia elektronicznej dokumentacji medycznej",{"entities": [(236,241, "medical_law"),(92,93, "medical_law")]}),
("czy w trakcie panującej epidemii koronawirusa możliwe jest zwołanie zebrania wspólnoty mieszkaniowej w jakiej formie można przeprowadzić takie zebranie",{"entities": [(68,76, "civil_law")]}),
("czy zobowiązana przez inspektorat nadzoru budowlanego gmina powinna zakończyć pracę naprawcze placu zabaw w określonym terminie czy klient może prosić inspektorat nadzoru budowlanego o informację na temat wykonanych przez gminę prac naprawczych",{"entities": [(100,105, "administrative_law"),(42,53, "administrative_law"),(171,182, "administrative_law"),(54,59, "administrative_law"),(94,99, "administrative_law"),(22,33, "administrative_law"),(151,162, "administrative_law")]}),
("czy klient może odmówić pacjentowi leczenia stomatologicznego w przypadku gdy ten w ciągu ostatnich  dni wrócił z zagranicy",{"entities": [(24,34, "medical_law"),(84,89, "medical_law")]}),
("czy klientka może wnosić o skrócenie okresu obowiązywania zakazu prowadzenia pojazdów mechanicznych w ruchu lądowym",{"entities": [(58,64, "criminal_law")]}),
("jak kształtują się podstawy odpowiedzialności klientki i podmiotu leczniczego",{"entities": [(19,27, "medical_law")]}),
("czy duża wspólnota mieszkaniowa składająca się z  lokali może podjąć uchwałę o powiększeniu wszystkich istniejących w danym budynku balkonów w liczbie  ze środków zgromadzonych na funduszu remontowym",{"entities": [(132,140, "civil_law"),(4,8, "civil_law"),(50,56, "civil_law"),(69,76, "civil_law")]}),
("czy lekarz stażysta może dodatkowo podjąć pracę na podstawie umowy zlecenie w jednostce macierzystej poza godzinami odbywania stażu",{"entities": [(67,75, "medical_law"),(106,115, "medical_law"),(11,19, "medical_law"),(78,87, "medical_law")]}),
("czy przepisy zobowiązują lekarzy do wysyłania formularzy odwołujących podejrzenie zarażenia chorobą zakaźną pacjenta",{"entities": [(92,99, "medical_law"),(70,81, "medical_law"),(100,107, "medical_law"),(36,45, "medical_law")]}),
("czy pracownik który w ciągu roku był na zwolnieniu lekarskim zachowuje prawo do urlopu wypoczynkowego za cały rok czy podstawa wymiaru urlopu będzie zmniejszona",{"entities": [(127,134, "labor_law"),(87,101, "labor_law")]}),
("czy tzw zejście po dyżurach medycznych wydłuża czas trwania szkolenia specjalizacyjnego",{"entities": [(19,27, "medical_law"),(60,69, "medical_law"),(39,46, "medical_law"),(47,51, "medical_law"),(8,15, "medical_law")]}),
("czy tarcza antykryzysowa lub inne przepisy przewidują pomoc finansową dla farmaceutów w związku z epidemią koronawirusa",{"entities": [(74,85, "medical_law"),(98,106, "medical_law")]}),
("czy lekarz który nie jest zatrudniony może zostać skierowany do pracy przy zwalczaniu epidemii przez wojewodę na jakiej podstawie pracodawca może oddelegować osobę zatrudnioną w podmiocie leczniczym do pracy przy zwalczaniu epidemii",{"entities": [(26,37, "medical_law"),(178,187, "medical_law"),(50,60, "medical_law"),(158,163, "medical_law"),(188,198, "medical_law"),(101,109, "medical_law")]}),
("czy podczas odbywania kwarantanny możliwa jest praca zdalna czy pracodawca może odmówić pracownikowi możliwości pracy zdalnej w trakcie kwarantanny",{"entities": [(53,59, "labor_law"),(47,52, "labor_law"),(88,100, "labor_law"),(118,125, "labor_law")]}),
("czy zakład opiekuńczoleczniczy dalej zol może przyjąć chorego niezdolnego do wyrażenia świadomej woli przed uzyskaniem zgody sądu co należy zrobić w sytuacji gdy pacjent został przyjęty do zol przed uzyskaniem zgody sądu a rodzina chce zabrać chorego do domu",{"entities": [(108,118, "medical_law"),(199,209, "medical_law"),(87,96, "medical_law"),(77,86, "medical_law"),(54,61, "medical_law"),(243,250, "medical_law"),(46,53, "medical_law"),(37,40, "medical_law"),(189,192, "medical_law")]}),
("czy pracodawca może zmusić pracowników do wykorzystania zaległych urlopów wypoczynkowych jeżeli nie były przewidziane w planie urlopowym",{"entities": [(74,88, "labor_law"),(66,73, "labor_law"),(56,65, "labor_law")]}),
("czy świadectwo pracy powinno uwzględniać zmianę formy prowadzenia działalności gospodarczej a w konsekwencji zmianę nazwy pracodawcy",{"entities": [(4,14, "labor_law"),(41,47, "labor_law"),(109,115, "labor_law")]}),
("czy klient jest uprawniony do wykonywania zabiegów w prywatnym gabinecie urologicznym",{"entities": [(53,62, "medical_law"),(16,26, "medical_law")]}),
("czy ojciec klientki może być jej pełnomocnikiem czy pełnomocnictwo musi mieć formę aktu notarialnego",{"entities": [(52,66, "civil_law")]}),
("jak przedstawia się kwestia odpowiedzialności zatrudnionej przez klientkę pielęgniarki",{"entities": [(46,58, "medical_law")]}),
("czy klientka może wystawić fakturę na pracodawcę który kupuje szczepionki dla swoich pracowników",{"entities": [(27,34, "tax_law")]}),
("jak kształtuje się odpowiedzialność lekarza oraz jakie prawa ma pacjent w przypadku błędu medycznego podczas zabiegu",{"entities": [(84,89, "medical_law")]}),
("czy klient powinien podpisywać wydruk opisu badania diagnostycznego odręcznie",{"entities": [(31,37, "medical_law"),(38,43, "medical_law")]}),
("czy farmaceuta jest uprawniony do wystawiania recept pro familiae i pro auctore",{"entities": [(53,56, "pharmaceutical_law"),(68,71, "pharmaceutical_law"),(57,65, "pharmaceutical_law")]}),
("czy umowa o pracę została skutecznie wypowiedziana czy zwolnienie lekarskie wpływa na skuteczność wypowiedzenia",{"entities": [(37,50, "labor_law"),(86,97, "labor_law")]}),
("kto powinien wyrazić zgodę na samodzielne odbywanie dyżurów medycznych przez klientkę",{"entities": [(42,51, "medical_law"),(21,26, "medical_law")]}),
("czy lekarz stażysta odpowiada za błąd medyczny czy lekarz stażysta ma obowiązek zawrzeć umowę ubezpieczenia odpowiedzialności cywilnej",{"entities": [(11,19, "medical_law"),(58,66, "medical_law"),(33,37, "medical_law")]}),
("czy aktualne przepisy regulują kierunek otwierania drzwi pomieszczenia w którym znajduje się kocioł gazowy o mocy  kw czy w  roku kiedy projekt budowlanybył zatwierdzany do pozwolenia na budowę przepisy regulowały kierunek otwierania drzwi w zależności od mocy kotła",{"entities": [(40,50, "administrative_law"),(223,233, "administrative_law"),(136,143, "administrative_law"),(187,193, "administrative_law"),(31,39, "administrative_law"),(214,222, "administrative_law"),(173,183, "administrative_law"),(57,70, "administrative_law")]}),
("jak przedstawia się obowiązek przejmowania dokumentacji medycznej w przypadku zakończenia prowadzenia działalności leczniczej jaką treść powinno zawierać oświadczenie pacjentek w sprawie przekazania dokumentacji medycznej",{"entities": [(78,89, "medical_law"),(131,136, "medical_law"),(167,176, "medical_law"),(126,130, "medical_law"),(137,144, "medical_law"),(30,42, "medical_law"),(115,125, "medical_law")]}),
("czy możliwe jest umorzenie egzekucji co do świadczeń wymagalnych w przyszłości ze źródeł innych niż wynagrodzenie za pracę",{"entities": [(17,26, "civil_law")]}),
("czy spadkobiercy mogą zostać pociągnięci do odpowiedzialności w ramach umowy ubezpieczenia czy spadkobiercy mogą wystąpić do ubezpieczyciela z informacją jakie szkody poniósł poszkodowany w jakim terminie spadkobiercy powinni ustosunkować się do pisma ubezpieczyciela",{"entities": [(4,16, "civil_law"),(95,107, "civil_law"),(205,217, "civil_law")]}),
("czy lekarz zatrudniony na kontrakcie ma prawo odmówić udzielania świadczenia usług medycznych na przekształconym oddziale w związku z rozprzestrzenianiem się koronawirusa",{"entities": [(11,22, "medical_law"),(26,36, "medical_law"),(97,112, "medical_law"),(54,64, "medical_law")]}),
("czy influvactetra można zapisać letniemu dziecku",{"entities": [(24,31, "medical_law")]}),
("czy klientka zobowiązana jest odbywać dyżury towarzyszące",{"entities": [(30,37, "medical_law")]}),
("czy klient ma obowiązek posiadania kasy fiskalnej",{"entities": [(24,34, "tax_law")]}),
("jakie są prawa i obowiązki klienta na przesłuchaniu w charakterze świadka",{"entities": [(0,5, "criminal_law"),(54,65, "criminal_law")]}),
("czy szpital w którym pracuje klientka jest szpitalem ii lub iiistopnia zabezpieczenia czy pracodawca klientki może wypłacać jej dodatek do wynagrodzenia jedynie za godziny przepracowane na bloku operacyjnymi z pacjentami z potwierdzonym zakażeniem covid",{"entities": [(237,247, "medical_law"),(172,185, "medical_law"),(71,85, "medical_law"),(43,52, "medical_law"),(115,123, "medical_law"),(210,220, "medical_law"),(53,55, "medical_law"),(223,236, "medical_law")]}),
("czy klientka może zagrodzić swoją część drogi tak aby sąsiad nie miał do niej dostępu czy w przedmiotowej sprawie doszło do zasiedzenia nieruchomości",{"entities": [(124,135, "civil_law")]}),
("jakie przepisy prawa obligują byłego zarządcę do przekazania dokumentacji wspólnoty mieszkaniowej",{"entities": [(49,60, "civil_law"),(21,29, "civil_law"),(37,45, "civil_law")]}),
("w jaki sposób klientka ma przesłać wniosek sporządzany w ramach zgłoszenia o sygn  w jaki terminie portal powinien zareagować na pismo",{"entities": [(99,105, "administrative_law")]}),
("czy przepisy powszechnie obowiązującego prawa wyznaczają kiedy skarbnik okręgowej izby aptekarskiej musi przedstawić sprawozdanie z wykonania budżetu oraz przedstawić projekt budżetu",{"entities": [(87,99, "pharmaceutical_law"),(142,149, "pharmaceutical_law"),(117,129, "pharmaceutical_law")]}),
("czy klient już teraz może związać się umową o pracę która miałaby zacząć obowiązywać od czasu planowego zakończenia jego rezydentury nie ryzykując koniecznością pracy na dwa etaty czy dyrektor szpitala może skutecznie pisemnie zagwarantować że w razie wydłużenia specjalizacji klienta ten będzie go dalej zatrudniał",{"entities": [(104,115, "medical_law"),(227,240, "medical_law"),(66,72, "medical_law"),(121,132, "medical_law"),(252,262, "medical_law")]}),
("czy klient musi uwzględnić w przychodzie pożyczę otrzymaną z urzędu pracy w ramach wsparcia przedsiębiorców w okresie epidemii covid czy klient musi od tej kwoty zapłacić podatek",{"entities": [(162,170, "medical_law")]}),
("czy lekarz stażysta może dodatkowo podjąć pracę na podstawie umowę zlecenie u innego pracodawcy przy pobieraniu wymazów na covid",{"entities": [(67,75, "medical_law"),(11,19, "medical_law")]}),
("jak kształtuje się odpowiedzialność klientki za błędy lekarskie czy klientka jest zobowiązana do podania numeru swojej polisy oc",{"entities": [(119,125, "medical_law"),(105,111, "medical_law"),(97,104, "medical_law")]}),
("jakiego rodzaju oświadczenie powinna wypisywać klientka pacjentom którzy posiadają przeciwwskazania do noszenia maseczek zakrywających usta i nos",{"entities": [(8,15, "medical_law"),(112,120, "medical_law")]}),
("czy legalne jest założenie spółki w składzie osobowym który jest w innej spółce czy usługi dostawy jedzenia są zwolnione z podatku vat czy spółka może rozszerzyć działalność o dostawy jedzenia i korzystać ze zwolnienia vat",{"entities": [(151,161, "tax_law"),(99,107, "tax_law"),(184,192, "tax_law"),(162,173, "tax_law"),(208,218, "tax_law"),(195,204, "tax_law"),(139,145, "tax_law"),(123,130, "tax_law"),(91,98, "tax_law"),(176,183, "tax_law")]}),
("na jakiej podstawie i w jaki sposób klient może uzyskać zadośćuczynienie od biura podróży",{"entities": [(76,81, "administrative_law")]}),
("co ma zrobić klientka aby sąd nie zwrócił pisma procesowego z przyczyny brak adresu zamieszkania syna",{"entities": [(48,59, "civil_law"),(77,83, "civil_law")]}),
("czy apteka może sprzedawać wodę mineralną czy apteka może kupować wodę mineralną w hurtowniach spożywczych",{"entities": [(58,65, "pharmaceutical_law"),(27,31, "pharmaceutical_law"),(66,70, "pharmaceutical_law"),(32,41, "pharmaceutical_law"),(71,80, "pharmaceutical_law")]}),
("czy można zlokalizować punkt szczepień w szkole",{"entities": [(29,38, "medical_law")]}),
("w jaki sposób klientka może doprowadzić do przedłużenia okresu specjalizacji w ten sposób żeby przez rok przebywać na urlopie bezpłatnym",{"entities": [(105,114, "medical_law"),(43,55, "medical_law")]}),
("czy klientka może wynająć komuś swój gabinet jaka jest podstawa prawna tego że klientka nie może zatrudniać innego lekarza czy lekarz pracujący na pół etatu musi płacić ubezpieczenie oc w pełnej wysokości",{"entities": [(55,63, "medical_law"),(97,107, "medical_law"),(64,70, "medical_law"),(134,143, "medical_law"),(188,194, "medical_law"),(151,156, "medical_law")]}),
("czy klientka może wynająć komuś swój gabinet jaka jest podstawa prawna tego że klientka nie może zatrudniać innego lekarza czy lekarz pracujący na pół etatu musi płacić ubezpieczenie oc w pełnej wysokości",{"entities": [(55,63, "medical_law"),(97,107, "medical_law"),(64,70, "medical_law"),(134,143, "medical_law"),(188,194, "medical_law"),(151,156, "medical_law")]}),
("jakich świadczeń może udzielać fizjoterapeuta w trakcie stanu epidemii jaka sankcja grozi mu za nieprzestrzeganie ograniczeń spowodowanych wprowadzeniem stanu epidemii",{"entities": [(56,61, "medical_law"),(153,158, "medical_law"),(31,45, "medical_law"),(139,152, "medical_law"),(114,124, "medical_law"),(96,113, "medical_law")]}),
("czy w przypadku wystawienia przez lekarza błędnej elektronicznej recepty ze  odpłatnością podczas gdy jest to lek refundowany pacjent może uzyskać refundację leku po okazaniu decyzji w aptece czy pacjent powinien udać się do lekarza po nową receptę",{"entities": [(114,125, "pharmaceutical_law"),(77,89, "pharmaceutical_law"),(147,157, "pharmaceutical_law")]}),
("czy były pracodawca ma prawo żądać od klienta zwrotu pewnej kwoty wynikającej z umowy lojalnościowej",{"entities": [(66,77, "labor_law")]}),
("w jaki sposób będzie przebiegało dziedziczenie udziału w prawie własności nieruchomości po śmierci któregoś z rodziców klienta w jaki sposób będzie przebiegało dziedziczenie udziału w prawie własności nieruchomości po śmierci drugiego z rodziców klienta czy aby klient odziedziczył udziały rodziców w prawie własności nieruchomości koniecznym jest sporządzenie testamentu",{"entities": [(332,342, "civil_law"),(57,63, "civil_law"),(184,190, "civil_law"),(301,307, "civil_law"),(21,32, "civil_law"),(148,159, "civil_law"),(33,46, "civil_law"),(160,173, "civil_law"),(64,73, "civil_law"),(191,200, "civil_law"),(308,317, "civil_law")]}),
("czy klient może zostać skierowany do pracy przy zwalczaniu epidemii przez wojewodę",{"entities": [(23,33, "medical_law")]}),
("jak kształtuje się odpowiedzialność lekarza zatrudnionego w podmiocie leczniczym na podstawie umowy cywilnoprawnej wobec pacjenta",{"entities": [(100,114, "medical_law"),(60,69, "medical_law"),(70,80, "medical_law")]}),
("czy obecnie lekarz ma obowiązek prowadzenia teleporad w formie wideo czy zwykła forma telefoniczna jest wystarczająca czy lekarz w dokumentacji medycznej sporządzanej w ramach teleporady ma obowiązek zawarcia elementu badanie w sytuacji w której teleporada świadczona jest telefonicznie a zatem  jak wskazuje klient  brak jest możliwości przeprowadzenia badania czy lekarz ma obowiązek weryfikowania tożsamości pacjenta na podstawie informacji o serii i numerze dowodu osobistego",{"entities": [(300,308, "administrative_law"),(104,117, "administrative_law")]}),
("czy wniosek o skrócenie kary ograniczenia wolności może zostać złożony przez pracodawcę skazanej",{"entities": [(42,50, "criminal_law"),(77,87, "criminal_law")]}),
("jakie akty prawne obowiązują klienta podczas prowadzenia zajęć czy studenci podczas zajęć z wykorzystaniem fantoma powinni dezynfekować ręce i zakładać rękawiczki czy konieczne jest każdorazowe dezynfekowanie fantoma czy studenci mają dezynfekować swoje ubrania",{"entities": [(67,75, "medical_law"),(221,229, "medical_law"),(18,28, "medical_law"),(107,114, "medical_law"),(209,216, "medical_law"),(123,135, "medical_law"),(235,247, "medical_law"),(57,62, "medical_law"),(84,89, "medical_law")]}),
("czy pisemne zapisy ustaleń wiążą strony czy dodatkowe zapisy wpływają na możliwość wypowiedzenia umowy",{"entities": [(4,11, "administrative_law"),(61,69, "administrative_law")]}),
("jak uregulowana jest instytucja tzw zejścia po dyżurze",{"entities": [(36,43, "medical_law"),(4,15, "medical_law")]}),
("czy klient może podważyć wiarygodność sporządzonych przez siebie oświadczeń czy prokurator miał prawo odmówić podjęcia czynności w sprawie przeciwko małżonce klienta czy przedstawione okoliczności mogą wpłynąć na decyzję sądu w zakresie złagodzenia kary jeżeli klient dobrowolnie podda się karze",{"entities": [(91,95, "criminal_law"),(80,90, "criminal_law"),(119,128, "criminal_law")]}),
("z czym wiąże się zadaniowy system czasu pracy czy zadaniowy system czasu pracy powinien zostać uwzględniony w umowie o pracę czy możliwe jest podpisanie umowy o pracę z późniejszym terminem rozpoczęcia jej wykonywania np miesiąc później",{"entities": [(181,189, "labor_law"),(17,26, "labor_law"),(50,59, "labor_law"),(142,152, "labor_law"),(169,180, "labor_law")]}),
("jaką stawką vat powinny być oprocentowane rękawice sprowadzane z łotwy czy import rękawic winylowych podlega zgłoszeniu do urzędu",{"entities": [(0,4, "medical_law"),(24,27, "medical_law"),(16,23, "medical_law")]}),
("czy sprzedaż części ułamkowej  lokalu użytkowego kupionego w  r w procedurze zwolnienia z vat będzie podlegała opodatkowania tym podatkiem",{"entities": [(77,87, "tax_law")]}),
("czy na zebraniu wspólnoty mieszkaniowej można omawiać kwestie zadłużenia poszczególnych członków wspólnoty mieszkaniowej posługując się imieniem oraz nazwiskiem osoby zadłużonej",{"entities": [(7,15, "civil_law"),(73,87, "civil_law")]}),
("czy lekarz może odmówić pracy w przypadku braku odpowiedniej odzieży ochronnej i szkoleń z zakresu indywidualnej ochrony przed koronawirusem",{"entities": [(61,68, "labor_law"),(48,60, "labor_law")]}),
("czy w sytuacji w której jeden z rodziców wyraża zgodę na leczenie dziecka a drugi rodzic nie wyraża zgody na leczenie dziecka lekarz może podjąć leczenie czy pismo ojca klienta stanowi dokumentację medyczną czy przychodnia może udostępnić matce pacjenta pismo ojca pacjenta",{"entities": [(211,222, "medical_law"),(48,53, "medical_law")]}),
("czy dowód osobisty jest konieczny do zawarcia umowy najmu",{"entities": [(24,33, "civil_law")]}),
("jakie są prawa i obowiązki świadka w postępowaniu karnym",{"entities": [(0,5, "criminal_law"),(27,34, "criminal_law"),(37,49, "criminal_law")]}),
("czy pracodawca może zobowiązać pracowników do wykorzystania urlopów wypoczynkowych jeżeli nie były przewidziane w planie urlopowym",{"entities": [(68,82, "labor_law"),(60,67, "labor_law")]}),
("czy klientka będzie mogła udzielać świadczeń zdrowotnych po  czerwca zarówno jeśli chodzi o nowych pacjentów jak i kontynuacji",{"entities": [(83,89, "medical_law"),(92,98, "medical_law")]}),
("czy wspólnota mieszkaniowa może czerpać korzyści z posiadania w kamienicy skrzynki energetycznej zktórej zasilane są również inne budynki",{"entities": [(74,82, "civil_law"),(64,73, "civil_law")]}),
("czy ochrona wynikająca z wniosku o obniżenie wymiaru czasu pracy oznacza również ochronę przed zwolnieniem z przyczyn leżących po stronie pracodawcy z wypłatą odpowiedniego odszkodowania",{"entities": [(12,22, "labor_law"),(45,52, "labor_law"),(109,117, "labor_law"),(81,88, "labor_law"),(35,44, "labor_law"),(118,126, "labor_law"),(4,11, "labor_law"),(151,158, "labor_law"),(95,106, "labor_law")]}),
("czy szpital może żądać od klientki zwrotu części wynagrodzenia w zaistniałych okolicznościach",{"entities": [(65,77, "medical_law")]}),
("jakie prawa przysługują klientce w związku z wezwaniem czy klientka może nie stawić się na przesłuchanie w związku z tym że jest w zaawansowanej ciąży",{"entities": [(0,5, "criminal_law"),(45,54, "criminal_law"),(91,104, "criminal_law")]}),
("w jaki sposób klient może stać się współwłaścicielem nieruchomości z jakimi kosztami będzie się to wiązało",{"entities": [(85,91, "administrative_law")]}),
("w jaki sposób klientka może zabezpieczyć się na przyszłość przed roszczeniami pacjentów jak należy dokumentować zgody uzyskiwane od pacjentów w przypadku prowadzenia dokumentacji elektronicznej czym różni się dokumentacja elektroniczna od dokumentacji w formie elektronicznej",{"entities": [(199,204, "medical_law"),(65,77, "medical_law"),(209,221, "medical_law")]}),
("czy pracownik apteki może odmówić sprzedaży towarów osobom niezakrywającym nosa i ust",{"entities": [(75,79, "criminal_law"),(14,20, "criminal_law"),(59,74, "criminal_law"),(44,51, "criminal_law"),(52,58, "criminal_law")]}),
("czy zapotrzebowanie z apteczki oddziałowej skierowane do apteki szpitalnej musi zostać podpisane przez ordynatora oddziału czy wystarczy zlecenie wysłanie przez elektroniczny system szpitalny",{"entities": [(80,86, "pharmaceutical_law"),(64,74, "pharmaceutical_law"),(4,19, "pharmaceutical_law")]}),
("jakie kroki należy podjąć aby dokonać przeniesienia własności apteki oraz przeniesienia zezwolenia na prowadzenie apteki na nabywcę co stanie się z umową najmu lokalu w którym prowadzona jest apteka",{"entities": [(88,98, "pharmaceutical_law"),(124,131, "pharmaceutical_law")]}),
("czy klientka może udzielić odpowiedzi sądowi w kontekście obowiązku zachowania tajemnicy zawodowej",{"entities": [(18,26, "criminal_law")]}),
("czy możliwe jest umorzenie egzekucji co do świadczeń wymagalnych w przyszłości ze źródeł innych niż wynagrodzenie za pracę",{"entities": [(17,26, "civil_law")]}),
("czy klient ma obowiązek uzyskać zgodę wspólnoty mieszkaniowej na dokonanie przekształcenia lokalu własnościowego w gabinet stomatologiczny",{"entities": [(65,74, "civil_law")]}),
("czy w związku z ostatnimi zmianami przepisów co do uprawnień wymaganych przy zakupie ziemi rolnej klient mimo że posiadał wcześniej ziemię rolną poniżej  ha musi posiadać aktualne uprawnienia wykonany kurs do zakupu ziemi rolnej",{"entities": [(139,144, "administrative_law"),(91,97, "administrative_law"),(26,34, "administrative_law"),(113,121, "administrative_law"),(85,90, "administrative_law"),(216,221, "administrative_law")]}),
("jak klient ma nazywać usługi wskazane na fakturze i wystawiane dla lex secure spk jakie pkd klient ma podawać na fakturach dla lex secure spk czy klient musi rozszerzyć swoją działalność w ceidg",{"entities": [(158,168, "tax_law"),(175,186, "tax_law"),(71,77, "tax_law"),(131,137, "tax_law"),(88,91, "tax_law"),(67,70, "tax_law"),(127,130, "tax_law"),(41,49, "tax_law")]}),
("czy klient może żądać od banku odszkodowania za działania oszustów",{"entities": [(25,30, "administrative_law")]}),
("w jaki sposób powinno zostać podniesione wynagrodzenie pracowników w związku z podniesieniem wysokości minimalnego wynagrodzenia za pracę",{"entities": [(103,114, "labor_law")]}),
("czy gabinet stomatologiczny może zatrudniać rejestratorki medyczne oraz sekretarki medyczne czy zamiast rejestratorek medycznych oraz sekretarek medycznych gabinet stomatologiczny może zatrudniać recepcjonistki",{"entities": [(33,43, "medical_law"),(185,195, "medical_law"),(12,27, "medical_law"),(164,179, "medical_law")]}),
("czy umowa najmu lokalu mieszkalnego nadal obowiązuje czy klient skutecznie przedłużył ją do dnia  czerwca  r czy klient może na koszt wynajmującego otworzyć drzwi do mieszkania celem odzyskania rzeczy czy klient może domagać się odszkodowania w związku z tym że musiał mieszkaćw mieszkaniu w którym gromadził się grzyb na ścianach",{"entities": [(134,147, "civil_law"),(194,200, "civil_law"),(279,289, "civil_law"),(128,133, "civil_law")]}),
("w jakich sytuacjach możliwe jest prowadzenie dokumentacji w formie papierowej jak wygląda sytuacja z rodo w przypadku korzystania z systemów obsługujących dokumentację medyczną czy lekarze w pełni mogą im zaufać kto ponosi odpowiedzialność za dane osobowe czy możliwe jest indywidualne stworzenie takiego programu przez jakiegoś informatyka",{"entities": [(248,255, "administrative_law"),(132,140, "administrative_law"),(101,105, "administrative_law")]}),
("czy szpital w którym pracuje klientka jest szpitalem ii lub iiistopnia zabezpieczenia czy pracodawca klientki może wypłacać jej dodatek do wynagrodzenia jedynie za godziny przepracowane na bloku operacyjnymi z pacjentami z potwierdzonym zakażeniem covid",{"entities": [(237,247, "medical_law"),(172,185, "medical_law"),(71,85, "medical_law"),(43,52, "medical_law"),(115,123, "medical_law"),(210,220, "medical_law"),(53,55, "medical_law"),(223,236, "medical_law")]}),
("czy apteka może sprzedać leki o kategorii otc podmiotom prowadzącym działalność handlowousługowym",{"entities": [(32,41, "pharmaceutical_law"),(42,45, "pharmaceutical_law"),(56,67, "pharmaceutical_law")]}),
("czy apteka może sprzedać testy na covid do domu dziecka",{"entities": [(25,30, "pharmaceutical_law")]}),
("czy klientka będzie mogła udzielać świadczeń zdrowotnych po  czerwca zarówno jeśli chodzi o nowych pacjentów jak i kontynuacji",{"entities": [(83,89, "medical_law"),(92,98, "medical_law")]}),
("czy klient powinien zapłacić za źle wykonane dzieło czy klient może się starać o zadośćuczynienie odszkodowanie lub ewentualne obniżenie ceny jakie konsekwencje grożą klientowi w przypadku braku zapłaty jakie są potencjalne koszty postępowania gdyby sprawa została skierowana na drogę sądową",{"entities": [(250,256, "civil_law")]}),
("czy prawo do uzyskania zasiłku opiekuńczego z uwagi na epidemię koronawirusa zostało przedłużony do  czerwca  r",{"entities": [(85,96, "labor_law"),(101,108, "labor_law")]}),
("czy apteka ma obowiązek umieszczać kody gtu na wszystkich fakturach czy tylko na fakturach dla przedsiębiorców czy apteka musi zamieszczać na fakturach jedynie kod gtu  czy jeszcze jakieś inne kody gtu czy hurtownie farmaceutyczne powinny wskazywać kody gtu na fakturach",{"entities": [(24,34, "pharmaceutical_law"),(58,67, "pharmaceutical_law"),(81,90, "pharmaceutical_law"),(142,151, "pharmaceutical_law"),(216,230, "pharmaceutical_law"),(35,39, "pharmaceutical_law"),(193,197, "pharmaceutical_law"),(249,253, "pharmaceutical_law"),(239,248, "pharmaceutical_law"),(206,215, "pharmaceutical_law")]}),
("czy właściciel lokalu może zbierać podpisy pod swoim projektem uchwały wspólnoty mieszkaniowej i uchwalić ją przez zebranie podpisów z pominięciem zarządu wspólnoty",{"entities": [(115,123, "civil_law"),(63,70, "civil_law")]}),
("czy dodatkowy urlop wypoczynkowy dla osób niepełnosprawnych w razie niewykorzystania przechodzi na następny rok",{"entities": [(4,13, "labor_law")]}),
("czy klientka może domagać się zapłaty dodatku covidowego za grudzień  r",{"entities": [(60,68, "medical_law"),(46,56, "medical_law")]}),
("czy lekarz dokonujący badania kwalifikacyjnego przed zaszczepieniem pacjenta musi zawsze wystawić zaświadczenie o przeprowadzeniu takiego badania",{"entities": [(114,129, "medical_law"),(98,111, "medical_law")]}),
("z jakich składników majątku komornik może prowadzić egzekucję",{"entities": [(42,51, "criminal_law")]}),
("czy klientka będzie musiała zawrzeć nową umowę o pracę czy klienta musi zawrzeć umowę ubezpieczenia odpowiedzialności cywilnej kto będzie pełnił rolę kierownika specjalizacji i czy będzie ponosił odpowiedzialność za błędy klientki czy specjalizacja klientki ulegnie przedłużeniu w związku z delegowaniem",{"entities": [(138,144, "medical_law"),(36,40, "medical_law")]}),
("czy w obecnej sytuacji możliwym jest przeprowadzenie egzaminów kończących kursy zawodowe na pośrednika w obrocie nieruchomościami oraz zarządcę nieruchomości z zachowaniem standardów sanitarnych jeśli jest to możliwe to jakie kroki należy podjąć aby móc przeprowadzić takie egzaminy",{"entities": [(74,79, "medical_law"),(37,52, "medical_law"),(183,194, "medical_law"),(172,182, "medical_law"),(6,13, "medical_law"),(209,216, "medical_law")]}),
("czy klientka będąc zatrudniona na podstawie umowy rezydenckiej może nie zgodzić się na podpisanie aneksu do umowy przewidującego odebranie dodatku do wynagrodzenia jakie konsekwencję mogą spotkać klientkę jeżeli nie podpisze aneksu",{"entities": [(87,97, "labor_law"),(216,224, "labor_law"),(188,195, "labor_law"),(72,79, "labor_law"),(114,128, "labor_law"),(170,182, "labor_law")]}),
("co klientka powinna zawrzeć w wyjaśnieniach do wielkopolskiej izby lekarskiej w przedmiocie prowadzonego postępowania przygotowawczego przez prokuraturę w którym występuje jako podejrzana",{"entities": [(92,104, "medical_law"),(141,152, "medical_law")]}),
("do kogo klientka powinna zwrócić się o wypłatę niniejszego dodatku do podmiotu leczniczego czy bezpośrednio do nfz",{"entities": [(79,90, "tax_law")]}),
("czy klient ma możliwość wglądu w nagranie monitoringu wspólnoty mieszkaniowej w celu identyfikacji właścicieli psów których nieczystości nie są usuwane",{"entities": [(24,30, "administrative_law"),(42,53, "administrative_law")]}),
("czy klient może uogólnić wpis na budynku mieszkalnym i zamiast modelowanie sylwetki mezoterapia igłowa trwałe usuwanie owłosienia fotoodmadzanie zabiegi na naczynia napisać modelowanie sylwetki zabiegi na twarz zabiegi laserowe",{"entities": [(75,83, "administrative_law"),(185,193, "administrative_law"),(63,74, "administrative_law"),(173,184, "administrative_law")]}),
("czy klientka musi przesłać całą dokumentację medyczną kancelarii prawnej",{"entities": [(27,31, "medical_law")]}),
("jakie konsekwencje prawne grożą klientowi w przypadku posługiwania się tytułem dietetyka",{"entities": [(0,5, "criminal_law"),(19,25, "criminal_law"),(32,41, "criminal_law")]}),
("czy klient po powrocie będzie musiał odbyć kwarantannę czy przepisy wprowadzające obowiązek kwarantanny po powrocie do polski są zgodne z konstytucją",{"entities": [(14,22, "constitutional_law"),(107,115, "constitutional_law"),(59,67, "constitutional_law")]}),
("jakie podmioty należy uznać za udzielające świadczeń zdrowotnych którym klientka powinna wydać dokumentację medyczną pacjenta w jaki sposób podmiot udzielający świadczeń zdrowotnych powinien wystąpić o udostępnienie dokumentacji czy udostępnienie dokumentacji ww podmiotowi jest zgodne z przepisami o ochronie danych osobowych",{"entities": [(301,309, "administrative_law"),(202,215, "administrative_law"),(233,246, "administrative_law")]}),
("czy klientka może ubiegać się o świadczenie postojowe",{"entities": [(32,43, "medical_law")]}),
("czy w trakcie tygodniowego stażu cząstkowego klientka jest zobowiązana dyżurować w przypadku odpowiedzi twierdzącej na którym oddziale klientka będzie zobowiązana dyżurować",{"entities": [(71,80, "medical_law"),(27,32, "medical_law"),(104,115, "medical_law")]}),
("czy lekarz może podjąć leczenie w przypadku osoby z otępieniem co do której lekarz poweźmie wątpliwości o jej świadomej zgodzie na leczenie",{"entities": [(110,119, "medical_law"),(120,127, "medical_law"),(92,103, "medical_law")]}),
("czy klientka może nadal prowadzić terapię małoletniego",{"entities": [(34,41, "medical_law")]}),
("czy mąż klientki może reprezentować swoją matkę w sprawie spadkowej jeżeli sam występuje jako zainteresowany czy w przedmiotowej sprawie mąż klientki może przeprowadzić postępowanie spadkowe przed notariuszem czy mąż klientki może domagać się części spadku który przypada jego matce w związku z tym że jest jej prawnym opiekunem",{"entities": [(58,67, "civil_law"),(182,190, "civil_law"),(197,208, "civil_law"),(42,47, "civil_law")]}),
("kto powinien dokonać zgłoszenia w systemie s i podpisać się pod listem przewodnim kto podpisuje oświadczenie czy spółka jest cudzoziemcem kto podpisuje listę obejmującą wspólników uprawnionych do powołania zarządu kto winien podpisać listę adresów do doręczeń w przypadku zarządu jednoosobowego",{"entities": [(158,168, "civil_law"),(86,95, "civil_law"),(142,151, "civil_law"),(6,12, "civil_law"),(218,224, "civil_law"),(152,157, "civil_law"),(234,239, "civil_law")]}),
("czy istnieje możliwość pociągnięcia do odpowiedzialności zawodowej biegłego lekarza za treść opinii",{"entities": [(87,92, "medical_law"),(67,75, "medical_law")]}),
("czy do dokonania podziału nieruchomości lokalowej mieszkalnej na lokal użytkowy i mieszkalny wymagana jest uchwała o wyrażeniu zgody wspólnoty mieszkaniowej gdyby uchwała wspólnoty była konieczna  czy w sytuacji ustalania wielkości udziałów w częściach wspólnych nieruchomości istnieje możliwość prawnego zobligowania do tego członka wspólnoty który nie wyraził by na to zgody jakie dokumenty oprócz przedstawionych powinna przygotować klientka do dokonania podziału nieruchomości u notariusza czy podczas jednego spotkania u notariusza klientka może dokonać podziału lokalu oraz przekazania własności jednego z nich poprzez darowiznę",{"entities": [(253,262, "civil_law"),(17,25, "civil_law"),(458,466, "civil_law"),(559,567, "civil_law"),(580,591, "civil_law"),(7,16, "civil_law"),(448,457, "civil_law"),(483,493, "civil_law"),(526,536, "civil_law"),(232,240, "civil_law"),(243,252, "civil_law"),(592,601, "civil_law")]}),
("czy pracodawca może zmniejszyć etat matce klientki czy pracodawca może oddelegować klientkę do innej apteki",{"entities": [(20,30, "labor_law")]}),
("czy istnieje obowiązek dokonania działu spadku w określonym terminie jakich obowiązków podatkowych należy dopełnić w związku ze spadkobraniem",{"entities": [(23,32, "civil_law"),(87,98, "civil_law")]}),
("jakie konsekwencje prawne grożą klientowi w przypadku posługiwania się tytułem dietetyka",{"entities": [(0,5, "criminal_law"),(19,25, "criminal_law"),(32,41, "criminal_law")]}),
("czy pracodawca ma prawo zastosować wskazane rozwiązanie czy pracodawca ma prawo ewidencjonowania czasu pracy osób które nie pracują w formie zdalnej",{"entities": [(124,131, "labor_law")]}),
("czy klient może zakończyć umowę o pracę i uniknąć zapłaty kary",{"entities": [(16,25, "labor_law")]}),
("w jaki sposób syn klientki może odwołać się od wyroku sądu w jaki sposób należy sprostować informację o rzekomym przebywaniu bez maseczki w budynku komisariatu policji",{"entities": [(129,137, "criminal_law")]}),
("czy spadkobiercy mogą ustalić że własność mieszkania będącego w spadku przypadnie w całości jednemu z nich niezależnie od wysokości udziału jaki zajmuje w wartości spadku w jaki sposób określa się wartość masy spadkowej czy istnieje konieczność wpisywania konkretnych kwot we wniosku o dział spadku",{"entities": [(33,41, "civil_law"),(197,204, "civil_law"),(268,272, "civil_law"),(210,219, "civil_law"),(286,291, "civil_law"),(84,91, "civil_law"),(22,29, "civil_law"),(4,16, "civil_law"),(205,209, "civil_law")]}),
("jakie są prawa i obowiązki klientki na przesłuchaniu w charakterze świadka",{"entities": [(0,5, "criminal_law"),(55,66, "criminal_law")]}),
("czy gdyby klient musiał zmienić stanowisko pracy u obecnego pracodawcy z powodu niezdolności do pracy na obecnym stanowisku  to pracodawca może zmienić jego obecne warunki płacy",{"entities": [(51,59, "labor_law"),(105,112, "labor_law")]}),
("co może uczynić klientka gdy służba aresztu śledczego utrudnia przekazywanie informacji na temat jej męża a szpital utrudnia jego leczenie",{"entities": [(77,87, "criminal_law"),(8,15, "criminal_law"),(54,62, "criminal_law"),(116,124, "criminal_law")]}),
("czy sanepid może żądać od lekarza żeby stwierdził czy pacjent jest zarażony koronawirusem",{"entities": [(4,11, "medical_law")]}),
("czy lekarce przysługuje do wynagrodzenia tzw dodatek covidowy oraz od kogo może go wyegzekwować",{"entities": [(53,61, "medical_law")]}),
("czy pracodawca może odmówić odbycia stażu zewnętrznego przez klienta",{"entities": [(28,35, "medical_law"),(36,41, "medical_law"),(42,54, "medical_law")]}),
("czy prokurator może zwolnić lekarza z tajemnicy zawodowej czy prokurator może zażądać wydania kopii dokumentacji medycznej od lekarza",{"entities": [(28,35, "criminal_law"),(20,27, "criminal_law"),(86,93, "criminal_law"),(4,14, "criminal_law"),(62,72, "criminal_law"),(113,122, "criminal_law")]}),
("czym różni się umowa darowizny od umowy sprzedaży oraz jak kształtują się koszty w przypadku zawarcia tych umów",{"entities": [(21,30, "civil_law")]}),
("czy w przypadku podważenia testamentu z  r zacznie ponownie obowiązywać testament sporządzony w  r czy można podważyć testament po otwarciu spadku czy po otwarciu spadku dzieci spadkodawcy mogą domagać się dodatkowego świadczenia oprócz zachowku czy można odczytać testament jeżeli jeden z spadkobiorców nie chce się stawić",{"entities": [(72,81, "civil_law"),(118,127, "civil_law"),(265,274, "civil_law"),(237,245, "civil_law"),(177,188, "civil_law"),(131,139, "civil_law"),(154,162, "civil_law"),(27,37, "civil_law")]}),
("czy po śmierci matki klienta samochody staną się własnością klienta czy własnością ojca klienta czy mama klienta może za życia sporządzić dokument w którym oświadczy kto odziedziczy samochody jeżeli tak to jak nazywa się taki dokument w jakiej formie należy go sporządzić i co należyw nim napisać czy w przypadku braku sporządzenia takiego dokumentu koniecznym będzie wystąpienie do sądu aby określił kto staje się właścicielem samochodów",{"entities": [(15,20, "civil_law"),(350,360, "civil_law"),(100,104, "civil_law"),(340,349, "civil_law"),(49,59, "civil_law"),(72,82, "civil_law"),(289,296, "civil_law"),(170,181, "civil_law"),(138,146, "civil_law"),(226,234, "civil_law"),(392,400, "civil_law"),(29,38, "civil_law"),(182,191, "civil_law")]}),
("czy klientka powinna posiadać kasę fiskalną i samodzielnie rozliczać pacjentów",{"entities": [(59,68, "tax_law"),(30,34, "tax_law"),(35,43, "tax_law")]}),
("czy sąd może zwolnić klientkę z tajemnicy lekarskiej czy osoba ubezwłasnowolniona może nie wyrazić zgody na umieszczenie jej w domu pomocy społecznej lub zakładzie pielęgnacyjnoopiekuńczym",{"entities": [(63,81, "medical_law")]}),
("czy po powrocie do pracy klientka będzie mogła być przeniesiona do pracy do innego miasta czy ochrona przed wypowiedzeniem umowy o pracę po urlopie wychowawczym zależy od wieku dziecka",{"entities": [(94,101, "labor_law"),(148,160, "labor_law")]}),
("w jakiej grupie powinna zostać zaszczepiona klientka",{"entities": [(31,43, "medical_law")]}),
("czy klientka będzie mogła udzielać świadczeń zdrowotnych po  czerwca zarówno jeśli chodzi o nowych pacjentów jak i kontynuacji",{"entities": [(83,89, "medical_law"),(92,98, "medical_law")]}),
("czy w zaistniałych okolicznościach klient jak i lekarze z którymi współpracuje muszą posiadać zgody pacjentów na przetwarzanie ich danych osobowych",{"entities": [(66,78, "administrative_law"),(113,126, "administrative_law")]}),
("czy pozwany powinien zawiadomić sąd o wykonaniu nakazu zapłaty w postępowaniu upominawczym",{"entities": [(4,11, "civil_law")]}),
("czy pomimo rozwiązania umowy zlecenia administrator będzie zobowiązany do dokonania rozliczenia zimnej wody za miesiąc grudzień kiedy umowa zlecenia obowiązywała w lutym to znaczy po jej rozwiązaniu czy administrator nieruchomości może przetwarzać dane osobowe członków wspólnoty po rozwiązaniu umowy",{"entities": [(253,260, "administrative_law"),(52,58, "administrative_law")]}),
("w jakich sytuacjach lekarz ma prawo odmowy przyjęcia pacjenta czy lekarz ma prawo odmówić wystawienia zwolnienia lekarskiego",{"entities": [(43,52, "medical_law")]}),
("czy lekarz który zrealizował program specjalizacji w zakresie położnictwa i ginekologii bez żadnej wcześniejszej specjalizacji i oczekuje na przystąpienie do egzaminu końcowego pes jest lekarzem w trakcie specjalizacji czy lekarz który zrealizował program specjalizacji w zakresie położnictwa i ginekologii bez żadnej wcześniejszej specjalizacji i oczekuje na egzamin końcowy pes może udzielać świadczeń gwarantowanych z zakresu ambulatoryjnej opieki specjalistycznej w ramach nfz",{"entities": [(158,166, "medical_law"),(76,87, "medical_law"),(295,306, "medical_law"),(129,137, "medical_law"),(348,356, "medical_law"),(167,176, "medical_law"),(186,194, "medical_law"),(29,36, "medical_law"),(248,255, "medical_law"),(177,180, "medical_law"),(376,379, "medical_law"),(62,73, "medical_law"),(281,292, "medical_law"),(99,112, "medical_law"),(318,331, "medical_law"),(451,467, "medical_law")]}),
("czy organ administracyjny powinien w piśmie wysłanym do klienta wskazać również na planowaną budowę wewnętrznej drogi dojazdowej czy klient może użyć w sprzeciwie argumentu że warunki zabudowy mogą uniemożliwić w przyszłości budowę kolejnego zjazdu do działki klienta czy organ administracyjny postąpił właściwie dając klientowi jedynie  dni na złożenie odpowiedzi jak należy odpowiedzieć na pismo czy ma to być forma zastrzeżeń czy sprzeciwu czy argumentem blokującym planowaną inwestycję może być fakt że budynki mają powstać nie w linii istniejącej zabudowy",{"entities": [(145,149, "administrative_law"),(44,52, "administrative_law"),(4,9, "administrative_law"),(272,277, "administrative_law"),(83,92, "administrative_law"),(469,478, "administrative_law"),(93,99, "administrative_law"),(225,231, "administrative_law"),(198,210, "administrative_law"),(184,192, "administrative_law"),(118,128, "administrative_law"),(10,25, "administrative_law"),(278,293, "administrative_law")]}),
("czy istnieje wzór programu zapewnienia jakości czy istnieje wzór programu szkoleń czy istnieje wzór raportu z audytu wewnętrznego",{"entities": [(18,26, "medical_law"),(65,73, "medical_law")]}),
("w jaki sposób klient może zabezpieczyć swój majątek tak żeby żona klienta nie mogła rozporządzać działką którą klient otrzymał od rodziców",{"entities": [(84,96, "civil_law"),(44,51, "civil_law")]}),
("czy klient ma obowiązek posiadania kasy fiskalnej",{"entities": [(24,34, "tax_law")]}),
("w jaki sposób syn klientki może odwołać się od wyroku sądu w jaki sposób należy sprostować informację o rzekomym przebywaniu bez maseczki w budynku komisariatu policji",{"entities": [(129,137, "criminal_law")]}),
("czy lekarz może wnosić o zapłatę za stwierdzenie zgonu jeżeli jego umowa o pełnienie dyżurów medycznych nie przewiduje takich obowiązków",{"entities": [(49,54, "medical_law"),(75,84, "medical_law")]}),
("czy w razie śmierci rodziców małżonki klienta siostry małżonki będą mogły dochodzić od niej zachowku w związku z uzyskaną darowizną nieruchomości jeżeli tak to w jakiej wysokości",{"entities": [(29,37, "civil_law"),(54,62, "civil_law"),(92,100, "civil_law"),(122,131, "civil_law")]}),
("co może zrobić klientka w związku z powziętymi wątpliwościami dotyczącymi nieprawidłowości w protokołach rozpraw oraz innymi nieprawidłowościami dotyczącymi postępowania przed sądem lekarskim czy fakt że okręgowy sąd lekarski w warszawie posiadał dokumentację medyczną pacjentek klientki może stanowić naruszenie przepisów o dokumentacji medycznej",{"entities": [(204,212, "criminal_law"),(196,200, "criminal_law"),(247,259, "criminal_law"),(213,216, "criminal_law"),(228,237, "criminal_law"),(62,73, "criminal_law"),(145,156, "criminal_law"),(260,268, "criminal_law")]}),
("jakich samochodów dotyczą dopłaty do samochodów elektrycznych czy dopłaty mogą dotyczyć samochodu demonstracyjnego",{"entities": [(26,33, "administrative_law"),(66,73, "administrative_law")]}),
("co należy zrobić jeśli w internecie pojawią się opinie oczerniające lekarza",{"entities": [(36,43, "administrative_law"),(55,67, "administrative_law"),(48,54, "administrative_law"),(25,35, "administrative_law")]}),
("czy możliwy jest rozwód w drodze ugody jak w przedstawionych okolicznościach doprowadzić do rozwodu",{"entities": [(77,88, "civil_law"),(17,23, "civil_law"),(33,38, "civil_law"),(4,11, "civil_law"),(26,32, "civil_law")]}),
("kto powinien zarejestrować się w centralnym rejestrze podmiotów akcyzowych  klientka jako osoba prywatna czy spółka jawna",{"entities": [(90,95, "tax_law"),(109,115, "tax_law"),(64,74, "tax_law")]}),
("ile dni urlopu wypoczynkowego przysługuje klientowi czy dni urlopu wypoczynkowego przysługują z góry czy z dołu",{"entities": [(15,29, "labor_law"),(67,81, "labor_law")]}),
("czy wprowadzenie przez urząd miasta takiej podwyżki jest zasadne i czy może ona być dokonana ze skutkiem wstecznym co grozi poprzedniej właścicielce jeśli nie wyrazi zgody na podwyżkę",{"entities": [(136,148, "civil_law"),(105,114, "civil_law"),(57,64, "civil_law"),(159,165, "civil_law"),(96,104, "civil_law"),(4,16, "civil_law"),(29,35, "civil_law"),(43,51, "civil_law"),(124,135, "civil_law")]}),
("czy postępowanie lekarza dyżurnego było zgodne z prawem czy przy poronieniu może asystować pielęgniarka czy poronienie należy odebrać na oddziale położniczym czy małżonka klienta ponosiłaby odpowiedzialność w razie wysunięcia roszczeń przeciwko szpitalowi przez pacjentkę",{"entities": [(17,24, "criminal_law")]}),
("jakie kroki może podjąć klientka aby bank odblokował jej środki znajdujące się na rachunku bankowym",{"entities": [(64,74, "civil_law")]}),
("jak rozliczyć dwuletni okres stażu technika farmacji jeżeli w jego trakcie technik przebywał na zwolnieniach lekarskich",{"entities": [(75,82, "pharmaceutical_law"),(44,52, "pharmaceutical_law"),(35,43, "pharmaceutical_law")]}),
("czy na rewersie recepty musi znajdować pieczątka osoby sporządzającej lek recepturowy",{"entities": [(7,15, "pharmaceutical_law"),(29,38, "pharmaceutical_law")]}),
("czy pracodawca ma możliwość zmuszenia klientki do pełnienia dodatkowych dyżurów poza wymiarem wymaganym w programie specjalizacji",{"entities": [(50,59, "medical_law"),(106,115, "medical_law"),(60,71, "medical_law")]}),
("czy pracodawca może wysłać pracownika na badania okresowe w czasie epidemii czy pracodawca wybiera placówkę do przeprowadzenia badania okresowego z której pracownik zobowiązany jest skorzystać",{"entities": [(20,26, "labor_law"),(49,57, "labor_law")]}),
("z jakim wyprzedzeniem pracodawca powinien informować pracownika o wyjeździe służbowym czy pracodawca w czasie trwania epidemii ma szczególne obowiązki przy organizowaniu wyjazdu służbowego np zapewnienie jednoosobowych pokoi w hotelu",{"entities": [(192,203, "labor_law")]}),
("czy w związku z ostatnimi zmianami przepisów co do uprawnień wymaganych przy zakupie ziemi rolnej klient mimo że posiadał wcześniej ziemię rolną poniżej  ha musi posiadać aktualne uprawnienia wykonany kurs do zakupu ziemi rolnej",{"entities": [(139,144, "administrative_law"),(91,97, "administrative_law"),(26,34, "administrative_law"),(113,121, "administrative_law"),(85,90, "administrative_law"),(216,221, "administrative_law")]}),
("po którym roku klient może pracować w przychodni jako lekarz pediatra czy klient mógłby w trakcie specjalizacji przyjmować pacjentów w przychodni pediatrycznej",{"entities": [(112,122, "medical_law"),(27,35, "medical_law")]}),
("czy pracodawca może odmówić klientowi udzielenia mu urlopu wypoczynkowego w okresie wypowiedzenia oraz urlopu na żądanie jeżeli zakłócałoby to pracę w zakładzie pracy",{"entities": [(59,73, "labor_law")]}),
("czy pracodawca może wezwać klienta do pracy podczas gdy przebywa on na urlopie wychowawczym czy wojewoda może skierować klienta do pracy przy zwalczaniu skutków epidemii podczas urlopu",{"entities": [(20,26, "labor_law"),(79,91, "labor_law")]}),
("czy opisy badań diagnostycznych muszą sporządzane w formie elektronicznej",{"entities": [(10,15, "medical_law"),(32,37, "medical_law")]}),
("czy mąż klientki może dochodzić jakiś praw względem mieszkania które wchodzi w skład masy spadkowej po jego dziadku czy jeżeli rodzice męża klientki przepiszą na niego mieszkanie to czy brat męża będzie mógł dochodzić po ich śmierci roszczeń związanych z dokonaną darowizną czy istnieje możliwość zabezpieczenia się przed sytuacją opisaną w pytaniu nr",{"entities": [(79,84, "civil_law"),(90,99, "civil_law"),(69,76, "civil_law"),(264,273, "civil_law"),(85,89, "civil_law")]}),
("czy lekarzowi który pracuje w zakładzie opieki leczniczej zol częste przypadki covid przysługuje tzw dodatek covidowy",{"entities": [(58,61, "medical_law"),(47,57, "medical_law")]}),
("w jaki sposób klient może uchronić się przed pretensjami pacjentów którzy wskazują że odmawia udzielenia pomocy medycznej",{"entities": [(94,104, "medical_law"),(86,93, "medical_law")]}),
("czy istnieje możliwość zmuszenia spadkobierców do sprzedaży mieszkania czy klient może stracić zadatek",{"entities": [(33,46, "civil_law")]}),
("czy klientka może skorzystać z obniżenia wymiaru etatu wynikającego z uprawnienia do urlopu wychowawczego",{"entities": [(41,48, "labor_law")]}),
("czy klientowi przysługuje dodatek za okres od listopada  r do stycznia  r",{"entities": [(46,55, "medical_law"),(57,58, "medical_law"),(62,70, "medical_law")]}),
("czy klientka w piśmie do pełnomocnika może zawrzeć informacje na temat procesu leczenia pacjentki",{"entities": [(15,21, "medical_law")]}),
("czy pacjenci leczeni przez lekarza dentystę odbywającego staż podyplomowy powinni być o tym poinformowani kto powinien ich o tym poinformować  lekarz stażysta czy jego pracodawca",{"entities": [(35,43, "medical_law"),(44,56, "medical_law"),(150,158, "medical_law"),(82,85, "medical_law"),(57,61, "medical_law"),(4,12, "medical_law"),(62,73, "medical_law")]}),
("jak powinna się zachować klientka w związku otrzymanym pismem czy klienta ma obowiązek złożyć zeznania mimo że obecnie przebywa na zwolnieniu lekarskim z powodu ciąży",{"entities": [(131,141, "criminal_law"),(94,102, "criminal_law"),(119,127, "criminal_law"),(44,54, "criminal_law"),(55,61, "criminal_law"),(87,93, "criminal_law")]}),
("czy klientka może podjąć skuteczne kroki dążące do obniżenia opłat utrzymania miejsc parkingowych",{"entities": [(67,77, "civil_law")]}),
("w jaki sposób oblicza się wymiar urlopu dla osoby zatrudnionej na  etatu",{"entities": [(14,21, "labor_law")]}),
("czy klientowi wolno wyjść do sklepu z rowerami czy klient może wyjść pobiegać lub pojeździć na rowerze czy przepisy dotyczące zakazu przemieszczania się są zgodne z konstytucją",{"entities": [(20,25, "constitutional_law"),(63,68, "constitutional_law"),(107,115, "constitutional_law")]}),
("jak powinno wyglądać rozliczenie finansowe koordynatora oddziału rehabilitacji jeżeli oddział jest obecnie oddziałem dla pacjentów zakażonych covid czy w obecnej sytuacji wypowiedzenie złożone przez klientkę jest skuteczne",{"entities": [(107,116, "medical_law"),(21,32, "medical_law"),(4,11, "medical_law"),(56,64, "medical_law"),(154,161, "medical_law"),(131,141, "medical_law")]}),
("czy konkurencyjna firma może żądać aby klient zaprzestał sprzedaży danego modelu krzeseł",{"entities": [(4,17, "international_law")]}),
("co klientka może zrobić z dokumentacją medyczną zgromadzoną w formie papierowej",{"entities": [(26,38, "medical_law")]}),
("do kogo klientka powinna zwrócić się o wypłatę niniejszego dodatku do podmiotu leczniczego czy bezpośrednio do nfz",{"entities": [(79,90, "tax_law")]}),
("jakie konsekwencje prawne wiążą się dla klienta w związku z skierowaniem przez wojewodę go do pracy w szpitalu tymczasowym",{"entities": [(26,31, "medical_law"),(79,87, "medical_law")]}),
("czy w związku z epidemią koronawirusa klient może dalej udzielać świadczeń fizjoterapeutycznych w domach pacjentów",{"entities": [(25,37, "medical_law"),(16,24, "medical_law")]}),
("czy istnieje kredyt dla osób otwierających nowy salon kosmetyczny który jest częściowo pomniejszany gdy salon prosperuje dalej czy istnieje pomoc unijna na otwarcie salonu kosmetycznego",{"entities": [(48,53, "administrative_law"),(104,109, "administrative_law"),(165,171, "administrative_law")]}),
("czy klient może wrócić na poprzednie stanowisko pracy czy można ukarać pracownika karą pieniężną i jednocześnie potrącić mu premię",{"entities": [(112,120, "labor_law")]}),
("czy apteka może sprzedać leki o kategorii otc podmiotom prowadzącym działalność handlowousługowym",{"entities": [(32,41, "pharmaceutical_law"),(42,45, "pharmaceutical_law"),(56,67, "pharmaceutical_law")]}),
("czy sprzedaż nieruchomości będzie zwolniona z podatku vat",{"entities": [(13,26, "tax_law"),(46,53, "tax_law"),(34,43, "tax_law")]}),
("w jaki sposób pracodawca powinien zrekompensować pracownikowi dzień ustawowo wolny od pracy przypadający w sobotę tj dnia  sierpnia  r",{"entities": [(49,61, "labor_law"),(123,131, "labor_law")]}),
("czy lekarz stażysta może być oddelegowany przez pracodawcę do pracy na dyżurze godzinnym na szpitalnym oddziale ratunkowym przy zwalczaniu koronawirusa jeżeli nadzór lekarza specjalisty byłby pełniony jedynie telefonicznie czy dyrekcja szpitala nawiązując nowy stosunek pracy może w umowie wpisać że umowa została zawarta z lekarzem zamiast lekarz stażysta",{"entities": [(174,185, "medical_law"),(139,151, "medical_law"),(11,19, "medical_law"),(324,332, "medical_law"),(92,102, "medical_law"),(192,200, "medical_law"),(159,165, "medical_law"),(314,321, "medical_law"),(25,28, "medical_law"),(71,78, "medical_law"),(112,122, "medical_law")]}),
("jak kształtują się podstawy odpowiedzialności klienta prowadzącego leczenie w ramach indywidualnej praktyki lekarskiej",{"entities": [(19,27, "medical_law"),(85,98, "medical_law"),(54,66, "medical_law")]}),
("jak przedstawia się kolejność dziedziczenia w przedmiotowej sprawie kiedy klientka może skutecznie odrzucić spadek",{"entities": [(99,107, "civil_law"),(30,43, "civil_law")]}),
("czy w wypadku śmierci krewnej klient musi podjąć jakieś kroki aby stać się pełnoprawnym właścicielem mieszkania czy w wypadku śmierci krewnej klient powinien zrobić coś z posiadanym testamentem",{"entities": [(22,29, "civil_law"),(134,141, "civil_law")]}),
("czy recepty elektroniczne na leki narkotyczne lub odurzające mogą być zrealizowane w terminie zaczynającym się od daty realizacji recepty",{"entities": [(50,60, "pharmaceutical_law")]}),
("czy klient powinien podpisać przesłane oświadczenie z datą wsteczną czy jeżeli klient zrezygnuje z pracy w danym podmiocie leczniczym utraci prawo do wypłaty dodatku za przepracowane miesiące w trakcie których spełniał przesłanki warunkujące przysługiwaniu dodatku covidowego",{"entities": [(107,112, "medical_law"),(169,182, "medical_law"),(113,122, "medical_law"),(123,133, "medical_law"),(219,229, "medical_law"),(54,58, "medical_law"),(86,96, "medical_law"),(150,157, "medical_law"),(183,191, "medical_law"),(134,140, "medical_law")]}),
("w jaki sposób mama klienta powinna przekazać własność mieszkania klientowi oraz bratu klienta aby skutkowało to jak najmniejszymi kosztami",{"entities": [(45,53, "civil_law"),(80,85, "civil_law"),(14,18, "civil_law")]}),
("czy klientka może zrezygnować z udziału w pracach zespołu",{"entities": [(42,49, "labor_law")]}),
("czy klientka jest zobowiązana podać dane wskazane w rozporządzeniu ministra zdrowia zmieniającym rozporządzenie w sprawie ogólnych warunków umów o udzielanie świadczeń opieki zdrowotnej z dnia  lipca  r",{"entities": [(67,75, "medical_law"),(41,49, "medical_law"),(36,40, "medical_law"),(30,35, "medical_law")]}),
("w jaki sposób klient wraz z resztą spadkobierców może sprzedać nieruchomość",{"entities": [(35,48, "civil_law")]}),
("czy lekarz psychiatra ma prawo po przeprowadzonym badaniu odesłać do centrum interwencji kryzysowej osobę która dokonała próby samobójczej aż do momentu jej wytrzeźwienia czy pacjenci powinni płacić za pobyt w centrum interwencji kryzysowej kto ponosi odpowiedzialność w przypadku ewentualnej szkody doznanej przez pacjenta odesłanego przez psychiatrę do centrum interwencji kryzysowej",{"entities": [(77,88, "medical_law"),(218,229, "medical_law"),(363,374, "medical_law"),(89,99, "medical_law"),(230,240, "medical_law"),(341,351, "medical_law"),(69,76, "medical_law"),(210,217, "medical_law"),(355,362, "medical_law"),(100,105, "medical_law"),(175,183, "medical_law")]}),
("czy po powrocie z urlopu macierzyńskiego klientka będzie zobowiązana do pracy w pełnym wymiarze godzin czy klientka będzie zobowiązana do pełnienia dyżurów po powrocie do pracy z urlopu macierzyńskiego czy klientce po powrocie do pracy z urlopu macierzyńskiego będzie przysługiwała przerwa na karmienie",{"entities": [(138,147, "medical_law"),(87,95, "medical_law"),(18,24, "medical_law"),(179,185, "medical_law"),(238,244, "medical_law")]}),
("czy w zaistniałych okolicznościach umowa ustna jest ważna i wiążąca czy mąż klientki może skutecznie rościć od pracodawcy przyrzeczonej podwyżki za miesiące od których miała ona obowiązywać zgodnie z ustną umową czy niedotrzymanie warunków rzeczonej umowy ustnej po stronie pracodawcy jest podstawą do skrócenia okresu wypowiedzenia bądź daje możliwość rozwiązania umowy bez wypowiedzenia przez męża klientki czy w razie powyższego rozwiązania stosunku pracy klientowi przysługiwałaby odprawa czy ze względu na obecną sytuację pandemiczną klient mógłby zostać zwolniony bez wskazania przyczyny oraz bez wypłacenia odprawy",{"entities": [(60,67, "labor_law"),(560,569, "labor_law"),(231,239, "labor_law"),(41,46, "labor_law"),(302,311, "labor_law"),(469,484, "labor_law"),(290,298, "labor_law"),(485,492, "labor_law"),(256,262, "labor_law")]}),
("czy w trakcie panującej epidemii koronawirusa możliwe jest zwołanie zebrania wspólnoty mieszkaniowej w jakiej formie można przeprowadzić takie zebranie",{"entities": [(68,76, "civil_law")]}),
("czy klient może odmówić przyjęcia pacjenta z uwagi na to że jest on roszczeniowy i nie można z nim dojść do porozumienia",{"entities": [(24,33, "medical_law"),(45,50, "medical_law")]}),
("czy lekarz jest obowiązany do wystawienia karty zgonu pacjenta z którym nie miał wcześniej kontaktu",{"entities": [(48,53, "medical_law"),(42,47, "medical_law")]}),
("czy w związku z rozwiązaniem stosunku pracy klientowi będzie przysługiwała odprawa emerytalna",{"entities": [(75,82, "labor_law")]}),
("czy w związku z tym iż w ostatnich pięciu latach dochody rodziców klientki nie zapewniały zgromadzenia oszczędności w kwocie odpowiadającej cenie nieruchomości grozi im kontrola dochodów przeprowadzona przez urząd skarbowy i związane z nią ewentualne kary czy w tej sytuacji łatwiejsze byłoby przekazanie klientce mieszkania zakupionegoprzez rodziców w formie darowizny",{"entities": [(314,324, "tax_law"),(146,159, "tax_law"),(6,13, "tax_law")]}),
("czy pracodawca ma prawo zastosować wskazane rozwiązanie czy pracodawca ma prawo ewidencjonowania czasu pracy osób które nie pracują w formie zdalnej",{"entities": [(124,131, "labor_law")]}),
("czy w sytuacji globalnego zagrożenia epidemiologicznego pracodawca ma prawo odmówić pracy zdalnej w przypadku gdy wnosi o to lekarz z obawy o zdrowie swoich pacjentów",{"entities": [(142,149, "medical_law"),(37,55, "medical_law")]}),
("jakie prawa i obowiązki ma osoba wezwana na przesłuchanie w charakterze świadka wpostępowaniu cywilnym jak kształtuje się odpowiedzialność klienta w przedmiotowej sprawie",{"entities": [(33,40, "medical_law"),(80,93, "medical_law")]}),
("czy pracodawca może oddelegować lekarza rezydenta do pracy w ramach dyżuru medycznego na izbie przyjęć szpitala czy klientka powinna otrzymać polecenie pracodawcy na piśmie czy klientka bez podpisania klauzuli optout może być zobowiązana do dyżurowania ponad normy przewidziane w przepisach prawa czy w przypadku pełnienia dyżuru medycznego w piątek klientce będzie przysługiwać tzw zejście po dyżurze",{"entities": [(166,172, "medical_law"),(280,290, "medical_law"),(313,322, "medical_law"),(68,74, "medical_law"),(323,329, "medical_law"),(383,390, "medical_law"),(259,264, "medical_law"),(222,225, "medical_law"),(241,252, "medical_law"),(201,209, "medical_law"),(210,216, "medical_law")]}),
("czy klient po powrocie będzie musiał odbyć kwarantannę czy przepisy wprowadzające obowiązek kwarantanny po powrocie do polski są zgodne z konstytucją",{"entities": [(14,22, "constitutional_law"),(107,115, "constitutional_law"),(59,67, "constitutional_law")]}),
("czy klient ma obowiązek wypełnienia i podpisania takiego pisma czy i bez niego należy mu się dodatek covidowy jak liczy się wysokości dodatku covidowego  za poszczególne dni przepracowane z pacjentami covidowymi czy od całości miesięcznej pensji",{"entities": [(174,187, "medical_law"),(57,62, "medical_law"),(24,35, "medical_law"),(142,152, "medical_law"),(101,109, "medical_law"),(190,200, "medical_law")]}),
("czy pracodawca może nakazać lekarzowi który nie podpisał klauzuli optout pracę ponad wymiar  godzin tygodniowo bez zgody pracownika czy w przypadku osób zatrudnionych w wymiarze  etatu tygodniowy limit godzin jest proporcjonalnie zmniejszony",{"entities": [(196,201, "labor_law")]}),
("czy nieobecność jednego z właścicieli wspólnoty mieszkaniowej stanowi przeszkodę do skutecznego i wiążącego odczytania aktu notarialnego",{"entities": [(4,15, "civil_law")]}),
("jakie są prawa i obowiązki klientki na przesłuchaniu w charakterze świadka",{"entities": [(0,5, "criminal_law"),(55,66, "criminal_law")]}),
("czy spadkobiercy mogą zostać pociągnięci do odpowiedzialności w ramach umowy ubezpieczenia czy spadkobiercy mogą wystąpić do ubezpieczyciela z informacją jakie szkody poniósł poszkodowany w jakim terminie spadkobiercy powinni ustosunkować się do pisma ubezpieczyciela",{"entities": [(4,16, "civil_law"),(95,107, "civil_law"),(205,217, "civil_law")]}),
("co może zrobić kobieta wobec swojego męża który stosuje wobec niej przemoc psychiczną i fizyczną jakie kary mogą spotkać osobę stosującą przemoc w rodzinie wobec żony",{"entities": [(97,102, "criminal_law"),(67,74, "criminal_law"),(137,144, "criminal_law")]}),
("gdzie klientka może znaleźć listę jednostek akredytowanych do prowadzenia szkoleń dla oia w krakowie",{"entities": [(34,43, "pharmaceutical_law")]}),
("czy dla lekarza rezydenta priorytetem jest zapewnienie ciągłości pracy w oddziale macierzystym czy też oddziale sor czy dla lekarza rezydenta priorytetem jest odbywanie szkolenia specjalizacyjnego zgodnie z programem specjalizacji czy zapewnianie ciągłości pracy w oddziałach niebędących oddziałami macierzystymi które nie są faktycznym miejscem odbywania specjalizacji czy lekarz rezydent chirurgii może na podstawie umowy o pracę odbywać dyżury niezwiązane z programem specjalizacji bez bezpośredniego nadzoru specjalisty lub kierownika specjalizacji czy klientka ma możliwość odmowy odbywania dyżurów na sorze ze skutkiem natychmiastowym",{"entities": [(159,168, "medical_law"),(512,523, "medical_law"),(432,439, "medical_law"),(207,216, "medical_law"),(461,470, "medical_law"),(169,178, "medical_law"),(26,37, "medical_law"),(142,153, "medical_law"),(265,275, "medical_law"),(607,612, "medical_law"),(55,64, "medical_law"),(247,256, "medical_law"),(381,389, "medical_law"),(276,287, "medical_law"),(179,196, "medical_law"),(82,94, "medical_law")]}),
("czy klientowi po dyżurze h w sobotę może przysługiwać dzień wolny w dni powszednie",{"entities": [(17,24, "medical_law")]}),
("czy klient jest obowiązany poinformować pracodawcę o zamiarze podjęcia dodatkowego zatrudnienia na podstawie umowy cywilnoprawnej zlecenia i uzyskać jego zgodę",{"entities": [(71,82, "labor_law"),(53,61, "labor_law")]}),
("w jaki sposób klientka może dochodzić zapłaty dodatku covidowego za listopad i grudzień  r",{"entities": [(68,76, "medical_law"),(79,87, "medical_law"),(54,64, "medical_law")]}),
("czy hurtownik importujący produkt leczniczy z obszaru ue może zaniechać weryfikacji autentyczności produktu i od razu wysłać produkt podmiotowi dokonującemu przepakowania czy hurtownik w przypadku zakupu produktu leczniczego z importu równoległego może wskazać od razu miejsce jego dostawy na podmiot dokonujący przepakowania czy musi najpierw samodzielnie przeprowadzić weryfikację autentyczności",{"entities": [(113,117, "pharmaceutical_law"),(264,268, "pharmaceutical_law"),(227,234, "pharmaceutical_law"),(84,98, "pharmaceutical_law"),(4,13, "pharmaceutical_law"),(175,184, "pharmaceutical_law"),(157,170, "pharmaceutical_law"),(312,325, "pharmaceutical_law")]}),
("czy wspólnota mieszkaniowa może pobierać opłaty na utrzymanie garażu mimo iż klient z niego nie korzysta",{"entities": [(32,40, "civil_law")]}),
("czy klientka odpowiada za to aby w aptece był farmaceuta co w przypadku gdy klientka będzie musiała wziąć l a nie będzie innego farmaceuty który mógłby pracować w aptece czy klientka musi wypracowywać nadgodziny jakich czynności musi klientka dokonać w związku z zakończeniem zatrudnienia na stanowisku kierownika apteki co stanie się z niewykorzystanym urlopem klientki",{"entities": [(100,105, "pharmaceutical_law"),(263,275, "pharmaceutical_law")]}),
("czy klient jest uprawniony do wydania zaświadczenia potrzebnego w ramach postępowaniao ubezwłasnowolnienie czy klient może wydać zaświadczenie pacjentce która nie posiada dowodu osobistego",{"entities": [(87,106, "medical_law"),(143,152, "medical_law"),(171,177, "medical_law"),(16,26, "medical_law"),(38,51, "medical_law"),(129,142, "medical_law")]}),
("czy korzystając z prawa do zmiany dziedziny specjalizacji klient będzie zobowiązany w dalszym ciągu pracować na obecnej umowie rezydenckiej czy ponowna rekrutacja musi odbyć się w najbliższym postępowaniu kwalifikacyjnym jakie są konsekwencje niezakwalifikowania się na rezydenturę po rezygnacji z poprzedniej",{"entities": [(34,43, "medical_law"),(100,108, "medical_law"),(270,281, "medical_law"),(112,119, "medical_law"),(94,99, "medical_law")]}),
("ile przerw na karmienie piersią przysługuje klientce i ile czasu mają trwać w przypadku gdyby klientka pracowała na pół etatu po  godziny dziennie ile przerw na karmienie piersią przysługuje klientce i ile czasu mają trwać w przypadku gdyby klientka pracowała na  etatu po  godzin dziennie czy praca w systemie równoważnego czasu pracy wpływa na ilość i długość przerw na karmienie piersią jeżeli klientce przysługiwałaby tylko jedna przerwa na karmienie piersią to ile minimalnie musiałaby pracować aby mieć do dyspozycji dwie przerwy po  minut",{"entities": [(311,323, "labor_law"),(294,299, "labor_law"),(24,31, "labor_law"),(171,178, "labor_law"),(382,389, "labor_law"),(455,462, "labor_law"),(103,112, "labor_law"),(250,259, "labor_law"),(346,351, "labor_law"),(406,421, "labor_law"),(14,23, "labor_law"),(161,170, "labor_law"),(372,381, "labor_law"),(445,454, "labor_law"),(4,10, "labor_law"),(151,157, "labor_law"),(362,368, "labor_law")]}),
("czy w sytuacji w której jeden z rodziców wyraża zgodę na leczenie dziecka a drugi rodzic nie wyraża zgody na leczenie dziecka lekarz może podjąć leczenie czy pismo ojca klienta stanowi dokumentację medyczną czy przychodnia może udostępnić matce pacjenta pismo ojca pacjenta",{"entities": [(211,222, "medical_law"),(48,53, "medical_law")]}),
("czy klientka może nadbudować budynek o pół piętra",{"entities": [(29,36, "administrative_law")]}),
("czy klientowi który jest na emeryturze przysługuje wyższa ulga podatkowa w związku z podwyższeniem maksymalnej kwoty jaką można wpłacić na ikze",{"entities": [(111,116, "tax_law"),(122,127, "tax_law"),(75,82, "tax_law"),(39,50, "tax_law"),(28,38, "tax_law"),(63,72, "tax_law")]}),
("czy jeżeli klient skorzysta ze zwolnienia ze składek zus a następnie uda się na zwolnienie l będzie to wpływało na możliwość skorzystania z ulgi czy możliwe jest skierowanie do pracy przy epidemii klienta bądź jego żonę",{"entities": [(69,72, "medical_law"),(149,156, "medical_law"),(162,173, "medical_law")]}),
("czy pracodawca ma obowiązek przedłużenia umowy czy działanie pracodawcy może stanowić dyskryminację klienta",{"entities": [(86,99, "labor_law")]}),
("czy wzór ankiety powinien mieć w formie nadruku treść pieczątki jako nagłówek czy treść pieczątki jest prawidłowa",{"entities": [(48,53, "medical_law"),(82,87, "medical_law"),(26,30, "medical_law"),(9,16, "medical_law"),(54,63, "medical_law"),(88,97, "medical_law")]}),
("czy klient miał obowiązek wypełnienia ankiety epidemiologicznej",{"entities": [(26,37, "medical_law"),(38,45, "medical_law")]}),
("na jak długo powinien być przedłużony urlop macierzyński",{"entities": [(26,37, "labor_law")]}),
("czy lekarz dokonujący badania kwalifikacyjnego przed zaszczepieniem pacjenta musi zawsze wystawić zaświadczenie o przeprowadzeniu takiego badania",{"entities": [(114,129, "medical_law"),(98,111, "medical_law")]}),
("co może zrobić klient aby nie musieć płacić alimentów na rzecz syna",{"entities": [(44,53, "civil_law")]}),
("czy apteka w czasie godzin dla seniora może obsługiwać również klientów którzy nie są seniorami oraz czy ustawodawca przewiduje kary za nieprzestrzeganie godzin dla seniora",{"entities": [(117,127, "criminal_law"),(31,38, "criminal_law")]}),
("czy pracodawca miał prawo odwołać klienta z urlopu w celu wykonania badań okresowych czy za dzień w którym odbędą się badania klientowi należy się ekwiwalent pieniężny",{"entities": [(147,157, "labor_law"),(74,84, "labor_law")]}),
("czy klientka może ubiegać się o świadczenie postojowe",{"entities": [(32,43, "medical_law")]}),
("czy klient powinien zarejestrować podmiot leczniczy aby móc zatrudniać innych fizjoterapeutów",{"entities": [(60,70, "medical_law"),(42,51, "medical_law"),(34,41, "medical_law"),(71,77, "medical_law")]}),
("czy pracodawca ma możliwość odsunięcia pracownika od wykonywania pracy w ramach kary za naruszenie obowiązków pracowniczych czy pracodawca ma możliwość czasowego oddelegowania pracownika do wykonywania innej pracy czy pracodawca ma możliwość zmuszenia pracownika do wykorzystania urlopu wypoczynkowego",{"entities": [(110,123, "labor_law"),(242,251, "labor_law")]}),
("czy pracownik tymczasowy może otrzymać mniejszą ilość dni urlopu niż to wynika z umowy o pracę zawartej z agencją pracy tymczasowej",{"entities": [(48,53, "labor_law")]}),
("czy klient może odmówić pacjentowi leczenia stomatologicznego w przypadku gdy ten w ciągu ostatnich  dni wrócił z zagranicy",{"entities": [(24,34, "medical_law"),(84,89, "medical_law")]}),
("czy osoba sprzedająca mieszkanie we wspólnocie mieszkaniowej jest zobowiązana do poinformowania potencjalnego nabywcy mieszkania o zadłużeniu wspólnoty czy zarządca budynku wystawiając sprzedającemu zaświadczenie o niezaleganiu z zaliczkami wobec wspólnoty powinien w takim zaświadczeniu napisać że wspólnota posiada długi czy nowy właściciel mieszkania w takiej wspólnocie mieszkaniowej jest zobowiązany do ponoszenia wszelkich kosztów które powstały w momencie kiedy nie był jeszcze członkiem wspólnoty",{"entities": [(156,164, "civil_law"),(408,418, "civil_law"),(317,322, "civil_law"),(327,331, "civil_law"),(288,295, "civil_law")]}),
("czy viregytk może być sprzedawany w ramach recepty ze  odpłatnością",{"entities": [(4,12, "pharmaceutical_law"),(22,33, "pharmaceutical_law")]}),
("czy zaproponowane przez pracodawcę córki klientki warunki rozwiązania umowy o pracę za porozumieniem stron są zgodne z prawem czy pracownik może ubiegać się w miesiącu lipcu o inne stanowisko pracy u tego samego pracodawcy",{"entities": [(87,100, "labor_law")]}),
("czy klientka ma obowiązek wykonania polecenia pracy na sorze w jaki sposób klientka powinna postąpić aby uchronić się przed oddelegowaniem w przypadku gdy nie uważa się za osobę kompetentną do pracy na danym stanowisku",{"entities": [(202,207, "medical_law"),(124,138, "medical_law"),(55,60, "medical_law"),(172,177, "medical_law"),(26,35, "medical_law"),(92,100, "medical_law")]}),
("czy tzw zejście lekarza po dyżurze wlicza się do czasu pracy lekarza i należy się za ten czas wynagrodzenie jeżeli odpowiedź na pierwsze pytanie jest przecząca to czy klient wraz z pracodawcą mogą ustalić że klientowi będzie przysługiwało wynagrodzenie za zejście po dyżurze",{"entities": [(89,93, "medical_law"),(8,15, "medical_law"),(256,263, "medical_law"),(27,34, "medical_law")]}),
("z czym wiąże się zadaniowy system czasu pracy czy zadaniowy system czasu pracy powinien zostać uwzględniony w umowie o pracę czy możliwe jest podpisanie umowy o pracę z późniejszym terminem rozpoczęcia jej wykonywania np miesiąc później",{"entities": [(181,189, "labor_law"),(17,26, "labor_law"),(50,59, "labor_law"),(142,152, "labor_law"),(169,180, "labor_law")]}),
("czy klient jako farmaceuta może zostać zatrudniony w ramach stażu z urzędu pracy z wynagrodzeniem niższym niż minimalne",{"entities": [(83,97, "labor_law")]}),
("czy jeśli w aptece znajduje się szyba pomiędzy farmaceutą a pacjentem to czy farmaceuta musi nosić maseczkę",{"entities": [(60,69, "medical_law"),(93,98, "medical_law"),(32,37, "medical_law"),(12,18, "medical_law")]}),
("jakie są kryteria wypłacania świadczeń z zakładowego funduszu socjalnego czy świadczenie musi być równe",{"entities": [(41,52, "labor_law")]}),
("czy klient może uogólnić wpis na budynku mieszkalnym i zamiast modelowanie sylwetki mezoterapia igłowa trwałe usuwanie owłosienia fotoodmadzanie zabiegi na naczynia napisać modelowanie sylwetki zabiegi na twarz zabiegi laserowe",{"entities": [(75,83, "administrative_law"),(185,193, "administrative_law"),(63,74, "administrative_law"),(173,184, "administrative_law")]}),
("czy brat powinien potwierdzić notariuszowi fakt przelania na swoje konto pieniędzy z konta matki czy można wezwać brata klienta do przedstawienia przed notariuszem bilingu wypłaty z własnego konta pieniędzy albo dowodu posiadania takiej sumy w celu rzekomego zdaniem przekazania kwoty   zł matce na podstawie umowy pożyczki czy można zobowiązać brata klienta przed notariuszem do wskazania świadków z imienia i nazwiska obecnych przy przeliczaniu i wręczaniu pieniędzy matce czy można go zobowiązać do pokazania przed notariuszem pisemnych potwierdzeń świadków o przekazaniu pieniędzy matce czy może jednak należy tę sprawę rozwiązać po spotkaniu z notariuszem w sprawie działu spadku które odbędzie się jakie jeszcze działania klient może jeszcze podjąć aby wyjaśnić swoje wątpliwości",{"entities": [(420,428, "civil_law"),(91,96, "civil_law"),(67,72, "civil_law"),(267,278, "civil_law"),(411,419, "civil_law"),(540,551, "civil_law"),(390,398, "civil_law"),(552,560, "civil_law"),(152,163, "civil_law"),(365,376, "civil_law"),(518,529, "civil_law"),(649,660, "civil_law"),(30,42, "civil_law"),(237,241, "civil_law")]}),
("czy lekarz wykonujący indywidualną praktykę lekarską może zatrudnić lekarza rezydenta prowadzić szkolenie specjalizacyjne czy lekarz prowadzący indywidualną praktykę lekarską może zatrudnić pielęgniarkę",{"entities": [(96,105, "medical_law"),(106,121, "medical_law")]}),
("czy zajęcie zostało dokonane zgodnie z obecnie obowiązującym porządkiem prawnym",{"entities": [(20,28, "civil_law")]}),
("czy jeżeli klientka ukończy kurs w cem i uzyska odpowiedni certyfikat to będzie mogła przeprowadzać zabiegi których nauczy się na tym kursie",{"entities": [(59,69, "medical_law"),(28,32, "medical_law")]}),
("jakie przepisy prawa obligują byłego zarządcę do przekazania dokumentacji wspólnoty mieszkaniowej",{"entities": [(49,60, "civil_law"),(21,29, "civil_law"),(37,45, "civil_law")]}),
("ile maksymalnie może pracować lekarz rezydent bez klauzuli optout w ciągu tygodnia wprzyjętym okresie rozliczeniowym",{"entities": [(21,29, "medical_law"),(37,45, "medical_law"),(68,73, "medical_law"),(50,58, "medical_law"),(59,65, "medical_law")]}),
("za jaki okres klientka powinna wypłacić pracownicy ekwiwalent za niewykorzystany urlop wypoczynkowy",{"entities": [(51,61, "labor_law"),(40,50, "labor_law"),(65,80, "labor_law")]}),
("w jaki sposób klient wraz z resztą spadkobierców może sprzedać nieruchomość",{"entities": [(35,48, "civil_law")]}),
("czy córka nieprzytomnego pacjenta może żądać udostępnienia dokumentacji medycznej oraz wskazania przez klientkę informacji objętych tajemnicą lekarską",{"entities": [(45,58, "medical_law"),(123,131, "medical_law"),(132,141, "medical_law")]}),
("czy dysponent zakładowego funduszu świadczeń socjalnych może dofinansować wszystkie imprezy pomimo sprzeciwu jednej z organizacji",{"entities": [(45,55, "labor_law"),(14,25, "labor_law")]}),
("czy klientka może otrzymać skierowanie przez wojewodę do innej jednostki poza miejsce odbywania stażu jakie w związku z tym będą prawa i obowiązki klientki",{"entities": [(96,101, "medical_law"),(63,72, "medical_law"),(45,53, "medical_law"),(27,38, "medical_law")]}),
("czy wspólnota mieszkaniowa może w ramach obowiązującej umowy żądać od firmy proeks przygotowania projektu elewacji zewnętrznej wg nowych wytycznych które wchodzą w życie  września br bez dodatkowego wynagrodzenia dla wykonawcy projektu",{"entities": [(115,126, "administrative_law"),(97,105, "administrative_law"),(106,114, "administrative_law")]}),
("jakie należy podjąć kroki w celu ubezwłasnowolnienia częściowego brata klienta",{"entities": [(33,52, "civil_law")]}),
("czy można cofnąć skierowanie na test w kierunku koronawirusa czy jeśli pacjentka nie wyraża zgody na wykonanie testu to klientka musi zgłosić podejrzenie wystąpienia zakażenia do sanepidu",{"entities": [(39,47, "medical_law"),(154,165, "medical_law"),(142,153, "medical_law"),(48,60, "medical_law"),(101,110, "medical_law"),(10,16, "medical_law"),(32,36, "medical_law"),(17,28, "medical_law")]}),
("co klient może zrobić we wskazanej sytuacji",{"entities": [(25,34, "medical_law")]}),
("czy oświadczenie o posiadanym prawie do dysponowania nieruchomością która stanowi współwłasność klienta i jego brata na cele budowlane może złożyć małżonka klienta",{"entities": [(120,124, "administrative_law"),(125,134, "administrative_law")]}),
("czy lekarzom przysługuje zasiłek opiekuńczy w sytuacji gdy zdecydują się na pozostanie w domu z uczącym się zdalnie dzieckiem w wieku poniżej  lat czy są od tego wyłączeni z powodu możliwości oddania dziecka do świetlicy szkolnej jako członkowie służb medycznych",{"entities": [(246,251, "medical_law"),(143,146, "medical_law"),(4,12, "medical_law")]}),
("czy nabywane od dystrybutora nowe podwozie pod zabudowę domków nabywane jako homologowana przyczepa ciężarowa musi być zarejestrowane przed dalszą odsprzedażą",{"entities": [(4,12, "administrative_law"),(63,71, "administrative_law")]}),
("czy przepisy ustawy o zasadach ustalania minimalnego wynagrodzenia zasadniczego pracowników zatrudnionych w podmiotach leczniczych dotyczą również osób zatrudnionych na stanowisku sprzątaczki",{"entities": [(67,79, "medical_law"),(131,138, "medical_law"),(31,40, "medical_law"),(80,91, "medical_law"),(169,179, "medical_law")]}),
("czy pracodawca może oddelegować lekarza rezydenta do pracy w szpitalnym oddziale ratunkowym",{"entities": [(61,71, "medical_law")]}),
("czy krajowa izba rozliczeniowa posiada informacje o posiadanych kontach bankowych osoby zmarłej czy klientka powinna złożyć ponowny wniosek o udzielenie informacji z krajowej izby rozliczeniowej jak wygląda zakres dostępu klientki do konta bankowego osoby zmarłej",{"entities": [(72,81, "administrative_law"),(166,174, "administrative_law")]}),
("czy dyrektor szkoły specjalnej może zarządzić odbywanie zajęć stacjonarnie również dla klas",{"entities": [(46,55, "medical_law"),(56,61, "medical_law")]}),
("czy klientka może zrzec się dodatku covidowego czy szpital może uzależniać skierowanie klientki na staż zewnętrzny od tego czy zrzeknie się ona dodatku covidowego",{"entities": [(127,135, "medical_law"),(64,74, "medical_law"),(36,46, "medical_law"),(104,114, "medical_law"),(99,103, "medical_law"),(75,86, "medical_law")]}),
("czy klientka może udzielić odpowiedzi sądowi w kontekście obowiązku zachowania tajemnicy zawodowej",{"entities": [(18,26, "criminal_law")]}),
("czy hurtownia farmaceutyczna może zaopatrywać i zbywać sprzęt medyczny",{"entities": [(55,61, "pharmaceutical_law"),(48,54, "pharmaceutical_law"),(34,45, "pharmaceutical_law")]}),
("w jaki sposób klient może dowodzić iż wskazane przez jego byłą żonę dochody są zaniżone",{"entities": [(58,62, "civil_law")]}),
("czy lekarz który skończył szkolenie specjalizacyjne jednak nie zdał jeszcze państwowego egzaminu specjalizacyjnego może wykonywać samodzielnie znieczulenia",{"entities": [(88,96, "medical_law"),(26,35, "medical_law"),(36,51, "medical_law"),(76,87, "medical_law"),(97,114, "medical_law")]}),
("w jakim udziale klientka oraz dzieci zmarłego męża klientki będą dziedziczyć spadek",{"entities": [(65,76, "civil_law")]}),
("na jakich zasadach lekarze mają prawo wystawić zaświadczenie pacjentowi zwalniające goz obowiązku maseczki czy poza przepisami z rozporządzenia są jeszcze jakieś inne przepisy czym lekarz powinien się kierować wydając zaświadczenie czy lekarz może wydać zaświadczenie powołując się na zasady etyki lekarskiej",{"entities": [(285,291, "medical_law"),(210,217, "medical_law"),(201,209, "medical_law"),(61,71, "medical_law"),(19,26, "medical_law"),(47,60, "medical_law"),(218,231, "medical_law"),(254,267, "medical_law")]}),
("czy podczas odbywania kwarantanny możliwa jest praca zdalna czy pracodawca może odmówić pracownikowi możliwości pracy zdalnej w trakcie kwarantanny",{"entities": [(53,59, "labor_law"),(47,52, "labor_law"),(88,100, "labor_law"),(118,125, "labor_law")]}),
("jakie uprawnienia przysługują klientowi jako konsumentowi w związku z wadą zakupionego przez internet przedmiotu",{"entities": [(93,101, "civil_law")]}),
("jakie należy podjąć kroki w celu ubezwłasnowolnienia częściowego brata klienta",{"entities": [(33,52, "civil_law")]}),
("czy w sytuacji gdy postępowanie egzekucyjne zostanie zawieszone klient nie będzie musiał wnosić opłat egzekucyjnych czy w takim wypadku klient będzie zwolniony z wszelkich opłat egzekucyjnokomorniczych",{"entities": [(102,115, "civil_law")]}),
("co w związku z zaistniałą sytuacją powinna uczynić klientka",{"entities": [(43,50, "criminal_law"),(26,34, "criminal_law"),(15,25, "criminal_law")]}),
("czy hurtownia nettle poprzez zawarcie tej umowy staje się hurtownią desygnowaną sopharma sp z oo czy umowa dystrybucyjna powinna wskazywać osoby odpowiadające za wstrzymanie iwycofanie produktów leczniczych czy osoby odpowiedzialne za reklamacje wyznaczone przez strony umowy odpowiadają również za reklamacje jakościowe czy dystrybutor powinien wskazać osobę odpowiedzialną czy odpowiedzialność za jakość produktu leczniczego może zostać przerzucona wyłącznie na dystrybutora i wyznaczoną przez niego osobę odpowiedzialną czy umowa powinna określać procedury jakościowe czy umowa podlega zgłoszeniu do gifu",{"entities": [(439,450, "pharmaceutical_law"),(432,438, "pharmaceutical_law"),(145,158, "pharmaceutical_law"),(246,256, "pharmaceutical_law"),(174,184, "pharmaceutical_law"),(399,405, "pharmaceutical_law"),(235,245, "pharmaceutical_law"),(299,309, "pharmaceutical_law"),(107,120, "pharmaceutical_law"),(325,336, "pharmaceutical_law"),(217,231, "pharmaceutical_law"),(360,374, "pharmaceutical_law"),(508,522, "pharmaceutical_law"),(541,549, "pharmaceutical_law"),(58,67, "pharmaceutical_law"),(276,287, "pharmaceutical_law"),(129,138, "pharmaceutical_law"),(310,320, "pharmaceutical_law"),(560,570, "pharmaceutical_law"),(479,489, "pharmaceutical_law"),(162,173, "pharmaceutical_law"),(589,599, "pharmaceutical_law"),(464,476, "pharmaceutical_law")]}),
("czy pracownik musi odebrać tablet służbowy przeznaczony do wykonywania pracy czy pracodawca obowiązany jest dostarczyć odpowiednie zabezpieczenie do sprzętu służbowego powierzonego pracownikowi",{"entities": [(108,118, "labor_law")]}),
("czy pracownik który w ciągu roku był na zwolnieniu lekarskim zachowuje prawo do urlopu wypoczynkowego za cały rok czy podstawa wymiaru urlopu będzie zmniejszona",{"entities": [(127,134, "labor_law"),(87,101, "labor_law")]}),
("w jaki sposób należy sklasyfikować działalność gospodarczą polegającą na udzielaniu porad z zakresu dietetyki czy po przekroczeniu progu wartości sprzedaży w wysokości  zł klientka będzie podlegała zwolnieniu z podatku vat w jaki sposób klientka może reklamować swoje usługi nie narażając się na odpowiedzialność wykroczeniową",{"entities": [(181,187, "administrative_law")]}),
("ile powinno wynosić wynagrodzenie klientki od dnia  lipca  r czy klientka powinna zażądać zawarcia umowy o pracę na czas określony",{"entities": [(12,19, "medical_law"),(59,60, "medical_law"),(116,120, "medical_law"),(4,11, "medical_law")]}),
("jaką ilość leku może wydać klientka na podstawie tak wystawionej recepty",{"entities": [(53,64, "pharmaceutical_law")]}),
("kto może pełnić funkcję przewodniczącego zespołu ds kontroli zakażeń szpitalnych",{"entities": [(9,15, "medical_law")]}),
("w jaki sposób klient może stać się współwłaścicielem nieruchomości z jakimi kosztami będzie się to wiązało",{"entities": [(85,91, "administrative_law")]}),
("jaka tabel opłat i prowizji obowiązuje klientkę  czy z dnia zawarcia umowy kredytu czy też obecna z wyższym oprocentowaniem",{"entities": [(91,97, "administrative_law"),(19,27, "administrative_law")]}),
("czy klientka może odmówić pacjentce i nie udostępnić jej dokumentacji medycznej",{"entities": [(26,35, "medical_law")]}),
("w jaki sposób gabinet lekarski klienta może sprowadzić preparaty witaminowe z innego kraju unii europejskiej które nie są dopuszczone do obrotu w polsce",{"entities": [(44,54, "pharmaceutical_law"),(137,143, "pharmaceutical_law"),(55,64, "pharmaceutical_law"),(65,75, "pharmaceutical_law")]}),
("czy pracodawca ma prawo żądać zaprzestania wykonywania pracy podjętej przed zatrudnieniem u niego",{"entities": [(30,42, "labor_law")]}),
("co należy zrobić jeśli w sieci pojawią się opinie oczerniające lekarza",{"entities": [(31,38, "administrative_law"),(50,62, "administrative_law"),(25,30, "administrative_law"),(43,49, "administrative_law")]}),
("czy bank powinien zwrócić klientce proporcjonalną część kosztów prowizji kredytu hipotecznego",{"entities": [(35,49, "administrative_law"),(64,72, "administrative_law")]}),
("czy postępowanie szpitala narusza prawa pracownicze a w szczególności przepisy obezpieczeństwie i higienie pracy",{"entities": [(26,33, "labor_law")]}),
("czy hurtownia farmaceutyczna powinna wystawić fakturę korygującą",{"entities": [(46,53, "tax_law")]}),
("ile ryczałtu można wziąć na leki recepturowe",{"entities": [(19,24, "pharmaceutical_law")]}),
("czy klient apteki może żądać duplikatów faktur na podstawie wylegitymowania się dokumentem tożsamości czy musi przedstawić dodatkowo wniosek",{"entities": [(50,59, "tax_law")]}),
("czy i na jakich zasadach pracownik zatrudniony na stanowisku specjalisty ds bhp może prowadzić szkolenia okresowe z zakresu bhp dla pozostałych pracowników",{"entities": [(76,79, "labor_law"),(124,127, "labor_law"),(105,113, "labor_law")]}),
("czy istnieje kredyt dla osób otwierających nowy salon kosmetyczny który jest częściowo pomniejszany gdy salon prosperuje dalej czy istnieje pomoc unijna na otwarcie salonu kosmetycznego",{"entities": [(48,53, "administrative_law"),(104,109, "administrative_law"),(165,171, "administrative_law")]}),
("kto w opisanej przez klientkę sytuacji jest spadkobiercą powołanym do spadku i w jakiej części",{"entities": [(44,56, "civil_law")]}),
("czy lekarz będzie miał prawo do odmowy reanimacji pacjenta jeżeli pracodawca nie zapewni mu odpowiedniego wyposażenia oraz środków ochronnych w związku z zagrożeniem związanym z koronawirusem",{"entities": [(81,88, "medical_law"),(166,175, "medical_law"),(131,141, "medical_law"),(106,117, "medical_law"),(154,165, "medical_law")]}),
("czy istnieje możliwość otwarcia punktu aptecznego w tej samej miejscowości w której istnieje już apteka czy istnieje możliwość otwarcia drugiej apteki w tej samej miejscowości w odległości około  metrów w jaki sposób wylicza się odległość w takim przypadku",{"entities": [(23,31, "pharmaceutical_law"),(127,135, "pharmaceutical_law"),(196,202, "pharmaceutical_law"),(39,49, "pharmaceutical_law"),(62,74, "pharmaceutical_law"),(163,175, "pharmaceutical_law"),(32,38, "pharmaceutical_law")]}),
("czy pracodawca może rozpisać urlop wypoczynkowy z pominięciem ustaleń wynikających z planu urlopów",{"entities": [(85,90, "labor_law")]}),
("czy recepcjonistka odpowiada za udostępnienie danych osobowych pacjentki osobie postronnej jakie konsekwencje może ponieść administrator danych klientka w związku z zaistniałą sytuacją czy klientka powinna podjąć w tej sprawie dodatkowe czynności",{"entities": [(4,18, "administrative_law"),(32,45, "administrative_law")]}),
("jak kształtuje się sytuacja podejrzanego w postępowaniu karnym",{"entities": [(28,40, "criminal_law"),(19,27, "criminal_law"),(43,55, "criminal_law")]}),
("czy dyrekcja może zabronić lekarzom rezydentom odbywania staży zewnętrznych czy lekarz dyżurny odpowiada za to że zalecenia wydane pielęgniarkom nie są realizowane na czas",{"entities": [(63,75, "medical_law"),(57,62, "medical_law"),(27,35, "medical_law"),(114,123, "medical_law"),(36,46, "medical_law")]}),
("czy klientowi przysługuje refundacja kosztów pełnomocnika",{"entities": [(4,13, "criminal_law"),(37,44, "criminal_law")]}),
("czy zachowanie dyrektora jest zgodne z prawem czy klient może podpisać umowę o pracę jako rezydent z innym podmiotem",{"entities": [(90,98, "medical_law")]}),
("czy klientka może ubiegać się o przyznanie świadczenia postojowego dla siebie",{"entities": [(32,42, "medical_law")]}),
("czy klient może skutecznie odwołać się od decyzji jakie są warunki pracy w przypadku oddelegowania do pracy przy zwalczaniu epidemii przez wojewodę",{"entities": [(59,66, "medical_law")]}),
("czy wystawienie mandatu karnego było zasadne",{"entities": [(24,31, "criminal_law")]}),
("czy budowa windy dla osób niepełnosprawnych może zostać zakwalifikowana jako remont i zostać sfinansowana z funduszu remontowego dużej wspólnoty mieszkaniowej",{"entities": [(26,43, "administrative_law")]}),
("czy klientka może zwolnić się od konieczności uiszczania opłat za odbiór i utylizację odpadów medycznych przez czas w którym nie będzie ich produkować czy asystentka klientki będzie uprawniona do pobierania zasiłku dla bezrobotnych w trakcie okresu wypowiedzenia umowy w jaki sposób skonstruować wypowiedzenie umowy zawartej z asystentką aby nie narazić się na konieczność wypłaty odprawy lub odszkodowania",{"entities": [(86,93, "administrative_law"),(129,135, "administrative_law"),(175,181, "administrative_law"),(75,85, "administrative_law"),(66,72, "administrative_law")]}),
("jakie są prawa i obowiązki klienta na przesłuchaniu w charakterze świadka",{"entities": [(0,5, "criminal_law"),(54,65, "criminal_law")]}),
("czy klient po powrocie będzie musiał odbyć kwarantannę czy przepisy wprowadzające obowiązek kwarantanny po powrocie do polski są zgodne z konstytucją",{"entities": [(14,22, "constitutional_law"),(107,115, "constitutional_law"),(59,67, "constitutional_law")]}),
("czy dyrektor szpitala mógł przyjąć że lekarze będą zgłaszani do dodatku covidowego dopiero wtedy gdy na oddziale będzie co najmniej  pacjentów chorych na covid",{"entities": [(143,150, "medical_law"),(72,82, "medical_law"),(27,34, "medical_law"),(38,45, "medical_law")]}),
("czy hurtownia farmaceutyczna może zaopatrywać się w towary z wyłączeniem produktów leczniczych od drogerii",{"entities": [(34,45, "pharmaceutical_law")]}),
("czy w związku z epidemią koronawirusa klient może dalej udzielać świadczeń fizjoterapeutycznych w domach pacjentów",{"entities": [(25,37, "medical_law"),(16,24, "medical_law")]}),
("czy objawy wymienione w przepisie   ust  pkt  rozporządzenia ministra zdrowia w sprawie chorób zakaźnych powodujących powstanie obowiązku hospitalizacji izolacji lub izolacji w warunkach domowych oraz obowiązku kwarantanny lub nadzoru epidemiologicznego muszą wystąpić łącznie aby skierować pacjenta na wykonanie testu molekularnego rtpcr po przeprowadzeniu teleporady czy też wystarczy wystąpienie któregokolwiek z objawów",{"entities": [(61,69, "medical_law"),(105,117, "medical_law"),(358,368, "medical_law"),(187,195, "medical_law"),(303,312, "medical_law"),(281,290, "medical_law"),(342,357, "medical_law"),(260,268, "medical_law"),(235,253, "medical_law"),(254,259, "medical_law")]}),
("czy klient może kontynuować pracę bez ważnych badań okresowych",{"entities": [(38,45, "labor_law"),(16,27, "labor_law")]}),
("jak kształtuje się odpowiedzialność lekarza zatrudnionego w podmiocie leczniczym na podstawie umowy cywilnoprawnej wobec pacjenta",{"entities": [(100,114, "medical_law"),(60,69, "medical_law"),(70,80, "medical_law")]}),
("czy klientka ma prawo odmówić podpisana historii leczenia pacjentki jeżeli nie jest pewna oraz nie ma możliwości tego zweryfikowania czy klientka ma obowiązek podpisać dokumentację medyczną ze wsteczną datą która nie spełnia norma prawnych czy pracodawca może przenieść odpowiedzialność za błąd medyczny na klientkę",{"entities": [(217,224, "medical_law"),(202,206, "medical_law"),(40,48, "medical_law"),(290,294, "medical_law")]}),
("czy dzieci klienta powinny obecnie dokonać czynności zmierzających do zrzeczenia się ewentualnego dziedziczenia po zmarłym spadkodawcy",{"entities": [(85,97, "civil_law"),(115,122, "civil_law"),(98,111, "civil_law")]}),
("czy klientka może wydać zaświadczenie o stanie zdrowia pacjenta rodzinie pacjenta w celu umożliwienia złożenia wniosku o ubezwłasnowolnienie pacjenta",{"entities": [(121,140, "medical_law"),(102,110, "medical_law"),(64,72, "medical_law"),(24,37, "medical_law")]}),
("czy w przypadku wypisania na recepcie pełnopłatnej leku dostępnego bez recepty klient może wydać jako zamiennik lek dostępny na receptę jeśli spełnia wszystkie kryteria zamiennika dotyczące postaci dawki i liczby dawek",{"entities": [(29,37, "pharmaceutical_law"),(160,168, "pharmaceutical_law"),(128,135, "pharmaceutical_law"),(116,124, "pharmaceutical_law")]}),
("czy klientka może udzielać świadczeń na podstawie umowy o świadczenie usług medycznych",{"entities": [(58,69, "medical_law")]}),
("czy klientka będąc farmaceutą klinicznym w jednym szpitalu zatrudniona na pełny etat może być jednocześnie zatrudniona na pełny etat w innym szpitalu jako kierownik działu farmacji również na pełny etat",{"entities": [(172,180, "pharmaceutical_law"),(74,79, "pharmaceutical_law"),(122,127, "pharmaceutical_law"),(192,197, "pharmaceutical_law")]}),
("czy pracodawca może rozpisać urlop wypoczynkowy z pominięciem ustaleń wynikających z planu urlopów",{"entities": [(85,90, "labor_law")]}),
("czy dowód osobisty jest konieczny do zawarcia umowy najmu",{"entities": [(24,33, "civil_law")]}),
("od kiedy lekarz specjalista może wystawić receptę z refundacją dla seniorów czy refundacja na szczepionki influvactetra i vaxigriptetra przysługuje seniorom jedynie w przypadku chorób współistniejących",{"entities": [(67,75, "pharmaceutical_law"),(42,49, "pharmaceutical_law"),(80,90, "pharmaceutical_law")]}),
("czy spółka będzie mogła uzyskać zmianę zezwolenia na prowadzenie apteki",{"entities": [(39,49, "pharmaceutical_law")]}),
("jak kształtuje się odpowiedzialność klientki za błędy lekarskie czy klientka jest zobowiązana do podania numeru swojej polisy oc",{"entities": [(119,125, "medical_law"),(105,111, "medical_law"),(97,104, "medical_law")]}),
("czy w przedmiotowej sprawie wspólnota mieszkaniowa jest zobowiązana do naprawy instalacji grzewczej",{"entities": [(79,89, "civil_law"),(71,78, "civil_law")]}),
("jakie kroki może podjąć wspólnota mieszkaniowa w celu usunięcia samochodu czy można wystosować pismo do matki właściciela samochodu z prośbą o przekazanie go synowi",{"entities": [(54,63, "administrative_law")]}),
("w jaki sposób zainteresowany może skorzystać z przysługującego mu urlopu okolicznościowego",{"entities": [(47,62, "labor_law"),(14,28, "labor_law")]}),
("jaka jest funkcjonalna różnica między rozwiązaniem które przewiduje kupno nieruchomości budynkowej wraz z nieruchomością gruntową dla których założono odrębne księgi wieczyste od kupna lokalu w dwulokalowym budynku gdzie nieruchomość gruntowa pozostaje we współwłasności właścicieli obu lokali",{"entities": [(256,270, "civil_law"),(159,165, "civil_law"),(106,120, "civil_law"),(121,129, "civil_law"),(179,184, "civil_law"),(23,30, "civil_law")]}),
("jak przedstawia się obowiązek przejmowania dokumentacji medycznej w przypadku zakończenia prowadzenia działalności leczniczej czy o zakończeniu działalności leczniczej należy informować pacjentów którzy się w niej regularnie leczą",{"entities": [(78,89, "medical_law"),(175,185, "medical_law"),(30,42, "medical_law"),(115,125, "medical_law"),(157,167, "medical_law")]}),
("czy klient powinien ponosić koszty odstąpienia od umowy o imprezę turystyczną",{"entities": [(20,27, "medical_law")]}),
("czy nieletni pacjent może być leczony w gabinecie bez obecności przedstawiciela ustawowego jeśli uprzednio wyraził on zgodę na leczenie czy przedstawiciel ustawowy lub opiekun prawny musi być obecny na wizycie na której będą podawane leki czy wystarczy tylko ogólna zgoda na podanie leków lub zgoda na leczenie czy nieletni pacjent który przychodzi na wizytę z opiekunem faktycznym powinien mieć zgodę przedstawiciela ustawowego na wizytę w obecności opiekuna faktycznego",{"entities": [(202,209, "medical_law"),(80,90, "medical_law"),(418,428, "medical_law"),(391,395, "medical_law"),(107,114, "medical_law"),(352,358, "medical_law"),(432,438, "medical_law"),(4,12, "medical_law"),(315,323, "medical_law"),(266,271, "medical_law"),(293,298, "medical_law"),(118,123, "medical_law"),(396,401, "medical_law"),(26,29, "medical_law"),(188,191, "medical_law"),(54,63, "medical_law"),(441,450, "medical_law"),(451,459, "medical_law")]}),
("co mogą zrobić spadkobiercy aby sprzedać nieruchomość należącą do spadku jeżeli jeden ze spadkobierców po wezwaniu nie stawia się na rozprawę",{"entities": [(106,114, "civil_law"),(89,102, "civil_law"),(15,27, "civil_law")]}),
("czy dzień kontaktu z zarażonym pacjentem wilcza się do czasu trwania kwarantanny",{"entities": [(31,40, "medical_law"),(10,18, "medical_law")]}),
("czy konkluzje opinii o sygn  i  są aktualne czy od momentu wysłania opinii o sygn  i  przepisy przywołane w tych opiniach uległy lub ulegną zmianie czy prowadzone są prace legislacyjne dotyczące zmiany przepisów przywołanych w opiniach o sygn  i",{"entities": [(113,121, "labor_law"),(227,235, "labor_law"),(166,171, "labor_law")]}),
("czy w okresie naprawy pojazdu klientowi przysługuje prawo do pojazdu zastępczego",{"entities": [(22,29, "civil_law"),(61,68, "civil_law"),(14,21, "civil_law")]}),
("czy klient może żądać usunięcia swojego adresu ze strony aresztu śledczego",{"entities": [(22,31, "administrative_law")]}),
("w jaki sposób określić pokrewieństwo między zmarłą a synem klientki we wnioskuo wyrażenie zgody na odrzucenie spadku czy w uzasadnieniu wystarczy wskazać że zmarła najprawdopodobniej miała długi oraz że wszyscy inni spadkobiercy odrzucili spadek",{"entities": [(189,194, "civil_law"),(80,89, "civil_law"),(216,228, "civil_law")]}),
("jak przebiega procedura zgłoszenia mobbingu jakie są koszty postępowania sądowego w sprawie o mobbing czy przegranie procesu o mobbing przez klienta może spowodować dla niego konsekwencje karne czy odwołanie klienta z zajmowanego stanowiska było zgodne z prawem",{"entities": [(94,101, "labor_law"),(127,134, "labor_law"),(230,240, "labor_law"),(35,43, "labor_law")]}),
("czy klient już teraz może związać się umową o pracę która miałaby zacząć obowiązywać od czasu planowego zakończenia jego rezydentury nie ryzykując koniecznością pracy na dwa etaty czy dyrektor szpitala może skutecznie pisemnie zagwarantować że w razie wydłużenia specjalizacji klienta ten będzie go dalej zatrudniał",{"entities": [(104,115, "medical_law"),(227,240, "medical_law"),(66,72, "medical_law"),(121,132, "medical_law"),(252,262, "medical_law")]}),
("czy klient może założyć działalność gospodarczą i skorzystać z dofinansowania jeszcze w trakcie odbywania stażu",{"entities": [(63,77, "medical_law")]}),
("czy istnieje możliwość aby osoba wnioskująca o zachowek go nie otrzymała czy może dojść do darowizny z zapisem że darczyńca daruje działkę i oświadcza że nie wchodzi ona w schedę spadkową czy może dojść do wydziedziczenia konkretnej osoby na mocy testamentu czy w takim przypadku należy uzasadnić dlaczego osoba ma być wydziedziczona czy może dojść do sprzedaży działki na rzecz osoby bliskiej np wnuka aby pieniądze te następnie zostały przekazane w formie darowizny innej osobie z bliskich żeby nie było już żadnego majątku do rozdysponowania który tworzyłby masę spadkową czy można zapisać spadek osobie która najbardziej się go domaga się i wtedy to ona musiałaby spłacić pozostałych spadkobierców co będzie w sytuacji kiedy ta osoba odrzuci spadek czy większy zachowek płaci się z tytułu otrzymanej darowizny czy testamentu jak wyliczyć zachowek w przypadku kiedy zapłacić będzie go musiał jeden ze spadkobierców który otrzyma cały spadek",{"entities": [(91,100, "civil_law"),(458,467, "civil_law"),(804,813, "civil_law"),(774,779, "civil_law"),(131,138, "civil_law"),(287,296, "civil_law"),(158,165, "civil_law"),(474,480, "civil_law"),(600,606, "civil_law"),(47,55, "civil_law"),(765,773, "civil_law"),(842,850, "civil_law"),(593,599, "civil_law"),(746,752, "civil_law"),(738,745, "civil_law"),(688,701, "civil_law"),(904,917, "civil_law"),(668,675, "civil_law"),(179,187, "civil_law"),(566,574, "civil_law"),(676,687, "civil_law"),(247,257, "civil_law"),(818,828, "civil_law")]}),
("czy klientka może zrealizować receptę ze zniżką jeżeli zawiera ona wszystkie wymagane prawem elementy ale oddział nfz  jest w całości w polu uprawnień dodatkowych",{"entities": [(141,150, "pharmaceutical_law"),(30,37, "pharmaceutical_law"),(18,29, "pharmaceutical_law"),(41,47, "pharmaceutical_law")]}),
("czy klientka może zrezygnować z udziału w pracach zespołu",{"entities": [(42,49, "labor_law")]}),
("w jakim zakresie pracodawca może zmienić pracownicy zakres obowiązków czy stanowisko nie zmniejszając wynagrodzenia jeżeli pracownica zawnioskuję o przerwę na karmienie dziecka czy pracodawca może się nie zgodzić na ustawienie tej przerwy na koniec dnia pracy",{"entities": [(41,51, "labor_law"),(205,212, "labor_law"),(159,168, "labor_law")]}),
("czy w opisanej przez klienta sytuacji policja może prowadzić postępowanie w sprawie wykroczenia z art  kodeksu wykroczeń jakie są prawa i obowiązki obwinionego",{"entities": [(121,126, "criminal_law"),(103,110, "criminal_law"),(51,60, "criminal_law"),(84,95, "criminal_law")]}),
("w jaki sposób syn klientki może odwołać się od wyroku sądu w jaki sposób należy sprostować informację o rzekomym przebywaniu bez maseczki w budynku komisariatu policji",{"entities": [(129,137, "criminal_law")]}),
("jakie akty prawne obowiązują klienta podczas prowadzenia zajęć czy studenci podczas zajęć z wykorzystaniem fantoma powinni dezynfekować ręce i zakładać rękawiczki czy konieczne jest każdorazowe dezynfekowanie fantoma czy studenci mają dezynfekować swoje ubrania",{"entities": [(67,75, "medical_law"),(221,229, "medical_law"),(18,28, "medical_law"),(107,114, "medical_law"),(209,216, "medical_law"),(123,135, "medical_law"),(235,247, "medical_law"),(57,62, "medical_law"),(84,89, "medical_law")]}),
("czy w świetle przepisów o ochronie danych osobowych klientka może przechowywać kopie zapasowe danych dotyczących wspólnoty związanych z wykonywaną umową po jej rozwiązaniu czy w świetle przepisów o ochronie danych osobowych klientka jest obowiązana do usunięcia kopii zapasowych danych oraz do zniszczenia lub wydania wspólnocie wydruków tych danych",{"entities": [(26,34, "administrative_law"),(198,206, "administrative_law"),(252,261, "administrative_law")]}),
("jakie są prawa i obowiązki klientki na przesłuchaniu w charakterze świadka",{"entities": [(0,5, "criminal_law"),(55,66, "criminal_law")]}),
("czy klientka musi wyrazić zgodę na proponowany przez pracodawcę system równoważnego czasu pracy taki system jest w zakładzie pracy czy klientka otrzyma  wynagrodzenia podstawowego w związku z pracą w szpitalu covidowym czy klientka może jednocześnie pracować w poz czy kwestie dotyczące pyt  powinny zostać ujęte w umowie o pracę",{"entities": [(192,197, "medical_law"),(250,258, "medical_law"),(261,264, "medical_law"),(167,179, "medical_law"),(26,31, "medical_law"),(64,70, "medical_law"),(101,107, "medical_law"),(292,299, "medical_law")]}),
("co może zrobić klient aby przedłużyć kwarantannę i wykonać badania na obecność koronawirusa",{"entities": [(26,36, "medical_law"),(37,48, "medical_law")]}),
("czy pracodawca ma możliwość oddelegowania klientki do pełnienia dyżurów medycznych na innym oddziale aniżeli wskazanym jako miejsce pracy w wiążącej klientkę umowie o pracę",{"entities": [(109,118, "labor_law")]}),
("jakiego rodzaju oświadczenie powinna wypisywać klientka pacjentom którzy posiadają przeciwwskazania do noszenia maseczek zakrywających usta i nos",{"entities": [(8,15, "medical_law"),(112,120, "medical_law")]}),
("jak przedstawiają się zasady odpowiedzialności cywilnej karnej i dyscyplinarnej apteki oraz technika farmaceutycznego w wypadku błędnego wydania leku",{"entities": [(92,100, "pharmaceutical_law"),(101,117, "pharmaceutical_law")]}),
("jakie konsekwencje wynikają z przepisania na recepcie leku refundowanego pacjentowi który nie jest uprawniony do otrzymania zniżki w jakim terminie nfz może dochodzić roszczeń z tytułu nieprawidłowości przy wystawieniu recepty czy w przypadku gdyby pacjent zwrócił lek do apteki to klientka nie poniosłaby negatywnych konsekwencji",{"entities": [(45,53, "pharmaceutical_law"),(306,317, "pharmaceutical_law"),(59,72, "pharmaceutical_law")]}),
("czy można zlokalizować punkt szczepień w szkole",{"entities": [(29,38, "medical_law")]}),
("czy wspólnota może podjąć uchwałę która pierwotnie miała być podjęta na zebraniu rocznym w  r z datą bieżącą tj  r",{"entities": [(92,93, "medical_law"),(57,60, "medical_law"),(96,100, "medical_law")]}),
("czy pracodawca ma możliwość udzielenia pracownikowi zatrudnionemu na podstawie umowy o pracę zaległego urlopu wypoczynkowego bez jego zgody jak kształtuje się kwestia urlopu dla członków zarządu zatrudnionych na podstawie umowy o pracę jaki będzie wymiar urlopu dla pracownika zatrudnionego na podstawie umowy o pracę w wymiarze  etatu",{"entities": [(187,194, "labor_law"),(110,124, "labor_law"),(39,51, "labor_law")]}),
("czy pracodawca może ustnie polecić klientowi kwalifikowanie pacjentów do szczepień na covid czy pracodawca powinien zapewnić rezydentom nadzór wykwalifikowanego w tym przedmiocie lekarza czy za kwalifikowanie pacjentów do szczepień przysługuje dodatek do wynagrodzenia",{"entities": [(45,59, "medical_law"),(194,208, "medical_law"),(136,142, "medical_law"),(73,82, "medical_law"),(222,231, "medical_law"),(143,160, "medical_law"),(125,135, "medical_law")]}),
("czy pracodawca może żądać od pracownika informacji na temat jego aktualnego dodatkowego zatrudnienia w związku z ryzykiem zakażenia pracownika koronawirusem w miejscu dodatkowego zatrudnienia czy pracodawca może zobowiązać pracownika do podpisania oświadczenia w którym pracownik wskaże swoje dodatkowe aktywności zawodowe oraz zobowiąże się do ich niewykonywania w czasie epidemii jakie konsekwencje grożą pracownikowi który nie podpisze oświadczenia",{"entities": [(76,87, "labor_law"),(167,178, "labor_law"),(430,438, "labor_law"),(65,75, "labor_law"),(113,121, "labor_law"),(407,419, "labor_law")]}),
("po jakim czasie można zutylizować recepty umowy z przedsiębiorstwami farmaceutycznymi dokumenty finansowe faktury rozliczenia itp",{"entities": [(69,85, "pharmaceutical_law")]}),
("czy możliwe jest dokonanie przez pracodawcę wypowiedzenia zmieniającego wraz z obniżeniem wynagrodzenia ewentualnie uzupełnienie różnicy dodatkiem",{"entities": [(58,71, "labor_law"),(79,89, "labor_law")]}),
("jakie są prawa i obowiązki świadka w postępowaniu karnym kto może zwolnić klientkę z tajemnicy lekarskiej",{"entities": [(0,5, "criminal_law"),(66,73, "criminal_law"),(27,34, "criminal_law"),(50,56, "criminal_law"),(37,49, "criminal_law")]}),
("czy możliwe jest uchylenie się od złożonego oświadczenia woli  zgody na rozwiązanie stosunku pracy",{"entities": [(34,43, "labor_law"),(17,26, "labor_law")]}),
("czy klientka może domagać się zapłaty dodatku covidowego za grudzień  r",{"entities": [(60,68, "medical_law"),(46,56, "medical_law")]}),
("w jaki sposób należy obecnie doprowadzić do dziedziczenia udziałów w funduszu własności pracowniczej pkp",{"entities": [(29,40, "civil_law"),(58,66, "civil_law"),(44,57, "civil_law"),(78,87, "civil_law")]}),
("z jakimi formalnościami wiąże się rozwiązanie umowy o pracę za porozumieniem stron",{"entities": [(63,76, "labor_law")]}),
("czy nieruchomość nabywa wspólnota mieszkaniowa czy też jej poszczególni członkowie kto będzie właścicielem nabytej nieruchomości kto będzie zobowiązany do zapłaty podatku od nieruchomości czy na zakup nieruchomości wspólnota może przeznaczyć środki zgromadzone na zaliczce remontowo  inwestycyjnej czy do nabycia nieruchomości wystarczy podjęcie uchwały większością głosów",{"entities": [(337,345, "civil_law"),(346,353, "civil_law"),(354,365, "civil_law"),(72,82, "civil_law"),(195,200, "civil_law")]}),
("czy klient może korzystać z dotychczasowych druków recept",{"entities": [(28,43, "medical_law")]}),
("czy klient może zostać skierowany do pracy przy zwalczaniu epidemii w szpitalu w którym odbywa szkolenie specjalizacyjne",{"entities": [(95,104, "medical_law"),(88,94, "medical_law"),(23,33, "medical_law")]}),
("jaki jest właściwy tryb załatwienia wszelkich formalności związanych z pełnieniem funkcji kierownika działu farmacji szpitalnej czy obecny kierownik powinien zgłosić zastępstwo czy powinna być opiniowana nowa osoba na okres zastępstwa czy w dziale farmacji szpitalnej klientka powinna składać podanie o rękojmie do izby aptekarskiej czy tylko zgłosić to do wojewódzkiego inspektora farmaceutycznego",{"entities": [(320,332, "pharmaceutical_law"),(108,116, "pharmaceutical_law"),(248,256, "pharmaceutical_law"),(117,127, "pharmaceutical_law"),(257,267, "pharmaceutical_law"),(371,381, "pharmaceutical_law"),(357,370, "pharmaceutical_law"),(204,208, "pharmaceutical_law")]}),
("czy klientka lekarz w przypadku powzięcia informacji że miała kontakt z pacjentem u którego zachodzi podejrzenie zachorowania na koronawirusa powinna zachować się w określony sposób",{"entities": [(101,112, "medical_law"),(72,81, "medical_law"),(129,141, "medical_law"),(62,69, "medical_law")]}),
("w jakim terminie pracodawca może żądać wyjaśnień od pracownika czy takiemu pracownikowi powinna zostać cofnięta premia",{"entities": [(75,87, "labor_law")]}),
("jak prawa i obowiązki ma klientka w związku z wezwaniem przez rzecznika odpowiedzialności zawodowej na przesłuchanie w charakterze świadka",{"entities": [(119,130, "criminal_law"),(46,55, "criminal_law"),(62,71, "criminal_law"),(72,89, "criminal_law"),(103,116, "criminal_law")]}),
("jakie przepisy regulują kwestię przeprowadzania badań okresowych maszynistów w czasie pandemii co może zrobić pracownik jeśli mimo zawieszenia obowiązku wykonywania badań okresowych pracodawca poleca mu wykonanie takich badań",{"entities": [(65,76, "labor_law"),(54,64, "labor_law"),(171,181, "labor_law")]}),
("czy konkurencyjna firma może żądać aby klient zaprzestał sprzedaży danego modelu krzeseł",{"entities": [(4,17, "international_law")]}),
("czy klientowi przysługuje prawo do żądania wypłaty dodatku z tytułu zajmowania się leczeniem pacjentów chorych na covid",{"entities": [(61,67, "medical_law"),(103,110, "medical_law"),(83,92, "medical_law"),(43,50, "medical_law"),(68,78, "medical_law")]}),
("czy klientka lekarz w przypadku powzięcia informacji że miała kontakt z pacjentem u którego zachodzi podejrzenie zachorowania na koronawirusa powinna zachować się w określony sposób",{"entities": [(101,112, "medical_law"),(72,81, "medical_law"),(129,141, "medical_law"),(62,69, "medical_law")]}),
("jakie kroki może podjąć wspólnota mieszkaniowa w celu usunięcia samochodu czy można wystosować pismo do matki właściciela samochodu z prośbą o przekazanie go synowi",{"entities": [(54,63, "administrative_law")]}),
("jaką procedurę należy rozpocząć i kto ma ją przeprowadzić aby ustalić czy są jacyś spadkobiercy po zmarłym",{"entities": [(62,69, "civil_law"),(83,95, "civil_law")]}),
("czy klient może samodzielnie pracować na szpitalnym oddziale ratunkowym bez osobistego nadzoru innego lekarza czy oddelegowanie jest zgodne z prawem jeżeli uniemożliwia to realizację programu specjalizacji",{"entities": [(102,109, "criminal_law")]}),
("czy polska apteka internetowa może sprzedawać wysyłkowo za granicę produkty lecznicze wyroby medyczne kosmetyki suplementy diety i środki spożywcze specjalnego przeznaczenia żywieniowego",{"entities": [(76,85, "pharmaceutical_law"),(86,92, "pharmaceutical_law"),(112,122, "pharmaceutical_law"),(160,173, "pharmaceutical_law"),(148,159, "pharmaceutical_law"),(138,147, "pharmaceutical_law")]}),
("czy pozwany powinien zawiadomić sąd o wykonaniu nakazu zapłaty w postępowaniu upominawczym",{"entities": [(4,11, "civil_law")]}),
("czy w trakcie pracy w ramach skierowania do pracy na podstawie decyzji wojewody klientka ma możliwość skorzystania z urlopu wypoczynkowego czy w trakcie trwania pracy w ramach ww skierowania klientka ma możliwość skorzystania z sześciu dni urlopu szkoleniowego",{"entities": [(102,114, "labor_law"),(213,225, "labor_law"),(124,138, "labor_law")]}),
("czy klient będący lekarzem stażystą może podpisać umowę zlecenie ze szpitalem w którym odbywa staż cząstkowy na potrzeby kwalifikowania do szczepień przeciwko covid",{"entities": [(121,135, "medical_law"),(56,64, "medical_law"),(68,77, "medical_law"),(112,120, "medical_law"),(87,93, "medical_law"),(18,26, "medical_law"),(94,98, "medical_law"),(139,148, "medical_law")]}),
("czy letni ojciec klientki pracownik sanepidu może zostać oddelegowany do pracy przy badaniach związanych z koronawirusem czy to że ojciec klientki od kilku lat pozostaje pod opieką lekarza wpływa na możliwość jego oddelegowania",{"entities": [(174,180, "labor_law")]}),
("co może zrobić klientka w związku z powziętymi wątpliwościami dotyczącymi nieprawidłowości w protokołach rozpraw oraz innymi nieprawidłowościami dotyczącymi postępowania przed sądem lekarskim czy fakt że okręgowy sąd lekarski w warszawie posiadał dokumentację medyczną pacjentek klientki może stanowić naruszenie przepisów o dokumentacji medycznej",{"entities": [(204,212, "criminal_law"),(196,200, "criminal_law"),(247,259, "criminal_law"),(213,216, "criminal_law"),(228,237, "criminal_law"),(62,73, "criminal_law"),(145,156, "criminal_law"),(260,268, "criminal_law")]}),
("jakie prawa i obowiązki ma osoba wezwana na przesłuchanie w charakterze świadka wpostępowaniu cywilnym jak kształtuje się odpowiedzialność klienta w przedmiotowej sprawie",{"entities": [(33,40, "medical_law"),(80,93, "medical_law")]}),
("na czym polega rozpoznanie sprawy na zasadach ogólnych czy po złożeniu sprzeciwu może zostać powołany biegły lub zostanie wykonana ekspertyza co umożliwiłoby żonie klienta obronę czy obrońcą żony klienta musi być prawnik czy też może być to osoba niewykonująca zawodu prawniczego czy wniesienie sprzeciwu i rozpoznanie sprawy na zasadach ogólnych wiąże się z dodatkowymi kosztami",{"entities": [(284,294, "criminal_law"),(71,80, "criminal_law"),(295,304, "criminal_law"),(46,54, "criminal_law"),(338,346, "criminal_law"),(15,26, "criminal_law"),(307,318, "criminal_law"),(158,163, "criminal_law"),(37,45, "criminal_law"),(329,337, "criminal_law")]}),
("jakie pozwolenia należy uzyskać chcąc wybudować staw rybny o powierzchni ponad  ha",{"entities": [(38,47, "administrative_law"),(6,16, "administrative_law")]}),
("jakie są koszty wniesienia pozwu jeśli klient skorzysta z ubezpieczenia ochrony prawnej czy jeśli rozstrzygnięcie będzie niekorzystne dla klienta koszty będą pokrywanez ubezpieczenia ochrony prawnej do jakiej kwoty ubezpieczyciel będzie pokrywał koszty czy zespół adwokatów i radców prawnych z lex secure podtrzymuje swoje stanowisko",{"entities": [(27,32, "civil_law")]}),
("czy wymagane jest wyrażenie zgody przez rodziców na zabieg powiększenia ust siedemnastoletniej pacjentki jeżeli tak to w jakiej formie należy udzielić wymaganej zgody",{"entities": [(52,58, "medical_law")]}),
("w jaki sposób należy rozumieć treść art    ustawy z dnia  czerwca  r  kodeks pracy czy pracownik jest zobowiązany odebrać harmonogram pracy w wyznaczonym przez pracodawcę miejscu",{"entities": [(122,133, "labor_law"),(58,65, "labor_law")]}),
("czy klientce mogą grozić konsekwencje w związku z tym że do dnia  kwietnia  r nie przebywała na kwarantannie czy klientka może w czasie kwarantanny podjąć pracę zdalną",{"entities": [(96,108, "medical_law"),(76,77, "medical_law")]}),
("czy klient ma obowiązek stawić się w prokuraturze w związku z faktem że przebywa na zwolnieniu lekarskim",{"entities": [(84,94, "criminal_law"),(72,80, "criminal_law"),(37,49, "criminal_law")]}),
("z jakimi formalnościami wiąże się rozwiązanie umowy o pracę za porozumieniem stron",{"entities": [(63,76, "labor_law")]}),
("czy klient ma obowiązek uzyskać pozwolenie na budowę ogrodzenia czy klient ma obowiązek uzyskać zgodę sąsiadów na budowę ogrodzenia",{"entities": [(32,42, "administrative_law"),(53,63, "administrative_law"),(46,52, "administrative_law"),(114,120, "administrative_law")]}),
("czy osoba wykonująca zlecone czynności w miejscu pracy i w domu w czasie kiedy jest taka potrzeba i raz w tygodniu pracująca w rejestracji w zależności jak przyjmują lekarze może być zatrudniona na umowę zlecenie czy musi na umowę o pracę kto ewentualnie mógłby podważyć charakter takiej umowy",{"entities": [(141,151, "labor_law"),(100,103, "labor_law")]}),
("czy klientka może zwolnić się od konieczności uiszczania opłat za odbiór i utylizację odpadów medycznych przez czas w którym nie będzie ich produkować czy asystentka klientki będzie uprawniona do pobierania zasiłku dla bezrobotnych w trakcie okresu wypowiedzenia umowy w jaki sposób skonstruować wypowiedzenie umowy zawartej z asystentką aby nie narazić się na konieczność wypłaty odprawy lub odszkodowania",{"entities": [(86,93, "administrative_law"),(129,135, "administrative_law"),(175,181, "administrative_law"),(75,85, "administrative_law"),(66,72, "administrative_law")]}),
("czy zasiedzenie służebności przesyłu stacja transformatorowa znajdująca się w pomieszczeniach należących do wspólnoty mieszkaniowej jest możliwe czy mimo zasiedzenia służebności przesyłu przez operatora energetycznego wspólnota może wyegzekwować opłaty za służebność",{"entities": [(16,27, "civil_law"),(166,177, "civil_law"),(4,15, "civil_law"),(28,36, "civil_law"),(178,186, "civil_law"),(154,165, "civil_law")]}),
("czy klient może udzielać świadczeń zdrowotnych pacjentom którzy nie są chorzy na covid czy klient jest obowiązany do odbycia kwarantanny",{"entities": [(117,124, "medical_law")]}),
("czy klient miał podstawy aby odmówić udzielania świadczeń zdrowotnych całej rodzinie problematycznego pacjenta",{"entities": [(16,24, "medical_law"),(37,47, "medical_law"),(76,84, "medical_law")]}),
("czy pracodawca może ustnie polecić klientowi kwalifikowanie pacjentów do szczepień na covid czy pracodawca powinien zapewnić rezydentom nadzór wykwalifikowanego w tym przedmiocie lekarza w jakich godzinach lekarz rezydent może kwalifikować pacjentów czy za kwalifikowanie pacjentów do szczepień przysługuje dodatek do wynagrodzenia",{"entities": [(45,59, "medical_law"),(257,271, "medical_law"),(136,142, "medical_law"),(213,221, "medical_law"),(227,239, "medical_law"),(73,82, "medical_law"),(285,294, "medical_law"),(143,160, "medical_law"),(125,135, "medical_law")]}),
("czy pracownikowi przysługuje urlop szkoleniowy w wymiarze  dni",{"entities": [(4,16, "labor_law")]}),
("czy można wypowiedzieć umowę o pracę wysyłając pracodawcy mailowo skan podpisanego pisma zawierającego wypowiedzenie umowy o pracę czy można wypowiedzieć umowę o pracę składając pismo zawierające wypowiedzenie umowy o pracę informując o tym fakcie nieobecnego właściciela firmy",{"entities": [(71,82, "labor_law"),(37,46, "labor_law")]}),
("czy pracodawca ma prawo przymusowo wysłać pracownika na urlop przekraczający liczbę godzin urlopu zaległego",{"entities": [(35,41, "labor_law")]}),
("czy aktualne przepisy regulują kierunek otwierania drzwi pomieszczenia w którym znajduje się kocioł gazowy o mocy  kw czy w  roku kiedy projekt budowlanybył zatwierdzany do pozwolenia na budowę przepisy regulowały kierunek otwierania drzwi w zależności od mocy kotła",{"entities": [(40,50, "administrative_law"),(223,233, "administrative_law"),(136,143, "administrative_law"),(187,193, "administrative_law"),(31,39, "administrative_law"),(214,222, "administrative_law"),(173,183, "administrative_law"),(57,70, "administrative_law")]}),
("jakie są prawa i obowiązki świadka w postępowaniu cywilnym czy klientka może odmówić stawienia sie na rozprawie w związku z wykupionymi biletami na samolot",{"entities": [(85,94, "medical_law")]}),
("czy straż ochrony kolei może żądać od maszynistów dozoru opisanego w piśmie z dnia  maja  r",{"entities": [(57,66, "labor_law"),(84,88, "labor_law"),(38,49, "labor_law")]}),
("czy w przedstawionej sytuacji klient będzie musiał rozpocząć opłacanie vat jakie koszty można odliczyć od vat",{"entities": [(81,87, "tax_law"),(88,93, "tax_law")]}),
("czy pracodawca ma możliwość oddelegowania klientki do pełnienia dyżurów medycznych na innym oddziale aniżeli wskazanym jako miejsce pracy w wiążącej klientkę umowie o pracę",{"entities": [(109,118, "labor_law")]}),
("jaki jest wymiar urlopu rodzicielskiego od kiedy klient może skorzystać z urlopu rodzicielskiego w jaki sposób należy zgłosić się do dobrowolnego ubezpieczenia chorobowego",{"entities": [(24,39, "labor_law"),(81,96, "labor_law")]}),
("czy zeznania świadków są wiarygodnymi zeznaniami dla okręgowego sądu lekarskiego bądź okręgowego rzecznika odpowiedzialności zawodowej czy nagranie rozmowy sporządzone bez zgody osoby nagrywanej może stanowić dowód w postępowaniu cywilnym czy okręgowy rzecznik odpowiedzialności zawodowej ma możliwość odnoszenia się do zasadności skierowań czy rozpoznawania chorób wydawanych przez klientkę czy decyzja okręgowego rzecznika odpowiedzialności zawodowej oparta zdaniem klientki na niezgodnych z prawdą ustaleniach powinna być zrewidowana czy klientka powinna otrzymać odpowiedź na odwołanie od decyzji okręgowego rzecznika odpowiedzialności zawodowej czy istnieje możliwość odwołania się od decyzji okręgowego rzecznika odpowiedzialności zawodowej wydanej na podstawie niezgodnych z dokumentacją szpitalną danych w jaki sposób klientka może uzyskać dostęp do akt sprawy postępowania dyscyplinarnego",{"entities": [(13,21, "civil_law"),(156,167, "civil_law"),(848,854, "civil_law"),(480,491, "civil_law"),(768,779, "civil_law")]}),
("czy klientka może zawrzeć umowę proponowaną przez pracodawcę u którego odbywa staż podyplomowy",{"entities": [(71,77, "medical_law"),(78,82, "medical_law")]}),
("w jaki sposób klient ma przekazać dokumentację medyczną co stanowi art   a kodeksu karnego",{"entities": [(34,46, "criminal_law"),(75,82, "criminal_law"),(59,66, "criminal_law"),(47,55, "criminal_law")]}),
("czy umowa o pracę została skutecznie wypowiedziana czy zwolnienie lekarskie wpływa na skuteczność wypowiedzenia",{"entities": [(37,50, "labor_law"),(86,97, "labor_law")]}),
("czy i w jaki sposób wspólnota mieszkaniowa mogłaby dokonać ocieplenia garaży",{"entities": [(59,69, "civil_law")]}),
("na czym polega instytucja zasiedzenia nieruchomości czy w przedmiotowej sprawie może dojść do zasiedzenia jeżeli tak to po jakim czasie",{"entities": [(15,25, "civil_law"),(8,14, "civil_law"),(26,37, "civil_law"),(94,105, "civil_law")]}),
("czy podwieszka znajdująca się nad miejscem postojowym położona jest na odpowiedniej wysokości czy klient może domagać się usunięcia podwieszki mimo że mógł się dowiedzieć o jej istnieniu w momencie zakupu miejsca postojowego",{"entities": [(122,131, "administrative_law")]}),
("czy przepisy powszechnie obowiązującego prawa wyznaczają kiedy skarbnik okręgowej izby aptekarskiej musi przedstawić sprawozdanie z wykonania budżetu oraz przedstawić projekt budżetu",{"entities": [(87,99, "pharmaceutical_law"),(142,149, "pharmaceutical_law"),(117,129, "pharmaceutical_law")]}),
("jak kształtują się prawa i obowiązki klientki w związku z wezwaniem na przesłuchanie do prokuratury",{"entities": [(4,14, "criminal_law"),(58,67, "criminal_law"),(71,84, "criminal_law")]}),
("na jaki okres czasu może być zastosowane tymczasowe aresztowanie jak kształtują się prawa i obowiązki pracownika oraz pracodawcy w przypadku tymczasowego aresztowania czy pracownik tymczasowo aresztowany może zostać zwolniony z pracy",{"entities": [(102,112, "criminal_law"),(69,79, "criminal_law")]}),
("czy klient aby nie odziedziczyć długów powinien zrzec się spadku po swojej siostrze",{"entities": [(19,31, "civil_law"),(32,38, "civil_law")]}),
("czy urlop dodatkowy przewidziany w   zakładowego układu zbiorowego pracy jest urlopem wypoczynkowym i powinien być jako taki traktowany",{"entities": [(10,19, "labor_law"),(86,99, "labor_law"),(78,85, "labor_law"),(37,48, "labor_law")]}),
("czy osoby zatrudnione w aptece na podstawie umowy cywilnoprawnej zlecenia zobowiązane są do dostarczenia zaświadczenia o zdolności do pracy wystawione przez lekarza medycyny pracy",{"entities": [(92,104, "labor_law")]}),
("czy pracodawca mógł rozwiązać umowę o pracę z klientką jakie uprawnienia przysługują klientce w związku z niewykorzystanym urlopem wypoczynkowym",{"entities": [(106,122, "labor_law"),(123,130, "labor_law")]}),
("czy umowa o pracę została skutecznie wypowiedziana czy zwolnienie lekarskie wpływa na skuteczność wypowiedzenia",{"entities": [(37,50, "labor_law"),(86,97, "labor_law")]}),
("jak kształtują się podstawy odpowiedzialności klienta prowadzącego leczenie w ramach indywidualnej praktyki lekarskiej",{"entities": [(19,27, "medical_law"),(85,98, "medical_law"),(54,66, "medical_law")]}),
("czy zarządca nieruchomości któremu deweloper powierzył zarząd nieruchomością wspólnąw formie aktu notarialnego może zrezygnować z zarządu i samodzielnie przekazać zarząd nieruchomością innemu podmiotowi bez angażowania w to wspólnoty mieszkaniowej",{"entities": [(98,110, "civil_law"),(4,12, "civil_law"),(35,44, "civil_law"),(55,61, "civil_law"),(163,169, "civil_law"),(62,76, "civil_law"),(170,184, "civil_law")]}),
("czy klientka może nie zgodzić się na nagrywanie wizyty czy klientka może odmówić leczenia w przypadku gdy pacjent odmówi wyłączenia kamery czy honorowy dawca krwi powinien zostać przyjęty przez lekarza bez kolejki",{"entities": [(194,201, "criminal_law"),(48,54, "criminal_law")]}),
("czy możliwe jest dokonanie sprzedaży samochodu wchodzącego w skład spadku bez przeprowadzenia postępowania spadkowego",{"entities": [(61,66, "civil_law"),(17,26, "civil_law")]}),
("czy klientka może odstąpić od kredytu konsumenckiego zawartego przy sprzedaży na raty",{"entities": [(18,26, "administrative_law")]}),
("czy klient po powrocie z dominikany będzie objęty obowiązkiem odbycia kwarantanny czy klient istnieje możliwość uniknięcia obowiązku kwarantanny",{"entities": [(62,69, "medical_law"),(43,49, "medical_law")]}),
("czy lekarz powinien wystawić dwie dodatkowe faktury za listopad i grudzień i zapłacić podatek niezależnie od tego kiedy otrzyma dodatek",{"entities": [(34,43, "medical_law"),(55,63, "medical_law"),(66,74, "medical_law"),(77,85, "medical_law")]}),
("czy pracodawca może jednostronnie zmniejszyć żonie klienta wymiar czasu pracy z  na  etatu czy w związku ze zmniejszeniem wymiaru zatrudnienia na skutek epidemii obecnie pracownikowi przysługuje jakieś dodatkowe świadczenie czy w przypadku zamknięcia zakładu pracy żona klienta będzie miała możliwość pobierania zasiłku dla bezrobotnych",{"entities": [(122,129, "labor_law"),(34,44, "labor_law"),(170,182, "labor_law")]}),
("jakie zmiany dla klienta wprowadza przesłany aneks umowy",{"entities": [(45,50, "medical_law")]}),
("jaki formularz powinien wypełnić klient do jakiej kategorii klient powinien zaliczyć swoją wierzytelność zaliczka za pośrednictwo kupna samochodu",{"entities": [(24,32, "civil_law"),(105,113, "civil_law"),(130,135, "civil_law")]}),
("czy klientka ma obowiązek wystawić w aptece fakturę na żądanie pacjenta na podstawie paragonu ile czasu ma klientka na wystawienie faktury na podstawie paragonu",{"entities": [(75,84, "tax_law"),(142,151, "tax_law"),(44,51, "tax_law"),(85,93, "tax_law")]}),
("czy apteka powinna złożyć sprawozdanie za  rok mimo że w tym okresie nie wytworzyła żadnych odpadów",{"entities": [(26,38, "pharmaceutical_law")]}),
("kiedy partner może opuścić spółkę partnerską w jakim okresie roku kalendarzowego czy obowiązuje okres wypowiedzenia",{"entities": [(34,44, "civil_law"),(6,13, "civil_law")]}),
("czy indywidualna interpretacja podatkowa jest prawnie wiążąca wstecz",{"entities": [(31,40, "tax_law")]}),
("w jaki sposób i w jakim terminie pracownik powinien złożyć wniosek o obniżenie wymiaru czasu pracy aby być chronionym od pierwszego dnia po powrocie do pracy czy ochrona wynikająca z wniosku oznacza również ochronę przed zwolnieniem z przyczyn leżących po stronie pracownika z zachowaniem okresu wypowiedzenia czy ochrona wynikająca z wniosku oznacza również ochronę przed zwolnieniem z przyczyn leżących po stronie pracodawcy np z powodu redukcji zatrudnienia z wypłatą odpowiedniego odszkodowania na podstawie przepisów ustawy o zwolnieniach grupowych czy przedsiębiorstwo klientki będzie mogło skierować pracownicę na przestój ekonomiczny płatny  albo obniżyć jej wymiar czasu pracy o  czy pracownica po złożeniu wniosku będzie chroniona również przed takimi działaniami jeżeli na wniosek pracownicy jej etat będzie zmniejszony najpierw np do  na podstawie ochrony wynikającej z wniosku to czy po zmniejszeniu o  na podstawie przepisów specustawy covid będzie on wynosił  czy podstawą zmniejszenia będzie etat obniżony na podstawie wniosku czy pełen etat z umowy o pracę",{"entities": [(170,180, "labor_law"),(322,332, "labor_law"),(79,86, "labor_law"),(792,802, "labor_law"),(621,629, "labor_law"),(235,243, "labor_law"),(387,395, "labor_law"),(207,214, "labor_law"),(359,366, "labor_law"),(277,288, "labor_law"),(69,78, "labor_law"),(819,830, "labor_law"),(244,252, "labor_law"),(396,404, "labor_law"),(966,973, "labor_law"),(162,169, "labor_law"),(314,321, "labor_law"),(988,1000, "labor_law"),(655,662, "labor_law"),(979,987, "labor_law"),(463,470, "labor_law"),(642,648, "labor_law"),(607,617, "labor_law"),(868,879, "labor_law"),(221,232, "labor_law"),(373,384, "labor_law")]}),
("czy osobą szczepiącą w aptece może być tylko i wyłącznie farmaceuta zatrudniony w aptece",{"entities": [(68,79, "medical_law"),(4,9, "medical_law"),(35,38, "medical_law"),(23,29, "medical_law")]}),
("czy pracodawca dowie się z jakiej przyczyny klient jest na kwarantannie czy w ważnej sprawie mechanik może przyjść do klienta żeby naprawić uszkodzoną instalację czy klient może odebrać list od listonosza który do niego przyjdzie czy gdyby klient wyszedł z domu i zatrzymała go na tym policja to czy w razie wykonania testu byłaby to podstawa do odwołania",{"entities": [(334,342, "medical_law"),(34,43, "medical_law"),(59,71, "medical_law"),(247,254, "medical_law"),(107,114, "medical_law"),(308,317, "medical_law")]}),
("czy pracodawca może wypowiedzieć klientce umowę o pracę w przypadku likwidacji stanowiska pracy czy klientce będzie przysługiwała odprawa czy klientka może przejść na emeryturę pomostową",{"entities": [(79,89, "labor_law"),(130,137, "labor_law")]}),
("czy klientka może samodzielnie wytwarzać korony protetyczne czy klientka może sprzedawać wytworzone korony innym lekarzom",{"entities": [(48,59, "medical_law"),(41,47, "medical_law"),(100,106, "medical_law")]}),
("czy osoby funkcyjne mogą świadczyć usługi na rzecz izby aptekarskiej w ramach prowadzonej działalności gospodarczej czy w takim przypadku izba będzie zobowiązana do odprowadzania składek na ubezpieczenia społeczne",{"entities": [(143,149, "administrative_law")]}),
("czy klient aby nie odziedziczyć długów powinien zrzec się spadku po swojej siostrze",{"entities": [(19,31, "civil_law"),(32,38, "civil_law")]}),
("czy lekarz może wystawić recepty refundowane w  dla seniorów w ramach leczenia szpitalnego i w ramach ambulatoryjnej opieki specjalistycznej w związku z zakończeniem leczenia szpitalnego czy lekarz może wystawić recepty refundowane w  dla seniorów w indywidualnej praktyce lekarskiej poza kontraktem z nfz czy można takie recepty wystawić pro familiae czy lekarz jest obowiązany zweryfikować uprzednio wystawione recepty",{"entities": [(339,342, "pharmaceutical_law"),(52,60, "pharmaceutical_law"),(239,247, "pharmaceutical_law"),(153,165, "pharmaceutical_law"),(379,391, "pharmaceutical_law"),(343,351, "pharmaceutical_law"),(33,44, "pharmaceutical_law"),(220,231, "pharmaceutical_law")]}),
("czy klientka musi uzyskać nowe upoważnienie do wystawiania recept refundowanych czy druki recept według starego wzoru tracą ważność w jaki sposób klientka może nabyć druki recept według nowego wzoru",{"entities": [(112,117, "pharmaceutical_law")]}),
("jak należy obliczyć należne wynagrodzenie lekarza rezydenta radiologii któremu przysługuje bon patriotyczny ile obecnie wynosi wynagrodzenie zasadnicze klienta",{"entities": [(95,107, "medical_law"),(91,94, "medical_law")]}),
("czy lekarz stażysta może być oddelegowany przez pracodawcę do pracy na dyżurze godzinnym na szpitalnym oddziale ratunkowym przy zwalczaniu koronawirusa jeżeli nadzór lekarza specjalisty byłby pełniony jedynie telefonicznie czy dyrekcja szpitala nawiązując nowy stosunek pracy może w umowie wpisać że umowa została zawarta z lekarzem zamiast lekarz stażysta",{"entities": [(174,185, "medical_law"),(139,151, "medical_law"),(11,19, "medical_law"),(324,332, "medical_law"),(92,102, "medical_law"),(192,200, "medical_law"),(159,165, "medical_law"),(314,321, "medical_law"),(25,28, "medical_law"),(71,78, "medical_law"),(112,122, "medical_law")]}),
("czy zasiłek opiekuńczy przewidziany w art  ust  ustawy o szczególnych rozwiązaniach związanych z zapobieganiem przeciwdziałaniem i zwalczaniem covid innych chorób zakaźnych oraz wywołanych nimi sytuacji kryzysowych przysługuje osobno każdemu z rodziców",{"entities": [(131,142, "medical_law"),(57,69, "medical_law"),(111,128, "medical_law"),(178,188, "medical_law"),(97,110, "medical_law"),(149,155, "medical_law"),(203,214, "medical_law"),(70,83, "medical_law")]}),
("czy testament sporządzony przez matkę klientki jest ważny",{"entities": [(4,13, "civil_law"),(32,37, "civil_law")]}),
("czy dzieci klienta powinny obecnie dokonać czynności zmierzających do zrzeczenia się ewentualnego dziedziczenia po zmarłym spadkodawcy",{"entities": [(85,97, "civil_law"),(115,122, "civil_law"),(98,111, "civil_law")]}),
("czy klienta będzie obowiązywać tajemnica lekarska podczas składania na piśmie zeznań przed sądem cywilnym",{"entities": [(71,77, "medical_law"),(58,67, "medical_law"),(78,84, "medical_law")]}),
("czy klient może iść na dyżur w trakcie kwarantanny",{"entities": [(23,28, "medical_law")]}),
("czy po uprawomocnieniu się postanowienia o umorzeniu postępowania pozwany może żądać zwrotu kwot ściągniętych w toku tej sprawy od kogo pozwany może żądać zwrotu kwot zajętych w postępowaniu egzekucyjnym czy oprócz żądania kwoty należności z postępowania egzekucyjnego można także żądać zwrotu kosztów egzekucyjnych czy uprawomocnienie się postanowienia o umorzeniu postępowania skutkuje tym że żadna z tych dwóch firm nie będzie mogła ponownie wystąpić z pozwem o to samo roszczenie",{"entities": [(167,175, "civil_law"),(92,96, "civil_law"),(162,166, "civil_law"),(379,387, "civil_law"),(43,52, "civil_law"),(356,365, "civil_law"),(302,315, "civil_law"),(66,73, "civil_law"),(136,143, "civil_law")]}),
("czy po podjęciu uchwały wspólnota mieszkaniowa będzie mogła skorygować zaliczki na poczet kosztów zarządu nieruchomością wspólną od stycznia  roku początek roku obrachunkowego",{"entities": [(106,120, "civil_law"),(16,23, "civil_law"),(71,79, "civil_law")]}),
("czy w związku z przedstawionym stanem faktycznym pracodawca może wypowiedzieć pracownicy umowę o pracę",{"entities": [(78,88, "labor_law")]}),
("czy pracodawca może zobowiązać klienta do pracy w godzinach nadliczbowych czy pracodawca może zobowiązać klienta do pracy w sobotę i niedzielę",{"entities": [(60,73, "labor_law")]}),
("czy klientka może prowadzić sprzedaż wysyłkową kosmetyków przez stronę internetową apteki",{"entities": [(47,57, "pharmaceutical_law"),(71,82, "pharmaceutical_law")]}),
("jak kształtuje się odpowiedzialność klienta za ewentualny błąd medyczny czy klient powinien udostępnić polisę pacjentce",{"entities": [(103,109, "medical_law"),(58,62, "medical_law")]}),
("co należy zrobić jeśli w sieci pojawią się opinie oczerniające lekarza",{"entities": [(31,38, "administrative_law"),(50,62, "administrative_law"),(25,30, "administrative_law"),(43,49, "administrative_law")]}),
("w jaki sposób można zabezpieczyć interesy klientki by mogła odziedziczyć mieszkanie po rodzicach",{"entities": [(60,72, "civil_law")]}),
("czy pacjenci mogą nagrywać lekarza podczas wizyty",{"entities": [(27,34, "criminal_law")]}),
("czy apteka może wystawić fakturę za zrealizowane recepty na pacjenta oraz leki dostępne bez recepty gdzie nabywcą jest sam pacjent ale płatnikiem dom opieki społecznej albo fundacja",{"entities": [(49,56, "tax_law"),(92,99, "tax_law"),(25,32, "tax_law"),(74,78, "tax_law"),(150,156, "tax_law"),(106,113, "tax_law"),(4,10, "tax_law")]}),
("czy klientka ma obowiązek pobierania od pacjentów zgody na przetwarzanie danych osobowych",{"entities": [(59,72, "administrative_law")]}),
("czy prawnie dopuszczalnym jest wprowadzenie możliwości głosowania elektronicznego przez internet przez członków wspólnoty mieszkaniowej mailowo lub przez odpowiedni program bez podpisu elektronicznego",{"entities": [(66,81, "civil_law"),(88,96, "civil_law"),(31,43, "civil_law")]}),
("jak przedstawia się kolejność dziedziczenia w przedmiotowej sprawie kiedy klientka może skutecznie odrzucić spadek",{"entities": [(99,107, "civil_law"),(30,43, "civil_law")]}),
("jakie są prawa i obowiązki klientki na przesłuchaniu w charakterze świadka",{"entities": [(0,5, "criminal_law"),(55,66, "criminal_law")]}),
("czy pracodawca może wysłać pracownika na badania okresowe w czasie epidemii czy pracodawca wybiera placówkę do przeprowadzenia badania okresowego z której pracownik zobowiązany jest skorzystać",{"entities": [(20,26, "labor_law"),(49,57, "labor_law")]}),
("jakie prawa i obowiązki ma klientka w związku z wezwaniem przez rzecznika odpowiedzialności zawodowej na przesłuchanie w charakterze świadka",{"entities": [(0,5, "criminal_law"),(121,132, "criminal_law"),(48,57, "criminal_law"),(64,73, "criminal_law"),(74,91, "criminal_law"),(105,118, "criminal_law")]}),
("czy klient może przekazać abw informacje na temat leczenia pacjenta",{"entities": [(16,25, "medical_law")]}),
("czy klientka może się odwołać od obniżenia premii do sądu pracy",{"entities": [(43,49, "labor_law")]}),
("czy klientka obecnie odpowiada za długi powstałe wskutek tego że jej matka nie płaci czynszu do spółdzielni czy po śmierci matki klientka będzie odpowiadała za długi powstałe za życia jej matki jeżeli przyjmie spadek lub go odrzuci",{"entities": [(123,128, "civil_law"),(188,193, "civil_law"),(79,84, "civil_law"),(34,39, "civil_law"),(160,165, "civil_law"),(85,92, "civil_law"),(210,216, "civil_law"),(40,48, "civil_law"),(166,174, "civil_law")]}),
("czy można pozbawić prawa własności osobę która otrzymała udział w nieruchomości w formie darowizny",{"entities": [(25,34, "civil_law")]}),
("czy klientka może być zobowiązana do pełnienia dyżurów medycznych w soboty czy klientka może pracować w szpitalu przez  godzin dziennie czy pracodawca może odmówić klientce wykorzystania urlopu z poprzednich lat jeśli tak to czy klientce należy się ekwiwalent na niewykorzystany urlop",{"entities": [(196,207, "medical_law"),(93,101, "medical_law"),(37,46, "medical_law"),(208,211, "medical_law"),(187,193, "medical_law"),(18,21, "medical_law")]}),
("czy obecnie lekarz ma obowiązek prowadzenia teleporad w formie wideo czy zwykła forma telefoniczna jest wystarczająca czy lekarz w dokumentacji medycznej sporządzanej w ramach teleporady ma obowiązek zawarcia elementu badanie w sytuacji w której teleporada świadczona jest telefonicznie a zatem  jak wskazuje klient  brak jest możliwości przeprowadzenia badania czy lekarz ma obowiązek weryfikowania tożsamości pacjenta na podstawie informacji o serii i numerze dowodu osobistego",{"entities": [(300,308, "administrative_law"),(104,117, "administrative_law")]}),
("czy możliwa jest zmiana przez pracodawcę wyznaczonego harmonogramugrafiku pracy",{"entities": [(17,23, "labor_law")]}),
("czy klient powinien podpisywać wydruk opisu badania diagnostycznego odręcznie",{"entities": [(31,37, "medical_law"),(38,43, "medical_law")]}),
("w jaki sposób przebiega odczytanie testamentu czym skutkuje wydziedziczenie testamentowe",{"entities": [(60,75, "civil_law"),(51,59, "civil_law"),(14,23, "civil_law"),(35,45, "civil_law")]}),
("czy klientka może samodzielnie pełnić dyżury na oddziale covidowym",{"entities": [(31,37, "medical_law")]}),
("czy klient może zostać powołany do pracy przy zwalczaniu epidemii czy przepisy określają co klient powinien zrobić z prowadzoną praktyką stomatologiczną",{"entities": [(79,88, "medical_law"),(128,136, "medical_law")]}),
("czy straż ochrony kolei może żądać od maszynistów dozoru opisanego w piśmie z dnia  maja  r",{"entities": [(57,66, "labor_law"),(84,88, "labor_law"),(38,49, "labor_law")]}),
("co powinna zrobić klientka  przyjąć spadek z dobrodziejstwem inwentarza czy go odrzucić jak i kiedy należy tego dokonać czy pełnoletnie dzieci klientki również powinny odrzucić spadek",{"entities": [(45,60, "civil_law"),(79,87, "civil_law"),(168,176, "civil_law"),(36,42, "civil_law"),(61,71, "civil_law")]}),
("czy klientka zobowiązana jest odbywać dyżury towarzyszące",{"entities": [(30,37, "medical_law")]}),
("jaka forma prawna przedsiębiorstwa pozwoli zatrudnić lekarza dentystę na podstawie umowy o pracę",{"entities": [(61,69, "medical_law"),(11,17, "medical_law")]}),
("czy w przedmiotowej sprawie doszło do skutecznego podjęcia uchwał czy zarządca ma obowiązek wykonać te uchwały",{"entities": [(59,65, "civil_law"),(70,78, "civil_law")]}),
("czy klientka może zapisać się na ldek",{"entities": [(18,25, "medical_law")]}),
("czy klientka może usunąć zęba pacjentce bez zgody rodzica",{"entities": [(30,39, "medical_law")]}),
("zgoda jakiego organu jest wymagana w niniejszej sytuacji",{"entities": [(26,34, "medical_law"),(0,5, "medical_law"),(14,20, "medical_law")]}),
("jakie są zasady oddelegowywania lekarzy rezydentów na oddział covidowy przez pracodawcę",{"entities": [(9,15, "medical_law"),(62,70, "medical_law")]}),
("czy na chwilę obecną klientka może zgłosić swojego męża do szczepienia przeciw covid w etapie pierwszym",{"entities": [(87,93, "medical_law"),(14,20, "medical_law")]}),
("czy wprowadzany porozumieniem zmieniającym warunki płacy i pracy pkt  ppkt  lit f umowy jest zgodny z prawem czy klientka musi podpisać porozumienie zmieniające",{"entities": [(51,56, "labor_law"),(16,29, "labor_law"),(136,148, "labor_law")]}),
("czy dyrektor szpitala może wymagać od lekarza podania listy pacjentów z podejrzeniem lub zdiagnozowanym covid których obsługiwał w celu uzasadnienia wypłacenia dodatku covidowego",{"entities": [(149,159, "medical_law"),(72,84, "medical_law"),(46,53, "medical_law")]}),
("jakie kroki prawne mogą podjąć osoby które nie chcą w swoim sąsiedztwie dyskotekiklubu nocnego ze względu na głośną i wulgarną muzykę oraz zniszczenia powstające przez uczestników zabawy",{"entities": [(47,51, "civil_law")]}),
("czy opisy badań diagnostycznych muszą sporządzane w formie elektronicznej",{"entities": [(10,15, "medical_law"),(32,37, "medical_law")]}),
("kto może złożyć zawiadomienie o możliwości popełnienia przestępstwa mając na uwadze iż przestępstwo te mogło zostać popełnione przez zarząd spółdzielni",{"entities": [(16,29, "criminal_law"),(43,54, "criminal_law"),(55,67, "criminal_law"),(9,15, "criminal_law")]}),
("czy w przedmiotowej sprawie rzecznik podlega odpowiedzialności karnej",{"entities": [(28,36, "medical_law")]}),
("czy klient może odbyć dyżury towarzyszące  i  listopada",{"entities": [(29,41, "medical_law")]}),
("czy istnieje możliwość poniesienia przez klientkę negatywnych konsekwencji w ramach postępowania dyscyplinarnego w związku z pomyłką technika farmacji",{"entities": [(50,61, "pharmaceutical_law"),(133,141, "pharmaceutical_law")]}),
("czy ośmioletnie dziecko może złożyć deklarację członkostwa w spółdzielni mieszkaniowej kogo należy powiadamiać o zebraniach opłatach etc w przypadku przyjęcia ośmioletniego dziecka do spółdzielni mieszkaniowej",{"entities": [(124,132, "civil_law")]}),
("czym różni się wiedza o popełnieniu czynu zabronionego od wiarygodnej informacji w tym przedmiocie czy psycholog jest zobowiązany do ustalenia wieku osoby z którą współżyła nastolatka czy jeżeli osoba z którą współżyła nastolatka nie ukończyła  roku życia psycholog ma obowiązek powiadomić organy ścigania czy jeżeli nastolatka chce dokonać aborcji nielegalnie psycholog jest zobowiązany do powiadomienia organów ścigania",{"entities": [(297,305, "criminal_law"),(70,80, "criminal_law"),(250,255, "criminal_law"),(328,332, "criminal_law"),(24,35, "criminal_law"),(133,142, "criminal_law"),(405,412, "criminal_law"),(333,340, "criminal_law"),(103,112, "criminal_law"),(256,265, "criminal_law"),(361,370, "criminal_law"),(36,41, "criminal_law"),(173,183, "criminal_law"),(219,229, "criminal_law"),(317,327, "criminal_law"),(163,172, "criminal_law"),(209,218, "criminal_law")]}),
("czy zarządca ma obowiązek udzielania firmom ubezpieczającym informacji dotyczących sprawcy szkody",{"entities": [(4,12, "civil_law")]}),
("jakie są prawa i obowiązki świadka w postępowaniu cywilnym czy klientka może odmówić stawienia sie na rozprawie w związku z wykupionymi biletami na samolot",{"entities": [(85,94, "medical_law")]}),
("czy można obecnie spożywać posiłki w restauracjach czy policjant może wylegitymować klienta restauracji",{"entities": [(55,64, "criminal_law")]}),
("czy możliwy jest rozwód w drodze ugody jak w przedstawionych okolicznościach doprowadzić do rozwodu",{"entities": [(77,88, "civil_law"),(17,23, "civil_law"),(33,38, "civil_law"),(4,11, "civil_law"),(26,32, "civil_law")]}),
("czy od  r administratorzy wspólnoty mieszkaniowej niezgodnie z prawem naliczali współwłaścicielom hali garażowej opłaty za partycypowanie w kosztach utrzymania nieruchomości wspólnej jeżeli tak to czy można domagać się zwrotu niesłusznie pobieranych od  r opłat za miejsca w garażu jeżeli odpowiedź na powyższe jest twierdząca czy można wówczas domagać się zapłaty od administratora wspólnoty mieszkaniowej",{"entities": [(174,182, "civil_law"),(149,159, "civil_law"),(98,102, "civil_law"),(140,148, "civil_law"),(103,112, "civil_law")]}),
("czy pracodawca może zobowiązać lekarza do pracy tylko w jednym miejscu czy pracownik może ponosić odpowiedzialność za niezastosowanie się do zarządzenia dyrektora czy pracodawca może żądać informacji w jakich miejscach pracują lekarze",{"entities": [(219,226, "labor_law"),(209,218, "labor_law")]}),
("czy pracodawca ma prawo oddelegować klienta do pracy przy kwalifikowaniu do szczepienia przeciw covid",{"entities": [(58,72, "medical_law")]}),
("jakie są koszty wniesienia pozwu jeśli klient skorzysta z ubezpieczenia ochrony prawnej czy jeśli rozstrzygnięcie będzie niekorzystne dla klienta koszty będą pokrywanez ubezpieczenia ochrony prawnej do jakiej kwoty ubezpieczyciel będzie pokrywał koszty czy zespół adwokatów i radców prawnych z lex secure podtrzymuje swoje stanowisko",{"entities": [(27,32, "civil_law")]}),
("czy postawienie przez właściciela lokalu blaszanego boxa na miejscu parkingowym w podziemnej hali garażowej wymaga podjęcia przez wspólnotę mieszkaniową uchwały jeżeli podział miejsc parkingowych wynika z umowy quoad usum",{"entities": [(130,139, "civil_law"),(183,195, "civil_law"),(22,33, "civil_law"),(93,97, "civil_law"),(168,175, "civil_law"),(153,160, "civil_law"),(140,152, "civil_law"),(98,107, "civil_law")]}),
("czy osoba która ukończyła staż podyplomowy ale nie zdała lekarskiego egzaminu końcowego posiada prawo do wykonywania zawodu lekarza",{"entities": [(69,77, "medical_law"),(78,87, "medical_law"),(26,30, "medical_law"),(31,42, "medical_law")]}),
("czy duża wspólnota mieszkaniowa składająca się z  lokali może podjąć uchwałę o powiększeniu wszystkich istniejących w danym budynku balkonów w liczbie  ze środków zgromadzonych na funduszu remontowym",{"entities": [(132,140, "civil_law"),(4,8, "civil_law"),(50,56, "civil_law"),(69,76, "civil_law")]}),
("czy szkolenie organizowane przez pracodawcę może się odbyć",{"entities": [(14,26, "medical_law"),(4,13, "medical_law")]}),
("w jaki sposób klientka może sprawdzić czy lokal nie jest zadłużony",{"entities": [(28,37, "civil_law")]}),
("czy żona klienta może ubiegać się o wypłatę środków z funduszu gwarantowanych świadczeń pracowniczych jakie warunki należy spełnić aby otrzymać takie świadczenie",{"entities": [(88,101, "labor_law")]}),
("czy status apteki może być aktywny z datą otwarcia apteki i rozpoczęcia sprzedaży tj  września br",{"entities": [(42,50, "pharmaceutical_law")]}),
("czy pracodawca może wezwać pracownika do pracy  dni przed końcem urlopu wypoczynkowego",{"entities": [(20,26, "labor_law")]}),
("czy lekarze rezydenci mogą żądać przeprowadzenia państwowego egzaminu specjalizacyjnego pes",{"entities": [(61,69, "medical_law"),(49,60, "medical_law"),(12,21, "medical_law"),(4,11, "medical_law"),(70,87, "medical_law")]}),
("czy fizjoterapeuta prowadzący indywidualną praktykę podlega obowiązkowi przeprowadzenia badań sanitarnoepidemiologicznych",{"entities": [(4,18, "medical_law"),(88,93, "medical_law")]}),
("czy lekarz dentysta może przepisać lek amantix zawierający siarczan amantadyny",{"entities": [(25,34, "pharmaceutical_law")]}),
("czy klient jest zobowiązany do zwrotu części wynagrodzenia której żąda szpital czy żona klienta zatrudniona w innym szpitalu przebywająca na urlopie macierzyńskim ma obowiązek zwrotu żądanej części wynagrodzenia",{"entities": [(183,190, "medical_law"),(96,107, "medical_law")]}),
("czy dyrektor szkoły specjalnej może zarządzić odbywanie zajęć stacjonarnie również dla klas",{"entities": [(46,55, "medical_law"),(56,61, "medical_law")]}),
("czy w przypadku wystawienia przez lekarza błędnej elektronicznej recepty ze  odpłatnością podczas gdy jest to lek refundowany pacjent może uzyskać refundację leku po okazaniu decyzji w aptece czy pacjent powinien udać się do lekarza po nową receptę",{"entities": [(114,125, "pharmaceutical_law"),(77,89, "pharmaceutical_law"),(147,157, "pharmaceutical_law")]}),
("czy czas przebywania na urlopie wychowawczym macierzyńskim lub zdrowotnym wlicza się w okres niewykonywania zawodu o którym mowa w ustawie o izbach aptekarskich",{"entities": [(131,138, "pharmaceutical_law")]}),
("czy dodatek do wynagrodzenia lekarza rezydenta z tytułu zobowiązania się do wykonywania zawodu lekarza na terytorium rzeczypospolitej polskiej w podmiocie wykonującym działalność leczniczą finansowaną ze środków publicznych po skończeniu specjalizacji przez określony czas tzw bon patriotyczny jest stały przez cały okres rezydentury czy też ulega zmianie co w sytuacji wydłużenia się rezydentury o np urlop rodzicielski w jakich podmiotach klient musiałby pracować aby spłacić bon na jakiej podstawie prawnej musiałby pracować czy klient mógłby zrezygnować z bonu lub go nie odpracować czy poniósłby za to jakieś konsekwencje czy zasady odpracowania bonu czy kary za jego nieodpracowanie mogłyby w przyszłości ulec zmianie",{"entities": [(402,407, "medical_law"),(576,586, "medical_law"),(212,223, "medical_law"),(631,637, "medical_law"),(457,465, "medical_law"),(519,527, "medical_law"),(578,586, "medical_law"),(49,55, "medical_law"),(448,456, "medical_law"),(510,518, "medical_law"),(106,116, "medical_law"),(145,154, "medical_law"),(281,293, "medical_law"),(268,272, "medical_law"),(277,280, "medical_law"),(478,481, "medical_law"),(322,333, "medical_law"),(385,396, "medical_law"),(370,380, "medical_law"),(546,557, "medical_law"),(560,564, "medical_law"),(651,655, "medical_law")]}),
("czy prokurator może zwolnić lekarza z tajemnicy zawodowej czy prokurator może zażądać wydania kopii dokumentacji medycznej od lekarza",{"entities": [(28,35, "criminal_law"),(20,27, "criminal_law"),(86,93, "criminal_law"),(4,14, "criminal_law"),(62,72, "criminal_law"),(113,122, "criminal_law")]}),
("czym jest instytucja interwenienta ubocznego",{"entities": [(10,20, "civil_law"),(21,34, "civil_law")]}),
("czy nfz powinien udzielić informacji których żąda klientka",{"entities": [(45,49, "administrative_law")]}),
("czy nową działkę należy włączyć do hipoteki czy klient powinien powiadomić o połączeniu bank",{"entities": [(35,43, "civil_law"),(9,16, "civil_law")]}),
("w jaki sposób klient powinien się zabezpieczyć przed odziedziczeniem długów po zmarłym wujku",{"entities": [(69,75, "civil_law"),(79,86, "civil_law"),(53,68, "civil_law")]}),
("kiedy partner może opuścić spółkę partnerską w jakim okresie roku kalendarzowego czy obowiązuje okres wypowiedzenia",{"entities": [(34,44, "civil_law"),(6,13, "civil_law")]}),
("jakie dokumenty klientka powinna obecnie złożyć aby zakończyć proces likwidacji spółki z oo",{"entities": [(62,68, "civil_law")]}),
("w jaki sposób mama klienta powinna przekazać własność mieszkania klientowi oraz bratu klienta aby skutkowało to jak najmniejszymi kosztami",{"entities": [(45,53, "civil_law"),(80,85, "civil_law"),(14,18, "civil_law")]}),
("jakie koszty wiążą się z dokonaniem darowizny udziału w nieruchomości przez byłego męża klientki",{"entities": [(36,45, "civil_law"),(25,35, "civil_law")]}),
("komu można powierzyć funkcję zastępcy kierownika apteki na czas krótszy niż  dni czy należy w związku z tym zawiadomić wojewódzkiego inspektora farmaceutycznego",{"entities": [(133,143, "pharmaceutical_law"),(119,132, "pharmaceutical_law"),(21,28, "pharmaceutical_law"),(29,37, "pharmaceutical_law")]}),
("czy z korespondencji z pacjentką wynika groźba w stosunku do klientki",{"entities": [(40,46, "criminal_law")]}),
("czy w przypadku śmierci wynajmującego umowa najmu wygasa czy z mocy prawa wstępując do niej następcy prawni wynajmującego a może umowa powinna w swojej treści wskazywać co dzieje się po śmierci wynajmującego",{"entities": [(24,37, "civil_law"),(108,121, "civil_law"),(172,178, "civil_law")]}),
("jakie są prawa i obowiązki klienta na przesłuchaniu w charakterze świadka",{"entities": [(0,5, "criminal_law"),(54,65, "criminal_law")]}),
("czy obowiązek posiadania kas fiskalnych online od  lipca  r dotyczy lekarzy i podmiotów leczniczych",{"entities": [(29,39, "tax_law"),(51,56, "tax_law"),(14,24, "tax_law"),(25,28, "tax_law"),(68,75, "tax_law"),(60,67, "tax_law")]}),
("czy wspólnota mieszkaniowa może podjąć uchwałę dotyczącą wykonania ocieplenia stropu całej powierzchni piwnicy obejmującą również sufity komórek lokatorskich",{"entities": [(111,121, "civil_law"),(103,110, "civil_law"),(67,77, "civil_law"),(47,56, "civil_law"),(78,84, "civil_law"),(39,46, "civil_law")]}),
("czy klientce może przysługiwać świadczenie postojowe za miesiąc w którym przez kilka dni pobierała zasiłek chorobowy czy zmniejszony obrót jest podstawą do ubiegania się o świadczenie postojowe",{"entities": [(156,165, "medical_law"),(31,42, "medical_law"),(172,183, "medical_law"),(56,63, "medical_law")]}),
("czy lekarz może odmówić pracy w przypadku braku odpowiedniej odzieży ochronnej i szkoleń z zakresu indywidualnej ochrony przed koronawirusem",{"entities": [(99,112, "medical_law")]}),
("w jaki sposób klientka może dowiedzieć się jakie zadłużenie wchodzi w skład spadku",{"entities": [(70,75, "civil_law"),(60,67, "civil_law")]}),
("czy do wykonania robót budowlanych w związku z przebudową części mieszkalnej budynku a także modernizacją elewacji budynku i umieszczeniem banerów reklamowych konieczna jest zgoda konserwatora zabytków",{"entities": [(17,22, "administrative_law"),(180,192, "administrative_law"),(23,34, "administrative_law"),(106,114, "administrative_law")]}),
("jakie pozwolenia należy uzyskać chcąc wybudować staw rybny o powierzchni ponad  ha",{"entities": [(38,47, "administrative_law"),(6,16, "administrative_law")]}),
("czy lekarz jest obowiązany do stwierdzenia zgonu pacjenta z którym nie miał wcześniej kontaktu",{"entities": [(43,48, "medical_law")]}),
("czy sklep może odmówić sprzedaży towarów osobom niezakrywającym nosa i ust",{"entities": [(64,68, "criminal_law"),(48,63, "criminal_law"),(33,40, "criminal_law"),(41,47, "criminal_law")]}),
("czy klient jest uprawniony do wykonania obdukcji pacjentki",{"entities": [(16,26, "medical_law"),(30,39, "medical_law")]}),
("czy klientka jako lekarz po  rż podlega obowiązkowi wprowadzeniu elektronicznej kasy fiskalnej czy są wyjątki na mocy których zastosowanie będą miały inne terminy wprowadzenia kas",{"entities": [(65,79, "tax_law"),(32,39, "tax_law")]}),
("czy żonie klienta przysługuje dodatek do wynagrodzenia za pracę w niedziele czy żonie klienta przysługuje dodatek do wynagrodzenia za pracę w systemie równoważnego czasu pracy",{"entities": [(151,163, "labor_law"),(66,75, "labor_law")]}),
("czy przedmiotowa inwestycja może być sfinansowana z funduszu remontowego czy jest możliwość zaciągnięcia kredytu w celu sfinansowania inwestycji czy należałoby stworzyć fundusz celowy",{"entities": [(61,72, "civil_law")]}),
("w jaki sposób klientka może odrzucić spadek",{"entities": [(28,36, "civil_law")]}),
("w jaki sposób gabinet lekarski klienta może sprowadzić preparaty witaminowe z innego kraju unii europejskiej które nie są dopuszczone do obrotu w polsce",{"entities": [(44,54, "pharmaceutical_law"),(137,143, "pharmaceutical_law"),(55,64, "pharmaceutical_law"),(65,75, "pharmaceutical_law")]}),
("czy z powodu niewypłacalności męża klientki jego rodzina np dziadkowie może zostać zobowiązana do płacenia alimentów na rzecz jego dziecka",{"entities": [(98,106, "civil_law"),(49,56, "civil_law"),(107,116, "civil_law")]}),
("czy klientka po śmierci swojego brata będzie zobowiązana do zapłaty zachowku na rzecz żyjącej córki brata czy na skutek darowania udziału w prawie własności nieruchomości synowi klientka będzie miała jakieś obowiązki względem swojej córki",{"entities": [(113,119, "civil_law"),(171,177, "civil_law"),(68,76, "civil_law"),(140,146, "civil_law"),(147,156, "civil_law")]}),
("czy wspólnota mieszkaniowa może żądać od właścicielki lokalu doprowadzenia jej balkonu do wyglądu zbieżnego z pozostałymi balkonami w budynku",{"entities": [(79,86, "civil_law"),(110,121, "civil_law")]}),
("czy klient może wykonywać znieczulenia na oddziale chirurgii jeżeli nie jest zatrudniony jako anestezjolog na oddziale anestezjologicznym",{"entities": [(77,88, "medical_law"),(26,38, "medical_law")]}),
("czy umowa o pracę została skutecznie wypowiedziana czy zwolnienie lekarskie wpływa na skuteczność wypowiedzenia",{"entities": [(37,50, "labor_law"),(86,97, "labor_law")]}),
("w jakim zakresie pracodawca może zmienić pracownicy zakres obowiązków czy stanowisko nie zmniejszając wynagrodzenia jeżeli pracownica zawnioskuję o przerwę na karmienie dziecka czy pracodawca może się nie zgodzić na ustawienie tej przerwy na koniec dnia pracy",{"entities": [(41,51, "labor_law"),(205,212, "labor_law"),(159,168, "labor_law")]}),
("czy wykonanie badania ekg może przeprowadzić osoba niebędąca pielęgniarką a pracująca w szpitalu np farmaceuta",{"entities": [(4,13, "medical_law")]}),
("jaką procedurę należy rozpocząć i kto ma ją przeprowadzić aby ustalić czy są jacyś spadkobiercy po zmarłym",{"entities": [(62,69, "civil_law"),(83,95, "civil_law")]}),
("czy pracodawca miał prawo wypowiedzieć umowę o pracę zawartą na czas określony czy pracodawca ma możliwość zmuszenia pracownika do wykorzystania przysługującego mu urlopu wypoczynkowego",{"entities": [(53,60, "labor_law"),(145,160, "labor_law"),(107,116, "labor_law")]}),
("czy dzieci klienta powinny obecnie dokonać czynności zmierzających do zrzeczenia się ewentualnego dziedziczenia po zmarłym spadkodawcy",{"entities": [(85,97, "civil_law"),(115,122, "civil_law"),(98,111, "civil_law")]}),
("czy zakład opiekuńczoleczniczy dalej zol może przyjąć chorego niezdolnego do wyrażenia świadomej woli przed uzyskaniem zgody sądu co należy zrobić w sytuacji gdy pacjent został przyjęty do zol przed uzyskaniem zgody sądu a rodzina chce zabrać chorego do domu",{"entities": [(108,118, "medical_law"),(199,209, "medical_law"),(87,96, "medical_law"),(77,86, "medical_law"),(54,61, "medical_law"),(243,250, "medical_law"),(46,53, "medical_law"),(37,40, "medical_law"),(189,192, "medical_law")]}),
("czy klient powinien ponosić koszty odstąpienia od umowy o imprezę turystyczną",{"entities": [(20,27, "medical_law")]}),
("jakie są prawa i obowiązki klientki na przesłuchaniu w charakterze świadka czy ze świadka klientka może stać się podejrzaną lub oskarżoną w sprawie",{"entities": [(0,5, "criminal_law"),(67,74, "criminal_law"),(82,89, "criminal_law"),(55,66, "criminal_law")]}),
("czy viregytk może być sprzedawany w ramach recepty ze  odpłatnością",{"entities": [(4,12, "pharmaceutical_law"),(22,33, "pharmaceutical_law")]}),
("czy w przedmiotowej sprawie ubezpieczyciel kierowcy będzie mógł domagać się regresu od syna klientki jakie kroki w przedmiotowej sprawie powinna podjąć klientka",{"entities": [(43,51, "administrative_law"),(52,58, "administrative_law")]}),
("czy właściciel mieszkania mógł przekazać sprawy mieszkania i dane osobowe klientki agencji nieruchomości czy klientka może wydać mieszkanie nieznanemu pracownikowi agencji nieruchomości",{"entities": [(83,90, "administrative_law"),(164,171, "administrative_law"),(66,73, "administrative_law")]}),
("czy apteka może sprzedać testy na covid do domu dziecka",{"entities": [(25,30, "pharmaceutical_law")]}),
("czy w przypadku pozytywnego wyniku badania na przeciwciała igg i igm należy zgłosić ten fakt do sanepidu",{"entities": [(28,34, "medical_law")]}),
("czy klient ma podstawy do ubiegania się o wypłatę tzw dodatku covidowego",{"entities": [(14,22, "medical_law"),(26,35, "medical_law")]}),
("jak powinno wyglądać rozliczenie finansowe koordynatora oddziału rehabilitacji jeżeli oddział jest obecnie oddziałem dla pacjentów zakażonych covid czy w obecnej sytuacji wypowiedzenie złożone przez klientkę jest skuteczne",{"entities": [(107,116, "medical_law"),(21,32, "medical_law"),(4,11, "medical_law"),(56,64, "medical_law"),(154,161, "medical_law"),(131,141, "medical_law")]}),
("czy obecnie pracodawca ma możliwość wydania klientce polecenia dotyczącego pełnienia samodzielnego dyżuru medycznego na innym oddziale podmiotu leczniczego",{"entities": [(75,84, "medical_law"),(99,105, "medical_law"),(85,98, "medical_law")]}),
("jakie są zasady oddelegowywania lekarzy rezydentów na oddział covidowy przez pracodawcę",{"entities": [(9,15, "medical_law"),(62,70, "medical_law")]}),
("czy w świetle obowiązujących przepisów dot covid możliwe jest zorganizowanie zebrania członków dużej wspólnoty mieszkaniowej",{"entities": [(77,85, "civil_law")]}),
("czy prawnie dopuszczalnym jest wprowadzenie możliwości głosowania elektronicznego przez internet przez członków wspólnoty mieszkaniowej mailowo lub przez odpowiedni program bez podpisu elektronicznego",{"entities": [(66,81, "civil_law"),(88,96, "civil_law"),(31,43, "civil_law")]}),
("czy po powrocie któryś z członków rodziny może zostać objęty kwarantanną",{"entities": [(25,33, "medical_law"),(54,60, "medical_law")]}),
("w jakim sądzie należy złożyć wniosek o ubezwłasnowolnienie jakie dokumenty należy dostarczyć do sądu aby orzekł o ubezwłasnowolnieniu",{"entities": [(8,14, "civil_law")]}),
("w jaki sposób klient może się zabezpieczyć na okoliczność że swój obowiązek alimentacyjny wobec byłej żony i córki wykonuje poprzez opłacanie należności za mieszkanie w którym uprawnione do alimentów mieszkają",{"entities": [(96,101, "civil_law"),(190,199, "civil_law"),(176,186, "civil_law")]}),
("czy lekarz może wnosić o zapłatę za stwierdzenie zgonu jeżeli jego umowa o pełnienie dyżurów medycznych nie przewiduje takich obowiązków",{"entities": [(49,54, "medical_law"),(75,84, "medical_law")]}),
("czy w związku z przedstawionym stanem faktycznym klientka może skorzystać z częściowego przestoju ekonomicznego",{"entities": [(88,97, "labor_law")]}),
("czy pracownik może złożyć wypowiedzenie umowy o pracę podczas przebywania na zwolnieniu lekarskim jakie są możliwości rozwiązania umowę o pracę i co się dzieje z niewykorzystanym urlopem wypoczynkowym czy nagana musi być zawarta w treści świadectwa pracy od jakiego momentu rozpoczyna się okres wypowiedzenia umowy o pracę czy jest to moment wysłania pisma czy jego odebrania",{"entities": [(187,200, "labor_law"),(162,178, "labor_law"),(179,186, "labor_law")]}),
("czy klient może samodzielnie opisywać i zatwierdzać badania rentgenowskie oraz badania tomografii komputerowej bez nadzoru lekarza specjalisty",{"entities": [(87,97, "medical_law"),(60,73, "medical_law"),(98,110, "medical_law"),(29,37, "medical_law")]}),
("czy zakres ubezpieczenia odpowiedzialności cywilnej lekarzy farmaceutów i innych osób świadczących usługi o charakterze medycznym tu ergo hestia obejmuje swoim zakresem szkody wynikłe z przeniesienia wirusa sarscov czy pracodawca może zmusić lekarza do wykonywania świadczeń planowych który odmówił wykonania zabiegu z uwagi na zagrożenie epidemiologiczne",{"entities": [(60,71, "medical_law"),(309,316, "medical_law"),(200,206, "medical_law"),(235,241, "medical_law"),(207,214, "medical_law"),(319,324, "medical_law"),(74,80, "medical_law"),(299,308, "medical_law")]}),
("czy w przypadku braku specjalisty na oddziale lekarz rezydent może nie opisać badania rtg wykonanego w związku z wypadkiem drogowym lub udarem pacjenta czy lekarz specjalista który kończy godzinny dyżur może opuścić miejsce pracy w przypadku braku osoby która przejmie oddział czy lekarz rezydent ma obowiązek stawienia się na dyżur przewidziany w grafiku jeżeli na oddziale w tym czasie nie będzie lekarza specjalisty",{"entities": [(22,33, "medical_law"),(197,202, "medical_law"),(327,332, "medical_law"),(310,319, "medical_law"),(163,174, "medical_law"),(53,61, "medical_law"),(288,296, "medical_law")]}),
("jak powinien wyglądać zapis przeniesienia zezwolenia na prowadzenie apteki w umowie sprzedaży czy można za pomocą jednej umowy sprzedać aptekę oraz punkt apteczny",{"entities": [(148,153, "pharmaceutical_law"),(136,142, "pharmaceutical_law"),(42,52, "pharmaceutical_law"),(22,27, "pharmaceutical_law")]}),
("czy tablica może być umieszczona w innym miejscu niż to wskazuje zdjęcie tj zamiast po prawej stronie okna to po lewej stronie okna",{"entities": [(56,64, "administrative_law"),(102,106, "administrative_law")]}),
("czy w ramach aptek prowadzonych pod jednym numerem nip można dokonywać przesunięć leków z grupy p psychotropowych",{"entities": [(43,50, "pharmaceutical_law"),(13,18, "pharmaceutical_law"),(71,81, "pharmaceutical_law"),(19,31, "pharmaceutical_law"),(51,54, "pharmaceutical_law")]}),
("czy farmaceuta działający w mediach społecznościowych np instagram może promować lub lokować produkty konkretnych suplementów diety na swoich profilach",{"entities": [(28,35, "pharmaceutical_law"),(36,53, "pharmaceutical_law")]}),
("czy klient może odmówić udania się w delegację z uwagi na stan epidemii",{"entities": [(24,30, "labor_law")]}),
("jakie są prawa i obowiązki klienta w związku z wezwaniem do stawiennictwa na przesłuchanie w charakterze podejrzanego",{"entities": [(0,5, "criminal_law"),(60,73, "criminal_law"),(93,104, "criminal_law"),(47,56, "criminal_law"),(77,90, "criminal_law")]}),
("czy nowa właścicielka nieruchomości powinna wystąpić do sądu z wnioskiem o eksmisję czy przepisy o covid chronią klienta przed eksmisją czy eksmisji powinny dokonać organy policji",{"entities": [(9,21, "civil_law"),(140,148, "civil_law")]}),
("czy zdaniem zespołu prawników z lex secure istnieją wątpliwości dotyczące zgodności ustawy o systemie informacji w ochronie zdrowiaz innymi aktami prawnymi np z konstytucją w zakresie praw obywateli do prywatności i ochrony ich dóbr osobistych",{"entities": [(93,101, "medical_law"),(52,63, "medical_law")]}),
("jakie są zasady ustalania tzw dodatku covidowego i w jaki sposób można dochodzić jego wypłacenia",{"entities": [(9,15, "medical_law"),(16,25, "medical_law"),(38,48, "medical_law")]}),
("czy klientce przysługuje prawo do otrzymywania dodatku covidowego za okres w którym przebywa na zwolnieniu lekarskim",{"entities": [(55,65, "medical_law")]}),
("czy wspólnota może zakazać klientce wjazdu na parking na nieruchomości wspólnej",{"entities": [(36,42, "civil_law")]}),
("czy możliwym jest darowanie kwoty  zł czy jeżeli obdarowana jest córką darczyńcy powstanie konieczność uiszczenia podatku od darowizn",{"entities": [(18,27, "civil_law"),(103,113, "civil_law"),(4,12, "civil_law")]}),
("w jaki sposób dzielony jest spadek po zmarłej babci w jakim czasie po śmierci spadkodawcy należy podjąć kroki prawne jakie formalności i gdzie należy dopełnić jakie opłaty się z tym wiążą",{"entities": [(28,34, "civil_law"),(78,89, "civil_law"),(46,51, "civil_law")]}),
("czy w związku z ostatnimi zmianami przepisów co do uprawnień wymaganych przy zakupie ziemi rolnej klient mimo że posiadał wcześniej ziemię rolną poniżej  ha musi posiadać aktualne uprawnienia wykonany kurs do zakupu ziemi rolnej",{"entities": [(139,144, "administrative_law"),(91,97, "administrative_law"),(26,34, "administrative_law"),(113,121, "administrative_law"),(85,90, "administrative_law"),(216,221, "administrative_law")]}),
("czy osoba która nie jest farmaceutą może być wspólnikiem spółki jawnej prowadzącej aptekę czy zmiana w strukturze właścicielskiej spółki pociąga za sobą konieczność uzyskania nowej koncesji",{"entities": [(83,89, "pharmaceutical_law"),(114,129, "pharmaceutical_law"),(137,144, "pharmaceutical_law"),(103,113, "pharmaceutical_law"),(71,82, "pharmaceutical_law")]}),
("dlaczego i w jakim zakresie zespół adwokatów i radców prawnych lex secure skontaktował się przy wydawaniu poprzedniej opinii dla klientki z okręgową izbą lekarską w warszawie czy decyzja wydana przez okręgowego rzecznika odpowiedzialności zawodowej oraz wyrok okręgowego sądu lekarskiego jest ostateczna czy klientka przedstawiając dowody w postaci nagrań może być przekonana że zostaną one przyjęte w charakterze dowodu oraz nie że klientka nie zostanie ukarana za ich przedstawienie",{"entities": [(54,62, "criminal_law"),(402,413, "criminal_law"),(118,124, "criminal_law"),(165,174, "criminal_law"),(211,220, "criminal_law"),(221,238, "criminal_law"),(276,287, "criminal_law"),(200,210, "criminal_law"),(260,270, "criminal_law")]}),
("czy klient jest uprawniony do wykonania obdukcji pacjentki",{"entities": [(16,26, "medical_law"),(30,39, "medical_law")]}),
("czy obecnie wspólnota mieszkaniowa może się domagać opłat od tauron dystrybucje za korzystanie przez nich z przedmiotowej skrzynki",{"entities": [(83,94, "civil_law")]}),
("jakie przepisy prawa obligują byłego zarządcę do przekazania dokumentacji wspólnoty mieszkaniowej",{"entities": [(49,60, "civil_law"),(21,29, "civil_law"),(37,45, "civil_law")]}),
("czy istnieją przepisy które regulują skuteczność bądź formę wprowadzenia opisanego przez klienta rozwiązania  przesyłania pracownikom poleceń drogą mailową",{"entities": [(54,59, "labor_law"),(73,82, "labor_law"),(37,48, "labor_law")]}),
("czy właściciel który chce przekształcić lokal z mieszkalnego na użytkowy musi mieć zgodę wspólnoty w postaci uchwały",{"entities": [(26,39, "civil_law")]}),
("jakie prawa i obowiązki ma klientka w związku z wezwaniem przez rzecznika odpowiedzialności zawodowej na przesłuchanie w charakterze świadka",{"entities": [(0,5, "criminal_law"),(121,132, "criminal_law"),(48,57, "criminal_law"),(64,73, "criminal_law"),(74,91, "criminal_law"),(105,118, "criminal_law")]}),
("czy pracownik apteki posiadający specjalizację i stopnia ma tytuł specjalisty",{"entities": [(21,32, "pharmaceutical_law")]}),
("jakie są prawa i obowiązki klientki na przesłuchaniu w charakterze świadka prowadzonegow ramach postępowania karnego",{"entities": [(0,5, "criminal_law"),(67,74, "criminal_law"),(55,66, "criminal_law")]}),
("czy pracując na podstawie tejże umowy o pracę klient może podjąć pracę w innej aptece na podstawie umowy zlecenia w świetle przepisów o zakazie konkurencji",{"entities": [(136,143, "labor_law")]}),
("czy klient ma obowiązek stawić się w prokuraturze w związku z faktem że przebywa na zwolnieniu lekarskim",{"entities": [(84,94, "criminal_law"),(72,80, "criminal_law"),(37,49, "criminal_law")]}),
("czy postawienie przez właściciela lokalu blaszanego boxa na miejscu parkingowym w podziemnej hali garażowej wymaga podjęcia przez wspólnotę mieszkaniową uchwały jeżeli podział miejsc parkingowych wynika z umowy quoad usum",{"entities": [(130,139, "civil_law"),(183,195, "civil_law"),(22,33, "civil_law"),(93,97, "civil_law"),(168,175, "civil_law"),(153,160, "civil_law"),(140,152, "civil_law"),(98,107, "civil_law")]}),
("jakie są podstawy odpowiedzialności lekarza prowadzącego indywidualną praktykę lekarską",{"entities": [(9,17, "medical_law"),(44,56, "medical_law")]}),
("czy klient jest zobowiązany do przestrzegania jakichkolwiek rekomendacji pochodzących nie od właścicieli apteki a wychodzących od zarządu sieci franczyzowej czy pracodawca może nakazać klientowi i innym pracownikom noszenie maseczek dokonywanie pomiaru temperatury i tym podobnych działań w ramach walki z epidemią",{"entities": [(130,137, "labor_law"),(271,280, "labor_law"),(298,303, "labor_law")]}),
("czy klient jako farmaceuta może zostać zatrudniony w ramach stażu z urzędu pracy z wynagrodzeniem niższym niż minimalne",{"entities": [(83,97, "labor_law")]}),
("czy obecnie istnieje obowiązek poinformowania właścicieli sąsiednich nieruchomości o wydaniu decyzji zmieniającej decyzję o pozwoleniu na budowę na sąsiedniej nieruchomości",{"entities": [(138,144, "administrative_law"),(124,134, "administrative_law"),(148,158, "administrative_law")]}),
("w jaki sposób mama klienta powinna przekazać własność mieszkania klientowi oraz bratu klienta aby skutkowało to jak najmniejszymi kosztami",{"entities": [(45,53, "civil_law"),(80,85, "civil_law"),(14,18, "civil_law")]}),
("czy żona klienta może podważyć pozytywną opinię opiniodawczego zespołu sądowych specjalistów",{"entities": [(71,79, "civil_law")]}),
("jaką specjalizację należy posiadać na stanowisku starszego asystenta farmaceutycznego",{"entities": [(0,4, "medical_law"),(38,48, "medical_law")]}),
("czy klientka obecnie odpowiada za długi powstałe wskutek tego że jej matka nie płaci czynszu do spółdzielni czy po śmierci matki klientka będzie odpowiadała za długi powstałe za życia jej matki jeżeli przyjmie spadek lub go odrzuci",{"entities": [(123,128, "civil_law"),(188,193, "civil_law"),(79,84, "civil_law"),(34,39, "civil_law"),(160,165, "civil_law"),(85,92, "civil_law"),(210,216, "civil_law"),(40,48, "civil_law"),(166,174, "civil_law")]}),
("z czym wiąże się zadaniowy system czasu pracy czy zadaniowy system czasu pracy powinien zostać uwzględniony w umowie o pracę czy możliwe jest podpisanie umowy o pracę z późniejszym terminem rozpoczęcia jej wykonywania np miesiąc później",{"entities": [(181,189, "labor_law"),(17,26, "labor_law"),(50,59, "labor_law"),(142,152, "labor_law"),(169,180, "labor_law")]}),
("czy klientka może cofnąć wypowiedzenie umowy o pracę rezydentura czy wojewoda musi wyznaczyć inne miejsce odbywania rezydentury jeżeli lekarz medycyny pracy stwierdzi że klientka nie może pracować w szpitalu covidowym w wielkopolsce",{"entities": [(69,77, "medical_law"),(188,196, "medical_law"),(83,92, "medical_law"),(18,24, "medical_law"),(116,127, "medical_law")]}),
("czy pracodawca może zobowiązać pracowników do wykorzystania zaległych urlopów wypoczynkowych jeżeli nie były przewidziane w planie urlopowym",{"entities": [(78,92, "labor_law"),(70,77, "labor_law"),(60,69, "labor_law")]}),
("kto powinien zarejestrować się w centralnym rejestrze podmiotów akcyzowych  klientka jako osoba prywatna czy spółka jawna",{"entities": [(90,95, "tax_law"),(109,115, "tax_law"),(64,74, "tax_law")]}),
("czy klientowi który jest na emeryturze przysługuje wyższa ulga podatkowa w związku z podwyższeniem maksymalnej kwoty jaką można wpłacić na ikze",{"entities": [(111,116, "tax_law"),(122,127, "tax_law"),(75,82, "tax_law"),(39,50, "tax_law"),(28,38, "tax_law"),(63,72, "tax_law")]}),
("czy wnioski z opinii o sygn  są aktualne w świetle przepisów rozporządzenia ministra zdrowia w sprawie chorób zakaźnych powodujących powstanie obowiązku hospitalizacji izolacji lub izolacji w warunkach domowych oraz obowiązku kwarantanny lub nadzoru epidemiologicznego",{"entities": [(76,84, "medical_law"),(120,132, "medical_law"),(202,210, "medical_law")]}),
("czy klient jest zobowiązany do prowadzenia elektronicznej dokumentacji medycznej od  lipca  r czy zleceniodawca klienta może zobowiązać klienta do prowadzenia elektronicznej dokumentacji medycznej jakie sankcje dla podmiotu leczniczego wiążą się z niezachowaniem obowiązku prowadzenia elektronicznej dokumentacji medycznej",{"entities": [(236,241, "medical_law"),(92,93, "medical_law")]}),
("czy wykreślenie niektórych zapisów przepisu o ochronie danych osobowych w załączonym pliku jest zgodne z prawem",{"entities": [(46,54, "administrative_law"),(35,43, "administrative_law")]}),
("czy członek wspólnoty jest zobowiązany do uiszczania zaliczki inwestycyjnoremontowej mimo że w planie gospodarczym wspólnota na bieżący rok i następny nie planuje żadnych remontów",{"entities": [(53,61, "civil_law")]}),
("jakie możliwości ma klient w związku z uporczywą wymianą sprzętu na kolejne posiadające wady egzemplarze",{"entities": [(68,75, "civil_law"),(88,92, "civil_law")]}),
("czy pracownikowi przysługuje urlop szkoleniowy w wymiarze  dni",{"entities": [(4,16, "labor_law")]}),
("czy pracodawca może zobowiązać pracowników do wykorzystania urlopów wypoczynkowych jeżeli nie były przewidziane w planie urlopowym",{"entities": [(68,82, "labor_law"),(60,67, "labor_law")]}),
("czy klient może odmówić przyjęcia pacjenta z uwagi na to że kwestionuje on metody leczenia klienta i nie można z nim dojść do porozumienia",{"entities": [(24,33, "medical_law"),(45,50, "medical_law")]}),
("czy klient może podważyć wiarygodność sporządzonych przez siebie oświadczeń czy prokurator miał prawo odmówić podjęcia czynności w sprawie przeciwko małżonce klienta czy przedstawione okoliczności mogą wpłynąć na decyzję sądu w zakresie złagodzenia kary jeżeli klient dobrowolnie podda się karze",{"entities": [(91,95, "criminal_law"),(80,90, "criminal_law"),(119,128, "criminal_law")]}),
("czy hurtownia farmaceutyczna może nabywać i zbywać sprzęt medyczny który nie jest wyrobem medycznym",{"entities": [(51,57, "pharmaceutical_law"),(44,50, "pharmaceutical_law")]}),
("czy w świetle postanowień umowy o pracę przesłanej przez klientkę pracodawca może polecić pracownikowi wykonywanie pracy w obydwu lokalizacjach w których znajduje się szpital",{"entities": [(154,162, "labor_law"),(90,102, "labor_law")]}),
("czy klientowi przysługuje dodatek za pracę w jednym miejscu na podstawie rozporządzenia ministra zdrowia z dnia  kwietnia  r w sprawie standardów w zakresie ograniczeń przy udzielaniu świadczeń opieki zdrowotnej pacjentom innym niż z podejrzeniem lub zakażeniem wirusem sarscov przez osoby wykonujące zawód medyczny mające bezpośredni kontakt z pacjentami z podejrzeniem lub zakażeniem tym wirusem",{"entities": [(88,96, "medical_law"),(323,334, "medical_law"),(251,261, "medical_law"),(375,385, "medical_law"),(262,269, "medical_law"),(173,183, "medical_law"),(157,167, "medical_law"),(123,124, "medical_law"),(335,342, "medical_law"),(270,277, "medical_law"),(135,145, "medical_law"),(345,355, "medical_law"),(45,51, "medical_law"),(234,246, "medical_law"),(358,370, "medical_law")]}),
("czy klientka podejmując pracę w hurtowni farmaceutycznej wykonywać będzie nadal zawód farmaceuty czy podejmując pracę w innym województwie należy zmienić właściwą izbę aptekarską",{"entities": [(32,40, "pharmaceutical_law"),(13,23, "pharmaceutical_law"),(101,111, "pharmaceutical_law"),(41,56, "pharmaceutical_law"),(163,167, "pharmaceutical_law")]}),
("czy bank powinien zwrócić klientce proporcjonalną część kosztów prowizji kredytu",{"entities": [(35,49, "administrative_law"),(64,72, "administrative_law")]}),
("jak powinno wyglądać zawiadomienie o zebraniu wspólnoty mieszkaniowej",{"entities": [(37,45, "civil_law")]}),
("w jaki sposób powinno zostać podniesione wynagrodzenie pracowników w związku z podniesieniem wysokości minimalnego wynagrodzenia za pracę",{"entities": [(103,114, "labor_law")]}),
("jakie możliwości ma klient w związku z uporczywą wymianą sprzętu na kolejne posiadające wady egzemplarze",{"entities": [(68,75, "civil_law"),(88,92, "civil_law")]}),
("czy zarządca ma obowiązek udzielania firmom ubezpieczającym informacji dotyczących sprawcy szkody",{"entities": [(4,12, "civil_law")]}),
("jak obecnie wyglądają regulacje dotyczące przyjmowania pacjenta małoletniego przez lekarza bez obecności opiekuna prawnego oraz wyrażania zgody przez takiego pacjenta oraz jego opiekuna jak również pacjenta który ukończył  rok życia",{"entities": [(12,21, "medical_law"),(64,76, "medical_law"),(42,54, "medical_law"),(213,221, "medical_law"),(95,104, "medical_law"),(105,113, "medical_law"),(177,185, "medical_law")]}),
("czy dyrektor szpitala może wymagać od lekarza podania listy pacjentów z podejrzeniem lub zdiagnozowanym covid których obsługiwał w celu uzasadnienia wypłacenia dodatku covidowego",{"entities": [(149,159, "medical_law"),(72,84, "medical_law"),(46,53, "medical_law")]}),
("czy w przypadku sprzedaży na kwotę do  złotych apteka może wystawić standardową fakturę vat czy musi wystawić tzw paragon z nip",{"entities": [(68,79, "tax_law"),(80,87, "tax_law"),(29,34, "tax_law"),(47,53, "tax_law"),(16,25, "tax_law")]}),
("w jaki sposób klient może dowodzić iż wskazane przez jego byłą żonę dochody są zaniżone",{"entities": [(58,62, "civil_law")]}),
("w jaki sposób klient ma przekazać dokumentację medyczną co stanowi art   a kodeksu karnego",{"entities": [(34,46, "criminal_law"),(75,82, "criminal_law"),(59,66, "criminal_law"),(47,55, "criminal_law")]}),
("czy klientka może pracować w innych miejscach",{"entities": [(18,26, "medical_law"),(29,35, "medical_law")]}),
("czy przychodnia może zaszczepić z pozostałych szczepionek pracowników medycznych spoza placówki zapisanych na szczepienie ale nie mających skierowania w systemie kto odpowiada za zachowanie kolejności szczepień zgodnie z planem",{"entities": [(110,121, "medical_law"),(4,15, "medical_law"),(58,69, "medical_law"),(21,31, "medical_law"),(153,161, "medical_law"),(201,210, "medical_law"),(130,138, "medical_law")]}),
("czy sąd jest zobowiązany poinformować poradnię o obowiązku poddania się terapii w danej placówce przez pacjenta",{"entities": [(4,7, "criminal_law"),(25,37, "criminal_law")]}),
("czy klient zobowiązany jest do ujawnienia pracodawcy informacji o swoich miejscach pracy",{"entities": [(73,82, "labor_law")]}),
("czy do dokonania podziału nieruchomości lokalowej mieszkalnej na lokal użytkowy i mieszkalny wymagana jest uchwała o wyrażeniu zgody wspólnoty mieszkaniowej gdyby uchwała wspólnoty była konieczna  czy w sytuacji ustalania wielkości udziałów w częściach wspólnych nieruchomości istnieje możliwość prawnego zobligowania do tego członka wspólnoty który nie wyraził by na to zgody jakie dokumenty oprócz przedstawionych powinna przygotować klientka do dokonania podziału nieruchomości u notariusza czy podczas jednego spotkania u notariusza klientka może dokonać podziału lokalu oraz przekazania własności jednego z nich poprzez darowiznę",{"entities": [(253,262, "civil_law"),(17,25, "civil_law"),(458,466, "civil_law"),(559,567, "civil_law"),(580,591, "civil_law"),(7,16, "civil_law"),(448,457, "civil_law"),(483,493, "civil_law"),(526,536, "civil_law"),(232,240, "civil_law"),(243,252, "civil_law"),(592,601, "civil_law")]}),
("czy klient może jakoś zmusić zarządcę wspólnoty do ścięcia zaniedbanej trawy",{"entities": [(29,37, "civil_law")]}),
("jak długo apteka musi pozostać zamknięta po jej sprzedaży w jakim terminie inspektorat sanitarny powinien rozpoznać wniosek o przeniesienie zezwolenia na prowadzenie apteki ogólnodostępnej",{"entities": [(140,150, "pharmaceutical_law"),(126,139, "pharmaceutical_law"),(31,40, "pharmaceutical_law")]}),
("co pozwany może zrobić gdyby sąd umorzył postępowanie w którym zapadł wyrok zaoczny i jednocześnie uchylił ten wyrok a przed uchyleniem doszłoby do wyegzekwowania całości należności zasądzonej przez komornika na podstawie wyroku zaocznego zaopatrzonego w klauzulę natychmiastowej wykonalności jakie prawa ma wówczas pozwany czy w takim przypadku pozwany może dochodzić zwrotu od klienta kwot wyegzekwowanych oraz czy klient powinien w takiej sytuacji złożyć ponownie tożsamy pozew",{"entities": [(199,208, "civil_law"),(387,391, "civil_law"),(163,170, "civil_law"),(3,10, "civil_law"),(316,323, "civil_law"),(346,353, "civil_law")]}),
("kto jest uprawniony do reprezentacji wspólnoty mieszkaniowej  uprawniony do wysłania wezwania do zapłaty wysłania wniosku o udostępnienie danych do cepiku złożenia pozwu w imieniu wspólnoty jakie dokumenty powinny stanowić dowód w postępowaniu sądowym",{"entities": [(164,169, "civil_law")]}),
("w jaki sposób dokonać przepisania udziału męża klientki we własności nieruchomości na dzieci klientki w jaki sposób klientka może przejąć dług męża",{"entities": [(59,68, "civil_law")]}),
("czy klient jest obowiązany poinformować pracodawcę o zamiarze podjęcia dodatkowego zatrudnienia na podstawie umowy cywilnoprawnej zlecenia i uzyskać jego zgodę",{"entities": [(71,82, "labor_law"),(53,61, "labor_law")]}),
("czy jeśli pacjentka nie wyraża zgody na wykonanie testu to klientka musi zgłosić podejrzenie wystąpienia zakażenia do sanepidu",{"entities": [(93,104, "medical_law"),(81,92, "medical_law"),(40,49, "medical_law")]}),
("czy klientka może pojechać na działkę z partnerem",{"entities": [(18,26, "medical_law")]}),
("czy z korespondencji z pacjentką wynika groźba w stosunku do klientki",{"entities": [(40,46, "criminal_law")]}),
("czy działanie szpitala może być uznane za dyskryminację czy pracodawca musi zawiadomić pracownika o zamiarze zwolnienia",{"entities": [(42,55, "labor_law"),(100,108, "labor_law"),(32,38, "labor_law")]}),
("co należy zrobić w przedstawionych okolicznościach czy klient powinien udostępnić żonie zmarłego pacjenta dokumentacje medyczną",{"entities": [(106,118, "medical_law")]}),
("czy klientce pracującej w równoważnym systemie czasu pracy przysługuje dodatek za pracę w weekendy",{"entities": [(26,37, "labor_law")]}),
("czy właściciel posiadający większość udziałów we współwłasności może doprowadzić do fizycznego podziału nieruchomości",{"entities": [(69,80, "civil_law"),(27,36, "civil_law"),(95,103, "civil_law"),(49,63, "civil_law"),(37,45, "civil_law")]}),
("czy klient może ubiegać się o część odszkodowania z polisy ubezpieczeniowej po ojcu czy klient ma szansę otrzymać od siostry zachowek w związku z tym że nie dopełniła obowiązku opieki nad ojcem który zginął tragicznie w wypadku czy klient chcąc odzyskać przedmioty pozostawione przez ojca powinien złożyć pozew do sądu przeciwko swojej siostrze czy matce",{"entities": [(336,344, "civil_law"),(125,133, "civil_law"),(305,310, "civil_law"),(79,83, "civil_law")]}),
("czy klientka będzie mogła być zwolniona z vat",{"entities": [(30,39, "tax_law")]}),
("czy klientka ma obowiązek wymiany kasy fiskalnej na kasę fiskalną online w niepublicznym zakładzie opieki zdrowotnej dalej jako nzoz",{"entities": [(75,88, "tax_law"),(99,105, "tax_law"),(89,98, "tax_law"),(52,56, "tax_law"),(57,65, "tax_law")]}),
("jaki wymiar czasu pracy będzie miał zastosowanie do klienta oddelegowanego na podstawie art    kodeksu pracy",{"entities": [(36,48, "labor_law")]}),
("jaki okres wypowiedzenia obowiązuje klientkę czy można skrócić okres wypowiedzenia",{"entities": [(55,62, "labor_law")]}),
("czy działalność dewelopera wypełnia znamiona przestępstwa oszustwa jakie kroki w przedmiotowej sprawie powinna podjąć mąż klientki",{"entities": [(67,72, "criminal_law"),(36,44, "criminal_law"),(27,35, "criminal_law"),(45,57, "criminal_law")]}),
("czy apteka może sprzedać testy na covid do domu dziecka",{"entities": [(25,30, "pharmaceutical_law")]}),
("czy klient aby nie odziedziczyć długów powinien zrzec się spadku po swojej siostrze",{"entities": [(19,31, "civil_law"),(32,38, "civil_law")]}),
("czy hurtownia farmaceutyczna powinna wystawić fakturę korygującą",{"entities": [(46,53, "tax_law")]}),
("czy porozumienie ze związkami zawodowymi może obowiązywać z datą wsteczną",{"entities": [(4,16, "labor_law")]}),
("czy klientce przysługuje prawo do wyższego stanowiska po przepracowaniu  lat czy klientka powinna złożyć odwołanie w określonym terminie",{"entities": [(73,76, "medical_law")]}),
("czy przepisy prawa przewidują ilu specjalistów neurologii musi zatrudniać szpital wykonujący świadczenia finansowane przez nfz na oddziale neurologicznym",{"entities": [(105,116, "medical_law"),(63,73, "medical_law"),(47,57, "medical_law"),(34,46, "medical_law")]}),
("czy w związku z zajściem w ciążę umowa pracownicy zostanie automatycznie przekształcona w umowę na czas nieokreślony",{"entities": [(39,49, "labor_law"),(27,32, "labor_law")]}),
("czy planowanie przez pracodawcę pracy w niedzielę jest podstawą do skrócenia przez klientkę okresu wypowiedzenia umowy o pracę",{"entities": [(67,76, "labor_law"),(55,63, "labor_law")]}),
("czy z prawnego punktu widzenia niepożądany odczyn poszczepienny jest zdarzeniem niepożądanym",{"entities": [(15,21, "pharmaceutical_law")]}),
("co należy zrobić aby móc sprzedać garaż wchodzący w skład spadku",{"entities": [(52,57, "civil_law")]}),
("czy dom pogrzebowy może przesyłać skany faktury papierowej bez zgody klienta",{"entities": [(48,58, "tax_law")]}),
("w jaki sposób klientka może żądać rekompensaty od szpitala który wykazywał ją jako lekarza udzielającego świadczeń zdrowotnych w tym szpitalu pomimo zakończonej współpracy",{"entities": [(34,46, "administrative_law")]}),
("czy klientka może negocjować pracę w wymiarze  lub  dni w tygodniu jakie załączniki stanowią integralną część umowy czy szpital będzie mógł zmienić miejsce wykonywania świadczeń z pracowni na poradnię dlaczego w   pkt  umowy jest mowa o dniach roboczych jeżeli w materiałach informacyjnych nie ma tego zapisu",{"entities": [(37,45, "medical_law")]}),
("czy wystawiając rachunek za lipiec klientka może wpisać kwotę  zł w miejsce uprzednio otrzymywanego tzw dodatku zembalowego",{"entities": [(16,24, "medical_law")]}),
("czy klient powinien wydać zaświadczenie o stanie zdrowia pełnoletniego pacjenta matce pacjenta w celu umożliwienia złożenia wniosku o ubezwłasnowolnienie pacjenta",{"entities": [(134,153, "medical_law"),(115,123, "medical_law"),(26,39, "medical_law")]}),
("czy zgodnym z prawem jest oferowanie odpłatnego wystawiania erecept oraz ezwolnień w intrenecie przez lekarzy prowadzących indywidualne praktyki lekarskie czy podmioty nieprowadzące działalności leczniczej mogą tworzyć platformy internetowe gromadzące różnych lekarzy za pośrednictwem których pacjenci mogą odpłatnie umówić teleporadę",{"entities": [(293,301, "medical_law"),(195,205, "medical_law")]}),
("w jakim udziale klientka oraz dzieci zmarłego męża klientki będą dziedziczyć spadek",{"entities": [(65,76, "civil_law")]}),
("czy klientka może ponosić odpowiedzialność za leczenie kanałowe dokonane  lat temu",{"entities": [(18,25, "medical_law"),(74,77, "medical_law")]}),
("czy klientka zobowiązana jest odbywać dyżury towarzyszące",{"entities": [(30,37, "medical_law")]}),
("czy lekarz pracujący w szpitalu jednoimiennym węzłowymkoordynacyjnym pracujący na oddziale niecovidowym który ma kontakt z personelem pracującym na oddziałach covidowych i pacjentami mogącymi być zarażonymi jest uprawniony do dodatku covidowego w wysokości  wynagrodzenia miesięcznego",{"entities": [(134,144, "medical_law"),(11,20, "medical_law"),(69,78, "medical_law"),(159,169, "medical_law"),(148,158, "medical_law"),(212,222, "medical_law"),(113,120, "medical_law"),(234,244, "medical_law"),(192,195, "medical_law"),(172,182, "medical_law")]}),
("jakich samochodów dotyczą dopłaty do samochodów elektrycznych czy dopłaty mogą dotyczyć samochodu demonstracyjnego",{"entities": [(26,33, "administrative_law"),(66,73, "administrative_law")]}),
("jaka jest sytuacja najemcy w wypadku śmierci wynajmującego",{"entities": [(19,26, "civil_law")]}),
("czy zaproponowane przez pracodawcę córki klientki warunki rozwiązania umowy o pracę za porozumieniem stron są zgodne z prawem czy pracownik może ubiegać się w miesiącu lipcu o inne stanowisko pracy u tego samego pracodawcy",{"entities": [(87,100, "labor_law")]}),
("czy starszy asystent farmaceutyczny pracujący w aptece zakładowej zobowiązany jest ukończyć specjalizacją szpitalną",{"entities": [(21,35, "pharmaceutical_law")]}),
("czy klientka może zrezygnować z odbywania dyżurów w związku z opieką nad miesięcznym dzieckiem czy dotyczy to tylko dyżurów samodzielnych czy może również towarzyszących czy klientka będzie musiała odrobić dyżury których nie pełniła z powodów zdrowotnych gdy pracowała będąc w ciąży w  r",{"entities": [(124,137, "medical_law"),(18,29, "medical_law")]}),
("czy postępowanie szpitala narusza prawa pracowników a w szczególności przepisy prawa atomowego przez wystawienie pracowników na duże promieniowanie jonizujące",{"entities": [(56,69, "medical_law"),(40,51, "medical_law"),(113,124, "medical_law")]}),
("czy w nieruchomości przeznaczonej na cele mieszkaniowe można rozpocząć prowadzenie działalności gospodarczej czy w takim przypadku wskazaną nieruchomość należałoby podzielić na dwie części  część przeznaczoną do celów mieszkaniowych oraz część przeznaczoną do wykonywania w niej działalności gospodarczej czy klient będzie mógł rozpocząć prace adaptacyjne części piwnicznej domu jedynie w przypadku gdy będzie jego jedynym właścicielem",{"entities": [(37,41, "administrative_law"),(196,208, "administrative_law"),(244,256, "administrative_law"),(212,217, "administrative_law"),(316,322, "administrative_law"),(403,409, "administrative_law")]}),
("czy spółka z oo może być komplementariuszem w spółce komandytowej czy wspólnik spółki z oo będącej wspólnikiem spółki komandytowej może być jednocześnie wspólnikiem spółki komandytowej",{"entities": [(99,110, "civil_law"),(153,164, "civil_law"),(53,65, "civil_law"),(118,130, "civil_law"),(91,98, "civil_law")]}),
("czy klientka może świadczyć usługi medycyny estetycznej w gabinecie kosmetycznym swojej znajomej czy klientka nadal będzie mogła rozliczać się kartą podatkową",{"entities": [(44,55, "medical_law"),(18,27, "medical_law")]}),
("czy klientka może korzystać z pełnomocnika podczas przesłuchania przez rzecznika odpowiedzialności zawodowej czy odmowa udziału pełnomocnika w przesłuchaniu świadka była uzasadniona",{"entities": [(157,164, "criminal_law"),(51,64, "criminal_law"),(71,80, "criminal_law"),(81,98, "criminal_law")]}),
("jakie są prawa i obowiązki klientki w związku z wezwaniem do stawiennictwa na przesłuchanie w charakterze podejrzanego",{"entities": [(0,5, "criminal_law"),(61,74, "criminal_law"),(94,105, "criminal_law"),(48,57, "criminal_law"),(78,91, "criminal_law")]}),
("czy możliwe jest udzielenie telefonicznej porady lekarskiej przez lekarza psychiatrę w świetle zmian związanych z zagrożeniem koronawirusem",{"entities": [(28,41, "medical_law"),(95,100, "medical_law"),(74,84, "medical_law"),(17,27, "medical_law"),(4,11, "medical_law"),(114,125, "medical_law")]}),
("czy klientka może odmówić wykonywania dyżurów w godzinach popołudniowych bez konieczności ich odrabiania",{"entities": [(77,89, "medical_law")]}),
("czy osobą szczepiącą w aptece może być tylko i wyłącznie farmaceuta zatrudniony w aptece",{"entities": [(68,79, "medical_law"),(4,9, "medical_law"),(35,38, "medical_law"),(23,29, "medical_law")]}),
("czy ustalenie z narodowym funduszem zdrowia kwalifikuje się jako pożyczka w rozumieniu art zzd ustawy o szczególnych rozwiązaniach związanych z zapobieganiem przeciwdziałaniem i zwalczaniem covid innych chorób zakaźnych oraz wywołanych nimi sytuacji kryzysowych o której mowa w oświadczeniu",{"entities": [(178,189, "medical_law"),(104,116, "medical_law"),(26,35, "medical_law"),(158,175, "medical_law"),(225,235, "medical_law"),(76,86, "medical_law"),(144,157, "medical_law"),(16,25, "medical_law"),(196,202, "medical_law"),(250,261, "medical_law"),(117,130, "medical_law")]}),
("czy klientka powinna mieć przy sobie akt małżeństwa w celu udowodnienia że certyfikat covid oraz karta ekuz zostały wystawione dla niej",{"entities": [(21,25, "medical_law"),(75,85, "medical_law"),(116,126, "medical_law")]}),
("czy w związku z wprowadzeniem stanu epidemii pracodawca może oddelegować rezydenta pediatrii na oddział internistyczny który nie jest dedykowany dla pacjentów chorych na covid",{"entities": [(30,35, "medical_law"),(16,29, "medical_law"),(159,166, "medical_law"),(83,92, "medical_law")]}),
("jakie kroki będzie mógł podjąć klient w związku z ewentualnym naruszeniem jego dóbr osobistych w internecie",{"entities": [(79,83, "administrative_law"),(12,18, "administrative_law"),(84,94, "administrative_law")]}),
("czy klient będzie mógł wybudować na działce następny budynek bez pozwolenia na budowę",{"entities": [(23,32, "administrative_law"),(36,43, "administrative_law"),(65,75, "administrative_law"),(11,17, "administrative_law"),(53,60, "administrative_law")]}),
("czy lekarz jest zobowiązany do wydania pacjentowi opisu tomografii przetłumaczonego na język polski",{"entities": [(56,66, "medical_law"),(50,55, "medical_law"),(39,49, "medical_law")]}),
("czy pracownikowi przysługuje urlop szkoleniowy w wymiarze  dni",{"entities": [(4,16, "labor_law")]}),
("czy klientka jako farmaceuta może sama sporządzić opis techniczny apteki ogólnodostępnej czy klientka potrzebuje odrębnej opinii od państwowej inspekcji sanitarnej oraz rzeczoznawcy od zabezpieczeń przeciwpożarowych skoro takie opinie zostały wydane w stosunku do całego budynku",{"entities": [(264,270, "pharmaceutical_law"),(73,88, "pharmaceutical_law")]}),
("czy klient może żądać usunięcia swojego adresu ze strony aresztu śledczego",{"entities": [(22,31, "administrative_law")]}),
("czy klientka musi wyrazić zgodę na proponowany przez pracodawcę system równoważnego czasu pracy taki system jest w zakładzie pracy czy klientka otrzyma  wynagrodzenia podstawowego w związku z pracą w szpitalu covidowym czy klientka może jednocześnie pracować w poz czy kwestie dotyczące pyt  powinny zostać ujęte w umowie o pracę",{"entities": [(192,197, "medical_law"),(250,258, "medical_law"),(261,264, "medical_law"),(167,179, "medical_law"),(26,31, "medical_law"),(64,70, "medical_law"),(101,107, "medical_law"),(292,299, "medical_law")]}),
("czy klientka może zgłosić aptekę pod nazwą apteka farmekspert lub apteka ekspert czy klientka nadal może prowadzić działalność w mediach społecznościowych oraz reklamować dermolek",{"entities": [(26,32, "pharmaceutical_law"),(129,136, "pharmaceutical_law"),(137,154, "pharmaceutical_law")]}),
("w jaki sposób wspólnota mieszkaniowa może uchronić się przed ewentualnymi roszczeniami przyszłych nabywców części współwłasności nieruchomości garażowej",{"entities": [(114,128, "civil_law"),(98,106, "civil_law")]}),
("jakie prawa przysługują klientce w związku z wezwaniem czy klientka może nie stawić się na przesłuchanie w związku z tym że jest w zaawansowanej ciąży",{"entities": [(0,5, "criminal_law"),(45,54, "criminal_law"),(91,104, "criminal_law")]}),
("jakie kroki prawne może podjąć klientka",{"entities": [(0,5, "criminal_law"),(12,18, "criminal_law")]}),
("czy nfz może zakwestionować wykonywanie świadczeń udzielanych w oddziałach dziennych psychiatrycznych i oddziałach dziennych terapii uzależnień za pośrednictwem systemów teleinformatycznych czy nfz może żądać w okresie epidemii od świadczeniodawcy przeniesienia personelu medycznego i pacjentów z oddziałów dziennych do poradni zdrowia psychicznego i poradni terapii uzależnień",{"entities": [(320,327, "medical_law"),(351,358, "medical_law"),(133,143, "medical_law"),(28,39, "medical_law"),(64,74, "medical_law"),(104,114, "medical_law"),(75,84, "medical_law"),(115,124, "medical_law"),(307,316, "medical_law"),(262,271, "medical_law")]}),
("czy można nie dopuścić do pracy pracownika który w sposób pośredni miał styczność z osobą zarażoną na koronawirusa",{"entities": [(84,89, "medical_law")]}),
("czy apteka może sprzedać testy na covid do domu dziecka",{"entities": [(25,30, "pharmaceutical_law")]}),
("ile dni urlopu wypoczynkowego przysługuje klientowi czy dni urlopu wypoczynkowego przysługują z góry czy z dołu",{"entities": [(15,29, "labor_law"),(67,81, "labor_law")]}),
("czy na roboty budowlane brat ojca musiał mieć pozwolenie od ojca współwłaściciela czy na wykonane roboty budowlane w latach  brat ojca musiał mieć pozwolenie od inspektora nadzoru budowlanego oraz od architektury na podstawie obowiązującego w tamtym okresie prawa budowlanego art  w którym roku nastąpiła nowelizacja prawa budowlanego art  jaki jest okres przedawnienia dotyczący ww robót budowlanych jakie konsekwencje prawne czekają brata ojca jeśli wymagana była zgoda ojca na wykonane roboty budowlane w latach  a on takiej zgody nie uzyskał",{"entities": [(46,56, "administrative_law"),(147,157, "administrative_law"),(383,388, "administrative_law"),(180,191, "administrative_law"),(264,275, "administrative_law"),(323,334, "administrative_law"),(14,23, "administrative_law"),(105,114, "administrative_law"),(496,505, "administrative_law"),(389,400, "administrative_law"),(7,13, "administrative_law"),(98,104, "administrative_law"),(489,495, "administrative_law")]}),
("czy w przedmiotowej sytuacji klientka jest jedynym spadkobiercą jakie kroki powinna podjąć klientka aby przeprowadzić postępowanie spadkowe czy odnalezienie testamentu zmarłego brata matki klientki wpłynęłoby na sprawę spadkową po jego żonie",{"entities": [(183,188, "civil_law"),(51,63, "civil_law"),(131,139, "civil_law"),(219,227, "civil_law"),(157,167, "civil_law")]}),
("czy w świetle testamentu spadkodawcy wnioski opinii o sygn  ulegną zmianie",{"entities": [(37,44, "civil_law"),(25,36, "civil_law"),(14,24, "civil_law")]}),
("jakich argumentów może użyć klientka odpowiadając na pismo w którym powiatowy urząd pracy negatywnie rozpatrzył jej wniosek o dofinansowanie",{"entities": [(23,27, "administrative_law")]}),
("co klientka może zrobić w związku z otrzymanym pismem",{"entities": [(36,46, "criminal_law")]}),
("w jaki sposób wspólnota mieszkaniowa może uchronić się przed ewentualnymi roszczeniami przyszłych nabywców części współwłasności nieruchomości garażowej",{"entities": [(114,128, "civil_law"),(98,106, "civil_law")]}),
("czy polska apteka internetowa może sprzedawać wysyłkowo za granicę produkty lecznicze wyroby medyczne kosmetyki suplementy diety i środki spożywcze specjalnego przeznaczenia żywieniowego",{"entities": [(76,85, "pharmaceutical_law"),(86,92, "pharmaceutical_law"),(112,122, "pharmaceutical_law"),(160,173, "pharmaceutical_law"),(148,159, "pharmaceutical_law"),(138,147, "pharmaceutical_law")]}),
("czy postępowanie szpitala narusza prawa pracownicze a w szczególności przepisy obezpieczeństwie i higienie pracy",{"entities": [(26,33, "labor_law")]}),
("kogo w rozumieniu przepisów uznaje się za inwalidę i w jaki sposób należałoby udokumentować inwalidztwo w ramach odwołania od decyzji o skierowaniu do pracy przy zwalczaniu epidemii",{"entities": [(162,172, "criminal_law")]}),
("jakie kompetencje posiada rzecznik praw pacjenta",{"entities": [(26,34, "medical_law")]}),
("czy na podstawie decyzji wydanej przez wojewódzkiego konserwatora zabytków możliwe jest używanie tylko jednego szyldu zawierającego logo firmy oraz zakres świadczonych usług",{"entities": [(53,65, "administrative_law"),(66,74, "administrative_law")]}),
("czy osoba zatrudniona na podstawie umowy o pracę w laboratorium diagnostycznym jako diagnostyk może udzielać świadczeń jako farmaceuta w ramach swojej działalności gospodarczej w aptece szpitalnej w przypadku w którym oba miejsca są innymi jednostkami organizacyjnymi tego samego szpitala czy osoba zatrudniona na podstawie umowy o pracę w laboratorium diagnostycznym jako diagnosta może udzielać świadczeń tego samego rodzaju w ramach działalności gospodarczej w innym laboratorium diagnostycznym należącym do tego samego szpitala",{"entities": [(64,78, "pharmaceutical_law"),(353,367, "pharmaceutical_law"),(483,497, "pharmaceutical_law"),(186,196, "pharmaceutical_law"),(51,63, "pharmaceutical_law"),(340,352, "pharmaceutical_law"),(470,482, "pharmaceutical_law")]}),
("czy w opisanej przez klienta sytuacji policja może prowadzić postępowanie w sprawie wykroczenia z art  kodeksu wykroczeń jakie są prawa i obowiązki obwinionego",{"entities": [(121,126, "criminal_law"),(103,110, "criminal_law"),(51,60, "criminal_law"),(84,95, "criminal_law")]}),
("czy opisy badań diagnostycznych muszą sporządzane w formie elektronicznej",{"entities": [(10,15, "medical_law"),(32,37, "medical_law")]}),
("czy i na jakich zasadach pracownik zatrudniony na stanowisku specjalisty ds bhp może prowadzić szkolenia okresowe z zakresu bhp dla pozostałych pracowników",{"entities": [(76,79, "labor_law"),(124,127, "labor_law"),(105,113, "labor_law")]}),
("czy i w jakich przypadkach pracodawca może nie udzielić pracownikowi urlopu uprzednio przewidzianego w planie urlopowym z jakim uprzedzeniem pracodawca powinien poinformować pracownika o braku możliwości udzielenia urlopu zgodnie z terminem przewidzianym w planie urlopowym w jaki sposób należy rozdysponować dni urlopu które nie zostały wykorzystane przez pracownika zgodnie z planem urlopów czy niewykorzystane dni urlopów zgodnie z planem urlopów pracownik może wykorzystać w późniejszym czasie w częściach",{"entities": [(378,384, "labor_law"),(435,441, "labor_law"),(232,240, "labor_law"),(86,100, "labor_law"),(479,490, "labor_law"),(385,392, "labor_law"),(417,424, "labor_law"),(442,449, "labor_law"),(241,254, "labor_law"),(56,68, "labor_law"),(110,119, "labor_law"),(264,273, "labor_law")]}),
("czy pracodawca może ustnie polecić klientowi kwalifikowanie pacjentów do szczepień na covid czy pracodawca powinien zapewnić rezydentom nadzór wykwalifikowanego w tym przedmiocie lekarza w jakich godzinach lekarz rezydent może kwalifikować pacjentów czy za kwalifikowanie pacjentów do szczepień przysługuje dodatek do wynagrodzenia",{"entities": [(45,59, "medical_law"),(257,271, "medical_law"),(136,142, "medical_law"),(213,221, "medical_law"),(227,239, "medical_law"),(73,82, "medical_law"),(285,294, "medical_law"),(143,160, "medical_law"),(125,135, "medical_law")]}),
("czy klientce należy się odprawa czy klientce należy się ekwiwalent za niewykorzystany urlop",{"entities": [(56,66, "labor_law"),(70,85, "labor_law"),(24,31, "labor_law")]}),
("czy klientka może udostępnić ubezpieczycielowi posiadaną dokumentację medyczną zmarłego pacjenta",{"entities": [(47,56, "medical_law"),(29,46, "medical_law")]}),
("czy datą zakończenia specjalizacji o której mowa w   ust  umowy o współpracy będzie data zakończenia szkolenia specjalizacyjnego data przystąpienia do państwowego egzaminu specjalizacyjnego czy data otrzymania tytułu specjalisty czy klientka może złożyć wypowiedzenie umowy o współpracy w terminie  miesięcy poprzedzających zakończenie okresu o którym mowa w   ust  umowy czy dopiero po zakończeniu tego okresu",{"entities": [(9,20, "medical_law"),(89,100, "medical_law"),(163,171, "medical_law"),(217,228, "medical_law"),(101,110, "medical_law"),(210,216, "medical_law"),(151,162, "medical_law"),(84,88, "medical_law"),(129,133, "medical_law"),(194,198, "medical_law"),(66,76, "medical_law"),(276,286, "medical_law"),(4,8, "medical_law"),(111,128, "medical_law"),(172,189, "medical_law")]}),
("w jaki sposób jednocześnie zachować w tajemnicy dokumentację medyczną pacjenta i wywiązać się z obowiązku względem ubezpieczyciela udzielania mu informacji o szkodzie",{"entities": [(131,141, "medical_law")]}),
("czy klient może samodzielnie podwyższyć stawkę o wskaźnik inflacji i wykazać nową stawkę na fakturze czy wymagany jest aneks do umowy",{"entities": [(40,46, "medical_law"),(82,88, "medical_law"),(119,124, "medical_law"),(77,81, "medical_law"),(29,39, "medical_law")]}),
("czy w związku z rozwiązaniem stosunku pracy klientowi będzie przysługiwała odprawa emerytalna",{"entities": [(75,82, "labor_law")]}),
("czy klientowi który jest na emeryturze przysługuje wyższa ulga podatkowa w związku z podwyższeniem maksymalnej kwoty jaką można wpłacić na ikze",{"entities": [(111,116, "tax_law"),(122,127, "tax_law"),(75,82, "tax_law"),(39,50, "tax_law"),(28,38, "tax_law"),(63,72, "tax_law")]}),
("kto może podpisać w imieniu spółki z oo umowę z członkiem zarządu czy podpisanie umowy z członkiem zarządu powinno być poprzedzone podjęciem uchwały wspólników czy wynagrodzenie otrzymywane przez członka zarządu z tytułu stosunku powołania i z tytułu umowy o pracę może być rozliczane razem",{"entities": [(58,65, "labor_law"),(99,106, "labor_law"),(204,211, "labor_law"),(48,57, "labor_law"),(89,98, "labor_law"),(70,80, "labor_law"),(196,203, "labor_law")]}),
("czy lekarz dentysta może przepisać lek amantix zawierający siarczan amantadyny",{"entities": [(25,34, "pharmaceutical_law")]}),
("czy testament sporządzony przez matkę klientki jest ważny",{"entities": [(4,13, "civil_law"),(32,37, "civil_law")]}),
("w jaki sposób gabinet lekarski klienta może sprowadzić preparaty witaminowe z innego kraju unii europejskiej które nie są dopuszczone do obrotu w polsce",{"entities": [(44,54, "pharmaceutical_law"),(137,143, "pharmaceutical_law"),(55,64, "pharmaceutical_law"),(65,75, "pharmaceutical_law")]}),
("czy i w jaki sposób wspólnota mieszkaniowa mogłaby dokonać ocieplenia garaży",{"entities": [(59,69, "civil_law")]}),
("czy zarządzenie dyrekcji szpitala jest dla klientki wiążące pomimo zapisu przewidzianego w zawartej przez nią umowie o pracę",{"entities": [(74,88, "labor_law")]}),
("czy klient jako członek wspólnoty może zostać zobowiązany do ponoszenia kosztów sądowych wprzedmiotowej sprawie czy złożone przez klienta pełnomocnictwo bez podania numeru księgi wieczystej mieszkania jest ważne",{"entities": [(80,88, "civil_law"),(138,152, "civil_law"),(61,71, "civil_law"),(172,178, "civil_law"),(179,189, "civil_law")]}),
("czy klientka jako lekarz rezydent może kwalifikować pacjentów do szczepień przeciwko covid",{"entities": [(25,33, "medical_law"),(39,51, "medical_law"),(65,74, "medical_law")]}),
("jaka jest procedura odwołania się przez lekarza od decyzji o skierowaniu do pracy przy zwalczaniu epidemii",{"entities": [(61,72, "medical_law")]}),
("czy wykonywanie pracy przy szczepieniach przeciwko covid w ramach umowy cywilnoprawnej zlecenia koliduje z otrzymywaniem dodatku covidowego przysługującego z tytułu zatrudnienia na podstawie umowy o pracę",{"entities": [(158,164, "medical_law"),(4,15, "medical_law"),(72,86, "medical_law"),(129,139, "medical_law"),(27,40, "medical_law")]}),
("czy postawienie przez właściciela lokalu blaszanego boxa na miejscu parkingowym w podziemnej hali garażowej wymaga podjęcia przez wspólnotę mieszkaniową uchwały jeżeli podział miejsc parkingowych wynika z umowy quoad usum",{"entities": [(130,139, "civil_law"),(183,195, "civil_law"),(22,33, "civil_law"),(93,97, "civil_law"),(168,175, "civil_law"),(153,160, "civil_law"),(140,152, "civil_law"),(98,107, "civil_law")]}),
("w jakiej wysokości grzywnę sąd może wymierzyć bratu klientki czy do odpowiedzialności mogą zostać pociągnięte również osoby zamieszkałe pod adresem na który doręczono wezwanie",{"entities": [(27,30, "criminal_law"),(68,85, "criminal_law")]}),
("jaki jest tryb i sposób stosowania kar porządkowych ze szczególnym uwzględnieniem okoliczności do kiedy pracodawca może wymierzyć pracownikowi karę porządkową",{"entities": [(130,142, "labor_law")]}),
("czy dyrektor szpitala miał prawo oddelegować klientkę do pracy w innej komórce szpitala czy klientce przysługuje zwrot kosztów związanych z dojazdem do nowego miejsca pracy czy klientkę obowiązuje ubezpieczenie wynikające z umowy o pracę jak postąpić w przypadku braku przeszkolenia klientki do pracy w nowym miejscu",{"entities": [(186,196, "medical_law"),(159,166, "medical_law"),(242,250, "medical_law")]}),
("czy klientowi przysługuje  dodatek do wynagrodzenia w jaki sposób można wyegzekwować zapłatę dodatku do wynagrodzenia kiedy należy wystosować wezwanie do zapłaty zaległego dodatku do wynagrodzenia",{"entities": [(131,141, "medical_law")]}),
("czy pracodawca może udzielić urlopu wypoczynkowego pracownikowi zwolnionemu od obowiązku wykonywania pracy w związku z koniecznością sprawowania osobistej opieki nad dzieckiem",{"entities": [(36,50, "labor_law"),(51,63, "labor_law")]}),
("czy klient może zakończyć umowę o pracę i uniknąć zapłaty kary",{"entities": [(16,25, "labor_law")]}),
("jaki jest wymiar urlopu rodzicielskiego od kiedy klient może skorzystać z urlopu rodzicielskiego w jaki sposób należy zgłosić się do dobrowolnego ubezpieczenia chorobowego",{"entities": [(24,39, "labor_law"),(81,96, "labor_law")]}),
("co dokładnie powinien zawierać wpis oil numer prawa wykonywania zawodu z ilu składać się cyfr czy farmaceuta przed wysłaniem refundacji powinien zweryfikować ten numer",{"entities": [(125,135, "pharmaceutical_law"),(145,157, "pharmaceutical_law"),(115,124, "pharmaceutical_law")]}),
("czy w podanej sytuacji żonie klienta przysługuje prawo do zapoznania się z materiałem dowodowym czy istnieje możliwość obejrzenia nagrania z płyty dvd która stanowi dowód w sprawie kiedy i gdzie można obejrzeć nagranie z płyty dvd czy policja powinna zostawić żonie klienta pokwitowanie lub protokół z czynności oględzin samochodu na potwierdzenie że nie stwierdzono uszkodzeń ani śladów kontaktu z innym autem",{"entities": [(399,404, "criminal_law"),(141,146, "criminal_law"),(221,226, "criminal_law"),(6,13, "criminal_law"),(23,28, "criminal_law"),(260,265, "criminal_law"),(157,164, "criminal_law"),(302,311, "criminal_law")]}),
("czy siostry ojca klientki muszą odbyć kwarantannę w miejscu zamieszkania rodziców klientki",{"entities": [(26,31, "medical_law"),(38,49, "medical_law")]}),
("czy w przypadku podważenia testamentu z  r zacznie ponownie obowiązywać testament sporządzony w  r czy można podważyć testament po otwarciu spadku czy po otwarciu spadku dzieci spadkodawcy mogą domagać się dodatkowego świadczenia oprócz zachowku czy można odczytać testament jeżeli jeden z spadkobiorców nie chce się stawić",{"entities": [(72,81, "civil_law"),(118,127, "civil_law"),(265,274, "civil_law"),(237,245, "civil_law"),(177,188, "civil_law"),(131,139, "civil_law"),(154,162, "civil_law"),(27,37, "civil_law")]}),
("jakie są prawa i obowiązki klientki na przesłuchaniu w charakterze świadka",{"entities": [(0,5, "criminal_law"),(55,66, "criminal_law")]}),
("co jeżeli pacjent nie odbiera telefonu czy wtedy klient powinien przedłużyć izolację",{"entities": [(65,75, "medical_law")]}),
("czy klient jako lekarz stażysta jest uprawniony do wykonywania szczepień na covid oraz do przeprowadzania badań kwalifikacyjnych przed szczepieniem w prywatnym gabinecie lekarskim poza godzinami odbywania stażu",{"entities": [(150,159, "medical_law"),(185,194, "medical_law"),(135,147, "medical_law"),(106,111, "medical_law"),(23,31, "medical_law"),(37,47, "medical_law"),(112,128, "medical_law"),(63,72, "medical_law")]}),
("czy przekazanie przez klienta dokumentacji medycznej ubezpieczycielowi stanowi naruszenie tajemnicy lekarskiej czy przekazanie ubezpieczycielowi przez klienta informacji niezapisanych mających istotny wpływ na przebieg sprawy stanowi naruszenie tajemnicy lekarskiej",{"entities": [(79,89, "medical_law"),(234,244, "medical_law"),(184,192, "medical_law"),(53,70, "medical_law"),(127,144, "medical_law")]}),
("czy nieletni pacjent może być leczony w gabinecie bez obecności przedstawiciela ustawowego jeśli uprzednio wyraził on zgodę na leczenie czy przedstawiciel ustawowy lub opiekun prawny musi być obecny na wizycie na której będą podawane leki czy wystarczy tylko ogólna zgoda na podanie leków lub zgoda na leczenie czy nieletni pacjent który przychodzi na wizytę z opiekunem faktycznym powinien mieć zgodę przedstawiciela ustawowego na wizytę w obecności opiekuna faktycznego",{"entities": [(202,209, "medical_law"),(80,90, "medical_law"),(418,428, "medical_law"),(391,395, "medical_law"),(107,114, "medical_law"),(352,358, "medical_law"),(432,438, "medical_law"),(4,12, "medical_law"),(315,323, "medical_law"),(266,271, "medical_law"),(293,298, "medical_law"),(118,123, "medical_law"),(396,401, "medical_law"),(26,29, "medical_law"),(188,191, "medical_law"),(54,63, "medical_law"),(441,450, "medical_law"),(451,459, "medical_law")]}),
("ile dni urlopu wypoczynkowego przysługuje klientowi czy dni urlopu wypoczynkowego przysługują z góry czy z dołu",{"entities": [(15,29, "labor_law"),(67,81, "labor_law")]}),
("czy klientka może zgłosić aptekę pod nazwą apteka farmekspert lub apteka ekspert czy klientka nadal może prowadzić działalność w mediach społecznościowych oraz reklamować dermolek",{"entities": [(26,32, "pharmaceutical_law"),(129,136, "pharmaceutical_law"),(137,154, "pharmaceutical_law")]}),
("czy opisy badań diagnostycznych muszą sporządzane w formie elektronicznej",{"entities": [(10,15, "medical_law"),(32,37, "medical_law")]}),
("czy koszt wykonania projektu a następnie dobudowy obciąża zainteresowanego właściciela czy wspólnotę mieszkaniową",{"entities": [(91,100, "civil_law"),(75,86, "civil_law"),(4,9, "civil_law")]}),
("który podmiot leczniczy powinien wypłacić dodatek covidowy klientce która realizując staż podyplomowy dyżurowała w podmiocie zewnętrznym w ramach szpitalnego oddziału ratunkowego",{"entities": [(14,23, "medical_law"),(115,124, "medical_law"),(33,41, "medical_law"),(158,166, "medical_law"),(6,13, "medical_law"),(125,136, "medical_law"),(50,58, "medical_law"),(85,89, "medical_law"),(90,101, "medical_law")]}),
("czy klientka chcąc przyjąć na terapię dziecko w gabinecie psychologicznym powinna ona na własną rękę uzyskać zgodę ojca leczenie",{"entities": [(58,73, "medical_law"),(30,37, "medical_law"),(19,26, "medical_law"),(109,114, "medical_law")]}),
("czy agresja słowna i fizyczna pacjenta na lekarza oraz pielęgniarki w przychodni kwalifikuje się jako atak na funkcjonariusza publicznego czy klientka może bez zgody pacjenta wykreślić go z listy pacjentów w przychodni w ramach nfz",{"entities": [(42,49, "criminal_law"),(160,165, "criminal_law")]}),
    
]

# %%
import pandas as pd
import os
from tqdm import tqdm
import spacy
from spacy.tokens import DocBin

#nlp = spacy.blank("en") # load a new spacy model
ner=nlp.get_pipe("document_ner")

db = DocBin() # create a DocBin object

for text, annot in tqdm(TRAIN_DATA): # data in previous format
    doc = nlp.make_doc(text) # create doc object from text
    ents = []
    for start, end, label in annot["entities"]: # add character indexes
        span = doc.char_span(start, end, label=label, alignment_mode="contract")
        if span is None:
            print("Skipping entity")
        else:
            ents.append(span)
    doc.ents = ents # label the text with the ents
    db.add(doc)

db.to_disk("train.spacy")
# Out:
# 100%|█████████████████████████████████████| 1984/1984 [00:00<00:00, 9626.47it/s]
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity

# %%
#train.spacy do folderu pl_document_ner
#cd pl_document_ner
#python3 -m spacy train config.cfg --output ./output --paths.train ./train.spacy --paths.dev ./train.spacy

# %%
nlp1 = spacy.load("pl_document_ner/output/model-best")

# %%
doc = nlp1("czy wspólnota mieszkaniowa może podjąć uchwałę dotyczącą zakupu wodomierzy odczytywanych radiowo do lokali pokrywając ich koszty czy wspólnota mieszkaniowa może odzyskać pomieszczenie gospodarcze jakie kroki wspólnota mieszkaniowa powinna podjąć aby odzyskać przedmiotowe pomieszczenie czy uprawnienie mieszkańców wspólnoty mieszkaniowej jest zgodne z przepisami rodo czy budowa windy dla osób niepełnosprawnych może zostać zakwalifikowana jako remont i zostać sfinansowana z funduszu remontowego dużej wspólnoty mieszkaniowej jakie czynności powinna podjąć wspólnota mieszkaniowa założenie funduszu celowego w celu wybudowania windy dla osób niepełnosprawnych czy wspólnota mieszkaniowa może uchwałą wspólników przeksięgować środki z funduszu remontowego na fundusz celowy czy nieruchomość nabywa wspólnota mieszkaniowa czy też jej poszczególni członkowie kto będzie właścicielem nabytej nieruchomości kto będzie zobowiązany do zapłaty podatku od nieruchomości czy na zakup nieruchomości wspólnota może przeznaczyć środki zgromadzone na zaliczce remontowo inwestycyjnej czy do nabycia nieruchomości wystarczy podjęcie uchwały większością głosów jaką treść powinny zawierać przedmiotowe tablice informacyjne jakie koszty musi ponieść wspólnota mieszkaniowa w związku ze złożeniem wniosku o stwierdzenie nabycia spadku w którego skład wchodzi nieruchomość pozostająca we wspólnocie czy z uwagi na uchybienie formalne podejmowanie uchwały poprzez indywidualne zbieranie głosów od członków wspólnoty mieszkaniowej które zostało dokonane przez inny podmiot niż zarząd lub zarządcę nieruchomości wspólnej istnieje przesłanka do stwierdzenia jej nieważności czy pomimo tego iż uchwała została podjęta większością głosów to nadal istnieje obowiązek dalszego zbierania głosów czy w treści uchwały należy zamieszczać rubrykę informującą o wstrzymaniu się od głosu w jaki sposób odpowiedzieć na zarzut iż sposób zbierania głosów mógł mieć istotny wpływ na treść uchwały czy zarząd wspólnoty mieszkaniowej ma możliwość wyjścia z inicjatywą anulowania uchwały a następnie zbierania głosów pod identyczną uchwałą z zachowaniem wymogów formalnych czy wspólnota może rozłożyć właścicielom lokali płatność na raty czy z każdym właścicielem lokalu należy zawrzeć odrębną umowę czy wspólnota")

# %%
spacy.displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">czy wspólnota mieszkaniowa może podjąć
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     uchwałę
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">civil_law</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     dotyczącą
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">civil_law</span>
# </mark>
#  zakupu wodomierzy odczytywanych radiowo do
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     lokali
# ...
